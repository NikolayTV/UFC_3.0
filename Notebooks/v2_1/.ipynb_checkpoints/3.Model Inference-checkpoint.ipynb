# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from catboost import CatBoostClassifier
import pandas as pd
import json
from pandas import json_normalize
from tqdm import tqdm_notebook as tqdm
import numpy as np
import ast
import time
import datetime

import sys
import os
sys.path.append(os.path.join(sys.path[0], '../../core/'))

from train_utils import calculate_roi, get_winner_favorite, combine_df, parse_odds

pd.set_option('display.precision',6)
pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None

# %%
def load_fighters():
    fighters_df = pd.read_csv("data_models/fighters_df.csv", index_col=0)

    fighters_df["dateOfBirth"] = pd.to_datetime(fighters_df["dateOfBirth"])
    fighters_cols = [
        # "id",
        "name",
        "weight",
        "height",
        "armSpan",
        "legSwing",
        "weightCategory.id",
        "weightCategory.name",
        "dateOfBirth",
        "country",
        "city",
        "timezone",
    ]
    fighters_df = fighters_df[fighters_cols]
    # fighters_df.set_index("id", inplace=True)
    f_name_dict = fighters_df['name'].to_dict()

    return fighters_df, f_name_dict

# %%
static_cols = ['country', 'city', 'armSpan', 'height', 'legSwing', 'timezone', 'weight']
f1_static_cols = ['f1_' + col for col in static_cols]
f2_static_cols = ['f2_' + col for col in static_cols]

cat_cols = ['country', 'city', 'timezone']
f1_cat_cols = ['f1_' + col for col in cat_cols]
f2_cat_cols = ['f2_' + col for col in cat_cols]

fighters_df, f_name_dict = load_fighters()
with open('data_models/generated_features_11.05.2021.txt', 'r') as outfile:
    generated_features = json.load(outfile)
num_cols = [i[3:] for i in generated_features['fighter1_stats']][:-8]
num_cols
# Out:
# ['cumsum_duration',
#  'cumsum_winner',
#  'cumsum_hitsTotal',
#  'cumsum_hitsSuccessful',
#  'cumsum_takedownTotal',
#  'cumsum_takedownSuccessful',
#  'cumsum_submissionAttempts',
#  'cumsum_takeovers',
#  'cumsum_accentedHitsTotal',
#  'cumsum_accentedHitsSuccessful',
#  'cumsum_knockdowns',
#  'cumsum_protectionPassage',
#  'cumsum_hitsHeadTotal',
#  'cumsum_hitsHeadSuccessful',
#  'cumsum_hitsBodyTotal',
#  'cumsum_hitsBodySuccessful',
#  'cumsum_hitsLegsTotal',
#  'cumsum_hitsLegsSuccessful',
#  'cumsum_accentedHitsPositionDistanceTotal',
#  'cumsum_accentedHitsPositionDistanceSuccessful',
#  'cumsum_accentedHitsPositionClinchTotal',
#  'cumsum_accentedHitsPositionClinchSuccessful',
#  'cumsum_accentedHitsPositionParterTotal',
#  'cumsum_accentedHitsPositionParterSuccessful',
#  'cumsum_def_hitsTotal',
#  'cumsum_def_hitsSuccessful',
#  'cumsum_def_takedownTotal',
#  'cumsum_def_takedownSuccessful',
#  'cumsum_def_submissionAttempts',
#  'cumsum_def_takeovers',
#  'cumsum_def_accentedHitsTotal',
#  'cumsum_def_accentedHitsSuccessful',
#  'cumsum_def_knockdowns',
#  'cumsum_def_protectionPassage',
#  'cumsum_def_hitsHeadTotal',
#  'cumsum_def_hitsHeadSuccessful',
#  'cumsum_def_hitsBodyTotal',
#  'cumsum_def_hitsBodySuccessful',
#  'cumsum_def_hitsLegsTotal',
#  'cumsum_def_hitsLegsSuccessful',
#  'cumsum_def_accentedHitsPositionDistanceTotal',
#  'cumsum_def_accentedHitsPositionDistanceSuccessful',
#  'cumsum_def_accentedHitsPositionClinchTotal',
#  'cumsum_def_accentedHitsPositionClinchSuccessful',
#  'cumsum_def_accentedHitsPositionParterTotal',
#  'cumsum_def_accentedHitsPositionParterSuccessful',
#  'cumsum_winMethods_[DEC]',
#  'cumsum_winMethods_[DQ]',
#  'cumsum_winMethods_[KO]',
#  'cumsum_winMethods_[SUB]',
#  'hits_accuracy',
#  'takedown_accuracy',
#  'accentedHits_accuracy',
#  'hitsHead_accuracy',
#  'hitsBody_accuracy',
#  'hitsLegs_accuracy',
#  'accentedHitsPositionDistance_accuracy',
#  'accentedHitsPositionClinch_accuracy',
#  'accentedHitsPositionParter_accuracy',
#  'DEC_percent',
#  'DQ_percent',
#  'KO_percent',
#  'SUB_percent',
#  'hits_PM',
#  'takedown_PM',
#  'accentedHits_PM',
#  'hitsHead_PM',
#  'hitsBody_PM',
#  'hitsLegs_PM',
#  'accentedHitsPositionDistance_PM',
#  'accentedHitsPositionClinch_PM',
#  'accentedHitsPositionParter_PM',
#  'knockdowns_PM',
#  'protectionPassage_PM',
#  'win_streak',
#  'loose_streak',
#  'def_hits_accuracy',
#  'def_takedown_accuracy',
#  'def_accentedHits_accuracy',
#  'def_hitsHead_accuracy',
#  'def_hitsBody_accuracy',
#  'def_hitsLegs_accuracy',
#  'def_accentedHitsPositionDistance_accuracy',
#  'def_accentedHitsPositionClinch_accuracy',
#  'def_accentedHitsPositionParter_accuracy',
#  'def_hits_PM',
#  'def_takedown_PM',
#  'def_accentedHits_PM',
#  'def_hitsHead_PM',
#  'def_hitsBody_PM',
#  'def_hitsLegs_PM',
#  'def_accentedHitsPositionDistance_PM',
#  'def_accentedHitsPositionClinch_PM',
#  'def_accentedHitsPositionParter_PM',
#  'def_knockdowns_PM',
#  'def_protectionPassage_PM',
#  'odds']

# %%
f_stats_events_cumulative = pd.read_csv('data_models/PROD_f_stats_events_cumulative_prod_19.05.2021.csv', index_col=0)
f_stats_events_cumulative['eventDate.date'] = pd.to_datetime(f_stats_events_cumulative['eventDate.date'])
f_stats_events_cumulative
# Out:
#       cumsum_duration  cumsum_winner  cumsum_hitsTotal  cumsum_hitsSuccessful  \
# 5253            300.0              1                66                     38
# 5341            600.0              1               102                     47
# 5517            761.0              2               124                     62
# 5564            917.0              3               160                     90
# 5729           1217.0              3               215                    119
# ...               ...            ...               ...                    ...
# 5807            240.0              0                11                      7
# 5888            271.0              0                42                     13
# 5886            300.0              0                71                     13
# 5901            300.0              1                64                     47
# 5895            118.0              0                25                     14
#
#       cumsum_takedownTotal  cumsum_takedownSuccessful  \
# 5253                     0                          0
# 5341                     0                          0
# 5517                     0                          0
# 5564                     0                          0
# 5729                     0                          0
# ...                    ...                        ...
# 5807                     0                          0
# 5888                     0                          0
# 5886                     0                          0
# 5901                     1                          1
# 5895                     0                          0
#
#       cumsum_submissionAttempts  cumsum_takeovers  cumsum_accentedHitsTotal  \
# 5253                          0                 0                        66
# 5341                          0                 0                       102
# 5517                          0                 0                       124
# 5564                          0                 0                       160
# 5729                          0                 0                       215
# ...                         ...               ...                       ...
# 5807                          0                 0                         8
# 5888                          0                 0                        40
# 5886                          0                 0                        71
# 5901                          0                 2                        23
# 5895                          0                 0                        25
#
#       cumsum_accentedHitsSuccessful  cumsum_knockdowns  \
# 5253                             38                  0
# 5341                             47                  0
# 5517                             62                  0
# 5564                             90                  0
# 5729                            119                  0
# ...                             ...                ...
# 5807                              4                  0
# 5888                             12                  0
# 5886                             13                  0
# 5901                              8                  0
# 5895                             14                  0
#
#       cumsum_protectionPassage  cumsum_hitsHeadTotal  \
# 5253                         0                    42
# 5341                         0                    72
# 5517                         0                    84
# 5564                         0                   104
# 5729                         0                   134
# ...                        ...                   ...
# 5807                         0                     7
# 5888                         0                    29
# 5886                         0                    61
# 5901                         1                    19
# 5895                         0                     7
#
#       cumsum_hitsHeadSuccessful  cumsum_hitsBodyTotal  \
# 5253                         16                     8
# 5341                         20                     9
# 5517                         26                    11
# 5564                         38                    17
# 5729                         45                    20
# ...                         ...                   ...
# 5807                          3                     0
# 5888                          4                     6
# 5886                          9                     8
# 5901                          5                     1
# 5895                          3                     7
#
#       cumsum_hitsBodySuccessful  cumsum_hitsLegsTotal  \
# 5253                          6                    16
# 5341                          6                    21
# 5517                          8                    29
# 5564                         14                    39
# 5729                         15                    61
# ...                         ...                   ...
# 5807                          0                     1
# 5888                          3                     5
# 5886                          3                     2
# 5901                          0                     3
# 5895                          3                    11
#
#       cumsum_hitsLegsSuccessful  cumsum_accentedHitsPositionDistanceTotal  \
# 5253                         16                                        66
# 5341                         21                                       102
# 5517                         28                                       123
# 5564                         38                                       147
# 5729                         59                                       201
# ...                         ...                                       ...
# 5807                          1                                         6
# 5888                          5                                        37
# 5886                          1                                        68
# 5901                          3                                        23
# 5895                          8                                        22
#
#       cumsum_accentedHitsPositionDistanceSuccessful  \
# 5253                                             38
# 5341                                             47
# 5517                                             61
# 5564                                             80
# 5729                                            109
# ...                                             ...
# 5807                                              3
# 5888                                              9
# 5886                                             11
# 5901                                              8
# 5895                                             12
#
#       cumsum_accentedHitsPositionClinchTotal  \
# 5253                                       0
# 5341                                       0
# 5517                                       0
# 5564                                       0
# 5729                                       1
# ...                                      ...
# 5807                                       2
# 5888                                       3
# 5886                                       3
# 5901                                       0
# 5895                                       1
#
#       cumsum_accentedHitsPositionClinchSuccessful  \
# 5253                                            0
# 5341                                            0
# 5517                                            0
# 5564                                            0
# 5729                                            0
# ...                                           ...
# 5807                                            1
# 5888                                            3
# 5886                                            2
# 5901                                            0
# 5895                                            0
#
#       cumsum_accentedHitsPositionParterTotal  \
# 5253                                       0
# 5341                                       0
# 5517                                       1
# 5564                                      13
# 5729                                      13
# ...                                      ...
# 5807                                       0
# 5888                                       0
# 5886                                       0
# 5901                                       0
# 5895                                       2
#
#       cumsum_accentedHitsPositionParterSuccessful  cumsum_def_hitsTotal  \
# 5253                                            0                    45
# 5341                                            0                   120
# 5517                                            1                   137
# 5564                                           10                   158
# 5729                                           10                   193
# ...                                           ...                   ...
# 5807                                            0                    29
# 5888                                            0                   112
# 5886                                            0                    88
# 5901                                            0                    52
# 5895                                            2                    26
#
#       cumsum_def_hitsSuccessful  cumsum_def_takedownTotal  \
# 5253                         15                         0
# 5341                         49                         0
# 5517                         55                         0
# 5564                         63                         1
# 5729                         78                         1
# ...                         ...                       ...
# 5807                         23                         6
# 5888                         56                         0
# 5886                         42                         0
# 5901                         32                         0
# 5895                         15                         0
#
#       cumsum_def_takedownSuccessful  cumsum_def_submissionAttempts  \
# 5253                              0                              0
# 5341                              0                              0
# 5517                              0                              0
# 5564                              0                              0
# 5729                              0                              0
# ...                             ...                            ...
# 5807                              4                              1
# 5888                              0                              0
# 5886                              0                              0
# 5901                              0                              0
# 5895                              0                              0
#
#       cumsum_def_takeovers  cumsum_def_accentedHitsTotal  \
# 5253                     0                            45
# 5341                     0                           120
# 5517                     0                           137
# 5564                     0                           157
# 5729                     0                           192
# ...                    ...                           ...
# 5807                     3                            11
# 5888                     2                            95
# 5886                     0                            88
# 5901                     0                            32
# 5895                     0                            26
#
#       cumsum_def_accentedHitsSuccessful  cumsum_def_knockdowns  \
# 5253                                 15                      0
# 5341                                 49                      0
# 5517                                 55                      0
# 5564                                 62                      0
# 5729                                 77                      0
# ...                                 ...                    ...
# 5807                                  6                      0
# 5888                                 43                      0
# 5886                                 42                      0
# 5901                                 15                      0
# 5895                                 15                      0
#
#       cumsum_def_protectionPassage  cumsum_def_hitsHeadTotal  \
# 5253                             0                        37
# 5341                             0                        95
# 5517                             0                       104
# 5564                             0                       121
# 5729                             0                       145
# ...                            ...                       ...
# 5807                             0                        10
# 5888                             0                        89
# 5886                             0                        66
# 5901                             1                        28
# 5895                             0                        22
#
#       cumsum_def_hitsHeadSuccessful  cumsum_def_hitsBodyTotal  \
# 5253                             10                         5
# 5341                             29                        17
# 5517                             32                        25
# 5564                             36                        26
# 5729                             44                        32
# ...                             ...                       ...
# 5807                              5                         1
# 5888                             37                         6
# 5886                             24                        20
# 5901                             11                         4
# 5895                             11                         2
#
#       cumsum_def_hitsBodySuccessful  cumsum_def_hitsLegsTotal  \
# 5253                              2                         3
# 5341                             13                         8
# 5517                             16                         8
# 5564                             17                        10
# 5729                             19                        15
# ...                             ...                       ...
# 5807                              1                         0
# 5888                              6                         0
# 5886                             17                         2
# 5901                              4                         0
# 5895                              2                         2
#
#       cumsum_def_hitsLegsSuccessful  \
# 5253                              3
# 5341                              7
# 5517                              7
# 5564                              9
# 5729                             14
# ...                             ...
# 5807                              0
# 5888                              0
# 5886                              1
# 5901                              0
# 5895                              2
#
#       cumsum_def_accentedHitsPositionDistanceTotal  \
# 5253                                            45
# 5341                                           113
# 5517                                           130
# 5564                                           149
# 5729                                           183
# ...                                            ...
# 5807                                             5
# 5888                                            50
# 5886                                            88
# 5901                                            31
# 5895                                            12
#
#       cumsum_def_accentedHitsPositionDistanceSuccessful  \
# 5253                                                 15
# 5341                                                 43
# 5517                                                 49
# 5564                                                 56
# 5729                                                 70
# ...                                                 ...
# 5807                                                  0
# 5888                                                 19
# 5886                                                 42
# 5901                                                 14
# 5895                                                  5
#
#       cumsum_def_accentedHitsPositionClinchTotal  \
# 5253                                           0
# 5341                                           7
# 5517                                           7
# 5564                                           8
# 5729                                           9
# ...                                          ...
# 5807                                           1
# 5888                                           6
# 5886                                           0
# 5901                                           1
# 5895                                           4
#
#       cumsum_def_accentedHitsPositionClinchSuccessful  \
# 5253                                                0
# 5341                                                6
# 5517                                                6
# 5564                                                6
# 5729                                                7
# ...                                               ...
# 5807                                                1
# 5888                                                5
# 5886                                                0
# 5901                                                1
# 5895                                                3
#
#       cumsum_def_accentedHitsPositionParterTotal  \
# 5253                                           0
# 5341                                           0
# 5517                                           0
# 5564                                           0
# 5729                                           0
# ...                                          ...
# 5807                                           5
# 5888                                          39
# 5886                                           0
# 5901                                           0
# 5895                                          10
#
#       cumsum_def_accentedHitsPositionParterSuccessful  \
# 5253                                                0
# 5341                                                0
# 5517                                                0
# 5564                                                0
# 5729                                                0
# ...                                               ...
# 5807                                                5
# 5888                                               19
# 5886                                                0
# 5901                                                0
# 5895                                                7
#
#       cumsum_winMethods_[DEC]  cumsum_winMethods_[DQ]  cumsum_winMethods_[KO]  \
# 5253                        1                       0                       0
# 5341                        2                       0                       0
# 5517                        2                       0                       1
# 5564                        2                       0                       2
# 5729                        3                       0                       2
# ...                       ...                     ...                     ...
# 5807                        0                       0                       0
# 5888                        0                       0                       1
# 5886                        1                       0                       0
# 5901                        1                       0                       0
# 5895                        0                       0                       1
#
#       cumsum_winMethods_[SUB]  current_duration  winner  current_hitsTotal  \
# 5253                        0             300.0    True                 66
# 5341                        0             300.0   False                 36
# 5517                        0             161.0    True                 22
# 5564                        0             156.0    True                 36
# 5729                        0             300.0   False                 55
# ...                       ...               ...     ...                ...
# 5807                        1             240.0   False                 11
# 5888                        0             271.0   False                 42
# 5886                        0             300.0   False                 71
# 5901                        0             300.0    True                 64
# 5895                        0             118.0   False                 25
#
#       current_hitsSuccessful  current_takedownTotal  \
# 5253                      38                      0
# 5341                       9                      0
# 5517                      15                      0
# 5564                      28                      0
# 5729                      29                      0
# ...                      ...                    ...
# 5807                       7                      0
# 5888                      13                      0
# 5886                      13                      0
# 5901                      47                      1
# 5895                      14                      0
#
#       current_takedownSuccessful  current_submissionAttempts  \
# 5253                           0                           0
# 5341                           0                           0
# 5517                           0                           0
# 5564                           0                           0
# 5729                           0                           0
# ...                          ...                         ...
# 5807                           0                           0
# 5888                           0                           0
# 5886                           0                           0
# 5901                           1                           0
# 5895                           0                           0
#
#       current_takeovers  current_accentedHitsTotal  \
# 5253                  0                         66
# 5341                  0                         36
# 5517                  0                         22
# 5564                  0                         36
# 5729                  0                         55
# ...                 ...                        ...
# 5807                  0                          8
# 5888                  0                         40
# 5886                  0                         71
# 5901                  2                         23
# 5895                  0                         25
#
#       current_accentedHitsSuccessful  current_knockdowns  \
# 5253                              38                   0
# 5341                               9                   0
# 5517                              15                   0
# 5564                              28                   0
# 5729                              29                   0
# ...                              ...                 ...
# 5807                               4                   0
# 5888                              12                   0
# 5886                              13                   0
# 5901                               8                   0
# 5895                              14                   0
#
#       current_protectionPassage  current_hitsHeadTotal  \
# 5253                          0                     42
# 5341                          0                     30
# 5517                          0                     12
# 5564                          0                     20
# 5729                          0                     30
# ...                         ...                    ...
# 5807                          0                      7
# 5888                          0                     29
# 5886                          0                     61
# 5901                          1                     19
# 5895                          0                      7
#
#       current_hitsHeadSuccessful  current_hitsBodyTotal  \
# 5253                          16                      8
# 5341                           4                      1
# 5517                           6                      2
# 5564                          12                      6
# 5729                           7                      3
# ...                          ...                    ...
# 5807                           3                      0
# 5888                           4                      6
# 5886                           9                      8
# 5901                           5                      1
# 5895                           3                      7
#
#       current_hitsBodySuccessful  current_hitsLegsTotal  \
# 5253                           6                     16
# 5341                           0                      5
# 5517                           2                      8
# 5564                           6                     10
# 5729                           1                     22
# ...                          ...                    ...
# 5807                           0                      1
# 5888                           3                      5
# 5886                           3                      2
# 5901                           0                      3
# 5895                           3                     11
#
#       current_hitsLegsSuccessful  current_accentedHitsPositionDistanceTotal  \
# 5253                          16                                         66
# 5341                           5                                         36
# 5517                           7                                         21
# 5564                          10                                         24
# 5729                          21                                         54
# ...                          ...                                        ...
# 5807                           1                                          6
# 5888                           5                                         37
# 5886                           1                                         68
# 5901                           3                                         23
# 5895                           8                                         22
#
#       current_accentedHitsPositionDistanceSuccessful  \
# 5253                                              38
# 5341                                               9
# 5517                                              14
# 5564                                              19
# 5729                                              29
# ...                                              ...
# 5807                                               3
# 5888                                               9
# 5886                                              11
# 5901                                               8
# 5895                                              12
#
#       current_accentedHitsPositionClinchTotal  \
# 5253                                        0
# 5341                                        0
# 5517                                        0
# 5564                                        0
# 5729                                        1
# ...                                       ...
# 5807                                        2
# 5888                                        3
# 5886                                        3
# 5901                                        0
# 5895                                        1
#
#       current_accentedHitsPositionClinchSuccessful  \
# 5253                                             0
# 5341                                             0
# 5517                                             0
# 5564                                             0
# 5729                                             0
# ...                                            ...
# 5807                                             1
# 5888                                             3
# 5886                                             2
# 5901                                             0
# 5895                                             0
#
#       current_accentedHitsPositionParterTotal  \
# 5253                                        0
# 5341                                        0
# 5517                                        1
# 5564                                       12
# 5729                                        0
# ...                                       ...
# 5807                                        0
# 5888                                        0
# 5886                                        0
# 5901                                        0
# 5895                                        2
#
#       current_accentedHitsPositionParterSuccessful  current_def_hitsTotal  \
# 5253                                             0                     45
# 5341                                             0                     75
# 5517                                             1                     17
# 5564                                             9                     21
# 5729                                             0                     35
# ...                                            ...                    ...
# 5807                                             0                     29
# 5888                                             0                    112
# 5886                                             0                     88
# 5901                                             0                     52
# 5895                                             2                     26
#
#       current_def_hitsSuccessful  current_def_takedownTotal  \
# 5253                          15                          0
# 5341                          34                          0
# 5517                           6                          0
# 5564                           8                          1
# 5729                          15                          0
# ...                          ...                        ...
# 5807                          23                          6
# 5888                          56                          0
# 5886                          42                          0
# 5901                          32                          0
# 5895                          15                          0
#
#       current_def_takedownSuccessful  current_def_submissionAttempts  \
# 5253                               0                               0
# 5341                               0                               0
# 5517                               0                               0
# 5564                               0                               0
# 5729                               0                               0
# ...                              ...                             ...
# 5807                               4                               1
# 5888                               0                               0
# 5886                               0                               0
# 5901                               0                               0
# 5895                               0                               0
#
#       current_def_takeovers  current_def_accentedHitsTotal  \
# 5253                      0                             45
# 5341                      0                             75
# 5517                      0                             17
# 5564                      0                             20
# 5729                      0                             35
# ...                     ...                            ...
# 5807                      3                             11
# 5888                      2                             95
# 5886                      0                             88
# 5901                      0                             32
# 5895                      0                             26
#
#       current_def_accentedHitsSuccessful  current_def_knockdowns  \
# 5253                                  15                       0
# 5341                                  34                       0
# 5517                                   6                       0
# 5564                                   7                       0
# 5729                                  15                       0
# ...                                  ...                     ...
# 5807                                   6                       0
# 5888                                  43                       0
# 5886                                  42                       0
# 5901                                  15                       0
# 5895                                  15                       0
#
#       current_def_protectionPassage  current_def_hitsHeadTotal  \
# 5253                              0                         37
# 5341                              0                         58
# 5517                              0                          9
# 5564                              0                         17
# 5729                              0                         24
# ...                             ...                        ...
# 5807                              0                         10
# 5888                              0                         89
# 5886                              0                         66
# 5901                              1                         28
# 5895                              0                         22
#
#       current_def_hitsHeadSuccessful  current_def_hitsBodyTotal  \
# 5253                              10                          5
# 5341                              19                         12
# 5517                               3                          8
# 5564                               4                          1
# 5729                               8                          6
# ...                              ...                        ...
# 5807                               5                          1
# 5888                              37                          6
# 5886                              24                         20
# 5901                              11                          4
# 5895                              11                          2
#
#       current_def_hitsBodySuccessful  current_def_hitsLegsTotal  \
# 5253                               2                          3
# 5341                              11                          5
# 5517                               3                          0
# 5564                               1                          2
# 5729                               2                          5
# ...                              ...                        ...
# 5807                               1                          0
# 5888                               6                          0
# 5886                              17                          2
# 5901                               4                          0
# 5895                               2                          2
#
#       current_def_hitsLegsSuccessful  \
# 5253                               3
# 5341                               4
# 5517                               0
# 5564                               2
# 5729                               5
# ...                              ...
# 5807                               0
# 5888                               0
# 5886                               1
# 5901                               0
# 5895                               2
#
#       current_def_accentedHitsPositionDistanceTotal  \
# 5253                                             45
# 5341                                             68
# 5517                                             17
# 5564                                             19
# 5729                                             34
# ...                                             ...
# 5807                                              5
# 5888                                             50
# 5886                                             88
# 5901                                             31
# 5895                                             12
#
#       current_def_accentedHitsPositionDistanceSuccessful  \
# 5253                                                 15
# 5341                                                 28
# 5517                                                  6
# 5564                                                  7
# 5729                                                 14
# ...                                                 ...
# 5807                                                  0
# 5888                                                 19
# 5886                                                 42
# 5901                                                 14
# 5895                                                  5
#
#       current_def_accentedHitsPositionClinchTotal  \
# 5253                                            0
# 5341                                            7
# 5517                                            0
# 5564                                            1
# 5729                                            1
# ...                                           ...
# 5807                                            1
# 5888                                            6
# 5886                                            0
# 5901                                            1
# 5895                                            4
#
#       current_def_accentedHitsPositionClinchSuccessful  \
# 5253                                                 0
# 5341                                                 6
# 5517                                                 0
# 5564                                                 0
# 5729                                                 1
# ...                                                ...
# 5807                                                 1
# 5888                                                 5
# 5886                                                 0
# 5901                                                 1
# 5895                                                 3
#
#       current_def_accentedHitsPositionParterTotal  \
# 5253                                            0
# 5341                                            0
# 5517                                            0
# 5564                                            0
# 5729                                            0
# ...                                           ...
# 5807                                            5
# 5888                                           39
# 5886                                            0
# 5901                                            0
# 5895                                           10
#
#       current_def_accentedHitsPositionParterSuccessful  \
# 5253                                                 0
# 5341                                                 0
# 5517                                                 0
# 5564                                                 0
# 5729                                                 0
# ...                                                ...
# 5807                                                 5
# 5888                                                19
# 5886                                                 0
# 5901                                                 0
# 5895                                                 7
#
#       current_winMethods_[DEC]  current_winMethods_[DQ]  \
# 5253                         1                        0
# 5341                         1                        0
# 5517                         0                        0
# 5564                         0                        0
# 5729                         1                        0
# ...                        ...                      ...
# 5807                         0                        0
# 5888                         0                        0
# 5886                         1                        0
# 5901                         1                        0
# 5895                         0                        0
#
#       current_winMethods_[KO]  current_winMethods_[SUB]  age  \
# 5253                        0                         0   28
# 5341                        0                         0   28
# 5517                        1                         0   28
# 5564                        1                         0   28
# 5729                        0                         0   29
# ...                       ...                       ...  ...
# 5807                        0                         1   28
# 5888                        1                         0   32
# 5886                        0                         0   26
# 5901                        0                         0   51
# 5895                        1                         0   29
#
#           eventDate.date  fighterId  fighter_nbr  odds  winnerId  \
# 5253 2019-10-18 00:00:01          1            1  1.70       1.0
# 5341 2019-12-21 00:00:07          1            2  5.50     103.0
# 5517 2020-06-27 00:00:03          1            1   NaN       1.0
# 5564 2020-07-25 00:00:04          1            2   NaN       1.0
# 5729 2020-11-07 00:00:09          1            1  1.29     277.0
# ...                  ...        ...          ...   ...       ...
# 5807 2021-01-20 00:00:07       3667            1  4.75     353.0
# 5888 2021-03-13 00:00:06       3677            1   NaN     666.0
# 5886 2021-03-13 00:00:04       3678            2   NaN     412.0
# 5901 2021-03-20 00:00:08       3679            1  3.40    3679.0
# 5895 2021-03-20 00:00:02       3680            1   NaN     119.0
#
#       count_of_fights  hits_accuracy  takedown_accuracy  \
# 5253                0       0.575758                NaN
# 5341                1       0.460784                NaN
# 5517                2       0.500000                NaN
# 5564                3       0.562500                NaN
# 5729                4       0.553488                NaN
# ...               ...            ...                ...
# 5807                0       0.636364                NaN
# 5888                0       0.309524                NaN
# 5886                0       0.183099                NaN
# 5901                0       0.734375                1.0
# 5895                0       0.560000                NaN
#
#       accentedHits_accuracy  hitsHead_accuracy  hitsBody_accuracy  \
# 5253               0.575758           0.380952           0.750000
# 5341               0.460784           0.277778           0.666667
# 5517               0.500000           0.309524           0.727273
# 5564               0.562500           0.365385           0.823529
# 5729               0.553488           0.335821           0.750000
# ...                     ...                ...                ...
# 5807               0.500000           0.428571                NaN
# 5888               0.300000           0.137931           0.500000
# 5886               0.183099           0.147541           0.375000
# 5901               0.347826           0.263158           0.000000
# 5895               0.560000           0.428571           0.428571
#
#       hitsLegs_accuracy  accentedHitsPositionDistance_accuracy  \
# 5253           1.000000                               0.575758
# 5341           1.000000                               0.460784
# 5517           0.965517                               0.495935
# 5564           0.974359                               0.544218
# 5729           0.967213                               0.542289
# ...                 ...                                    ...
# 5807           1.000000                               0.500000
# 5888           1.000000                               0.243243
# 5886           0.500000                               0.161765
# 5901           1.000000                               0.347826
# 5895           0.727273                               0.545455
#
#       accentedHitsPositionClinch_accuracy  \
# 5253                                  NaN
# 5341                                  NaN
# 5517                                  NaN
# 5564                                  NaN
# 5729                             0.000000
# ...                                   ...
# 5807                             0.500000
# 5888                             1.000000
# 5886                             0.666667
# 5901                                  NaN
# 5895                             0.000000
#
#       accentedHitsPositionParter_accuracy  def_hits_accuracy  \
# 5253                                  NaN           0.333333
# 5341                                  NaN           0.408333
# 5517                             1.000000           0.401460
# 5564                             0.769231           0.398734
# 5729                             0.769231           0.404145
# ...                                   ...                ...
# 5807                                  NaN           0.793103
# 5888                                  NaN           0.500000
# 5886                                  NaN           0.477273
# 5901                                  NaN           0.615385
# 5895                             1.000000           0.576923
#
#       def_takedown_accuracy  def_accentedHits_accuracy  def_hitsHead_accuracy  \
# 5253                    NaN                   0.333333               0.270270
# 5341                    NaN                   0.408333               0.305263
# 5517                    NaN                   0.401460               0.307692
# 5564               0.000000                   0.394904               0.297521
# 5729               0.000000                   0.401042               0.303448
# ...                     ...                        ...                    ...
# 5807               0.666667                   0.545455               0.500000
# 5888                    NaN                   0.452632               0.415730
# 5886                    NaN                   0.477273               0.363636
# 5901                    NaN                   0.468750               0.392857
# 5895                    NaN                   0.576923               0.500000
#
#       def_hitsBody_accuracy  def_hitsLegs_accuracy  \
# 5253               0.400000               1.000000
# 5341               0.764706               0.875000
# 5517               0.640000               0.875000
# 5564               0.653846               0.900000
# 5729               0.593750               0.933333
# ...                     ...                    ...
# 5807               1.000000                    NaN
# 5888               1.000000                    NaN
# 5886               0.850000               0.500000
# 5901               1.000000                    NaN
# 5895               1.000000               1.000000
#
#       def_accentedHitsPositionDistance_accuracy  \
# 5253                                   0.333333
# 5341                                   0.380531
# 5517                                   0.376923
# 5564                                   0.375839
# 5729                                   0.382514
# ...                                         ...
# 5807                                   0.000000
# 5888                                   0.380000
# 5886                                   0.477273
# 5901                                   0.451613
# 5895                                   0.416667
#
#       def_accentedHitsPositionClinch_accuracy  \
# 5253                                      NaN
# 5341                                 0.857143
# 5517                                 0.857143
# 5564                                 0.750000
# 5729                                 0.777778
# ...                                       ...
# 5807                                 1.000000
# 5888                                 0.833333
# 5886                                      NaN
# 5901                                 1.000000
# 5895                                 0.750000
#
#       def_accentedHitsPositionParter_accuracy  DEC_percent  DQ_percent  \
# 5253                                      NaN     1.000000         0.0
# 5341                                      NaN     2.000000         0.0
# 5517                                      NaN     1.000000         0.0
# 5564                                      NaN     0.666667         0.0
# 5729                                      NaN     1.000000         0.0
# ...                                       ...          ...         ...
# 5807                                 1.000000          NaN         NaN
# 5888                                 0.487179          NaN         NaN
# 5886                                      NaN          inf         NaN
# 5901                                      NaN     1.000000         0.0
# 5895                                 0.700000          NaN         NaN
#
#       KO_percent  SUB_percent   hits_PM  takedown_PM  accentedHits_PM  \
# 5253    0.000000          0.0  7.600000          0.0         7.600000
# 5341    0.000000          0.0  4.700000          0.0         4.700000
# 5517    0.500000          0.0  4.888305          0.0         4.888305
# 5564    0.666667          0.0  5.888768          0.0         5.888768
# 5729    0.666667          0.0  5.866886          0.0         5.866886
# ...          ...          ...       ...          ...              ...
# 5807         NaN          inf  1.750000          0.0         1.000000
# 5888         inf          NaN  2.878229          0.0         2.656827
# 5886         NaN          NaN  2.600000          0.0         2.600000
# 5901    0.000000          0.0  9.400000          0.2         1.600000
# 5895         inf          NaN  7.118644          0.0         7.118644
#
#       hitsHead_PM  hitsBody_PM  hitsLegs_PM  accentedHitsPositionDistance_PM  \
# 5253     3.200000     1.200000     3.200000                         7.600000
# 5341     2.000000     0.600000     2.100000                         4.700000
# 5517     2.049934     0.630749     2.207622                         4.809461
# 5564     2.486369     0.916031     2.486369                         5.234460
# 5729     2.218570     0.739523     2.908792                         5.373870
# ...           ...          ...          ...                              ...
# 5807     0.750000     0.000000     0.250000                         0.750000
# 5888     0.885609     0.664207     1.107011                         1.992620
# 5886     1.800000     0.600000     0.200000                         2.200000
# 5901     1.000000     0.000000     0.600000                         1.600000
# 5895     1.525424     1.525424     4.067797                         6.101695
#
#       accentedHitsPositionClinch_PM  accentedHitsPositionParter_PM  \
# 5253                       0.000000                       0.000000
# 5341                       0.000000                       0.000000
# 5517                       0.000000                       0.078844
# 5564                       0.000000                       0.654308
# 5729                       0.000000                       0.493016
# ...                             ...                            ...
# 5807                       0.250000                       0.000000
# 5888                       0.664207                       0.000000
# 5886                       0.400000                       0.000000
# 5901                       0.000000                       0.000000
# 5895                       0.000000                       1.016949
#
#       def_hits_PM  def_takedown_PM  def_accentedHits_PM  def_hitsHead_PM  \
# 5253     3.000000              0.0             3.000000         2.000000
# 5341     4.900000              0.0             4.900000         2.900000
# 5517     4.336399              0.0             4.336399         2.522996
# 5564     4.122137              0.0             4.056707         2.355507
# 5729     3.845522              0.0             3.796220         2.169269
# ...           ...              ...                  ...              ...
# 5807     5.750000              1.0             1.500000         1.250000
# 5888    12.398524              0.0             9.520295         8.191882
# 5886     8.400000              0.0             8.400000         4.800000
# 5901     6.400000              0.0             3.000000         2.200000
# 5895     7.627119              0.0             7.627119         5.593220
#
#       def_hitsBody_PM  def_hitsLegs_PM  def_accentedHitsPositionDistance_PM  \
# 5253         0.400000         0.600000                             3.000000
# 5341         1.300000         0.700000                             4.300000
# 5517         1.261498         0.551905                             3.863338
# 5564         1.112323         0.588877                             3.664122
# 5729         0.936730         0.690222                             3.451109
# ...               ...              ...                                  ...
# 5807         0.250000         0.000000                             0.000000
# 5888         1.328413         0.000000                             4.206642
# 5886         3.400000         0.200000                             8.400000
# 5901         0.800000         0.000000                             2.800000
# 5895         1.016949         1.016949                             2.542373
#
#       def_accentedHitsPositionClinch_PM  def_accentedHitsPositionParter_PM  \
# 5253                           0.000000                           0.000000
# 5341                           0.600000                           0.000000
# 5517                           0.473062                           0.000000
# 5564                           0.392585                           0.000000
# 5729                           0.345111                           0.000000
# ...                                 ...                                ...
# 5807                           0.250000                           1.250000
# 5888                           1.107011                           4.206642
# 5886                           0.000000                           0.000000
# 5901                           0.200000                           0.000000
# 5895                           1.525424                           3.559322
#
#       knockdowns_PM  def_knockdowns_PM  protectionPassage_PM  \
# 5253            0.0                0.0                   0.0
# 5341            0.0                0.0                   0.0
# 5517            0.0                0.0                   0.0
# 5564            0.0                0.0                   0.0
# 5729            0.0                0.0                   0.0
# ...             ...                ...                   ...
# 5807            0.0                0.0                   0.0
# 5888            0.0                0.0                   0.0
# 5886            0.0                0.0                   0.0
# 5901            0.0                0.0                   0.2
# 5895            0.0                0.0                   0.0
#
#       def_protectionPassage_PM  win_streak  loose_streak       fighterName
# 5253                       0.0           1             0      Tanner Boser
# 5341                       0.0           0             1      Tanner Boser
# 5517                       0.0           1             0      Tanner Boser
# 5564                       0.0           2             0      Tanner Boser
# 5729                       0.0           0             1      Tanner Boser
# ...                        ...         ...           ...               ...
# 5807                       0.0           0             1  Gaetano Pirrello
# 5888                       0.0           0             1      Marcelo Rojo
# 5886                       0.0           0             1       Rafa Garcia
# 5901                       0.2           1             0   Montserrat Ruiz
# 5895                       0.0           0             1     Jesse Strader
#
# [11854 rows x 154 columns]

# %%
clf = CatBoostClassifier()
clf.load_model('data_models/catboost_v2_1_19.05.2021.cat')
f1_id, f2_id = 141, 453
event_date, time_zone = datetime.date(2021, 1, 16), 'Europe/Berlin'
f1_odd, f2_odd = 3.37, 1.34
weightCategory_id, event_name = 6, 'UFC Fight Night'
city, country = 'Abu Dhabi', 'United Arab Emirates'
clf.feature_names_


f1_id, f2_id = 3610, 3664
event_date, time_zone = datetime.date(2021, 1, 20), 'Europe/Berlin'
f1_odd, f2_odd = 3.37, 1.34
weightCategory_id, event_name = 6, 'UFC Fight Night'
city, country = 'Abu Dhabi', 'United Arab Emirates'
clf.feature_names_
# Out:
# ['age_difference',
#  'armSpan_difference',
#  'cumsum_def_hitsTotal_difference',
#  'cumsum_hitsSuccessful_difference',
#  'cumsum_submissionAttempts_difference',
#  'def_accentedHitsPositionDistance_accuracy_difference',
#  'def_hitsHead_accuracy_difference',
#  'def_hitsLegs_PM_difference',
#  'def_hitsLegs_accuracy_difference',
#  'cumsum_takeovers_difference',
#  'cumsum_takedownTotal_difference',
#  'isHomeCity_difference',
#  'isHomeCountry_difference',
#  'takedown_PM_difference',
#  'win_streak_difference']

# %%
is_fight_night = 'fight night' in str(event_name).lower()

### Static stats
f1_birthDate = fighters_df.loc[int(f1_id), ['dateOfBirth']]
f1_static_stats = fighters_df.loc[int(f1_id), static_cols].values
f1_age = ((pd.to_datetime(event_date) - pd.to_datetime(f1_birthDate)) / 365).dt.days.values[0]

f2_birthDate = fighters_df.loc[int(f2_id), ['dateOfBirth']]
f2_static_stats = fighters_df.loc[int(f2_id), static_cols].values
f2_age = ((pd.to_datetime(event_date) - pd.to_datetime(f2_birthDate)) / 365).dt.days.values[0]

### Dynamic stats
fighter1_stats = f_stats_events_cumulative[
    (f_stats_events_cumulative['fighterId'] == int(f1_id)) &
    (f_stats_events_cumulative['eventDate.date'] < pd.to_datetime(event_date))]
# fighter1_stats = fighter1_stats.iloc[[-1]].reset_index(drop=True)
fighter1_stats['cumsum_hitsTotal']
# Out:
# Series([], Name: cumsum_hitsTotal, dtype: int64)

# %%
fighter1_stats.shape[0]
# Out:
# 0

# %%
fighter2_stats = f_stats_events_cumulative[
    (f_stats_events_cumulative['fighterId'] == int(f2_id)) &
    (f_stats_events_cumulative['eventDate.date'] < pd.to_datetime(event_date))]
# fighter2_stats = fighter2_stats.iloc[[-1]].reset_index(drop=True)
fighter2_stats
# Out:
# Empty DataFrame
# Columns: [cumsum_duration, cumsum_winner, cumsum_hitsTotal, cumsum_hitsSuccessful, cumsum_takedownTotal, cumsum_takedownSuccessful, cumsum_submissionAttempts, cumsum_takeovers, cumsum_accentedHitsTotal, cumsum_accentedHitsSuccessful, cumsum_knockdowns, cumsum_protectionPassage, cumsum_hitsHeadTotal, cumsum_hitsHeadSuccessful, cumsum_hitsBodyTotal, cumsum_hitsBodySuccessful, cumsum_hitsLegsTotal, cumsum_hitsLegsSuccessful, cumsum_accentedHitsPositionDistanceTotal, cumsum_accentedHitsPositionDistanceSuccessful, cumsum_accentedHitsPositionClinchTotal, cumsum_accentedHitsPositionClinchSuccessful, cumsum_accentedHitsPositionParterTotal, cumsum_accentedHitsPositionParterSuccessful, cumsum_def_hitsTotal, cumsum_def_hitsSuccessful, cumsum_def_takedownTotal, cumsum_def_takedownSuccessful, cumsum_def_submissionAttempts, cumsum_def_takeovers, cumsum_def_accentedHitsTotal, cumsum_def_accentedHitsSuccessful, cumsum_def_knockdowns, cumsum_def_protectionPassage, cumsum_def_hitsHeadTotal, cumsum_def_hitsHeadSuccessful, cumsum_def_hitsBodyTotal, cumsum_def_hitsBodySuccessful, cumsum_def_hitsLegsTotal, cumsum_def_hitsLegsSuccessful, cumsum_def_accentedHitsPositionDistanceTotal, cumsum_def_accentedHitsPositionDistanceSuccessful, cumsum_def_accentedHitsPositionClinchTotal, cumsum_def_accentedHitsPositionClinchSuccessful, cumsum_def_accentedHitsPositionParterTotal, cumsum_def_accentedHitsPositionParterSuccessful, cumsum_winMethods_[DEC], cumsum_winMethods_[DQ], cumsum_winMethods_[KO], cumsum_winMethods_[SUB], current_duration, winner, current_hitsTotal, current_hitsSuccessful, current_takedownTotal, current_takedownSuccessful, current_submissionAttempts, current_takeovers, current_accentedHitsTotal, current_accentedHitsSuccessful, current_knockdowns, current_protectionPassage, current_hitsHeadTotal, current_hitsHeadSuccessful, current_hitsBodyTotal, current_hitsBodySuccessful, current_hitsLegsTotal, current_hitsLegsSuccessful, current_accentedHitsPositionDistanceTotal, current_accentedHitsPositionDistanceSuccessful, current_accentedHitsPositionClinchTotal, current_accentedHitsPositionClinchSuccessful, current_accentedHitsPositionParterTotal, current_accentedHitsPositionParterSuccessful, current_def_hitsTotal, current_def_hitsSuccessful, current_def_takedownTotal, current_def_takedownSuccessful, current_def_submissionAttempts, current_def_takeovers, current_def_accentedHitsTotal, current_def_accentedHitsSuccessful, current_def_knockdowns, current_def_protectionPassage, current_def_hitsHeadTotal, current_def_hitsHeadSuccessful, current_def_hitsBodyTotal, current_def_hitsBodySuccessful, current_def_hitsLegsTotal, current_def_hitsLegsSuccessful, current_def_accentedHitsPositionDistanceTotal, current_def_accentedHitsPositionDistanceSuccessful, current_def_accentedHitsPositionClinchTotal, current_def_accentedHitsPositionClinchSuccessful, current_def_accentedHitsPositionParterTotal, current_def_accentedHitsPositionParterSuccessful, current_winMethods_[DEC], current_winMethods_[DQ], current_winMethods_[KO], current_winMethods_[SUB], ...]
# Index: []

# %%
# Create prediction vector
X_df = pd.DataFrame(index=[0])

X_df = X_df.join(fighter1_stats[num_cols].add_prefix("f1_"))
X_df = X_df.join(fighter2_stats[num_cols].add_prefix("f2_"))

X_df.loc[0, ['f1_age', 'f2_age', 'f1_odds', 'f2_odds']] = f1_age, f2_age, f1_odd, f2_odd

X_df[['weightCategory.id', 'city', 'country', 'is_fight_night', 'timezone']] = \
    weightCategory_id, city, country, is_fight_night, time_zone
print(X_df.shape)
X_df
# Out:
# (1, 201)
#    f1_cumsum_duration  f1_cumsum_winner  f1_cumsum_hitsTotal  \
# 0               717.0                 1                  105
#
#    f1_cumsum_hitsSuccessful  f1_cumsum_takedownTotal  \
# 0                        60                        3
#
#    f1_cumsum_takedownSuccessful  f1_cumsum_submissionAttempts  \
# 0                             0                             4
#
#    f1_cumsum_takeovers  f1_cumsum_accentedHitsTotal  \
# 0                    0                           76
#
#    f1_cumsum_accentedHitsSuccessful  f1_cumsum_knockdowns  \
# 0                                31                     0
#
#    f1_cumsum_protectionPassage  f1_cumsum_hitsHeadTotal  \
# 0                            0                       63
#
#    f1_cumsum_hitsHeadSuccessful  f1_cumsum_hitsBodyTotal  \
# 0                            22                       11
#
#    f1_cumsum_hitsBodySuccessful  f1_cumsum_hitsLegsTotal  \
# 0                             7                        2
#
#    f1_cumsum_hitsLegsSuccessful  f1_cumsum_accentedHitsPositionDistanceTotal  \
# 0                             2                                           68
#
#    f1_cumsum_accentedHitsPositionDistanceSuccessful  \
# 0                                                27
#
#    f1_cumsum_accentedHitsPositionClinchTotal  \
# 0                                          8
#
#    f1_cumsum_accentedHitsPositionClinchSuccessful  \
# 0                                               4
#
#    f1_cumsum_accentedHitsPositionParterTotal  \
# 0                                          0
#
#    f1_cumsum_accentedHitsPositionParterSuccessful  f1_cumsum_def_hitsTotal  \
# 0                                               0                      166
#
#    f1_cumsum_def_hitsSuccessful  f1_cumsum_def_takedownTotal  \
# 0                            89                            2
#
#    f1_cumsum_def_takedownSuccessful  f1_cumsum_def_submissionAttempts  \
# 0                                 1                                 0
#
#    f1_cumsum_def_takeovers  f1_cumsum_def_accentedHitsTotal  \
# 0                        3                              128
#
#    f1_cumsum_def_accentedHitsSuccessful  f1_cumsum_def_knockdowns  \
# 0                                    61                         0
#
#    f1_cumsum_def_protectionPassage  f1_cumsum_def_hitsHeadTotal  \
# 0                                0                          106
#
#    f1_cumsum_def_hitsHeadSuccessful  f1_cumsum_def_hitsBodyTotal  \
# 0                                44                            4
#
#    f1_cumsum_def_hitsBodySuccessful  f1_cumsum_def_hitsLegsTotal  \
# 0                                 4                           18
#
#    f1_cumsum_def_hitsLegsSuccessful  \
# 0                                13
#
#    f1_cumsum_def_accentedHitsPositionDistanceTotal  \
# 0                                              101
#
#    f1_cumsum_def_accentedHitsPositionDistanceSuccessful  \
# 0                                                 41
#
#    f1_cumsum_def_accentedHitsPositionClinchTotal  \
# 0                                              4
#
#    f1_cumsum_def_accentedHitsPositionClinchSuccessful  \
# 0                                                  3
#
#    f1_cumsum_def_accentedHitsPositionParterTotal  \
# 0                                             23
#
#    f1_cumsum_def_accentedHitsPositionParterSuccessful  \
# 0                                                 17
#
#    f1_cumsum_winMethods_[DEC]  f1_cumsum_winMethods_[DQ]  \
# 0                           1                          0
#
#    f1_cumsum_winMethods_[KO]  f1_cumsum_winMethods_[SUB]  f1_hits_accuracy  \
# 0                          1                           1          0.571429
#
#    f1_takedown_accuracy  f1_accentedHits_accuracy  f1_hitsHead_accuracy  \
# 0                   0.0                  0.407895              0.349206
#
#    f1_hitsBody_accuracy  f1_hitsLegs_accuracy  \
# 0              0.636364                   1.0
#
#    f1_accentedHitsPositionDistance_accuracy  \
# 0                                  0.397059
#
#    f1_accentedHitsPositionClinch_accuracy  \
# 0                                     0.5
#
#    f1_accentedHitsPositionParter_accuracy  f1_DEC_percent  f1_DQ_percent  \
# 0                                     NaN             1.0            0.0
#
#    f1_KO_percent  f1_SUB_percent  f1_hits_PM  f1_takedown_PM  \
# 0            1.0             1.0    5.020921             0.0
#
#    f1_accentedHits_PM  f1_hitsHead_PM  f1_hitsBody_PM  f1_hitsLegs_PM  \
# 0            2.594142        1.841004        0.585774        0.167364
#
#    f1_accentedHitsPositionDistance_PM  f1_accentedHitsPositionClinch_PM  \
# 0                            2.259414                          0.334728
#
#    f1_accentedHitsPositionParter_PM  f1_knockdowns_PM  \
# 0                               0.0               0.0
#
#    f1_protectionPassage_PM  f1_win_streak  f1_loose_streak  \
# 0                      0.0              1                0
#
#    f1_def_hits_accuracy  f1_def_takedown_accuracy  \
# 0              0.536145                       0.5
#
#    f1_def_accentedHits_accuracy  f1_def_hitsHead_accuracy  \
# 0                      0.476562                  0.415094
#
#    f1_def_hitsBody_accuracy  f1_def_hitsLegs_accuracy  \
# 0                       1.0                  0.722222
#
#    f1_def_accentedHitsPositionDistance_accuracy  \
# 0                                      0.405941
#
#    f1_def_accentedHitsPositionClinch_accuracy  \
# 0                                        0.75
#
#    f1_def_accentedHitsPositionParter_accuracy  f1_def_hits_PM  \
# 0                                     0.73913        7.447699
#
#    f1_def_takedown_PM  f1_def_accentedHits_PM  f1_def_hitsHead_PM  \
# 0            0.083682                5.104603            3.682008
#
#    f1_def_hitsBody_PM  f1_def_hitsLegs_PM  \
# 0            0.334728            1.087866
#
#    f1_def_accentedHitsPositionDistance_PM  \
# 0                                3.430962
#
#    f1_def_accentedHitsPositionClinch_PM  f1_def_accentedHitsPositionParter_PM  \
# 0                              0.251046                              1.422594
#
#    f1_def_knockdowns_PM  f1_def_protectionPassage_PM  f1_odds  \
# 0                   0.0                          0.0     3.37
#
#    f2_cumsum_duration  f2_cumsum_winner  f2_cumsum_hitsTotal  \
# 0              1500.0                 4                  176
#
#    f2_cumsum_hitsSuccessful  f2_cumsum_takedownTotal  \
# 0                        97                       15
#
#    f2_cumsum_takedownSuccessful  f2_cumsum_submissionAttempts  \
# 0                             2                             0
#
#    f2_cumsum_takeovers  f2_cumsum_accentedHitsTotal  \
# 0                    5                          132
#
#    f2_cumsum_accentedHitsSuccessful  f2_cumsum_knockdowns  \
# 0                                58                     0
#
#    f2_cumsum_protectionPassage  f2_cumsum_hitsHeadTotal  \
# 0                            0                      111
#
#    f2_cumsum_hitsHeadSuccessful  f2_cumsum_hitsBodyTotal  \
# 0                            40                       18
#
#    f2_cumsum_hitsBodySuccessful  f2_cumsum_hitsLegsTotal  \
# 0                            15                        3
#
#    f2_cumsum_hitsLegsSuccessful  f2_cumsum_accentedHitsPositionDistanceTotal  \
# 0                             3                                          100
#
#    f2_cumsum_accentedHitsPositionDistanceSuccessful  \
# 0                                                35
#
#    f2_cumsum_accentedHitsPositionClinchTotal  \
# 0                                         29
#
#    f2_cumsum_accentedHitsPositionClinchSuccessful  \
# 0                                              21
#
#    f2_cumsum_accentedHitsPositionParterTotal  \
# 0                                          3
#
#    f2_cumsum_accentedHitsPositionParterSuccessful  f2_cumsum_def_hitsTotal  \
# 0                                               2                      210
#
#    f2_cumsum_def_hitsSuccessful  f2_cumsum_def_takedownTotal  \
# 0                            71                            4
#
#    f2_cumsum_def_takedownSuccessful  f2_cumsum_def_submissionAttempts  \
# 0                                 1                                 0
#
#    f2_cumsum_def_takeovers  f2_cumsum_def_accentedHitsTotal  \
# 0                        0                              181
#
#    f2_cumsum_def_accentedHitsSuccessful  f2_cumsum_def_knockdowns  \
# 0                                    46                         0
#
#    f2_cumsum_def_protectionPassage  f2_cumsum_def_hitsHeadTotal  \
# 0                                0                          146
#
#    f2_cumsum_def_hitsHeadSuccessful  f2_cumsum_def_hitsBodyTotal  \
# 0                                25                           16
#
#    f2_cumsum_def_hitsBodySuccessful  f2_cumsum_def_hitsLegsTotal  \
# 0                                 9                           19
#
#    f2_cumsum_def_hitsLegsSuccessful  \
# 0                                12
#
#    f2_cumsum_def_accentedHitsPositionDistanceTotal  \
# 0                                              162
#
#    f2_cumsum_def_accentedHitsPositionDistanceSuccessful  \
# 0                                                 34
#
#    f2_cumsum_def_accentedHitsPositionClinchTotal  \
# 0                                             17
#
#    f2_cumsum_def_accentedHitsPositionClinchSuccessful  \
# 0                                                 11
#
#    f2_cumsum_def_accentedHitsPositionParterTotal  \
# 0                                              2
#
#    f2_cumsum_def_accentedHitsPositionParterSuccessful  \
# 0                                                  1
#
#    f2_cumsum_winMethods_[DEC]  f2_cumsum_winMethods_[DQ]  \
# 0                           5                          0
#
#    f2_cumsum_winMethods_[KO]  f2_cumsum_winMethods_[SUB]  f2_hits_accuracy  \
# 0                          0                           0          0.551136
#
#    f2_takedown_accuracy  f2_accentedHits_accuracy  f2_hitsHead_accuracy  \
# 0              0.133333                  0.439394               0.36036
#
#    f2_hitsBody_accuracy  f2_hitsLegs_accuracy  \
# 0              0.833333                   1.0
#
#    f2_accentedHitsPositionDistance_accuracy  \
# 0                                      0.35
#
#    f2_accentedHitsPositionClinch_accuracy  \
# 0                                0.724138
#
#    f2_accentedHitsPositionParter_accuracy  f2_DEC_percent  f2_DQ_percent  \
# 0                                0.666667            1.25            0.0
#
#    f2_KO_percent  f2_SUB_percent  f2_hits_PM  f2_takedown_PM  \
# 0            0.0             0.0        3.88            0.08
#
#    f2_accentedHits_PM  f2_hitsHead_PM  f2_hitsBody_PM  f2_hitsLegs_PM  \
# 0                2.32             1.6             0.6            0.12
#
#    f2_accentedHitsPositionDistance_PM  f2_accentedHitsPositionClinch_PM  \
# 0                                 1.4                              0.84
#
#    f2_accentedHitsPositionParter_PM  f2_knockdowns_PM  \
# 0                              0.08               0.0
#
#    f2_protectionPassage_PM  f2_win_streak  f2_loose_streak  \
# 0                      0.0              1                0
#
#    f2_def_hits_accuracy  f2_def_takedown_accuracy  \
# 0              0.338095                      0.25
#
#    f2_def_accentedHits_accuracy  f2_def_hitsHead_accuracy  \
# 0                      0.254144                  0.171233
#
#    f2_def_hitsBody_accuracy  f2_def_hitsLegs_accuracy  \
# 0                    0.5625                  0.631579
#
#    f2_def_accentedHitsPositionDistance_accuracy  \
# 0                                      0.209877
#
#    f2_def_accentedHitsPositionClinch_accuracy  \
# 0                                    0.647059
#
#    f2_def_accentedHitsPositionParter_accuracy  f2_def_hits_PM  \
# 0                                         0.5            2.84
#
#    f2_def_takedown_PM  f2_def_accentedHits_PM  f2_def_hitsHead_PM  \
# 0                0.04                    1.84                 1.0
#
#    f2_def_hitsBody_PM  f2_def_hitsLegs_PM  \
# 0                0.36                0.48
#
#    f2_def_accentedHitsPositionDistance_PM  \
# 0                                    1.36
#
#    f2_def_accentedHitsPositionClinch_PM  f2_def_accentedHitsPositionParter_PM  \
# 0                                  0.44                                  0.04
#
#    f2_def_knockdowns_PM  f2_def_protectionPassage_PM  f2_odds  f1_age  f2_age  \
# 0                   0.0                          0.0     1.34    30.0    33.0
#
#    weightCategory.id       city               country  is_fight_night  \
# 0                  6  Abu Dhabi  United Arab Emirates            True
#
#         timezone
# 0  Europe/Berlin

# %%
X_df[f1_static_cols] = f1_static_stats
X_df[f2_static_cols] = f2_static_stats
print(X_df.shape)
X_df
# Out:
# (1, 215)
#    f1_cumsum_duration  f1_cumsum_winner  f1_cumsum_hitsTotal  \
# 0               717.0                 1                  105
#
#    f1_cumsum_hitsSuccessful  f1_cumsum_takedownTotal  \
# 0                        60                        3
#
#    f1_cumsum_takedownSuccessful  f1_cumsum_submissionAttempts  \
# 0                             0                             4
#
#    f1_cumsum_takeovers  f1_cumsum_accentedHitsTotal  \
# 0                    0                           76
#
#    f1_cumsum_accentedHitsSuccessful  f1_cumsum_knockdowns  \
# 0                                31                     0
#
#    f1_cumsum_protectionPassage  f1_cumsum_hitsHeadTotal  \
# 0                            0                       63
#
#    f1_cumsum_hitsHeadSuccessful  f1_cumsum_hitsBodyTotal  \
# 0                            22                       11
#
#    f1_cumsum_hitsBodySuccessful  f1_cumsum_hitsLegsTotal  \
# 0                             7                        2
#
#    f1_cumsum_hitsLegsSuccessful  f1_cumsum_accentedHitsPositionDistanceTotal  \
# 0                             2                                           68
#
#    f1_cumsum_accentedHitsPositionDistanceSuccessful  \
# 0                                                27
#
#    f1_cumsum_accentedHitsPositionClinchTotal  \
# 0                                          8
#
#    f1_cumsum_accentedHitsPositionClinchSuccessful  \
# 0                                               4
#
#    f1_cumsum_accentedHitsPositionParterTotal  \
# 0                                          0
#
#    f1_cumsum_accentedHitsPositionParterSuccessful  f1_cumsum_def_hitsTotal  \
# 0                                               0                      166
#
#    f1_cumsum_def_hitsSuccessful  f1_cumsum_def_takedownTotal  \
# 0                            89                            2
#
#    f1_cumsum_def_takedownSuccessful  f1_cumsum_def_submissionAttempts  \
# 0                                 1                                 0
#
#    f1_cumsum_def_takeovers  f1_cumsum_def_accentedHitsTotal  \
# 0                        3                              128
#
#    f1_cumsum_def_accentedHitsSuccessful  f1_cumsum_def_knockdowns  \
# 0                                    61                         0
#
#    f1_cumsum_def_protectionPassage  f1_cumsum_def_hitsHeadTotal  \
# 0                                0                          106
#
#    f1_cumsum_def_hitsHeadSuccessful  f1_cumsum_def_hitsBodyTotal  \
# 0                                44                            4
#
#    f1_cumsum_def_hitsBodySuccessful  f1_cumsum_def_hitsLegsTotal  \
# 0                                 4                           18
#
#    f1_cumsum_def_hitsLegsSuccessful  \
# 0                                13
#
#    f1_cumsum_def_accentedHitsPositionDistanceTotal  \
# 0                                              101
#
#    f1_cumsum_def_accentedHitsPositionDistanceSuccessful  \
# 0                                                 41
#
#    f1_cumsum_def_accentedHitsPositionClinchTotal  \
# 0                                              4
#
#    f1_cumsum_def_accentedHitsPositionClinchSuccessful  \
# 0                                                  3
#
#    f1_cumsum_def_accentedHitsPositionParterTotal  \
# 0                                             23
#
#    f1_cumsum_def_accentedHitsPositionParterSuccessful  \
# 0                                                 17
#
#    f1_cumsum_winMethods_[DEC]  f1_cumsum_winMethods_[DQ]  \
# 0                           1                          0
#
#    f1_cumsum_winMethods_[KO]  f1_cumsum_winMethods_[SUB]  f1_hits_accuracy  \
# 0                          1                           1          0.571429
#
#    f1_takedown_accuracy  f1_accentedHits_accuracy  f1_hitsHead_accuracy  \
# 0                   0.0                  0.407895              0.349206
#
#    f1_hitsBody_accuracy  f1_hitsLegs_accuracy  \
# 0              0.636364                   1.0
#
#    f1_accentedHitsPositionDistance_accuracy  \
# 0                                  0.397059
#
#    f1_accentedHitsPositionClinch_accuracy  \
# 0                                     0.5
#
#    f1_accentedHitsPositionParter_accuracy  f1_DEC_percent  f1_DQ_percent  \
# 0                                     NaN             1.0            0.0
#
#    f1_KO_percent  f1_SUB_percent  f1_hits_PM  f1_takedown_PM  \
# 0            1.0             1.0    5.020921             0.0
#
#    f1_accentedHits_PM  f1_hitsHead_PM  f1_hitsBody_PM  f1_hitsLegs_PM  \
# 0            2.594142        1.841004        0.585774        0.167364
#
#    f1_accentedHitsPositionDistance_PM  f1_accentedHitsPositionClinch_PM  \
# 0                            2.259414                          0.334728
#
#    f1_accentedHitsPositionParter_PM  f1_knockdowns_PM  \
# 0                               0.0               0.0
#
#    f1_protectionPassage_PM  f1_win_streak  f1_loose_streak  \
# 0                      0.0              1                0
#
#    f1_def_hits_accuracy  f1_def_takedown_accuracy  \
# 0              0.536145                       0.5
#
#    f1_def_accentedHits_accuracy  f1_def_hitsHead_accuracy  \
# 0                      0.476562                  0.415094
#
#    f1_def_hitsBody_accuracy  f1_def_hitsLegs_accuracy  \
# 0                       1.0                  0.722222
#
#    f1_def_accentedHitsPositionDistance_accuracy  \
# 0                                      0.405941
#
#    f1_def_accentedHitsPositionClinch_accuracy  \
# 0                                        0.75
#
#    f1_def_accentedHitsPositionParter_accuracy  f1_def_hits_PM  \
# 0                                     0.73913        7.447699
#
#    f1_def_takedown_PM  f1_def_accentedHits_PM  f1_def_hitsHead_PM  \
# 0            0.083682                5.104603            3.682008
#
#    f1_def_hitsBody_PM  f1_def_hitsLegs_PM  \
# 0            0.334728            1.087866
#
#    f1_def_accentedHitsPositionDistance_PM  \
# 0                                3.430962
#
#    f1_def_accentedHitsPositionClinch_PM  f1_def_accentedHitsPositionParter_PM  \
# 0                              0.251046                              1.422594
#
#    f1_def_knockdowns_PM  f1_def_protectionPassage_PM  f1_odds  \
# 0                   0.0                          0.0     3.37
#
#    f2_cumsum_duration  f2_cumsum_winner  f2_cumsum_hitsTotal  \
# 0              1500.0                 4                  176
#
#    f2_cumsum_hitsSuccessful  f2_cumsum_takedownTotal  \
# 0                        97                       15
#
#    f2_cumsum_takedownSuccessful  f2_cumsum_submissionAttempts  \
# 0                             2                             0
#
#    f2_cumsum_takeovers  f2_cumsum_accentedHitsTotal  \
# 0                    5                          132
#
#    f2_cumsum_accentedHitsSuccessful  f2_cumsum_knockdowns  \
# 0                                58                     0
#
#    f2_cumsum_protectionPassage  f2_cumsum_hitsHeadTotal  \
# 0                            0                      111
#
#    f2_cumsum_hitsHeadSuccessful  f2_cumsum_hitsBodyTotal  \
# 0                            40                       18
#
#    f2_cumsum_hitsBodySuccessful  f2_cumsum_hitsLegsTotal  \
# 0                            15                        3
#
#    f2_cumsum_hitsLegsSuccessful  f2_cumsum_accentedHitsPositionDistanceTotal  \
# 0                             3                                          100
#
#    f2_cumsum_accentedHitsPositionDistanceSuccessful  \
# 0                                                35
#
#    f2_cumsum_accentedHitsPositionClinchTotal  \
# 0                                         29
#
#    f2_cumsum_accentedHitsPositionClinchSuccessful  \
# 0                                              21
#
#    f2_cumsum_accentedHitsPositionParterTotal  \
# 0                                          3
#
#    f2_cumsum_accentedHitsPositionParterSuccessful  f2_cumsum_def_hitsTotal  \
# 0                                               2                      210
#
#    f2_cumsum_def_hitsSuccessful  f2_cumsum_def_takedownTotal  \
# 0                            71                            4
#
#    f2_cumsum_def_takedownSuccessful  f2_cumsum_def_submissionAttempts  \
# 0                                 1                                 0
#
#    f2_cumsum_def_takeovers  f2_cumsum_def_accentedHitsTotal  \
# 0                        0                              181
#
#    f2_cumsum_def_accentedHitsSuccessful  f2_cumsum_def_knockdowns  \
# 0                                    46                         0
#
#    f2_cumsum_def_protectionPassage  f2_cumsum_def_hitsHeadTotal  \
# 0                                0                          146
#
#    f2_cumsum_def_hitsHeadSuccessful  f2_cumsum_def_hitsBodyTotal  \
# 0                                25                           16
#
#    f2_cumsum_def_hitsBodySuccessful  f2_cumsum_def_hitsLegsTotal  \
# 0                                 9                           19
#
#    f2_cumsum_def_hitsLegsSuccessful  \
# 0                                12
#
#    f2_cumsum_def_accentedHitsPositionDistanceTotal  \
# 0                                              162
#
#    f2_cumsum_def_accentedHitsPositionDistanceSuccessful  \
# 0                                                 34
#
#    f2_cumsum_def_accentedHitsPositionClinchTotal  \
# 0                                             17
#
#    f2_cumsum_def_accentedHitsPositionClinchSuccessful  \
# 0                                                 11
#
#    f2_cumsum_def_accentedHitsPositionParterTotal  \
# 0                                              2
#
#    f2_cumsum_def_accentedHitsPositionParterSuccessful  \
# 0                                                  1
#
#    f2_cumsum_winMethods_[DEC]  f2_cumsum_winMethods_[DQ]  \
# 0                           5                          0
#
#    f2_cumsum_winMethods_[KO]  f2_cumsum_winMethods_[SUB]  f2_hits_accuracy  \
# 0                          0                           0          0.551136
#
#    f2_takedown_accuracy  f2_accentedHits_accuracy  f2_hitsHead_accuracy  \
# 0              0.133333                  0.439394               0.36036
#
#    f2_hitsBody_accuracy  f2_hitsLegs_accuracy  \
# 0              0.833333                   1.0
#
#    f2_accentedHitsPositionDistance_accuracy  \
# 0                                      0.35
#
#    f2_accentedHitsPositionClinch_accuracy  \
# 0                                0.724138
#
#    f2_accentedHitsPositionParter_accuracy  f2_DEC_percent  f2_DQ_percent  \
# 0                                0.666667            1.25            0.0
#
#    f2_KO_percent  f2_SUB_percent  f2_hits_PM  f2_takedown_PM  \
# 0            0.0             0.0        3.88            0.08
#
#    f2_accentedHits_PM  f2_hitsHead_PM  f2_hitsBody_PM  f2_hitsLegs_PM  \
# 0                2.32             1.6             0.6            0.12
#
#    f2_accentedHitsPositionDistance_PM  f2_accentedHitsPositionClinch_PM  \
# 0                                 1.4                              0.84
#
#    f2_accentedHitsPositionParter_PM  f2_knockdowns_PM  \
# 0                              0.08               0.0
#
#    f2_protectionPassage_PM  f2_win_streak  f2_loose_streak  \
# 0                      0.0              1                0
#
#    f2_def_hits_accuracy  f2_def_takedown_accuracy  \
# 0              0.338095                      0.25
#
#    f2_def_accentedHits_accuracy  f2_def_hitsHead_accuracy  \
# 0                      0.254144                  0.171233
#
#    f2_def_hitsBody_accuracy  f2_def_hitsLegs_accuracy  \
# 0                    0.5625                  0.631579
#
#    f2_def_accentedHitsPositionDistance_accuracy  \
# 0                                      0.209877
#
#    f2_def_accentedHitsPositionClinch_accuracy  \
# 0                                    0.647059
#
#    f2_def_accentedHitsPositionParter_accuracy  f2_def_hits_PM  \
# 0                                         0.5            2.84
#
#    f2_def_takedown_PM  f2_def_accentedHits_PM  f2_def_hitsHead_PM  \
# 0                0.04                    1.84                 1.0
#
#    f2_def_hitsBody_PM  f2_def_hitsLegs_PM  \
# 0                0.36                0.48
#
#    f2_def_accentedHitsPositionDistance_PM  \
# 0                                    1.36
#
#    f2_def_accentedHitsPositionClinch_PM  f2_def_accentedHitsPositionParter_PM  \
# 0                                  0.44                                  0.04
#
#    f2_def_knockdowns_PM  f2_def_protectionPassage_PM  f2_odds  f1_age  f2_age  \
# 0                   0.0                          0.0     1.34    30.0    33.0
#
#    weightCategory.id       city               country  is_fight_night  \
# 0                  6  Abu Dhabi  United Arab Emirates            True
#
#         timezone f1_country  f1_city  f1_armSpan  f1_height  f1_legSwing  \
# 0  Europe/Berlin    Germany  unknown       190.5     182.88          NaN
#
#      f1_timezone  f1_weight  f2_country  f2_city  f2_armSpan  f2_height  \
# 0  Europe/Berlin      77.11  Azerbaijan  unknown      193.04      177.8
#
#    f2_legSwing f2_timezone  f2_weight
# 0       106.68   Asia/Baku      77.11

# %%
binary_fighter_cols = []
for prefix in ["f1_", "f2_"]:
    for key in ["isHomeCity", "isHomeCountry", "isHomeTimezone"]:
        binary_fighter_cols.append(prefix + key)

binary_stats = []
binary_cols = ['city', 'country', 'timezone']
for prefix in ["f1_", "f2_"]:
    for col in binary_cols:
        binary_stats.append(int(X_df.loc[0, prefix + col] == X_df.loc[0, col]))

X_df[binary_fighter_cols] = binary_stats
print(X_df.shape)
X_df[binary_fighter_cols]
# Out:
# (1, 221)
#    f1_isHomeCity  f1_isHomeCountry  f1_isHomeTimezone  f2_isHomeCity  \
# 0              0                 0                  1              0
#
#    f2_isHomeCountry  f2_isHomeTimezone
# 0                 0                  0

# %%
X_df[f1_cat_cols + f2_cat_cols] = X_df[f1_cat_cols + f2_cat_cols].fillna('unknown')
X_df[f1_cat_cols + f2_cat_cols]
# Out:
#   f1_country  f1_city    f1_timezone  f2_country  f2_city f2_timezone
# 0    Germany  unknown  Europe/Berlin  Azerbaijan  unknown   Asia/Baku

# %%
# Difference
diff_cols = []
fighter1_stat_cols = generated_features['fighter1_stats']
for col in fighter1_stat_cols:
    new_col_name = col[3:] + '_difference'
    diff_cols.append(new_col_name)
    X_df[new_col_name] = X_df['f1_' + col[3:]].astype(float) - X_df['f2_' + col[3:]].astype(float)
X_df[diff_cols]
# Out:
#    cumsum_duration_difference  cumsum_winner_difference  \
# 0                      -783.0                      -3.0
#
#    cumsum_hitsTotal_difference  cumsum_hitsSuccessful_difference  \
# 0                        -71.0                             -37.0
#
#    cumsum_takedownTotal_difference  cumsum_takedownSuccessful_difference  \
# 0                            -12.0                                  -2.0
#
#    cumsum_submissionAttempts_difference  cumsum_takeovers_difference  \
# 0                                   4.0                         -5.0
#
#    cumsum_accentedHitsTotal_difference  \
# 0                                -56.0
#
#    cumsum_accentedHitsSuccessful_difference  cumsum_knockdowns_difference  \
# 0                                     -27.0                           0.0
#
#    cumsum_protectionPassage_difference  cumsum_hitsHeadTotal_difference  \
# 0                                  0.0                            -48.0
#
#    cumsum_hitsHeadSuccessful_difference  cumsum_hitsBodyTotal_difference  \
# 0                                 -18.0                             -7.0
#
#    cumsum_hitsBodySuccessful_difference  cumsum_hitsLegsTotal_difference  \
# 0                                  -8.0                             -1.0
#
#    cumsum_hitsLegsSuccessful_difference  \
# 0                                  -1.0
#
#    cumsum_accentedHitsPositionDistanceTotal_difference  \
# 0                                              -32.0
#
#    cumsum_accentedHitsPositionDistanceSuccessful_difference  \
# 0                                               -8.0
#
#    cumsum_accentedHitsPositionClinchTotal_difference  \
# 0                                              -21.0
#
#    cumsum_accentedHitsPositionClinchSuccessful_difference  \
# 0                                              -17.0
#
#    cumsum_accentedHitsPositionParterTotal_difference  \
# 0                                               -3.0
#
#    cumsum_accentedHitsPositionParterSuccessful_difference  \
# 0                                               -2.0
#
#    cumsum_def_hitsTotal_difference  cumsum_def_hitsSuccessful_difference  \
# 0                            -44.0                                  18.0
#
#    cumsum_def_takedownTotal_difference  \
# 0                                 -2.0
#
#    cumsum_def_takedownSuccessful_difference  \
# 0                                       0.0
#
#    cumsum_def_submissionAttempts_difference  cumsum_def_takeovers_difference  \
# 0                                       0.0                              3.0
#
#    cumsum_def_accentedHitsTotal_difference  \
# 0                                    -53.0
#
#    cumsum_def_accentedHitsSuccessful_difference  \
# 0                                          15.0
#
#    cumsum_def_knockdowns_difference  cumsum_def_protectionPassage_difference  \
# 0                               0.0                                      0.0
#
#    cumsum_def_hitsHeadTotal_difference  \
# 0                                -40.0
#
#    cumsum_def_hitsHeadSuccessful_difference  \
# 0                                      19.0
#
#    cumsum_def_hitsBodyTotal_difference  \
# 0                                -12.0
#
#    cumsum_def_hitsBodySuccessful_difference  \
# 0                                      -5.0
#
#    cumsum_def_hitsLegsTotal_difference  \
# 0                                 -1.0
#
#    cumsum_def_hitsLegsSuccessful_difference  \
# 0                                       1.0
#
#    cumsum_def_accentedHitsPositionDistanceTotal_difference  \
# 0                                              -61.0
#
#    cumsum_def_accentedHitsPositionDistanceSuccessful_difference  \
# 0                                                7.0
#
#    cumsum_def_accentedHitsPositionClinchTotal_difference  \
# 0                                              -13.0
#
#    cumsum_def_accentedHitsPositionClinchSuccessful_difference  \
# 0                                               -8.0
#
#    cumsum_def_accentedHitsPositionParterTotal_difference  \
# 0                                               21.0
#
#    cumsum_def_accentedHitsPositionParterSuccessful_difference  \
# 0                                               16.0
#
#    cumsum_winMethods_[DEC]_difference  cumsum_winMethods_[DQ]_difference  \
# 0                                -4.0                                0.0
#
#    cumsum_winMethods_[KO]_difference  cumsum_winMethods_[SUB]_difference  \
# 0                                1.0                                 1.0
#
#    hits_accuracy_difference  takedown_accuracy_difference  \
# 0                  0.020292                     -0.133333
#
#    accentedHits_accuracy_difference  hitsHead_accuracy_difference  \
# 0                         -0.031499                     -0.011154
#
#    hitsBody_accuracy_difference  hitsLegs_accuracy_difference  \
# 0                      -0.19697                           0.0
#
#    accentedHitsPositionDistance_accuracy_difference  \
# 0                                          0.047059
#
#    accentedHitsPositionClinch_accuracy_difference  \
# 0                                       -0.224138
#
#    accentedHitsPositionParter_accuracy_difference  DEC_percent_difference  \
# 0                                             NaN                   -0.25
#
#    DQ_percent_difference  KO_percent_difference  SUB_percent_difference  \
# 0                    0.0                    1.0                     1.0
#
#    hits_PM_difference  takedown_PM_difference  accentedHits_PM_difference  \
# 0            1.140921                   -0.08                    0.274142
#
#    hitsHead_PM_difference  hitsBody_PM_difference  hitsLegs_PM_difference  \
# 0                0.241004               -0.014226                0.047364
#
#    accentedHitsPositionDistance_PM_difference  \
# 0                                    0.859414
#
#    accentedHitsPositionClinch_PM_difference  \
# 0                                 -0.505272
#
#    accentedHitsPositionParter_PM_difference  knockdowns_PM_difference  \
# 0                                     -0.08                       0.0
#
#    protectionPassage_PM_difference  win_streak_difference  \
# 0                              0.0                    0.0
#
#    loose_streak_difference  def_hits_accuracy_difference  \
# 0                      0.0                      0.198049
#
#    def_takedown_accuracy_difference  def_accentedHits_accuracy_difference  \
# 0                              0.25                              0.222419
#
#    def_hitsHead_accuracy_difference  def_hitsBody_accuracy_difference  \
# 0                          0.243861                            0.4375
#
#    def_hitsLegs_accuracy_difference  \
# 0                          0.090643
#
#    def_accentedHitsPositionDistance_accuracy_difference  \
# 0                                           0.196064
#
#    def_accentedHitsPositionClinch_accuracy_difference  \
# 0                                           0.102941
#
#    def_accentedHitsPositionParter_accuracy_difference  def_hits_PM_difference  \
# 0                                            0.23913                 4.607699
#
#    def_takedown_PM_difference  def_accentedHits_PM_difference  \
# 0                    0.043682                        3.264603
#
#    def_hitsHead_PM_difference  def_hitsBody_PM_difference  \
# 0                    2.682008                   -0.025272
#
#    def_hitsLegs_PM_difference  def_accentedHitsPositionDistance_PM_difference  \
# 0                    0.607866                                        2.070962
#
#    def_accentedHitsPositionClinch_PM_difference  \
# 0                                     -0.188954
#
#    def_accentedHitsPositionParter_PM_difference  def_knockdowns_PM_difference  \
# 0                                      1.382594                           0.0
#
#    def_protectionPassage_PM_difference  odds_difference  age_difference  \
# 0                                  0.0             2.03            -3.0
#
#    height_difference  weight_difference  armSpan_difference  \
# 0               5.08                0.0               -2.54
#
#    legSwing_difference  isHomeCity_difference  isHomeCountry_difference  \
# 0                  NaN                    0.0                       0.0
#
#    isHomeTimezone_difference
# 0                        1.0

# %%
X_df_reversed = X_df.copy()

reversed_cols = []
for col in X_df.columns:
    if 'f2' in col:
        new_col_name = col.replace('f2', 'f1')
    elif 'f1' in col:
        new_col_name = col.replace('f1', 'f2')
    else:
        new_col_name = col
    reversed_cols.append(new_col_name)
X_df_reversed.columns = reversed_cols
X_df_reversed
# Out:
#    f2_cumsum_duration  f2_cumsum_winner  f2_cumsum_hitsTotal  \
# 0               717.0                 1                  105
#
#    f2_cumsum_hitsSuccessful  f2_cumsum_takedownTotal  \
# 0                        60                        3
#
#    f2_cumsum_takedownSuccessful  f2_cumsum_submissionAttempts  \
# 0                             0                             4
#
#    f2_cumsum_takeovers  f2_cumsum_accentedHitsTotal  \
# 0                    0                           76
#
#    f2_cumsum_accentedHitsSuccessful  f2_cumsum_knockdowns  \
# 0                                31                     0
#
#    f2_cumsum_protectionPassage  f2_cumsum_hitsHeadTotal  \
# 0                            0                       63
#
#    f2_cumsum_hitsHeadSuccessful  f2_cumsum_hitsBodyTotal  \
# 0                            22                       11
#
#    f2_cumsum_hitsBodySuccessful  f2_cumsum_hitsLegsTotal  \
# 0                             7                        2
#
#    f2_cumsum_hitsLegsSuccessful  f2_cumsum_accentedHitsPositionDistanceTotal  \
# 0                             2                                           68
#
#    f2_cumsum_accentedHitsPositionDistanceSuccessful  \
# 0                                                27
#
#    f2_cumsum_accentedHitsPositionClinchTotal  \
# 0                                          8
#
#    f2_cumsum_accentedHitsPositionClinchSuccessful  \
# 0                                               4
#
#    f2_cumsum_accentedHitsPositionParterTotal  \
# 0                                          0
#
#    f2_cumsum_accentedHitsPositionParterSuccessful  f2_cumsum_def_hitsTotal  \
# 0                                               0                      166
#
#    f2_cumsum_def_hitsSuccessful  f2_cumsum_def_takedownTotal  \
# 0                            89                            2
#
#    f2_cumsum_def_takedownSuccessful  f2_cumsum_def_submissionAttempts  \
# 0                                 1                                 0
#
#    f2_cumsum_def_takeovers  f2_cumsum_def_accentedHitsTotal  \
# 0                        3                              128
#
#    f2_cumsum_def_accentedHitsSuccessful  f2_cumsum_def_knockdowns  \
# 0                                    61                         0
#
#    f2_cumsum_def_protectionPassage  f2_cumsum_def_hitsHeadTotal  \
# 0                                0                          106
#
#    f2_cumsum_def_hitsHeadSuccessful  f2_cumsum_def_hitsBodyTotal  \
# 0                                44                            4
#
#    f2_cumsum_def_hitsBodySuccessful  f2_cumsum_def_hitsLegsTotal  \
# 0                                 4                           18
#
#    f2_cumsum_def_hitsLegsSuccessful  \
# 0                                13
#
#    f2_cumsum_def_accentedHitsPositionDistanceTotal  \
# 0                                              101
#
#    f2_cumsum_def_accentedHitsPositionDistanceSuccessful  \
# 0                                                 41
#
#    f2_cumsum_def_accentedHitsPositionClinchTotal  \
# 0                                              4
#
#    f2_cumsum_def_accentedHitsPositionClinchSuccessful  \
# 0                                                  3
#
#    f2_cumsum_def_accentedHitsPositionParterTotal  \
# 0                                             23
#
#    f2_cumsum_def_accentedHitsPositionParterSuccessful  \
# 0                                                 17
#
#    f2_cumsum_winMethods_[DEC]  f2_cumsum_winMethods_[DQ]  \
# 0                           1                          0
#
#    f2_cumsum_winMethods_[KO]  f2_cumsum_winMethods_[SUB]  f2_hits_accuracy  \
# 0                          1                           1          0.571429
#
#    f2_takedown_accuracy  f2_accentedHits_accuracy  f2_hitsHead_accuracy  \
# 0                   0.0                  0.407895              0.349206
#
#    f2_hitsBody_accuracy  f2_hitsLegs_accuracy  \
# 0              0.636364                   1.0
#
#    f2_accentedHitsPositionDistance_accuracy  \
# 0                                  0.397059
#
#    f2_accentedHitsPositionClinch_accuracy  \
# 0                                     0.5
#
#    f2_accentedHitsPositionParter_accuracy  f2_DEC_percent  f2_DQ_percent  \
# 0                                     NaN             1.0            0.0
#
#    f2_KO_percent  f2_SUB_percent  f2_hits_PM  f2_takedown_PM  \
# 0            1.0             1.0    5.020921             0.0
#
#    f2_accentedHits_PM  f2_hitsHead_PM  f2_hitsBody_PM  f2_hitsLegs_PM  \
# 0            2.594142        1.841004        0.585774        0.167364
#
#    f2_accentedHitsPositionDistance_PM  f2_accentedHitsPositionClinch_PM  \
# 0                            2.259414                          0.334728
#
#    f2_accentedHitsPositionParter_PM  f2_knockdowns_PM  \
# 0                               0.0               0.0
#
#    f2_protectionPassage_PM  f2_win_streak  f2_loose_streak  \
# 0                      0.0              1                0
#
#    f2_def_hits_accuracy  f2_def_takedown_accuracy  \
# 0              0.536145                       0.5
#
#    f2_def_accentedHits_accuracy  f2_def_hitsHead_accuracy  \
# 0                      0.476562                  0.415094
#
#    f2_def_hitsBody_accuracy  f2_def_hitsLegs_accuracy  \
# 0                       1.0                  0.722222
#
#    f2_def_accentedHitsPositionDistance_accuracy  \
# 0                                      0.405941
#
#    f2_def_accentedHitsPositionClinch_accuracy  \
# 0                                        0.75
#
#    f2_def_accentedHitsPositionParter_accuracy  f2_def_hits_PM  \
# 0                                     0.73913        7.447699
#
#    f2_def_takedown_PM  f2_def_accentedHits_PM  f2_def_hitsHead_PM  \
# 0            0.083682                5.104603            3.682008
#
#    f2_def_hitsBody_PM  f2_def_hitsLegs_PM  \
# 0            0.334728            1.087866
#
#    f2_def_accentedHitsPositionDistance_PM  \
# 0                                3.430962
#
#    f2_def_accentedHitsPositionClinch_PM  f2_def_accentedHitsPositionParter_PM  \
# 0                              0.251046                              1.422594
#
#    f2_def_knockdowns_PM  f2_def_protectionPassage_PM  f2_odds  \
# 0                   0.0                          0.0     3.37
#
#    f1_cumsum_duration  f1_cumsum_winner  f1_cumsum_hitsTotal  \
# 0              1500.0                 4                  176
#
#    f1_cumsum_hitsSuccessful  f1_cumsum_takedownTotal  \
# 0                        97                       15
#
#    f1_cumsum_takedownSuccessful  f1_cumsum_submissionAttempts  \
# 0                             2                             0
#
#    f1_cumsum_takeovers  f1_cumsum_accentedHitsTotal  \
# 0                    5                          132
#
#    f1_cumsum_accentedHitsSuccessful  f1_cumsum_knockdowns  \
# 0                                58                     0
#
#    f1_cumsum_protectionPassage  f1_cumsum_hitsHeadTotal  \
# 0                            0                      111
#
#    f1_cumsum_hitsHeadSuccessful  f1_cumsum_hitsBodyTotal  \
# 0                            40                       18
#
#    f1_cumsum_hitsBodySuccessful  f1_cumsum_hitsLegsTotal  \
# 0                            15                        3
#
#    f1_cumsum_hitsLegsSuccessful  f1_cumsum_accentedHitsPositionDistanceTotal  \
# 0                             3                                          100
#
#    f1_cumsum_accentedHitsPositionDistanceSuccessful  \
# 0                                                35
#
#    f1_cumsum_accentedHitsPositionClinchTotal  \
# 0                                         29
#
#    f1_cumsum_accentedHitsPositionClinchSuccessful  \
# 0                                              21
#
#    f1_cumsum_accentedHitsPositionParterTotal  \
# 0                                          3
#
#    f1_cumsum_accentedHitsPositionParterSuccessful  f1_cumsum_def_hitsTotal  \
# 0                                               2                      210
#
#    f1_cumsum_def_hitsSuccessful  f1_cumsum_def_takedownTotal  \
# 0                            71                            4
#
#    f1_cumsum_def_takedownSuccessful  f1_cumsum_def_submissionAttempts  \
# 0                                 1                                 0
#
#    f1_cumsum_def_takeovers  f1_cumsum_def_accentedHitsTotal  \
# 0                        0                              181
#
#    f1_cumsum_def_accentedHitsSuccessful  f1_cumsum_def_knockdowns  \
# 0                                    46                         0
#
#    f1_cumsum_def_protectionPassage  f1_cumsum_def_hitsHeadTotal  \
# 0                                0                          146
#
#    f1_cumsum_def_hitsHeadSuccessful  f1_cumsum_def_hitsBodyTotal  \
# 0                                25                           16
#
#    f1_cumsum_def_hitsBodySuccessful  f1_cumsum_def_hitsLegsTotal  \
# 0                                 9                           19
#
#    f1_cumsum_def_hitsLegsSuccessful  \
# 0                                12
#
#    f1_cumsum_def_accentedHitsPositionDistanceTotal  \
# 0                                              162
#
#    f1_cumsum_def_accentedHitsPositionDistanceSuccessful  \
# 0                                                 34
#
#    f1_cumsum_def_accentedHitsPositionClinchTotal  \
# 0                                             17
#
#    f1_cumsum_def_accentedHitsPositionClinchSuccessful  \
# 0                                                 11
#
#    f1_cumsum_def_accentedHitsPositionParterTotal  \
# 0                                              2
#
#    f1_cumsum_def_accentedHitsPositionParterSuccessful  \
# 0                                                  1
#
#    f1_cumsum_winMethods_[DEC]  f1_cumsum_winMethods_[DQ]  \
# 0                           5                          0
#
#    f1_cumsum_winMethods_[KO]  f1_cumsum_winMethods_[SUB]  f1_hits_accuracy  \
# 0                          0                           0          0.551136
#
#    f1_takedown_accuracy  f1_accentedHits_accuracy  f1_hitsHead_accuracy  \
# 0              0.133333                  0.439394               0.36036
#
#    f1_hitsBody_accuracy  f1_hitsLegs_accuracy  \
# 0              0.833333                   1.0
#
#    f1_accentedHitsPositionDistance_accuracy  \
# 0                                      0.35
#
#    f1_accentedHitsPositionClinch_accuracy  \
# 0                                0.724138
#
#    f1_accentedHitsPositionParter_accuracy  f1_DEC_percent  f1_DQ_percent  \
# 0                                0.666667            1.25            0.0
#
#    f1_KO_percent  f1_SUB_percent  f1_hits_PM  f1_takedown_PM  \
# 0            0.0             0.0        3.88            0.08
#
#    f1_accentedHits_PM  f1_hitsHead_PM  f1_hitsBody_PM  f1_hitsLegs_PM  \
# 0                2.32             1.6             0.6            0.12
#
#    f1_accentedHitsPositionDistance_PM  f1_accentedHitsPositionClinch_PM  \
# 0                                 1.4                              0.84
#
#    f1_accentedHitsPositionParter_PM  f1_knockdowns_PM  \
# 0                              0.08               0.0
#
#    f1_protectionPassage_PM  f1_win_streak  f1_loose_streak  \
# 0                      0.0              1                0
#
#    f1_def_hits_accuracy  f1_def_takedown_accuracy  \
# 0              0.338095                      0.25
#
#    f1_def_accentedHits_accuracy  f1_def_hitsHead_accuracy  \
# 0                      0.254144                  0.171233
#
#    f1_def_hitsBody_accuracy  f1_def_hitsLegs_accuracy  \
# 0                    0.5625                  0.631579
#
#    f1_def_accentedHitsPositionDistance_accuracy  \
# 0                                      0.209877
#
#    f1_def_accentedHitsPositionClinch_accuracy  \
# 0                                    0.647059
#
#    f1_def_accentedHitsPositionParter_accuracy  f1_def_hits_PM  \
# 0                                         0.5            2.84
#
#    f1_def_takedown_PM  f1_def_accentedHits_PM  f1_def_hitsHead_PM  \
# 0                0.04                    1.84                 1.0
#
#    f1_def_hitsBody_PM  f1_def_hitsLegs_PM  \
# 0                0.36                0.48
#
#    f1_def_accentedHitsPositionDistance_PM  \
# 0                                    1.36
#
#    f1_def_accentedHitsPositionClinch_PM  f1_def_accentedHitsPositionParter_PM  \
# 0                                  0.44                                  0.04
#
#    f1_def_knockdowns_PM  f1_def_protectionPassage_PM  f1_odds  f2_age  f1_age  \
# 0                   0.0                          0.0     1.34    30.0    33.0
#
#    weightCategory.id       city               country  is_fight_night  \
# 0                  6  Abu Dhabi  United Arab Emirates            True
#
#         timezone f2_country  f2_city  f2_armSpan  f2_height  f2_legSwing  \
# 0  Europe/Berlin    Germany  unknown       190.5     182.88          NaN
#
#      f2_timezone  f2_weight  f1_country  f1_city  f1_armSpan  f1_height  \
# 0  Europe/Berlin      77.11  Azerbaijan  unknown      193.04      177.8
#
#    f1_legSwing f1_timezone  f1_weight  f2_isHomeCity  f2_isHomeCountry  \
# 0       106.68   Asia/Baku      77.11              0                 0
#
#    f2_isHomeTimezone  f1_isHomeCity  f1_isHomeCountry  f1_isHomeTimezone  \
# 0                  1              0                 0                  0
#
#    cumsum_duration_difference  cumsum_winner_difference  \
# 0                      -783.0                      -3.0
#
#    cumsum_hitsTotal_difference  cumsum_hitsSuccessful_difference  \
# 0                        -71.0                             -37.0
#
#    cumsum_takedownTotal_difference  cumsum_takedownSuccessful_difference  \
# 0                            -12.0                                  -2.0
#
#    cumsum_submissionAttempts_difference  cumsum_takeovers_difference  \
# 0                                   4.0                         -5.0
#
#    cumsum_accentedHitsTotal_difference  \
# 0                                -56.0
#
#    cumsum_accentedHitsSuccessful_difference  cumsum_knockdowns_difference  \
# 0                                     -27.0                           0.0
#
#    cumsum_protectionPassage_difference  cumsum_hitsHeadTotal_difference  \
# 0                                  0.0                            -48.0
#
#    cumsum_hitsHeadSuccessful_difference  cumsum_hitsBodyTotal_difference  \
# 0                                 -18.0                             -7.0
#
#    cumsum_hitsBodySuccessful_difference  cumsum_hitsLegsTotal_difference  \
# 0                                  -8.0                             -1.0
#
#    cumsum_hitsLegsSuccessful_difference  \
# 0                                  -1.0
#
#    cumsum_accentedHitsPositionDistanceTotal_difference  \
# 0                                              -32.0
#
#    cumsum_accentedHitsPositionDistanceSuccessful_difference  \
# 0                                               -8.0
#
#    cumsum_accentedHitsPositionClinchTotal_difference  \
# 0                                              -21.0
#
#    cumsum_accentedHitsPositionClinchSuccessful_difference  \
# 0                                              -17.0
#
#    cumsum_accentedHitsPositionParterTotal_difference  \
# 0                                               -3.0
#
#    cumsum_accentedHitsPositionParterSuccessful_difference  \
# 0                                               -2.0
#
#    cumsum_def_hitsTotal_difference  cumsum_def_hitsSuccessful_difference  \
# 0                            -44.0                                  18.0
#
#    cumsum_def_takedownTotal_difference  \
# 0                                 -2.0
#
#    cumsum_def_takedownSuccessful_difference  \
# 0                                       0.0
#
#    cumsum_def_submissionAttempts_difference  cumsum_def_takeovers_difference  \
# 0                                       0.0                              3.0
#
#    cumsum_def_accentedHitsTotal_difference  \
# 0                                    -53.0
#
#    cumsum_def_accentedHitsSuccessful_difference  \
# 0                                          15.0
#
#    cumsum_def_knockdowns_difference  cumsum_def_protectionPassage_difference  \
# 0                               0.0                                      0.0
#
#    cumsum_def_hitsHeadTotal_difference  \
# 0                                -40.0
#
#    cumsum_def_hitsHeadSuccessful_difference  \
# 0                                      19.0
#
#    cumsum_def_hitsBodyTotal_difference  \
# 0                                -12.0
#
#    cumsum_def_hitsBodySuccessful_difference  \
# 0                                      -5.0
#
#    cumsum_def_hitsLegsTotal_difference  \
# 0                                 -1.0
#
#    cumsum_def_hitsLegsSuccessful_difference  \
# 0                                       1.0
#
#    cumsum_def_accentedHitsPositionDistanceTotal_difference  \
# 0                                              -61.0
#
#    cumsum_def_accentedHitsPositionDistanceSuccessful_difference  \
# 0                                                7.0
#
#    cumsum_def_accentedHitsPositionClinchTotal_difference  \
# 0                                              -13.0
#
#    cumsum_def_accentedHitsPositionClinchSuccessful_difference  \
# 0                                               -8.0
#
#    cumsum_def_accentedHitsPositionParterTotal_difference  \
# 0                                               21.0
#
#    cumsum_def_accentedHitsPositionParterSuccessful_difference  \
# 0                                               16.0
#
#    cumsum_winMethods_[DEC]_difference  cumsum_winMethods_[DQ]_difference  \
# 0                                -4.0                                0.0
#
#    cumsum_winMethods_[KO]_difference  cumsum_winMethods_[SUB]_difference  \
# 0                                1.0                                 1.0
#
#    hits_accuracy_difference  takedown_accuracy_difference  \
# 0                  0.020292                     -0.133333
#
#    accentedHits_accuracy_difference  hitsHead_accuracy_difference  \
# 0                         -0.031499                     -0.011154
#
#    hitsBody_accuracy_difference  hitsLegs_accuracy_difference  \
# 0                      -0.19697                           0.0
#
#    accentedHitsPositionDistance_accuracy_difference  \
# 0                                          0.047059
#
#    accentedHitsPositionClinch_accuracy_difference  \
# 0                                       -0.224138
#
#    accentedHitsPositionParter_accuracy_difference  DEC_percent_difference  \
# 0                                             NaN                   -0.25
#
#    DQ_percent_difference  KO_percent_difference  SUB_percent_difference  \
# 0                    0.0                    1.0                     1.0
#
#    hits_PM_difference  takedown_PM_difference  accentedHits_PM_difference  \
# 0            1.140921                   -0.08                    0.274142
#
#    hitsHead_PM_difference  hitsBody_PM_difference  hitsLegs_PM_difference  \
# 0                0.241004               -0.014226                0.047364
#
#    accentedHitsPositionDistance_PM_difference  \
# 0                                    0.859414
#
#    accentedHitsPositionClinch_PM_difference  \
# 0                                 -0.505272
#
#    accentedHitsPositionParter_PM_difference  knockdowns_PM_difference  \
# 0                                     -0.08                       0.0
#
#    protectionPassage_PM_difference  win_streak_difference  \
# 0                              0.0                    0.0
#
#    loose_streak_difference  def_hits_accuracy_difference  \
# 0                      0.0                      0.198049
#
#    def_takedown_accuracy_difference  def_accentedHits_accuracy_difference  \
# 0                              0.25                              0.222419
#
#    def_hitsHead_accuracy_difference  def_hitsBody_accuracy_difference  \
# 0                          0.243861                            0.4375
#
#    def_hitsLegs_accuracy_difference  \
# 0                          0.090643
#
#    def_accentedHitsPositionDistance_accuracy_difference  \
# 0                                           0.196064
#
#    def_accentedHitsPositionClinch_accuracy_difference  \
# 0                                           0.102941
#
#    def_accentedHitsPositionParter_accuracy_difference  def_hits_PM_difference  \
# 0                                            0.23913                 4.607699
#
#    def_takedown_PM_difference  def_accentedHits_PM_difference  \
# 0                    0.043682                        3.264603
#
#    def_hitsHead_PM_difference  def_hitsBody_PM_difference  \
# 0                    2.682008                   -0.025272
#
#    def_hitsLegs_PM_difference  def_accentedHitsPositionDistance_PM_difference  \
# 0                    0.607866                                        2.070962
#
#    def_accentedHitsPositionClinch_PM_difference  \
# 0                                     -0.188954
#
#    def_accentedHitsPositionParter_PM_difference  def_knockdowns_PM_difference  \
# 0                                      1.382594                           0.0
#
#    def_protectionPassage_PM_difference  odds_difference  age_difference  \
# 0                                  0.0             2.03            -3.0
#
#    height_difference  weight_difference  armSpan_difference  \
# 0               5.08                0.0               -2.54
#
#    legSwing_difference  isHomeCity_difference  isHomeCountry_difference  \
# 0                  NaN                    0.0                       0.0
#
#    isHomeTimezone_difference
# 0                        1.0

# %%
diff_cols = []
for col in fighter1_stat_cols:
    new_col_name = col[3:] + '_difference'
    diff_cols.append(new_col_name)
    X_df_reversed[new_col_name] = X_df_reversed['f1_' + col[3:]].astype(float) - \
        X_df_reversed['f2_' + col[3:]].astype(float)
X_df_reversed[diff_cols]
# Out:
#    cumsum_duration_difference  cumsum_winner_difference  \
# 0                       783.0                       3.0
#
#    cumsum_hitsTotal_difference  cumsum_hitsSuccessful_difference  \
# 0                         71.0                              37.0
#
#    cumsum_takedownTotal_difference  cumsum_takedownSuccessful_difference  \
# 0                             12.0                                   2.0
#
#    cumsum_submissionAttempts_difference  cumsum_takeovers_difference  \
# 0                                  -4.0                          5.0
#
#    cumsum_accentedHitsTotal_difference  \
# 0                                 56.0
#
#    cumsum_accentedHitsSuccessful_difference  cumsum_knockdowns_difference  \
# 0                                      27.0                           0.0
#
#    cumsum_protectionPassage_difference  cumsum_hitsHeadTotal_difference  \
# 0                                  0.0                             48.0
#
#    cumsum_hitsHeadSuccessful_difference  cumsum_hitsBodyTotal_difference  \
# 0                                  18.0                              7.0
#
#    cumsum_hitsBodySuccessful_difference  cumsum_hitsLegsTotal_difference  \
# 0                                   8.0                              1.0
#
#    cumsum_hitsLegsSuccessful_difference  \
# 0                                   1.0
#
#    cumsum_accentedHitsPositionDistanceTotal_difference  \
# 0                                               32.0
#
#    cumsum_accentedHitsPositionDistanceSuccessful_difference  \
# 0                                                8.0
#
#    cumsum_accentedHitsPositionClinchTotal_difference  \
# 0                                               21.0
#
#    cumsum_accentedHitsPositionClinchSuccessful_difference  \
# 0                                               17.0
#
#    cumsum_accentedHitsPositionParterTotal_difference  \
# 0                                                3.0
#
#    cumsum_accentedHitsPositionParterSuccessful_difference  \
# 0                                                2.0
#
#    cumsum_def_hitsTotal_difference  cumsum_def_hitsSuccessful_difference  \
# 0                             44.0                                 -18.0
#
#    cumsum_def_takedownTotal_difference  \
# 0                                  2.0
#
#    cumsum_def_takedownSuccessful_difference  \
# 0                                       0.0
#
#    cumsum_def_submissionAttempts_difference  cumsum_def_takeovers_difference  \
# 0                                       0.0                             -3.0
#
#    cumsum_def_accentedHitsTotal_difference  \
# 0                                     53.0
#
#    cumsum_def_accentedHitsSuccessful_difference  \
# 0                                         -15.0
#
#    cumsum_def_knockdowns_difference  cumsum_def_protectionPassage_difference  \
# 0                               0.0                                      0.0
#
#    cumsum_def_hitsHeadTotal_difference  \
# 0                                 40.0
#
#    cumsum_def_hitsHeadSuccessful_difference  \
# 0                                     -19.0
#
#    cumsum_def_hitsBodyTotal_difference  \
# 0                                 12.0
#
#    cumsum_def_hitsBodySuccessful_difference  \
# 0                                       5.0
#
#    cumsum_def_hitsLegsTotal_difference  \
# 0                                  1.0
#
#    cumsum_def_hitsLegsSuccessful_difference  \
# 0                                      -1.0
#
#    cumsum_def_accentedHitsPositionDistanceTotal_difference  \
# 0                                               61.0
#
#    cumsum_def_accentedHitsPositionDistanceSuccessful_difference  \
# 0                                               -7.0
#
#    cumsum_def_accentedHitsPositionClinchTotal_difference  \
# 0                                               13.0
#
#    cumsum_def_accentedHitsPositionClinchSuccessful_difference  \
# 0                                                8.0
#
#    cumsum_def_accentedHitsPositionParterTotal_difference  \
# 0                                              -21.0
#
#    cumsum_def_accentedHitsPositionParterSuccessful_difference  \
# 0                                              -16.0
#
#    cumsum_winMethods_[DEC]_difference  cumsum_winMethods_[DQ]_difference  \
# 0                                 4.0                                0.0
#
#    cumsum_winMethods_[KO]_difference  cumsum_winMethods_[SUB]_difference  \
# 0                               -1.0                                -1.0
#
#    hits_accuracy_difference  takedown_accuracy_difference  \
# 0                 -0.020292                      0.133333
#
#    accentedHits_accuracy_difference  hitsHead_accuracy_difference  \
# 0                          0.031499                      0.011154
#
#    hitsBody_accuracy_difference  hitsLegs_accuracy_difference  \
# 0                       0.19697                           0.0
#
#    accentedHitsPositionDistance_accuracy_difference  \
# 0                                         -0.047059
#
#    accentedHitsPositionClinch_accuracy_difference  \
# 0                                        0.224138
#
#    accentedHitsPositionParter_accuracy_difference  DEC_percent_difference  \
# 0                                             NaN                    0.25
#
#    DQ_percent_difference  KO_percent_difference  SUB_percent_difference  \
# 0                    0.0                   -1.0                    -1.0
#
#    hits_PM_difference  takedown_PM_difference  accentedHits_PM_difference  \
# 0           -1.140921                    0.08                   -0.274142
#
#    hitsHead_PM_difference  hitsBody_PM_difference  hitsLegs_PM_difference  \
# 0               -0.241004                0.014226               -0.047364
#
#    accentedHitsPositionDistance_PM_difference  \
# 0                                   -0.859414
#
#    accentedHitsPositionClinch_PM_difference  \
# 0                                  0.505272
#
#    accentedHitsPositionParter_PM_difference  knockdowns_PM_difference  \
# 0                                      0.08                       0.0
#
#    protectionPassage_PM_difference  win_streak_difference  \
# 0                              0.0                    0.0
#
#    loose_streak_difference  def_hits_accuracy_difference  \
# 0                      0.0                     -0.198049
#
#    def_takedown_accuracy_difference  def_accentedHits_accuracy_difference  \
# 0                             -0.25                             -0.222419
#
#    def_hitsHead_accuracy_difference  def_hitsBody_accuracy_difference  \
# 0                         -0.243861                           -0.4375
#
#    def_hitsLegs_accuracy_difference  \
# 0                         -0.090643
#
#    def_accentedHitsPositionDistance_accuracy_difference  \
# 0                                          -0.196064
#
#    def_accentedHitsPositionClinch_accuracy_difference  \
# 0                                          -0.102941
#
#    def_accentedHitsPositionParter_accuracy_difference  def_hits_PM_difference  \
# 0                                           -0.23913                -4.607699
#
#    def_takedown_PM_difference  def_accentedHits_PM_difference  \
# 0                   -0.043682                       -3.264603
#
#    def_hitsHead_PM_difference  def_hitsBody_PM_difference  \
# 0                   -2.682008                    0.025272
#
#    def_hitsLegs_PM_difference  def_accentedHitsPositionDistance_PM_difference  \
# 0                   -0.607866                                       -2.070962
#
#    def_accentedHitsPositionClinch_PM_difference  \
# 0                                      0.188954
#
#    def_accentedHitsPositionParter_PM_difference  def_knockdowns_PM_difference  \
# 0                                     -1.382594                           0.0
#
#    def_protectionPassage_PM_difference  odds_difference  age_difference  \
# 0                                  0.0            -2.03             3.0
#
#    height_difference  weight_difference  armSpan_difference  \
# 0              -5.08                0.0                2.54
#
#    legSwing_difference  isHomeCity_difference  isHomeCountry_difference  \
# 0                  NaN                    0.0                       0.0
#
#    isHomeTimezone_difference
# 0                       -1.0

# %%
X_df[['f1_cumsum_hitsTotal', 'f2_cumsum_hitsTotal']]
# Out:
#    f1_cumsum_hitsTotal  f2_cumsum_hitsTotal
# 0                  105                  176

# %%
X_df[clf.feature_names_]
# Out:
#    age_difference  armSpan_difference  cumsum_def_hitsTotal_difference  \
# 0            -3.0               -2.54                            -44.0
#
#    cumsum_hitsSuccessful_difference  cumsum_submissionAttempts_difference  \
# 0                             -37.0                                   4.0
#
#    def_accentedHitsPositionDistance_accuracy_difference  \
# 0                                           0.196064
#
#    def_hitsHead_accuracy_difference  def_hitsLegs_PM_difference  \
# 0                          0.243861                    0.607866
#
#    def_hitsLegs_accuracy_difference  cumsum_takeovers_difference  \
# 0                          0.090643                         -5.0
#
#    cumsum_takedownTotal_difference  isHomeCity_difference  \
# 0                            -12.0                    0.0
#
#    isHomeCountry_difference  takedown_PM_difference  win_streak_difference
# 0                       0.0                   -0.08                    0.0

# %%
X_df_reversed[clf.feature_names_]
# Out:
#    age_difference  armSpan_difference  cumsum_def_hitsTotal_difference  \
# 0             3.0                2.54                             44.0
#
#    cumsum_hitsSuccessful_difference  cumsum_submissionAttempts_difference  \
# 0                              37.0                                  -4.0
#
#    def_accentedHitsPositionDistance_accuracy_difference  \
# 0                                          -0.196064
#
#    def_hitsHead_accuracy_difference  def_hitsLegs_PM_difference  \
# 0                         -0.243861                   -0.607866
#
#    def_hitsLegs_accuracy_difference  cumsum_takeovers_difference  \
# 0                         -0.090643                          5.0
#
#    cumsum_takedownTotal_difference  isHomeCity_difference  \
# 0                             12.0                    0.0
#
#    isHomeCountry_difference  takedown_PM_difference  win_streak_difference
# 0                       0.0                    0.08                    0.0

# %%
y_proba1 = clf.predict_proba(X_df[clf.feature_names_])[:, 1]
y_proba2 = clf.predict_proba(X_df_reversed[clf.feature_names_])[:, 0]
y_proba = (y_proba1 + y_proba2) / 2
y_proba1, y_proba2, y_proba
# Out:
# (array([0.43673265]), array([0.44452294]), array([0.44062779]))
