# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from catboost import CatBoostClassifier
import pandas as pd
import json
from pandas import json_normalize
from tqdm import tqdm_notebook as tqdm
import numpy as np
import ast
import json

import sys
import os
sys.path.append(os.path.join(sys.path[0], '../../'))

from core.train_utils import calculate_roi, get_winner_favorite, combine_df

pd.set_option('display.precision',6)
pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None

# %%
with open('../../data/Catboost_v1_0/generated_features_08.04.2021.txt', 'r') as outfile:
    generated_features = json.load(outfile)
fighter1_stats = generated_features['fighter1_stats']
fighter2_stats = generated_features['fighter2_stats']
difference_cols = generated_features['difference_cols']

cat_cols = ['city', 'country', 'is_fight_night', 'weightCategory.id', 
              'f1_country', 'f2_country', 'f1_city', 'f2_city']

train_cols = cat_cols +  fighter1_stats + fighter2_stats + ['f1_odds', 'f2_odds', 'odds_difference'] # #  difference_cols + fighter1_stats + fighter2_stats + cat_cols +

# %%
df = pd.read_csv('../../data/Catboost_v1_0/events_joined_total_08.04.2021.csv', index_col=0)
df['eventDate.date'] = pd.to_datetime(df['eventDate.date'])
df['weightCategory.id'] = df['weightCategory.id'].astype('object')


# df = df[~df['odds_difference'].isna()]

# df = df[df['type'] == 'straight']
# df = df[df['type'] == 'reversed']
print(df.shape)

df[cat_cols] = df[cat_cols].fillna('unknown')
df = df[(df['f1_count_of_fights'] >= 2) & (df['f2_count_of_fights'] >= 2)]

train1 = df[(df['eventDate.date'].dt.year > 2005) & (df['eventDate.date'].dt.year < 2020) &
           ((df['type']=='straight'))]

val1  = df[(df['eventDate.date'].dt.year >= 2020) &
          ((df['type']=='straight'))]
val1 = val1.reset_index()
val1 = val1[~val1['odds_difference'].isna()]
# 'f1_timezone', 'f2_timezone', 'timezone', 'f1_name', 'f2_name', 

train1 = df[(df['eventDate.date'].dt.year > 2005) & (df['eventDate.date'].dt.year < 2020) &
           ((df['type']=='straight'))]

val1  = df[(df['eventDate.date'].dt.year >= 2020) &
          ((df['type']=='straight'))]
val1 = val1.reset_index()
val1 = val1[~val1['odds_difference'].isna()]


train2 = df[(df['eventDate.date'].dt.year > 2005) & (df['eventDate.date'].dt.year < 2020) &
           ((df['type']=='reversed'))]

val2  = df[(df['eventDate.date'].dt.year >= 2020) &
          ((df['type']=='reversed'))]
val2 = val2.reset_index()
val2 = val2[~val2['odds_difference'].isna()]
# 'f1_timezone', 'f2_timezone', 'timezone', 'f1_name', 'f2_name', 

print(train1.shape, val1.shape)
print(train2.shape, val2.shape)
# Out:
# (13754, 214)
# (2935, 214) (311, 215)
# (2935, 214) (311, 215)

# %%
X_train = train1[train_cols].drop(['f1_odds', 'f2_odds', 'odds_difference'], axis=1)
y_train = train1['winner'].astype(int)

X_val = val1[train_cols].drop(['f1_odds', 'f2_odds', 'odds_difference'], axis=1)
y_val = val1['winner'].astype(int)

print(X_train.shape, X_val.shape)
clf1 = CatBoostClassifier(iterations=2000, 
                           depth=4,
                           learning_rate=0.01,
                           loss_function='Logloss',
                           colsample_bylevel=1,
                           subsample=0.4,
                           random_strength=1,
                           l2_leaf_reg=30,
#                            reg_lambda=40,
                           eval_metric='Accuracy',
                           boosting_type='Plain', # 'Plain'
                           bootstrap_type='Bernoulli',# 'Bernoulli' Bayesian
                           max_ctr_complexity=5,
                           task_type='GPU',
#                            cat_features=cat_cols
                           cat_features=[0,1,2,3,4,5,6,7]
                          )

clf1.fit(X_train, y_train, plot=True, eval_set=(X_val, y_val), verbose=False)

clf1.save_model('../../models/Catboost_v1_0/catboost_v1_0_06.04.2021_1.cat')
clf1.get_feature_importance(prettified=True)#[:50]['Feature Id'].values
# Out:
# (2935, 130) (311, 130)
#             <style>
#                 .highcharts-tooltip {
#     display: none !important;
# }
# .highcharts-halo {
#     display: none !important;
# }
#
# .catboost {
#     position: relative;
# }
#
# .catboost-panel {
#     position: absolute;
#     height: 100%;
#     width: 280px;
# }
#
# .catboost-panel__controls {
#     margin-left: 0;
# }
#
# .catboost-panel__controls_label {
#     padding: 5px 0 0 8px;
#     cursor: pointer;
#     width: 80px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls_label_time {
#     width: inherit;
# }
#
# .catboost-panel__controls2 {
#     margin-top: 10px;
# }
#
# .catboost-panel__controls2_label {
#     padding: 5px 11px 0 8px;
#     cursor: pointer;
#     width: 90px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls2_label-long {
#     width: 170px;
# }
#
# .catboost-panel__series {
#     height: 340px;
#     overflow-y: auto;
# }
#
# .catboost-graph {
#     margin-left: 290px;
# }
#
# .catboost-graph__tabs {
#     padding: 0 0 0 20px;
# }
#
# .catboost-graph__tab {
#     display: inline-block;
#     padding: 5px 10px 0 0;
# }
#
# .catboost-graph__tab {
#     color: #999;
#     cursor: pointer;
#     transition: color 0.1s linear;
# }
#
# .catboost-graph__tab:hover {
#     color: #333;
# }
#
# .catboost-graph__tab_active {
#     color: #000;
#     cursor: auto;
# }
#
# .catboost-graph__charts {
#     padding-top: 20px;
# }
#
# .catboost-graph__chart {
#     display: none;
# }
#
# .catboost-graph__chart_active {
#     display: block;
# }
#
# .catboost-panel__serie {
#     padding-bottom: 5px;
#     border-bottom: 1px solid rgba(0, 0, 0, 0.3);
#     position: relative;
# }
#
# .catboost-panel__serie_bottom,
# .catboost-panel__serie_middle,
# .catboost-panel__serie_top {
#     white-space: nowrap;
#     position: relative;
# }
#
# #catboost-control-test {
#     margin-left: 11px;
# }
#
# .catboost-panel__serie_label {
#     padding: 0 0 0 8px;
#     width: 200px;
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     cursor: pointer;
#     margin-bottom: 0;
#     overflow: hidden;
#     position: relative;
#     top: 5px;
# }
#
# .catboost-panel__serie_hint {
#     position: absolute;
#     font-size: 9px;
#     left: 0;
# }
#
# .catboost-panel__serie__learn_hint {
#     top: 56px;
# }
#
# .catboost-panel__serie__test_hint {
#     top: 82px;
# }
#
# .catboost-panel__serie_bottom {
#     padding-bottom: 6px;
# }
#
# .catboost-panel__serie_time {
#     position: absolute;
#     top: 5px;
#     right: 2px;
#     height: 20px;
#     padding: 0 0 0 20px;
#     margin-bottom: 3px;
#     overflow: hidden;
#
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     text-align: left;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_test_pic {
#     width: 13px;
#     height: 1px;
#     border-top-width: 1px;
#     position: relative;
#     top: -3px;
#     margin-right: 5px;
# }
#
# .catboost-panel__serie_learn_pic {
#     border-top-style: dashed;
# }
#
# .catboost-panel__serie_test_pic {
#     border-top-style: solid;
# }
#
# .catboost-panel__serie-value {
#     display: inline-block;
#     min-width: 30px;
#     margin-right: 2px;
# }
#
# .catboost-panel__controls_label .catboost-panel__serie_learn_pic {
#     padding-left: 4px;
# }
#
# .catboost-panel__serie_names {
#     white-space: nowrap;
# }
#
# .catboost-panel__serie_scroll {
#     width: 240px;
#     overflow-x: auto;
#     margin-left: 20px;
# }
#
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_learn_value,
# .catboost-panel__serie_best_test_value {
#     width: 85px;
#     position: relative;
#     padding: 0 8px 0 0;
#     box-sizing: content-box;
#     overflow: hidden;
#     text-overflow: ellipsis;
#     top: 5px;
# }
#
# .catboost-panel__serie_iteration,
# .catboost-panel__serie_best_iteration {
#     display: inline-block;
#     position: absolute;
#     box-sizing: content-box;
#     overflow: hidden;
#     right: 2px;
# }
#
# .catboost-panel__serie_iteration {
#     top: 55px;
# }
#
# .catboost-panel__serie_best_iteration {
#     top: 80px;
# }
#
# .catboost-panel__control_slider {
#     width: 100px !important;
#     margin-left: 0;
#     position: relative;
#     display: inline-block !important;
#     top: 3px;
# }
#
# .catboost-panel__control_slidervalue {
#     width: 50px;
#     padding: 2px 3px;
#     margin-left: 4px;
# }
#
# .catboost-panel__serie_time_spend,
# .catboost-panel__serie_time_left {
#     display: inline-block;
# }
#
# .catboost-panel__serie_time_left {
#     margin-left: 10px;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_best_learn_value {
#     display: inline-block;
# }
# .catboost-panel__serie_test_pic,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_test_value {
#     display: inline-block;
# }
#
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_pic,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_name,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_learn_value {
#     display: none;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_pic,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_name,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_test_value {
#     display: none;
# }
#
# /*
# .catboost-panel__series_learn_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_test_value {
#     width: 216px;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_learn_value {
#     width: 216px;
# }
# */
# .catboost-panel__series_test_disabled .catboost-panel__serie__test_hint,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_iteration {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled.catboost-panel__series_learn_disabled .catboost-panel__serie_middle {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled .catboost-panel__serie_bottom {
#     display: none;
# }
#
#             </style>
#             <script>
#                 window.__define = window.define;window.__require = window.require;window.define = undefined;window.require = undefined;/**
# * plotly.js (basic - minified) v1.27.1
# * Copyright 2012-2017, Plotly, Inc.
# * All rights reserved.
# * Licensed under the MIT license
# */
# !function(t){if("object"==typeof exports&&"undefined"!=typeof module)module.exports=t();else if("function"==typeof define&&define.amd)define([],t);else{var e;e="undefined"!=typeof window?window:"undefined"!=typeof global?global:"undefined"!=typeof self?self:this,e.Plotly=t()}}(function(){var t;return function t(e,r,n){function a(i,l){if(!r[i]){if(!e[i]){var s="function"==typeof require&&require;if(!l&&s)return s(i,!0);if(o)return o(i,!0);var c=new Error("Cannot find module '"+i+"'");throw c.code="MODULE_NOT_FOUND",c}var u=r[i]={exports:{}};e[i][0].call(u.exports,function(t){var r=e[i][1][t];return a(r||t)},u,u.exports,t,e,r,n)}return r[i].exports}for(var o="function"==typeof require&&require,i=0;i<n.length;i++)a(n[i]);return a}({1:[function(t,e,r){"use strict";var n=t("../src/lib"),a={"X,X div":"font-family:'Open Sans', verdana, arial, sans-serif;margin:0;padding:0;","X input,X button":"font-family:'Open Sans', verdana, arial, sans-serif;","X input:focus,X button:focus":"outline:none;","X a":"text-decoration:none;","X a:hover":"text-decoration:none;","X .crisp":"shape-rendering:crispEdges;","X .user-select-none":"-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;-o-user-select:none;user-select:none;","X svg":"overflow:hidden;","X svg a":"fill:#447adb;","X svg a:hover":"fill:#3c6dc5;","X .main-svg":"position:absolute;top:0;left:0;pointer-events:none;","X .main-svg .draglayer":"pointer-events:all;","X .cursor-default":"cursor:default;","X .cursor-pointer":"cursor:pointer;","X .cursor-crosshair":"cursor:crosshair;","X .cursor-move":"cursor:move;","X .cursor-col-resize":"cursor:col-resize;","X .cursor-row-resize":"cursor:row-resize;","X .cursor-ns-resize":"cursor:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
#                Feature Id  Importances
# 0             f2_legSwing     6.930295
# 1                  f2_age     6.578274
# 2                 f2_city     6.447510
# 3                 f1_city     6.289612
# 4             f1_legSwing     5.677287
# ..                    ...          ...
# 125         f1_DQ_percent     0.002640
# 126  f2_cumsum_knockdowns     0.000675
# 127         f2_DQ_percent     0.000137
# 128  f1_cumsum_knockdowns     0.000000
# 129      f1_knockdowns_PM     0.000000
#
# [130 rows x 2 columns]

# %%
X_train = train2[train_cols].drop(['f1_odds', 'f2_odds', 'odds_difference'], axis=1)
y_train = train2['winner'].astype(int)

X_val = val2[train_cols].drop(['f1_odds', 'f2_odds', 'odds_difference'], axis=1)
y_val = val2['winner'].astype(int)

clf2 = CatBoostClassifier(iterations=2000, 
                           depth=4,
                           learning_rate=0.01,
                           loss_function='Logloss',
                           colsample_bylevel=1,
#                            subsample=0.1,
                           random_strength=1,
                           l2_leaf_reg=30,
#                            reg_lambda=40,
                           eval_metric='Accuracy',
                           boosting_type='Plain', # 'Plain'
                           bootstrap_type='Bernoulli',# 'Bernoulli' Bayesian
                           max_ctr_complexity=5,
                           task_type='GPU',
#                            cat_features=cat_cols
                           cat_features=[0,1,2,3,4,5,6,7]
                          )



clf2.fit(X_train, y_train, plot=True, eval_set=(X_val, y_val), verbose=False)

clf2.save_model('../../models/Catboost_v1_0/catboost_v1_0_06.04.2021_2.cat')
clf2.get_feature_importance(prettified=True)#[:50]['Feature Id'].values
# Out:
#             <style>
#                 .highcharts-tooltip {
#     display: none !important;
# }
# .highcharts-halo {
#     display: none !important;
# }
#
# .catboost {
#     position: relative;
# }
#
# .catboost-panel {
#     position: absolute;
#     height: 100%;
#     width: 280px;
# }
#
# .catboost-panel__controls {
#     margin-left: 0;
# }
#
# .catboost-panel__controls_label {
#     padding: 5px 0 0 8px;
#     cursor: pointer;
#     width: 80px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls_label_time {
#     width: inherit;
# }
#
# .catboost-panel__controls2 {
#     margin-top: 10px;
# }
#
# .catboost-panel__controls2_label {
#     padding: 5px 11px 0 8px;
#     cursor: pointer;
#     width: 90px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls2_label-long {
#     width: 170px;
# }
#
# .catboost-panel__series {
#     height: 340px;
#     overflow-y: auto;
# }
#
# .catboost-graph {
#     margin-left: 290px;
# }
#
# .catboost-graph__tabs {
#     padding: 0 0 0 20px;
# }
#
# .catboost-graph__tab {
#     display: inline-block;
#     padding: 5px 10px 0 0;
# }
#
# .catboost-graph__tab {
#     color: #999;
#     cursor: pointer;
#     transition: color 0.1s linear;
# }
#
# .catboost-graph__tab:hover {
#     color: #333;
# }
#
# .catboost-graph__tab_active {
#     color: #000;
#     cursor: auto;
# }
#
# .catboost-graph__charts {
#     padding-top: 20px;
# }
#
# .catboost-graph__chart {
#     display: none;
# }
#
# .catboost-graph__chart_active {
#     display: block;
# }
#
# .catboost-panel__serie {
#     padding-bottom: 5px;
#     border-bottom: 1px solid rgba(0, 0, 0, 0.3);
#     position: relative;
# }
#
# .catboost-panel__serie_bottom,
# .catboost-panel__serie_middle,
# .catboost-panel__serie_top {
#     white-space: nowrap;
#     position: relative;
# }
#
# #catboost-control-test {
#     margin-left: 11px;
# }
#
# .catboost-panel__serie_label {
#     padding: 0 0 0 8px;
#     width: 200px;
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     cursor: pointer;
#     margin-bottom: 0;
#     overflow: hidden;
#     position: relative;
#     top: 5px;
# }
#
# .catboost-panel__serie_hint {
#     position: absolute;
#     font-size: 9px;
#     left: 0;
# }
#
# .catboost-panel__serie__learn_hint {
#     top: 56px;
# }
#
# .catboost-panel__serie__test_hint {
#     top: 82px;
# }
#
# .catboost-panel__serie_bottom {
#     padding-bottom: 6px;
# }
#
# .catboost-panel__serie_time {
#     position: absolute;
#     top: 5px;
#     right: 2px;
#     height: 20px;
#     padding: 0 0 0 20px;
#     margin-bottom: 3px;
#     overflow: hidden;
#
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     text-align: left;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_test_pic {
#     width: 13px;
#     height: 1px;
#     border-top-width: 1px;
#     position: relative;
#     top: -3px;
#     margin-right: 5px;
# }
#
# .catboost-panel__serie_learn_pic {
#     border-top-style: dashed;
# }
#
# .catboost-panel__serie_test_pic {
#     border-top-style: solid;
# }
#
# .catboost-panel__serie-value {
#     display: inline-block;
#     min-width: 30px;
#     margin-right: 2px;
# }
#
# .catboost-panel__controls_label .catboost-panel__serie_learn_pic {
#     padding-left: 4px;
# }
#
# .catboost-panel__serie_names {
#     white-space: nowrap;
# }
#
# .catboost-panel__serie_scroll {
#     width: 240px;
#     overflow-x: auto;
#     margin-left: 20px;
# }
#
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_learn_value,
# .catboost-panel__serie_best_test_value {
#     width: 85px;
#     position: relative;
#     padding: 0 8px 0 0;
#     box-sizing: content-box;
#     overflow: hidden;
#     text-overflow: ellipsis;
#     top: 5px;
# }
#
# .catboost-panel__serie_iteration,
# .catboost-panel__serie_best_iteration {
#     display: inline-block;
#     position: absolute;
#     box-sizing: content-box;
#     overflow: hidden;
#     right: 2px;
# }
#
# .catboost-panel__serie_iteration {
#     top: 55px;
# }
#
# .catboost-panel__serie_best_iteration {
#     top: 80px;
# }
#
# .catboost-panel__control_slider {
#     width: 100px !important;
#     margin-left: 0;
#     position: relative;
#     display: inline-block !important;
#     top: 3px;
# }
#
# .catboost-panel__control_slidervalue {
#     width: 50px;
#     padding: 2px 3px;
#     margin-left: 4px;
# }
#
# .catboost-panel__serie_time_spend,
# .catboost-panel__serie_time_left {
#     display: inline-block;
# }
#
# .catboost-panel__serie_time_left {
#     margin-left: 10px;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_best_learn_value {
#     display: inline-block;
# }
# .catboost-panel__serie_test_pic,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_test_value {
#     display: inline-block;
# }
#
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_pic,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_name,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_learn_value {
#     display: none;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_pic,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_name,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_test_value {
#     display: none;
# }
#
# /*
# .catboost-panel__series_learn_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_test_value {
#     width: 216px;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_learn_value {
#     width: 216px;
# }
# */
# .catboost-panel__series_test_disabled .catboost-panel__serie__test_hint,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_iteration {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled.catboost-panel__series_learn_disabled .catboost-panel__serie_middle {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled .catboost-panel__serie_bottom {
#     display: none;
# }
#
#             </style>
#             <script>
#                 window.__define = window.define;window.__require = window.require;window.define = undefined;window.require = undefined;/**
# * plotly.js (basic - minified) v1.27.1
# * Copyright 2012-2017, Plotly, Inc.
# * All rights reserved.
# * Licensed under the MIT license
# */
# !function(t){if("object"==typeof exports&&"undefined"!=typeof module)module.exports=t();else if("function"==typeof define&&define.amd)define([],t);else{var e;e="undefined"!=typeof window?window:"undefined"!=typeof global?global:"undefined"!=typeof self?self:this,e.Plotly=t()}}(function(){var t;return function t(e,r,n){function a(i,l){if(!r[i]){if(!e[i]){var s="function"==typeof require&&require;if(!l&&s)return s(i,!0);if(o)return o(i,!0);var c=new Error("Cannot find module '"+i+"'");throw c.code="MODULE_NOT_FOUND",c}var u=r[i]={exports:{}};e[i][0].call(u.exports,function(t){var r=e[i][1][t];return a(r||t)},u,u.exports,t,e,r,n)}return r[i].exports}for(var o="function"==typeof require&&require,i=0;i<n.length;i++)a(n[i]);return a}({1:[function(t,e,r){"use strict";var n=t("../src/lib"),a={"X,X div":"font-family:'Open Sans', verdana, arial, sans-serif;margin:0;padding:0;","X input,X button":"font-family:'Open Sans', verdana, arial, sans-serif;","X input:focus,X button:focus":"outline:none;","X a":"text-decoration:none;","X a:hover":"text-decoration:none;","X .crisp":"shape-rendering:crispEdges;","X .user-select-none":"-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;-o-user-select:none;user-select:none;","X svg":"overflow:hidden;","X svg a":"fill:#447adb;","X svg a:hover":"fill:#3c6dc5;","X .main-svg":"position:absolute;top:0;left:0;pointer-events:none;","X .main-svg .draglayer":"pointer-events:all;","X .cursor-default":"cursor:default;","X .cursor-pointer":"cursor:pointer;","X .cursor-crosshair":"cursor:crosshair;","X .cursor-move":"cursor:move;","X .cursor-col-resize":"cursor:col-resize;","X .cursor-row-resize":"cursor:row-resize;","X .cursor-ns-resize":"cursor:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
#                                     Feature Id  Importances
# 0                                  f1_legSwing    10.483947
# 1                                      f1_city     9.800144
# 2                                       f1_age     9.438807
# 3                                      f2_city     8.276201
# 4                                  f2_legSwing     7.156146
# ..                                         ...          ...
# 125                             f1_hitsBody_PM     0.000000
# 126                       f2_cumsum_knockdowns     0.000000
# 127  f2_cumsum_accentedHitsPositionClinchTotal     0.000000
# 128                              f2_DQ_percent     0.000000
# 129                           f2_knockdowns_PM     0.000000
#
# [130 rows x 2 columns]

# %%
clf2.get_feature_importance(prettified=True)['Feature Id'].values
# Out:
# array(['f1_legSwing', 'f1_city', 'f1_age', 'f2_city', 'f2_legSwing',
#        'weightCategory.id', 'f1_hitsHead_PM', 'f2_age', 'f2_takedown_PM',
#        'f1_country', 'f1_protectionPassage_PM',
#        'f2_accentedHitsPositionParter_PM', 'f1_cumsum_protectionPassage',
#        'f1_cumsum_winner', 'f1_takedown_PM', 'f2_win_streak',
#        'f2_country', 'city', 'country', 'f1_cumsum_hitsHeadSuccessful',
#        'f2_armSpan', 'f1_isHomeTimezone', 'f1_cumsum_takedownSuccessful',
#        'f1_accentedHits_accuracy', 'f2_hitsHead_PM',
#        'f1_cumsum_accentedHitsSuccessful', 'f1_win_streak',
#        'f1_cumsum_winMethods_[SUB]', 'f2_protectionPassage_PM',
#        'f2_isHomeCountry', 'f1_hitsHead_accuracy', 'f2_hitsHead_accuracy',
#        'f2_accentedHits_accuracy', 'is_fight_night', 'f2_hits_accuracy',
#        'f1_DEC_percent', 'f2_accentedHits_PM',
#        'f1_accentedHitsPositionParter_accuracy', 'f2_takedown_accuracy',
#        'f2_cumsum_hitsHeadSuccessful',
#        'f1_cumsum_accentedHitsPositionParterSuccessful',
#        'f1_isHomeCountry', 'f1_loose_streak', 'f2_cumsum_winMethods_[KO]',
#        'f2_KO_percent', 'f2_accentedHitsPositionDistance_accuracy',
#        'f1_accentedHits_PM', 'f1_cumsum_takedownTotal',
#        'f2_accentedHitsPositionParter_accuracy', 'f1_SUB_percent',
#        'f1_accentedHitsPositionParter_PM', 'f1_cumsum_hitsTotal',
#        'f2_cumsum_winMethods_[SUB]',
#        'f1_cumsum_accentedHitsPositionDistanceTotal', 'f2_isHomeTimezone',
#        'f2_accentedHitsPositionDistance_PM', 'f1_cumsum_duration',
#        'f2_cumsum_winner', 'f1_cumsum_accentedHitsPositionParterTotal',
#        'f1_accentedHitsPositionClinch_accuracy',
#        'f1_cumsum_hitsHeadTotal', 'f2_SUB_percent',
#        'f2_hitsLegs_accuracy', 'f1_armSpan', 'f2_loose_streak',
#        'f2_cumsum_accentedHitsPositionDistanceTotal',
#        'f2_cumsum_accentedHitsSuccessful', 'f2_cumsum_accentedHitsTotal',
#        'f1_cumsum_accentedHitsPositionDistanceSuccessful',
#        'f2_accentedHitsPositionClinch_accuracy',
#        'f2_cumsum_accentedHitsPositionParterTotal',
#        'f2_cumsum_accentedHitsPositionParterSuccessful',
#        'f2_cumsum_duration', 'f2_cumsum_takeovers',
#        'f1_accentedHitsPositionDistance_PM', 'f2_cumsum_hitsLegsTotal',
#        'f1_hitsBody_accuracy', 'f2_hits_PM', 'f1_takedown_accuracy',
#        'f2_height', 'f1_accentedHitsPositionDistance_accuracy',
#        'f2_hitsLegs_PM', 'f1_cumsum_accentedHitsTotal', 'f1_hits_PM',
#        'f2_cumsum_accentedHitsPositionDistanceSuccessful',
#        'f2_hitsBody_PM', 'f2_cumsum_hitsSuccessful',
#        'f2_cumsum_takedownSuccessful', 'f1_hitsLegs_PM',
#        'f2_cumsum_hitsTotal', 'f2_cumsum_hitsBodyTotal', 'f1_isHomeCity',
#        'f1_cumsum_hitsSuccessful', 'f1_KO_percent',
#        'f2_cumsum_hitsLegsSuccessful', 'f1_hits_accuracy', 'f1_height',
#        'f2_cumsum_winMethods_[DQ]',
#        'f1_cumsum_accentedHitsPositionClinchTotal',
#        'f1_cumsum_hitsLegsSuccessful', 'f1_cumsum_submissionAttempts',
#        'f2_cumsum_protectionPassage', 'f2_cumsum_hitsBodySuccessful',
#        'f2_DEC_percent', 'f2_cumsum_winMethods_[DEC]',
#        'f2_accentedHitsPositionClinch_PM', 'f2_cumsum_takedownTotal',
#        'f2_isHomeCity', 'f1_cumsum_hitsBodySuccessful',
#        'f1_cumsum_winMethods_[KO]', 'f1_cumsum_winMethods_[DEC]',
#        'f1_cumsum_accentedHitsPositionClinchSuccessful',
#        'f2_hitsBody_accuracy', 'f1_accentedHitsPositionClinch_PM',
#        'f1_cumsum_winMethods_[DQ]', 'f2_cumsum_hitsHeadTotal',
#        'f2_cumsum_accentedHitsPositionClinchSuccessful',
#        'f1_cumsum_knockdowns', 'f2_cumsum_submissionAttempts',
#        'f1_knockdowns_PM', 'f1_DQ_percent', 'f1_cumsum_takeovers',
#        'f1_cumsum_hitsBodyTotal', 'f1_cumsum_hitsLegsTotal',
#        'f1_hitsLegs_accuracy', 'f1_hitsBody_PM', 'f2_cumsum_knockdowns',
#        'f2_cumsum_accentedHitsPositionClinchTotal', 'f2_DQ_percent',
#        'f2_knockdowns_PM'], dtype=object)

# %%
print('Точность букмейкера')
val1['bookmaker_bet'] = (val1['f1_odds'] < val1['f2_odds']).astype(int)
(val1['bookmaker_bet'] == val1['winner']).mean()
# Out:
# Точность букмейкера
# 0.662379421221865

# %%
y_proba = clf1.predict_proba(val1[clf1.feature_names_])
val1['y_proba'] = y_proba[:,1]
val1['y_pred'] = val1['y_proba'] > 0.5

y_proba = clf2.predict_proba(val2[clf2.feature_names_])
val2['y_proba'] = y_proba[:,1]
val2['y_pred'] = val2['y_proba'] > 0.5

val1['y_proba_comb'] = (val1['y_proba'] + 1-val2['y_proba']) / 2
val1['y_pred_comb'] = val1['y_proba_comb'] > 0.5

(val1['y_pred'] != val2['y_pred']).mean()
# Out:
# 0.9196141479099679

# %%
cols = ['f1_cumsum_duration',
  'f1_cumsum_winner',
  'f1_cumsum_hitsTotal',
  'f1_cumsum_hitsSuccessful',
  'f1_cumsum_takedownTotal',
  'f1_cumsum_takedownSuccessful',
  'f1_cumsum_submissionAttempts',
  'f1_cumsum_takeovers',
  'f1_cumsum_accentedHitsTotal',
  'f1_cumsum_accentedHitsSuccessful',
  'f1_cumsum_knockdowns',
  'f1_cumsum_protectionPassage',
  'f1_cumsum_hitsHeadTotal',
  'f1_cumsum_hitsHeadSuccessful',
  'f1_cumsum_hitsBodyTotal',
  'f1_cumsum_hitsBodySuccessful',
  'f1_cumsum_hitsLegsTotal',
  'f1_cumsum_hitsLegsSuccessful',
  'f1_cumsum_accentedHitsPositionDistanceTotal',
  'f1_cumsum_accentedHitsPositionDistanceSuccessful',
  'f1_cumsum_accentedHitsPositionClinchTotal',
  'f1_cumsum_accentedHitsPositionClinchSuccessful',
  'f1_cumsum_accentedHitsPositionParterTotal',
  'f1_cumsum_accentedHitsPositionParterSuccessful',
  'f1_cumsum_winMethods_[DEC]',
  'f1_cumsum_winMethods_[DQ]',
  'f1_cumsum_winMethods_[KO]',
  'f1_cumsum_winMethods_[SUB]',
  'f1_hits_accuracy',
  'f1_takedown_accuracy',
  'f1_accentedHits_accuracy',
  'f1_hitsHead_accuracy',
  'f1_hitsBody_accuracy',
  'f1_hitsLegs_accuracy',
  'f1_accentedHitsPositionDistance_accuracy',
  'f1_accentedHitsPositionClinch_accuracy',
  'f1_accentedHitsPositionParter_accuracy',
  'f1_DEC_percent',
  'f1_DQ_percent',
  'f1_KO_percent',
  'f1_SUB_percent',
  'f1_hits_PM',
  'f1_takedown_PM',
  'f1_accentedHits_PM',
  'f1_hitsHead_PM',
  'f1_hitsBody_PM',
  'f1_hitsLegs_PM',
  'f1_accentedHitsPositionDistance_PM',
  'f1_accentedHitsPositionClinch_PM',
  'f1_accentedHitsPositionParter_PM',
  'f1_knockdowns_PM',
  'f1_protectionPassage_PM',
  'f1_win_streak',
  'f1_loose_streak',
  'f2_cumsum_duration',
  'f2_cumsum_winner',
  'f2_cumsum_hitsTotal',
  'f2_cumsum_hitsSuccessful',
  'f2_cumsum_takedownTotal',
  'f2_cumsum_takedownSuccessful',
  'f2_cumsum_submissionAttempts',
  'f2_cumsum_takeovers',
  'f2_cumsum_accentedHitsTotal',
  'f2_cumsum_accentedHitsSuccessful',
  'f2_cumsum_knockdowns',
  'f2_cumsum_protectionPassage',
  'f2_cumsum_hitsHeadTotal',
  'f2_cumsum_hitsHeadSuccessful',
  'f2_cumsum_hitsBodyTotal',
  'f2_cumsum_hitsBodySuccessful',
  'f2_cumsum_hitsLegsTotal',
  'f2_cumsum_hitsLegsSuccessful',
  'f2_cumsum_accentedHitsPositionDistanceTotal',
  'f2_cumsum_accentedHitsPositionDistanceSuccessful',
  'f2_cumsum_accentedHitsPositionClinchTotal',
  'f2_cumsum_accentedHitsPositionClinchSuccessful',
  'f2_cumsum_accentedHitsPositionParterTotal',
  'f2_cumsum_accentedHitsPositionParterSuccessful',
  'f2_cumsum_winMethods_[DEC]',
  'f2_cumsum_winMethods_[DQ]',
  'f2_cumsum_winMethods_[KO]',
  'f2_cumsum_winMethods_[SUB]',
  'f2_hits_accuracy',
  'f2_takedown_accuracy',
  'f2_accentedHits_accuracy',
  'f2_hitsHead_accuracy',
  'f2_hitsBody_accuracy',
  'f2_hitsLegs_accuracy',
  'f2_accentedHitsPositionDistance_accuracy',
  'f2_accentedHitsPositionClinch_accuracy',
  'f2_accentedHitsPositionParter_accuracy',
  'f2_DEC_percent',
  'f2_DQ_percent',
  'f2_KO_percent',
  'f2_SUB_percent',
  'f2_hits_PM',
  'f2_takedown_PM',
  'f2_accentedHits_PM',
  'f2_hitsHead_PM',
  'f2_hitsBody_PM',
  'f2_hitsLegs_PM',
  'f2_accentedHitsPositionDistance_PM',
  'f2_accentedHitsPositionClinch_PM',
  'f2_accentedHitsPositionParter_PM',
  'f2_knockdowns_PM',
  'f2_protectionPassage_PM',
  'f2_win_streak',
  'f2_loose_streak',
  'f1_age',
  'f2_age',
  'f1_odds',
  'f2_odds',
  'weightCategory.id',
  'city',
  'country',
  'is_fight_night',
  'timezone',
  'f1_country',
  'f1_city',
  'f1_armSpan',
  'f1_height',
  'f1_legSwing',
  'f1_timezone',
  'f2_country',
  'f2_city',
  'f2_armSpan',
  'f2_height',
  'f2_legSwing',
  'f2_timezone',
  'f1_isHomeCity',
  'f1_isHomeCountry',
  'f1_isHomeTimezone',
  'f2_isHomeCity',
  'f2_isHomeCountry',
  'f2_isHomeTimezone']
val1[cols][:1]
# Out:
#    f1_cumsum_duration  f1_cumsum_winner  f1_cumsum_hitsTotal  \
# 0              7959.0                25               1552.0
#
#    f1_cumsum_hitsSuccessful  f1_cumsum_takedownTotal  \
# 0                     798.0                     32.0
#
#    f1_cumsum_takedownSuccessful  f1_cumsum_submissionAttempts  \
# 0                          11.0                          10.0
#
#    f1_cumsum_takeovers  f1_cumsum_accentedHitsTotal  \
# 0                  1.0                       1460.0
#
#    f1_cumsum_accentedHitsSuccessful  f1_cumsum_knockdowns  \
# 0                             718.0                   0.0
#
#    f1_cumsum_protectionPassage  f1_cumsum_hitsHeadTotal  \
# 0                         14.0                   1040.0
#
#    f1_cumsum_hitsHeadSuccessful  f1_cumsum_hitsBodyTotal  \
# 0                         393.0                    228.0
#
#    f1_cumsum_hitsBodySuccessful  f1_cumsum_hitsLegsTotal  \
# 0                         159.0                    192.0
#
#    f1_cumsum_hitsLegsSuccessful  f1_cumsum_accentedHitsPositionDistanceTotal  \
# 0                         166.0                                       1245.0
#
#    f1_cumsum_accentedHitsPositionDistanceSuccessful  \
# 0                                             571.0
#
#    f1_cumsum_accentedHitsPositionClinchTotal  \
# 0                                      103.0
#
#    f1_cumsum_accentedHitsPositionClinchSuccessful  \
# 0                                            65.0
#
#    f1_cumsum_accentedHitsPositionParterTotal  \
# 0                                      112.0
#
#    f1_cumsum_accentedHitsPositionParterSuccessful  f1_cumsum_winMethods_[DEC]  \
# 0                                            82.0                          12
#
#    f1_cumsum_winMethods_[DQ]  f1_cumsum_winMethods_[KO]  \
# 0                          0                         16
#
#    f1_cumsum_winMethods_[SUB]  f1_hits_accuracy  f1_takedown_accuracy  \
# 0                           7          0.514175               0.34375
#
#    f1_accentedHits_accuracy  f1_hitsHead_accuracy  f1_hitsBody_accuracy  \
# 0                  0.491781              0.377885              0.697368
#
#    f1_hitsLegs_accuracy  f1_accentedHitsPositionDistance_accuracy  \
# 0              0.864583                                  0.458635
#
#    f1_accentedHitsPositionClinch_accuracy  \
# 0                                0.631068
#
#    f1_accentedHitsPositionParter_accuracy  f1_DEC_percent  f1_DQ_percent  \
# 0                                0.732143            0.48            0.0
#
#    f1_KO_percent  f1_SUB_percent  f1_hits_PM  f1_takedown_PM  \
# 0           0.64            0.28    6.015831        0.082925
#
#    f1_accentedHits_PM  f1_hitsHead_PM  f1_hitsBody_PM  f1_hitsLegs_PM  \
# 0             5.41274        2.962684        1.198643        1.251413
#
#    f1_accentedHitsPositionDistance_PM  f1_accentedHitsPositionClinch_PM  \
# 0                            4.304561                          0.490011
#
#    f1_accentedHitsPositionParter_PM  f1_knockdowns_PM  \
# 0                          0.618168               0.0
#
#    f1_protectionPassage_PM  f1_win_streak  f1_loose_streak  \
# 0                 0.105541              0                2
#
#    f2_cumsum_duration  f2_cumsum_winner  f2_cumsum_hitsTotal  \
# 0              2061.0                 9                423.0
#
#    f2_cumsum_hitsSuccessful  f2_cumsum_takedownTotal  \
# 0                     260.0                      6.0
#
#    f2_cumsum_takedownSuccessful  f2_cumsum_submissionAttempts  \
# 0                           4.0                           0.0
#
#    f2_cumsum_takeovers  f2_cumsum_accentedHitsTotal  \
# 0                  0.0                        350.0
#
#    f2_cumsum_accentedHitsSuccessful  f2_cumsum_knockdowns  \
# 0                             189.0                   0.0
#
#    f2_cumsum_protectionPassage  f2_cumsum_hitsHeadTotal  \
# 0                          6.0                    299.0
#
#    f2_cumsum_hitsHeadSuccessful  f2_cumsum_hitsBodyTotal  \
# 0                         156.0                     38.0
#
#    f2_cumsum_hitsBodySuccessful  f2_cumsum_hitsLegsTotal  \
# 0                          24.0                     13.0
#
#    f2_cumsum_hitsLegsSuccessful  f2_cumsum_accentedHitsPositionDistanceTotal  \
# 0                           9.0                                        273.0
#
#    f2_cumsum_accentedHitsPositionDistanceSuccessful  \
# 0                                             135.0
#
#    f2_cumsum_accentedHitsPositionClinchTotal  \
# 0                                       16.0
#
#    f2_cumsum_accentedHitsPositionClinchSuccessful  \
# 0                                            13.0
#
#    f2_cumsum_accentedHitsPositionParterTotal  \
# 0                                       61.0
#
#    f2_cumsum_accentedHitsPositionParterSuccessful  f2_cumsum_winMethods_[DEC]  \
# 0                                            41.0                           2
#
#    f2_cumsum_winMethods_[DQ]  f2_cumsum_winMethods_[KO]  \
# 0                          0                          7
#
#    f2_cumsum_winMethods_[SUB]  f2_hits_accuracy  f2_takedown_accuracy  \
# 0                           2          0.614657              0.666667
#
#    f2_accentedHits_accuracy  f2_hitsHead_accuracy  f2_hitsBody_accuracy  \
# 0                      0.54              0.521739              0.631579
#
#    f2_hitsLegs_accuracy  f2_accentedHitsPositionDistance_accuracy  \
# 0              0.692308                                  0.494505
#
#    f2_accentedHitsPositionClinch_accuracy  \
# 0                                  0.8125
#
#    f2_accentedHitsPositionParter_accuracy  f2_DEC_percent  f2_DQ_percent  \
# 0                                0.672131        0.222222            0.0
#
#    f2_KO_percent  f2_SUB_percent  f2_hits_PM  f2_takedown_PM  \
# 0       0.777778        0.222222    7.569141        0.116448
#
#    f2_accentedHits_PM  f2_hitsHead_PM  f2_hitsBody_PM  f2_hitsLegs_PM  \
# 0            5.502183        4.541485         0.69869        0.262009
#
#    f2_accentedHitsPositionDistance_PM  f2_accentedHitsPositionClinch_PM  \
# 0                            3.930131                          0.378457
#
#    f2_accentedHitsPositionParter_PM  f2_knockdowns_PM  \
# 0                          1.193595               0.0
#
#    f2_protectionPassage_PM  f2_win_streak  f2_loose_streak  f1_age  f2_age  \
# 0                 0.174672              0                1    36.0    31.0
#
#    f1_odds  f2_odds  weightCategory.id       city country  is_fight_night  \
# 0     3.61     1.29                 14  Las Vegas     USA           False
#
#               timezone f1_country f1_city  f1_armSpan  f1_height  f1_legSwing  \
# 0  America/Los_Angeles        USA  Denver      185.42     185.42       102.87
#
#       f1_timezone f2_country f2_city  f2_armSpan  f2_height  f2_legSwing  \
# 0  America/Denver    Ireland  Dublin      187.96     175.26        101.6
#
#         f2_timezone  f1_isHomeCity  f1_isHomeCountry  f1_isHomeTimezone  \
# 0  America/New_York              0                 1                  0
#
#    f2_isHomeCity  f2_isHomeCountry  f2_isHomeTimezone
# 0              0                 0                  0

# %%
q = val1[:1][cols]
q
# Out:
#    f1_cumsum_duration  f1_cumsum_winner  f1_cumsum_hitsTotal  \
# 0              7959.0                25               1552.0
#
#    f1_cumsum_hitsSuccessful  f1_cumsum_takedownTotal  \
# 0                     798.0                     32.0
#
#    f1_cumsum_takedownSuccessful  f1_cumsum_submissionAttempts  \
# 0                          11.0                          10.0
#
#    f1_cumsum_takeovers  f1_cumsum_accentedHitsTotal  \
# 0                  1.0                       1460.0
#
#    f1_cumsum_accentedHitsSuccessful  f1_cumsum_knockdowns  \
# 0                             718.0                   0.0
#
#    f1_cumsum_protectionPassage  f1_cumsum_hitsHeadTotal  \
# 0                         14.0                   1040.0
#
#    f1_cumsum_hitsHeadSuccessful  f1_cumsum_hitsBodyTotal  \
# 0                         393.0                    228.0
#
#    f1_cumsum_hitsBodySuccessful  f1_cumsum_hitsLegsTotal  \
# 0                         159.0                    192.0
#
#    f1_cumsum_hitsLegsSuccessful  f1_cumsum_accentedHitsPositionDistanceTotal  \
# 0                         166.0                                       1245.0
#
#    f1_cumsum_accentedHitsPositionDistanceSuccessful  \
# 0                                             571.0
#
#    f1_cumsum_accentedHitsPositionClinchTotal  \
# 0                                      103.0
#
#    f1_cumsum_accentedHitsPositionClinchSuccessful  \
# 0                                            65.0
#
#    f1_cumsum_accentedHitsPositionParterTotal  \
# 0                                      112.0
#
#    f1_cumsum_accentedHitsPositionParterSuccessful  f1_cumsum_winMethods_[DEC]  \
# 0                                            82.0                          12
#
#    f1_cumsum_winMethods_[DQ]  f1_cumsum_winMethods_[KO]  \
# 0                          0                         16
#
#    f1_cumsum_winMethods_[SUB]  f1_hits_accuracy  f1_takedown_accuracy  \
# 0                           7          0.514175               0.34375
#
#    f1_accentedHits_accuracy  f1_hitsHead_accuracy  f1_hitsBody_accuracy  \
# 0                  0.491781              0.377885              0.697368
#
#    f1_hitsLegs_accuracy  f1_accentedHitsPositionDistance_accuracy  \
# 0              0.864583                                  0.458635
#
#    f1_accentedHitsPositionClinch_accuracy  \
# 0                                0.631068
#
#    f1_accentedHitsPositionParter_accuracy  f1_DEC_percent  f1_DQ_percent  \
# 0                                0.732143            0.48            0.0
#
#    f1_KO_percent  f1_SUB_percent  f1_hits_PM  f1_takedown_PM  \
# 0           0.64            0.28    6.015831        0.082925
#
#    f1_accentedHits_PM  f1_hitsHead_PM  f1_hitsBody_PM  f1_hitsLegs_PM  \
# 0             5.41274        2.962684        1.198643        1.251413
#
#    f1_accentedHitsPositionDistance_PM  f1_accentedHitsPositionClinch_PM  \
# 0                            4.304561                          0.490011
#
#    f1_accentedHitsPositionParter_PM  f1_knockdowns_PM  \
# 0                          0.618168               0.0
#
#    f1_protectionPassage_PM  f1_win_streak  f1_loose_streak  \
# 0                 0.105541              0                2
#
#    f2_cumsum_duration  f2_cumsum_winner  f2_cumsum_hitsTotal  \
# 0              2061.0                 9                423.0
#
#    f2_cumsum_hitsSuccessful  f2_cumsum_takedownTotal  \
# 0                     260.0                      6.0
#
#    f2_cumsum_takedownSuccessful  f2_cumsum_submissionAttempts  \
# 0                           4.0                           0.0
#
#    f2_cumsum_takeovers  f2_cumsum_accentedHitsTotal  \
# 0                  0.0                        350.0
#
#    f2_cumsum_accentedHitsSuccessful  f2_cumsum_knockdowns  \
# 0                             189.0                   0.0
#
#    f2_cumsum_protectionPassage  f2_cumsum_hitsHeadTotal  \
# 0                          6.0                    299.0
#
#    f2_cumsum_hitsHeadSuccessful  f2_cumsum_hitsBodyTotal  \
# 0                         156.0                     38.0
#
#    f2_cumsum_hitsBodySuccessful  f2_cumsum_hitsLegsTotal  \
# 0                          24.0                     13.0
#
#    f2_cumsum_hitsLegsSuccessful  f2_cumsum_accentedHitsPositionDistanceTotal  \
# 0                           9.0                                        273.0
#
#    f2_cumsum_accentedHitsPositionDistanceSuccessful  \
# 0                                             135.0
#
#    f2_cumsum_accentedHitsPositionClinchTotal  \
# 0                                       16.0
#
#    f2_cumsum_accentedHitsPositionClinchSuccessful  \
# 0                                            13.0
#
#    f2_cumsum_accentedHitsPositionParterTotal  \
# 0                                       61.0
#
#    f2_cumsum_accentedHitsPositionParterSuccessful  f2_cumsum_winMethods_[DEC]  \
# 0                                            41.0                           2
#
#    f2_cumsum_winMethods_[DQ]  f2_cumsum_winMethods_[KO]  \
# 0                          0                          7
#
#    f2_cumsum_winMethods_[SUB]  f2_hits_accuracy  f2_takedown_accuracy  \
# 0                           2          0.614657              0.666667
#
#    f2_accentedHits_accuracy  f2_hitsHead_accuracy  f2_hitsBody_accuracy  \
# 0                      0.54              0.521739              0.631579
#
#    f2_hitsLegs_accuracy  f2_accentedHitsPositionDistance_accuracy  \
# 0              0.692308                                  0.494505
#
#    f2_accentedHitsPositionClinch_accuracy  \
# 0                                  0.8125
#
#    f2_accentedHitsPositionParter_accuracy  f2_DEC_percent  f2_DQ_percent  \
# 0                                0.672131        0.222222            0.0
#
#    f2_KO_percent  f2_SUB_percent  f2_hits_PM  f2_takedown_PM  \
# 0       0.777778        0.222222    7.569141        0.116448
#
#    f2_accentedHits_PM  f2_hitsHead_PM  f2_hitsBody_PM  f2_hitsLegs_PM  \
# 0            5.502183        4.541485         0.69869        0.262009
#
#    f2_accentedHitsPositionDistance_PM  f2_accentedHitsPositionClinch_PM  \
# 0                            3.930131                          0.378457
#
#    f2_accentedHitsPositionParter_PM  f2_knockdowns_PM  \
# 0                          1.193595               0.0
#
#    f2_protectionPassage_PM  f2_win_streak  f2_loose_streak  f1_age  f2_age  \
# 0                 0.174672              0                1    36.0    31.0
#
#    f1_odds  f2_odds  weightCategory.id       city country  is_fight_night  \
# 0     3.61     1.29                 14  Las Vegas     USA           False
#
#               timezone f1_country f1_city  f1_armSpan  f1_height  f1_legSwing  \
# 0  America/Los_Angeles        USA  Denver      185.42     185.42       102.87
#
#       f1_timezone f2_country f2_city  f2_armSpan  f2_height  f2_legSwing  \
# 0  America/Denver    Ireland  Dublin      187.96     175.26        101.6
#
#         f2_timezone  f1_isHomeCity  f1_isHomeCountry  f1_isHomeTimezone  \
# 0  America/New_York              0                 1                  0
#
#    f2_isHomeCity  f2_isHomeCountry  f2_isHomeTimezone
# 0              0                 0                  0

# %%
val1[cols][:1][(val1[cols][:1] == [7959.0, 25, 1552.0, 798.0, 32.0, 11.0, 10.0, 1.0, 1460.0, 718.0, 0.0, 14.0, 1040.0, 393.0, 228.0, 159.0, 192.0, 166.0, 1245.0, 571.0, 103.0, 65.0, 112.0, 82.0, 12, 0, 16, 7, 0.5141752577319587, 0.34375, 0.4917808219178082, 0.3778846153846154, 0.6973684210526315, 0.8645833333333334, 0.4586345381526104, 0.6310679611650486, 0.7321428571428571, 0.48, 0.0, 0.64, 0.28, 6.015831134564643, 0.0829249905767056, 5.4127402940067855, 2.9626837542404827, 1.198643045608745, 1.2514134941575576, 4.304560874481719, 0.4900113079532605, 0.6181681115718055, 0.0, 0.1055408970976253, 0, 2, 2061.0, 9, 423.0, 260.0, 6.0, 4.0, 0.0, 0.0, 350.0, 189.0, 0.0, 6.0, 299.0, 156.0, 38.0, 24.0, 13.0, 9.0, 273.0, 135.0, 16.0, 13.0, 61.0, 41.0, 2, 0, 7, 2, 0.6146572104018913, 0.6666666666666666, 0.54, 0.5217391304347826, 0.631578947368421, 0.6923076923076923, 0.4945054945054945, 0.8125, 0.6721311475409836, 0.2222222222222222, 0.0, 0.7777777777777778, 0.2222222222222222, 7.5691411935953425, 0.1164483260553129, 5.502183406113537, 4.541484716157205, 0.6986899563318778, 0.2620087336244541, 3.930131004366812, 0.3784570596797671, 1.1935953420669578, 0.0, 0.1746724890829694, 0, 1, 36.0, 31.0, 3.61, 1.29, '14', 'Lass Vegas', 'USA', False, 'America/Los_Angeles', 'USA', 'Denver', 185.42, 185.42, 102.87, 'America/Denver', 'Ireland', 'Dublin', 187.96, 175.26, 101.6, 'America/New_York', 0, 1, 0, 0, 0, 0]) == False]
# Out:
#    f1_cumsum_duration  f1_cumsum_winner  f1_cumsum_hitsTotal  \
# 0                 NaN               NaN                  NaN
#
#    f1_cumsum_hitsSuccessful  f1_cumsum_takedownTotal  \
# 0                       NaN                      NaN
#
#    f1_cumsum_takedownSuccessful  f1_cumsum_submissionAttempts  \
# 0                           NaN                           NaN
#
#    f1_cumsum_takeovers  f1_cumsum_accentedHitsTotal  \
# 0                  NaN                          NaN
#
#    f1_cumsum_accentedHitsSuccessful  f1_cumsum_knockdowns  \
# 0                               NaN                   NaN
#
#    f1_cumsum_protectionPassage  f1_cumsum_hitsHeadTotal  \
# 0                          NaN                      NaN
#
#    f1_cumsum_hitsHeadSuccessful  f1_cumsum_hitsBodyTotal  \
# 0                           NaN                      NaN
#
#    f1_cumsum_hitsBodySuccessful  f1_cumsum_hitsLegsTotal  \
# 0                           NaN                      NaN
#
#    f1_cumsum_hitsLegsSuccessful  f1_cumsum_accentedHitsPositionDistanceTotal  \
# 0                           NaN                                          NaN
#
#    f1_cumsum_accentedHitsPositionDistanceSuccessful  \
# 0                                               NaN
#
#    f1_cumsum_accentedHitsPositionClinchTotal  \
# 0                                        NaN
#
#    f1_cumsum_accentedHitsPositionClinchSuccessful  \
# 0                                             NaN
#
#    f1_cumsum_accentedHitsPositionParterTotal  \
# 0                                        NaN
#
#    f1_cumsum_accentedHitsPositionParterSuccessful  f1_cumsum_winMethods_[DEC]  \
# 0                                             NaN                         NaN
#
#    f1_cumsum_winMethods_[DQ]  f1_cumsum_winMethods_[KO]  \
# 0                        NaN                        NaN
#
#    f1_cumsum_winMethods_[SUB]  f1_hits_accuracy  f1_takedown_accuracy  \
# 0                         NaN               NaN                   NaN
#
#    f1_accentedHits_accuracy  f1_hitsHead_accuracy  f1_hitsBody_accuracy  \
# 0                       NaN                   NaN                   NaN
#
#    f1_hitsLegs_accuracy  f1_accentedHitsPositionDistance_accuracy  \
# 0                   NaN                                       NaN
#
#    f1_accentedHitsPositionClinch_accuracy  \
# 0                                     NaN
#
#    f1_accentedHitsPositionParter_accuracy  f1_DEC_percent  f1_DQ_percent  \
# 0                                     NaN             NaN            NaN
#
#    f1_KO_percent  f1_SUB_percent  f1_hits_PM  f1_takedown_PM  \
# 0            NaN             NaN         NaN             NaN
#
#    f1_accentedHits_PM  f1_hitsHead_PM  f1_hitsBody_PM  f1_hitsLegs_PM  \
# 0                 NaN             NaN             NaN             NaN
#
#    f1_accentedHitsPositionDistance_PM  f1_accentedHitsPositionClinch_PM  \
# 0                                 NaN                               NaN
#
#    f1_accentedHitsPositionParter_PM  f1_knockdowns_PM  \
# 0                               NaN               NaN
#
#    f1_protectionPassage_PM  f1_win_streak  f1_loose_streak  \
# 0                      NaN            NaN              NaN
#
#    f2_cumsum_duration  f2_cumsum_winner  f2_cumsum_hitsTotal  \
# 0                 NaN               NaN                  NaN
#
#    f2_cumsum_hitsSuccessful  f2_cumsum_takedownTotal  \
# 0                       NaN                      NaN
#
#    f2_cumsum_takedownSuccessful  f2_cumsum_submissionAttempts  \
# 0                           NaN                           NaN
#
#    f2_cumsum_takeovers  f2_cumsum_accentedHitsTotal  \
# 0                  NaN                          NaN
#
#    f2_cumsum_accentedHitsSuccessful  f2_cumsum_knockdowns  \
# 0                               NaN                   NaN
#
#    f2_cumsum_protectionPassage  f2_cumsum_hitsHeadTotal  \
# 0                          NaN                      NaN
#
#    f2_cumsum_hitsHeadSuccessful  f2_cumsum_hitsBodyTotal  \
# 0                           NaN                      NaN
#
#    f2_cumsum_hitsBodySuccessful  f2_cumsum_hitsLegsTotal  \
# 0                           NaN                      NaN
#
#    f2_cumsum_hitsLegsSuccessful  f2_cumsum_accentedHitsPositionDistanceTotal  \
# 0                           NaN                                          NaN
#
#    f2_cumsum_accentedHitsPositionDistanceSuccessful  \
# 0                                               NaN
#
#    f2_cumsum_accentedHitsPositionClinchTotal  \
# 0                                        NaN
#
#    f2_cumsum_accentedHitsPositionClinchSuccessful  \
# 0                                             NaN
#
#    f2_cumsum_accentedHitsPositionParterTotal  \
# 0                                        NaN
#
#    f2_cumsum_accentedHitsPositionParterSuccessful  f2_cumsum_winMethods_[DEC]  \
# 0                                             NaN                         NaN
#
#    f2_cumsum_winMethods_[DQ]  f2_cumsum_winMethods_[KO]  \
# 0                        NaN                        NaN
#
#    f2_cumsum_winMethods_[SUB]  f2_hits_accuracy  f2_takedown_accuracy  \
# 0                         NaN               NaN                   NaN
#
#    f2_accentedHits_accuracy  f2_hitsHead_accuracy  f2_hitsBody_accuracy  \
# 0                       NaN                   NaN                   NaN
#
#    f2_hitsLegs_accuracy  f2_accentedHitsPositionDistance_accuracy  \
# 0                   NaN                                       NaN
#
#    f2_accentedHitsPositionClinch_accuracy  \
# 0                                     NaN
#
#    f2_accentedHitsPositionParter_accuracy  f2_DEC_percent  f2_DQ_percent  \
# 0                                     NaN             NaN            NaN
#
#    f2_KO_percent  f2_SUB_percent  f2_hits_PM  f2_takedown_PM  \
# 0            NaN             NaN         NaN             NaN
#
#    f2_accentedHits_PM  f2_hitsHead_PM  f2_hitsBody_PM  f2_hitsLegs_PM  \
# 0                 NaN             NaN             NaN             NaN
#
#    f2_accentedHitsPositionDistance_PM  f2_accentedHitsPositionClinch_PM  \
# 0                                 NaN                               NaN
#
#    f2_accentedHitsPositionParter_PM  f2_knockdowns_PM  \
# 0                               NaN               NaN
#
#    f2_protectionPassage_PM  f2_win_streak  f2_loose_streak  f1_age  f2_age  \
# 0                      NaN            NaN              NaN     NaN     NaN
#
#    f1_odds  f2_odds  weightCategory.id       city country  is_fight_night  \
# 0      NaN      NaN                 14  Las Vegas     NaN             NaN
#
#   timezone f1_country f1_city  f1_armSpan  f1_height  f1_legSwing f1_timezone  \
# 0      NaN        NaN     NaN         NaN        NaN          NaN         NaN
#
#   f2_country f2_city  f2_armSpan  f2_height  f2_legSwing f2_timezone  \
# 0        NaN     NaN         NaN        NaN          NaN         NaN
#
#    f1_isHomeCity  f1_isHomeCountry  f1_isHomeTimezone  f2_isHomeCity  \
# 0            NaN               NaN                NaN            NaN
#
#    f2_isHomeCountry  f2_isHomeTimezone
# 0               NaN                NaN

# %%
w = pd.Series([7959.0, 25, 1552.0, 798.0, 32.0, 11.0, 10.0, 1.0, 1460.0, 718.0, 0.0, 14.0, 1040.0, 393.0, 228.0, 159.0, 192.0, 166.0, 1245.0, 571.0, 103.0, 65.0, 112.0, 82.0, 12, 0, 16, 7, 0.5141752577319587, 0.34375, 0.4917808219178082, 0.3778846153846154, 0.6973684210526315, 0.8645833333333334, 0.4586345381526104, 0.6310679611650486, 0.7321428571428571, 0.48, 0.0, 0.64, 0.28, 6.015831134564643, 0.0829249905767056, 5.4127402940067855, 2.9626837542404827, 1.198643045608745, 1.2514134941575576, 4.304560874481719, 0.4900113079532605, 0.6181681115718055, 0.0, 0.1055408970976253, 0, 2, 2061.0, 9, 423.0, 260.0, 6.0, 4.0, 0.0, 0.0, 350.0, 189.0, 0.0, 6.0, 299.0, 156.0, 38.0, 24.0, 13.0, 9.0, 273.0, 135.0, 16.0, 13.0, 61.0, 41.0, 2, 0, 7, 2, 0.6146572104018913, 0.6666666666666666, 0.54, 0.5217391304347826, 0.631578947368421, 0.6923076923076923, 0.4945054945054945, 0.8125, 0.6721311475409836, 0.2222222222222222, 0.0, 0.7777777777777778, 0.2222222222222222, 7.5691411935953425, 0.1164483260553129, 5.502183406113537, 4.541484716157205, 0.6986899563318778, 0.2620087336244541, 3.930131004366812, 0.3784570596797671, 1.1935953420669578, 0.0, 0.1746724890829694, 0, 1, 36.0, 31.0, 3.61, 1.29, '14', 'Lass Vegas', 'USA', False, 'America/Los_Angeles', 'USA', 'Denver', 185.42, 185.42, 102.87, 'America/Denver', 'Ireland', 'Dublin', 187.96, 175.26, 101.6, 'America/New_York', 0, 1, 0, 0, 0, 0])
w
# Out:
# 0      7959.0
# 1          25
# 2      1552.0
# 3       798.0
# 4        32.0
#         ...
# 130         1
# 131         0
# 132         0
# 133         0
# 134         0
# Length: 135, dtype: object

# %%
q.shape
# Out:
# (1, 135)

# %%
calculate_roi(val1, pred_col='y_pred')
calculate_roi(val2, pred_col='y_pred')
calculate_roi(val1, pred_col='y_pred_comb')
# Out:
#   0%|          | 0/311 [00:00<?, ?it/s]
# {'accuracy:': 0.5659163987138264,
#  'bets_count:': 311,
#  'finish_bank:': 18.0,
#  'roi:': 0.05787781350482315}
#   0%|          | 0/311 [00:00<?, ?it/s]
# {'accuracy:': 0.5755627009646302,
#  'bets_count:': 311,
#  'finish_bank:': 1072.0,
#  'roi:': 3.446945337620579}
#   0%|          | 0/311 [00:00<?, ?it/s]
# {'accuracy:': 0.5691318327974276,
#  'bets_count:': 311,
#  'finish_bank:': 384.0,
#  'roi:': 1.2347266881028935}

# %%
same_preds = val1[val1['y_pred'] != val2['y_pred']]
calculate_roi(same_preds)
# Out:
#   0%|          | 0/286 [00:00<?, ?it/s]
# {'accuracy:': 0.5769230769230769,
#  'bets_count:': 286,
#  'finish_bank:': 749.0,
#  'roi:': 2.6188811188811187}

# %%
val1 = get_winner_favorite(val1)
val2 = get_winner_favorite(val2)

bet_on_favorite = val1[val1['y_pred'] == val1['favorite']]
calculate_roi(bet_on_favorite, pred_col='y_pred')
bet_on_favorite = val2[val2['y_pred'] == val2['favorite']]
calculate_roi(bet_on_favorite, pred_col='y_pred')
bet_on_favorite = val1[val1['y_pred_comb'] == val1['favorite']]
calculate_roi(bet_on_favorite, pred_col='y_pred_comb')
# Out:
#   0%|          | 0/187 [00:00<?, ?it/s]
# {'accuracy:': 0.6898395721925134,
#  'bets_count:': 187,
#  'finish_bank:': 618.0,
#  'roi:': 3.304812834224599}
#   0%|          | 0/178 [00:00<?, ?it/s]
# {'accuracy:': 0.702247191011236,
#  'bets_count:': 178,
#  'finish_bank:': 874.0,
#  'roi:': 4.910112359550562}
#   0%|          | 0/184 [00:00<?, ?it/s]
# {'accuracy:': 0.6956521739130435,
#  'bets_count:': 184,
#  'finish_bank:': 829.0,
#  'roi:': 4.505434782608695}

# %%
val1 = get_winner_favorite(val1)
val2 = get_winner_favorite(val2)

bet_on_favorite = val1[val1['y_pred'] != val1['favorite']]
calculate_roi(bet_on_favorite, pred_col='y_pred')
bet_on_favorite = val2[val2['y_pred'] != val2['favorite']]
calculate_roi(bet_on_favorite, pred_col='y_pred')
bet_on_favorite = val1[val1['y_pred_comb'] != val1['favorite']]
calculate_roi(bet_on_favorite, pred_col='y_pred_comb')
# Out:
#   0%|          | 0/124 [00:00<?, ?it/s]
# {'accuracy:': 0.3790322580645161,
#  'bets_count:': 124,
#  'finish_bank:': -600.0,
#  'roi:': -4.838709677419356}
#   0%|          | 0/133 [00:00<?, ?it/s]
# {'accuracy:': 0.40601503759398494,
#  'bets_count:': 133,
#  'finish_bank:': 198.0,
#  'roi:': 1.4887218045112782}
#   0%|          | 0/127 [00:00<?, ?it/s]
# {'accuracy:': 0.3858267716535433,
#  'bets_count:': 127,
#  'finish_bank:': -445.0,
#  'roi:': -3.5039370078740157}

# %%
from catboost import Pool
import matplotlib.pyplot as plt

fi = clf1.get_feature_importance(Pool(X_val, label=y_val, cat_features=[0,1,2,3,4,5,6,7]),
                                type='LossFunctionChange')

feature_score1 = pd.DataFrame(list(zip(X_val.dtypes.index, fi)),
                                columns=['Feature','Score'])

feature_score1 = feature_score1.sort_values(by='Score', ascending=False, inplace=False, kind='quicksort', na_position='last')

plt.rcParams["figure.figsize"] = (12,7)
ax = feature_score1.plot('Feature', 'Score', kind='bar', color='c')
ax.set_title("Feature Importance using {}".format('LossFunctionChange'), fontsize = 14)
ax.set_xlabel("features")
plt.show()

# %%
fi = clf2.get_feature_importance(Pool(X_val, label=y_val, cat_features=[0,1,2,3,4,5,6,7]),
                                type='LossFunctionChange')

feature_score2 = pd.DataFrame(list(zip(X_val.dtypes.index, fi)),
                                columns=['Feature','Score'])

feature_score2 = feature_score2.sort_values(by='Score', ascending=False, inplace=False, kind='quicksort', na_position='last')

plt.rcParams["figure.figsize"] = (12,7)
ax = feature_score2.plot('Feature', 'Score', kind='bar', color='c')
ax.set_title("Feature Importance using {}".format('LossFunctionChange'), fontsize = 14)
ax.set_xlabel("features")
plt.show()

# %%
features1 = feature_score1[feature_score1['Score'] >= 0]
features2 = feature_score2[feature_score2['Score'] >= 0]
features1
# Out:
#                           Feature     Score
# 123                        f2_age  0.010991
# 113                f2_hitsHead_PM  0.002266
# 82   f2_cumsum_hitsHeadSuccessful  0.002080
# 121                 f2_win_streak  0.001583
# 62                         f1_age  0.001453
# ..                            ...       ...
# 107                 f2_DQ_percent  0.000006
# 101          f2_hitsBody_accuracy  0.000005
# 66                  f1_isHomeCity  0.000002
# 58               f1_knockdowns_PM  0.000000
# 18           f1_cumsum_knockdowns  0.000000
#
# [83 rows x 2 columns]

# %%
train_cols = set(features1['Feature']) & set(features2['Feature'])
train_cols = features1['Feature']#.drop('odds_difference', axis=1)
train_cols.tolist()
# Out:
# ['f2_age',
#  'f2_hitsHead_PM',
#  'f2_cumsum_hitsHeadSuccessful',
#  'f2_win_streak',
#  'f1_age',
#  'f1_takedown_PM',
#  'f1_accentedHitsPositionParter_PM',
#  'f2_accentedHits_accuracy',
#  'f1_accentedHits_accuracy',
#  'f2_hitsHead_accuracy',
#  'f1_takedown_accuracy',
#  'f1_KO_percent',
#  'f2_cumsum_accentedHitsSuccessful',
#  'f1_armSpan',
#  'f1_win_streak',
#  'f2_cumsum_accentedHitsTotal',
#  'f2_cumsum_hitsHeadTotal',
#  'f2_SUB_percent',
#  'f1_hits_PM',
#  'f2_cumsum_accentedHitsPositionDistanceSuccessful',
#  'f2_cumsum_hitsTotal',
#  'f2_accentedHitsPositionDistance_accuracy',
#  'f2_loose_streak',
#  'f1_protectionPassage_PM',
#  'f2_cumsum_accentedHitsPositionDistanceTotal',
#  'f1_city',
#  'f2_cumsum_takedownTotal',
#  'f2_cumsum_accentedHitsPositionParterSuccessful',
#  'f2_armSpan',
#  'f1_cumsum_accentedHitsPositionParterSuccessful',
#  'f1_accentedHitsPositionDistance_accuracy',
#  'f1_hitsHead_accuracy',
#  'f2_cumsum_winner',
#  'f2_isHomeCountry',
#  'f2_cumsum_accentedHitsPositionParterTotal',
#  'f2_accentedHits_PM',
#  'f2_cumsum_takeovers',
#  'f2_hitsLegs_PM',
#  'f2_cumsum_hitsLegsTotal',
#  'f1_cumsum_takedownSuccessful',
#  'f1_isHomeCountry',
#  'f1_cumsum_accentedHitsPositionParterTotal',
#  'f1_hitsBody_accuracy',
#  'f2_KO_percent',
#  'f2_cumsum_duration',
#  'f1_hitsLegs_PM',
#  'f2_cumsum_accentedHitsPositionClinchSuccessful',
#  'f2_cumsum_protectionPassage',
#  'f2_cumsum_hitsLegsSuccessful',
#  'f2_cumsum_accentedHitsPositionClinchTotal',
#  'f1_cumsum_hitsHeadTotal',
#  'f1_cumsum_hitsLegsTotal',
#  'f2_cumsum_hitsSuccessful',
#  'f1_isHomeTimezone',
#  'f2_cumsum_winMethods_[DEC]',
#  'f2_knockdowns_PM',
#  'f1_cumsum_accentedHitsPositionDistanceTotal',
#  'f1_cumsum_takedownTotal',
#  'f1_cumsum_accentedHitsPositionDistanceSuccessful',
#  'f2_hitsBody_PM',
#  'f1_cumsum_duration',
#  'f2_cumsum_winMethods_[SUB]',
#  'f1_cumsum_protectionPassage',
#  'f2_cumsum_hitsBodySuccessful',
#  'f2_cumsum_winMethods_[DQ]',
#  'f1_cumsum_hitsTotal',
#  'f1_cumsum_hitsSuccessful',
#  'f1_loose_streak',
#  'f1_hits_accuracy',
#  'f2_accentedHitsPositionDistance_PM',
#  'f2_hitsLegs_accuracy',
#  'f2_accentedHitsPositionParter_PM',
#  'f2_cumsum_knockdowns',
#  'f1_cumsum_winMethods_[SUB]',
#  'f1_cumsum_submissionAttempts',
#  'f1_hitsBody_PM',
#  'f1_cumsum_winMethods_[DEC]',
#  'f2_isHomeCity',
#  'f2_DQ_percent',
#  'f2_hitsBody_accuracy',
#  'f1_isHomeCity',
#  'f1_knockdowns_PM',
#  'f1_cumsum_knockdowns']

# %%
features1[['Feature']]
# Out:
#                           Feature
# 123                        f2_age
# 113                f2_hitsHead_PM
# 82   f2_cumsum_hitsHeadSuccessful
# 121                 f2_win_streak
# 62                         f1_age
# ..                            ...
# 107                 f2_DQ_percent
# 101          f2_hitsBody_accuracy
# 66                  f1_isHomeCity
# 58               f1_knockdowns_PM
# 18           f1_cumsum_knockdowns
#
# [83 rows x 1 columns]
