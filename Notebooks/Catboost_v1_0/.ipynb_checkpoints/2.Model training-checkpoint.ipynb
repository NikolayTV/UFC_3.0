# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from catboost import CatBoostClassifier
import catboost 

import pandas as pd
import json
from pandas import json_normalize
from tqdm import tqdm_notebook as tqdm
import numpy as np
import ast
import json

import sys
import os
sys.path.append(os.path.join(sys.path[0], '../../'))

from core.train_utils import calculate_roi, get_winner_favorite, combine_df

pd.set_option('display.precision',6)
pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None
print(pd.__version__, catboost.__version__, np.__version__)
# Out:
# 1.2.2 0.22 1.19.2

# %%
with open('./data_models/generated_features_08.04.2021.txt', 'r') as outfile:
    generated_features = json.load(outfile)
fighter1_stats = generated_features['fighter1_stats']
fighter2_stats = generated_features['fighter2_stats']
difference_cols = generated_features['difference_cols']

cat_cols = ['city', 'country', 'is_fight_night', 'weightCategory.id', 
              'f1_country', 'f2_country', 'f1_city', 'f2_city']

train_cols = cat_cols + fighter1_stats + fighter2_stats + difference_cols + ['f1_odds', 'f2_odds', 'odds_difference']# +  #['f1_odds', 'f2_odds', 'odds_difference'] +

# %%
df = pd.read_csv('./data_models/events_joined_total_08.04.2021.csv', index_col=0)
df['eventDate.date'] = pd.to_datetime(df['eventDate.date'])
df['weightCategory.id'] = df['weightCategory.id'].astype('object')

print(df.shape)

df[cat_cols] = df[cat_cols].fillna('unknown')
df = df[(df['f1_count_of_fights'] >= 1) & (df['f2_count_of_fights'] >= 1)]

train1 = df[(df['eventDate.date'].dt.year > 2005) & (df['eventDate.date'].dt.year < 2020) &
           ((df['type']=='straight'))]

val1  = df[(df['eventDate.date'].dt.year == 2020) & (df['eventDate.date'].dt.year < 2021) &
          ((df['type']=='straight'))]
val1 = val1.reset_index()
val1 = val1[~val1['odds_difference'].isna()]
# 'f1_timezone', 'f2_timezone', 'timezone', 'f1_name', 'f2_name', 


train2 = df[(df['eventDate.date'].dt.year > 2005) & (df['eventDate.date'].dt.year < 2020) &
           ((df['type']=='reversed'))]

val2  = df[(df['eventDate.date'].dt.year == 2020) & (df['eventDate.date'].dt.year < 2021) &
          ((df['type']=='reversed'))]
val2 = val2.reset_index()
val2 = val2[~val2['odds_difference'].isna()]

print(train1.shape, val1.shape)
print(train2.shape, val2.shape)
# Out:
# (13754, 214)
# (3976, 214) (331, 215)
# (3976, 214) (331, 215)

# %%
val1
# Out:
#      index       city country  duration eventDate.date eventDate.timezone  \
# 0     6359  Las Vegas     USA      40.0     2020-01-18      Europe/Berlin
# 1     6360  Las Vegas     USA     106.0     2020-01-18      Europe/Berlin
# 2     6361  Las Vegas     USA     300.0     2020-01-18      Europe/Berlin
# 3     6362  Las Vegas     USA     300.0     2020-01-18      Europe/Berlin
# 4     6363  Las Vegas     USA     300.0     2020-01-18      Europe/Berlin
# ..     ...        ...     ...       ...            ...                ...
# 341   6792  Las Vegas     USA     300.0     2020-12-19      Europe/Berlin
# 342   6793  Las Vegas     USA     300.0     2020-12-19      Europe/Berlin
# 343   6794  Las Vegas     USA     300.0     2020-12-19      Europe/Berlin
# 344   6796  Las Vegas     USA     300.0     2020-12-19      Europe/Berlin
# 345   6797  Las Vegas     USA     300.0     2020-12-19      Europe/Berlin
#
#      fighterId_1  fighterId_2     id             name  rounds  \
# 0            347          211  39796          UFC 246     1.0
# 1            292          404  39804          UFC 246     2.0
# 2            562          427  39805          UFC 246     3.0
# 3            521          407  39807          UFC 246     3.0
# 4            525          233  39820          UFC 246     3.0
# ..           ...          ...    ...              ...     ...
# 341         3419          286  40352  UFC Fight Night     3.0
# 342         1995          653  40354  UFC Fight Night     3.0
# 343          161          667  40356  UFC Fight Night     3.0
# 344          244          292  40383  UFC Fight Night     3.0
# 345          645          633  40387  UFC Fight Night     3.0
#
#                 timezone  weightCategory.id       weightCategory.name  \
# 0    America/Los_Angeles                 14             Не определена
# 1    America/Los_Angeles                 14             Не определена
# 2    America/Los_Angeles                 14             Не определена
# 3    America/Los_Angeles                 14             Не определена
# 4    America/Los_Angeles                 14             Не определена
# ..                   ...                ...                       ...
# 341  America/Los_Angeles                  6           Полусредний вес
# 342  America/Los_Angeles                  7               Средний вес
# 343  America/Los_Angeles                 12     Женский легчайший вес
# 344  America/Los_Angeles                  6           Полусредний вес
# 345  America/Los_Angeles                 11  Женский наилегчайший вес
#
#     winMethods  winnerId            f1_name            f2_name  f1_odds  \
# 0       ['KO']     211.0     Donald Cerrone     Conor McGregor     3.61
# 1      ['SUB']     404.0     Anthony Pettis     Diego Ferreira     2.89
# 2      ['DEC']     427.0  Raquel Pennington         Holly Holm     2.12
# 3      ['DEC']     521.0       Sodiq Yusuff         Andre Fili     1.70
# 4      ['DEC']     233.0      Maycee Barber  Roxanne Modafferi     1.11
# ..         ...       ...                ...                ...      ...
# 341    ['DEC']     286.0     Khaos Williams     Michel Pereira     2.06
# 342    ['DEC']     653.0     Antonio Arroyo         Deron Winn     1.61
# 343    ['DEC']     161.0     Pannie Kianzad     Sijara Eubanks     2.36
# 344    ['DEC']     292.0        Alex Morono     Anthony Pettis     2.89
# 345    ['DEC']     633.0  Gillian Robertson       Taila Santos     1.94
#
#      f2_odds  f1_age  f2_age  f1_height  f2_height  f1_armSpan  f2_armSpan  \
# 0       1.29    36.0    31.0     185.42     175.26      185.42      187.96
# 1       1.42    32.0    35.0     177.80     175.26      182.88      187.96
# 2       1.73    31.0    38.0     170.18     172.72      170.18      175.26
# 3       2.17    26.0    29.0     175.26     180.34      180.34      187.96
# 4       6.79    21.0    37.0     165.10     170.18      165.10      175.26
# ..       ...     ...     ...        ...        ...         ...         ...
# 341     1.83    26.0    27.0     182.88     185.42      182.88      185.42
# 342     2.41    31.0    31.0     190.50     167.64      185.42      177.80
# 343     1.64    29.0    35.0     170.18     162.56      167.64      170.18
# 344     1.44    30.0    33.0     180.34     177.80      182.88      182.88
# 345     1.93    25.0    27.0     165.10     165.10      160.02      172.72
#
#      f1_legSwing  f2_legSwing f1_country f2_country        f1_city  \
# 0         102.87       101.60        USA    Ireland         Denver
# 1         101.60       101.60        USA     Brazil      Milwaukee
# 2          93.98        96.52        USA        USA        unknown
# 3         101.70       101.60    Nigeria        USA          Lagos
# 4         101.70        96.52        USA        USA        unknown
# ..           ...          ...        ...        ...            ...
# 341       101.70       101.70    unknown     Brazil        unknown
# 342       101.70       101.70    unknown        USA        unknown
# 343       101.70       101.70       Iran        USA          Ahvaz
# 344        99.06       101.60        USA        USA        unknown
# 345        90.17       101.70     Canada     Brazil  Niagara Falls
#
#             f2_city       f1_timezone        f2_timezone  f1_isHomeCity  \
# 0            Dublin    America/Denver   America/New_York              0
# 1            Manaus   America/Chicago     America/Manaus              0
# 2           unknown  America/New_York   America/New_York              0
# 3       Federal Way      Africa/Lagos   America/New_York              0
# 4        Wilmington  America/New_York   America/New_York              0
# ..              ...               ...                ...            ...
# 341          Tucuma               NaN      America/Belem              0
# 342         Liberty               NaN                NaN              0
# 343         unknown       Asia/Tehran   America/New_York              0
# 344       Milwaukee  America/New_York    America/Chicago              0
# 345  Jaragua do Sul  America/New_York  America/Sao_Paulo              0
#
#      f2_isHomeCity  f1_isHomeCountry  f2_isHomeCountry  f1_isHomeTimezone  \
# 0                0                 1                 0                  0
# 1                0                 1                 0                  0
# 2                0                 1                 1                  0
# 3                0                 0                 1                  0
# 4                0                 1                 1                  0
# ..             ...               ...               ...                ...
# 341              0                 0                 0                  0
# 342              0                 0                 1                  0
# 343              0                 0                 1                  0
# 344              0                 1                 1                  0
# 345              0                 0                 0                  0
#
#      f2_isHomeTimezone  f1_cumsum_duration  f1_cumsum_winner  \
# 0                    0              7959.0                25
# 1                    0              4013.0                10
# 2                    0              3153.0                 7
# 3                    0               688.0                 3
# 4                    0               486.0                 3
# ..                 ...                 ...               ...
# 341                  0                57.0                 2
# 342                  0               600.0                 0
# 343                  0              1031.0                 2
# 344                  0              2473.0                 7
# 345                  0              1772.0                 6
#
#      f1_cumsum_hitsTotal  f1_cumsum_hitsSuccessful  f1_cumsum_takedownTotal  \
# 0                 1552.0                     798.0                     32.0
# 1                  553.0                     324.0                      7.0
# 2                  539.0                     312.0                     17.0
# 3                  224.0                     120.0                      0.0
# 4                  179.0                     108.0                      1.0
# ..                   ...                       ...                      ...
# 341                 27.0                      15.0                      1.0
# 342                 18.0                      14.0                      0.0
# 343                161.0                      69.0                      0.0
# 344                616.0                     310.0                      5.0
# 345                207.0                     121.0                     16.0
#
#      f1_cumsum_takedownSuccessful  f1_cumsum_submissionAttempts  \
# 0                            11.0                          10.0
# 1                             2.0                           9.0
# 2                             9.0                           5.0
# 3                             0.0                           0.0
# 4                             1.0                           0.0
# ..                            ...                           ...
# 341                           0.0                           0.0
# 342                           0.0                           0.0
# 343                           0.0                           1.0
# 344                           2.0                           4.0
# 345                           7.0                           4.0
#
#      f1_cumsum_takeovers  f1_cumsum_accentedHitsTotal  \
# 0                    1.0                       1460.0
# 1                    4.0                        454.0
# 2                    0.0                        378.0
# 3                    0.0                        190.0
# 4                    0.0                        171.0
# ..                   ...                          ...
# 341                  0.0                         27.0
# 342                  1.0                          8.0
# 343                  0.0                        146.0
# 344                  3.0                        555.0
# 345                  5.0                        152.0
#
#      f1_cumsum_accentedHitsSuccessful  f1_cumsum_knockdowns  \
# 0                               718.0                   0.0
# 1                               231.0                   0.0
# 2                               179.0                   0.0
# 3                                88.0                   0.0
# 4                               100.0                   0.0
# ..                                ...                   ...
# 341                              15.0                   0.0
# 342                               5.0                   0.0
# 343                              56.0                   0.0
# 344                             257.0                   0.0
# 345                              77.0                   0.0
#
#      f1_cumsum_protectionPassage  f1_cumsum_hitsHeadTotal  \
# 0                           14.0                   1040.0
# 1                            4.0                    351.0
# 2                            6.0                    287.0
# 3                            1.0                    160.0
# 4                            1.0                    148.0
# ..                           ...                      ...
# 341                          0.0                     19.0
# 342                          0.0                      7.0
# 343                          0.0                    121.0
# 344                          5.0                    498.0
# 345                         13.0                    133.0
#
#      f1_cumsum_hitsHeadSuccessful  f1_cumsum_hitsBodyTotal  \
# 0                           393.0                    228.0
# 1                           151.0                     66.0
# 2                           111.0                     63.0
# 3                            65.0                     18.0
# 4                            81.0                     16.0
# ..                            ...                      ...
# 341                           8.0                      4.0
# 342                           4.0                      0.0
# 343                          38.0                     14.0
# 344                         215.0                     40.0
# 345                          64.0                      9.0
#
#      f1_cumsum_hitsBodySuccessful  f1_cumsum_hitsLegsTotal  \
# 0                           159.0                    192.0
# 1                            45.0                     37.0
# 2                            42.0                     28.0
# 3                            14.0                     12.0
# 4                            13.0                      7.0
# ..                            ...                      ...
# 341                           4.0                      4.0
# 342                           0.0                      1.0
# 343                           7.0                     11.0
# 344                          29.0                     17.0
# 345                           6.0                     10.0
#
#      f1_cumsum_hitsLegsSuccessful  \
# 0                           166.0
# 1                            35.0
# 2                            26.0
# 3                             9.0
# 4                             6.0
# ..                            ...
# 341                           3.0
# 342                           1.0
# 343                          11.0
# 344                          13.0
# 345                           7.0
#
#      f1_cumsum_accentedHitsPositionDistanceTotal  \
# 0                                         1245.0
# 1                                          406.0
# 2                                          259.0
# 3                                          160.0
# 4                                          100.0
# ..                                           ...
# 341                                         19.0
# 342                                          2.0
# 343                                        135.0
# 344                                        461.0
# 345                                         78.0
#
#      f1_cumsum_accentedHitsPositionDistanceSuccessful  \
# 0                                               571.0
# 1                                               195.0
# 2                                                97.0
# 3                                                69.0
# 4                                                42.0
# ..                                                ...
# 341                                               8.0
# 342                                               1.0
# 343                                              49.0
# 344                                             193.0
# 345                                              24.0
#
#      f1_cumsum_accentedHitsPositionClinchTotal  \
# 0                                        103.0
# 1                                         27.0
# 2                                         69.0
# 3                                         11.0
# 4                                         36.0
# ..                                         ...
# 341                                        4.0
# 342                                        0.0
# 343                                       11.0
# 344                                       46.0
# 345                                        3.0
#
#      f1_cumsum_accentedHitsPositionClinchSuccessful  \
# 0                                              65.0
# 1                                              19.0
# 2                                              44.0
# 3                                               6.0
# 4                                              32.0
# ..                                              ...
# 341                                             4.0
# 342                                             0.0
# 343                                             7.0
# 344                                            35.0
# 345                                             3.0
#
#      f1_cumsum_accentedHitsPositionParterTotal  \
# 0                                        112.0
# 1                                         21.0
# 2                                         50.0
# 3                                         19.0
# 4                                         35.0
# ..                                         ...
# 341                                        4.0
# 342                                        6.0
# 343                                        0.0
# 344                                       48.0
# 345                                       71.0
#
#      f1_cumsum_accentedHitsPositionParterSuccessful  \
# 0                                              82.0
# 1                                              17.0
# 2                                              38.0
# 3                                              13.0
# 4                                              26.0
# ..                                              ...
# 341                                             3.0
# 342                                             4.0
# 343                                             0.0
# 344                                            29.0
# 345                                            50.0
#
#      f1_cumsum_winMethods_[DEC]  f1_cumsum_winMethods_[DQ]  \
# 0                            12                          0
# 1                             7                          0
# 2                             8                          0
# 3                             1                          0
# 4                             0                          0
# ..                          ...                        ...
# 341                           0                          0
# 342                           2                          0
# 343                           2                          0
# 344                           7                          0
# 345                           1                          0
#
#      f1_cumsum_winMethods_[KO]  f1_cumsum_winMethods_[SUB]  f1_hits_accuracy  \
# 0                           16                           7          0.514175
# 1                            6                           5          0.585895
# 2                            1                           2          0.578850
# 3                            2                           0          0.535714
# 4                            3                           0          0.603352
# ..                         ...                         ...               ...
# 341                          2                           0          0.555556
# 342                          0                           0          0.777778
# 343                          0                           1          0.428571
# 344                          2                           1          0.503247
# 345                          2                           5          0.584541
#
#      f1_takedown_accuracy  f1_accentedHits_accuracy  f1_hitsHead_accuracy  \
# 0                0.343750                  0.491781              0.377885
# 1                0.285714                  0.508811              0.430199
# 2                0.529412                  0.473545              0.386760
# 3                     NaN                  0.463158              0.406250
# 4                1.000000                  0.584795              0.547297
# ..                    ...                       ...                   ...
# 341              0.000000                  0.555556              0.421053
# 342                   NaN                  0.625000              0.571429
# 343                   NaN                  0.383562              0.314050
# 344              0.400000                  0.463063              0.431727
# 345              0.437500                  0.506579              0.481203
#
#      f1_hitsBody_accuracy  f1_hitsLegs_accuracy  \
# 0                0.697368              0.864583
# 1                0.681818              0.945946
# 2                0.666667              0.928571
# 3                0.777778              0.750000
# 4                0.812500              0.857143
# ..                    ...                   ...
# 341              1.000000              0.750000
# 342                   NaN              1.000000
# 343              0.500000              1.000000
# 344              0.725000              0.764706
# 345              0.666667              0.700000
#
#      f1_accentedHitsPositionDistance_accuracy  \
# 0                                    0.458635
# 1                                    0.480296
# 2                                    0.374517
# 3                                    0.431250
# 4                                    0.420000
# ..                                        ...
# 341                                  0.421053
# 342                                  0.500000
# 343                                  0.362963
# 344                                  0.418655
# 345                                  0.307692
#
#      f1_accentedHitsPositionClinch_accuracy  \
# 0                                  0.631068
# 1                                  0.703704
# 2                                  0.637681
# 3                                  0.545455
# 4                                  0.888889
# ..                                      ...
# 341                                1.000000
# 342                                     NaN
# 343                                0.636364
# 344                                0.760870
# 345                                1.000000
#
#      f1_accentedHitsPositionParter_accuracy  f1_DEC_percent  f1_DQ_percent  \
# 0                                  0.732143        0.480000            0.0
# 1                                  0.809524        0.700000            0.0
# 2                                  0.760000        1.142857            0.0
# 3                                  0.684211        0.333333            0.0
# 4                                  0.742857        0.000000            0.0
# ..                                      ...             ...            ...
# 341                                0.750000        0.000000            0.0
# 342                                0.666667             inf            NaN
# 343                                     NaN        1.000000            0.0
# 344                                0.604167        1.000000            0.0
# 345                                0.704225        0.166667            0.0
#
#      f1_KO_percent  f1_SUB_percent  f1_hits_PM  f1_takedown_PM  \
# 0         0.640000        0.280000    6.015831        0.082925
# 1         0.600000        0.500000    4.844256        0.029903
# 2         0.142857        0.285714    5.937203        0.171265
# 3         0.666667        0.000000   10.465116        0.000000
# 4         1.000000        0.000000   13.333333        0.123457
# ..             ...             ...         ...             ...
# 341       1.000000        0.000000   15.789474        0.000000
# 342            NaN             NaN    1.400000        0.000000
# 343       0.000000        0.500000    4.015519        0.000000
# 344       0.285714        0.142857    7.521229        0.048524
# 345       0.333333        0.833333    4.097065        0.237020
#
#      f1_accentedHits_PM  f1_hitsHead_PM  f1_hitsBody_PM  f1_hitsLegs_PM  \
# 0              5.412740        2.962684        1.198643        1.251413
# 1              3.453775        2.257663        0.672813        0.523299
# 2              3.406280        2.112274        0.799239        0.494767
# 3              7.674419        5.668605        1.220930        0.784884
# 4             12.345679       10.000000        1.604938        0.740741
# ..                  ...             ...             ...             ...
# 341           15.789474        8.421053        4.210526        3.157895
# 342            0.500000        0.400000        0.000000        0.100000
# 343            3.258972        2.211445        0.407371        0.640155
# 344            6.235342        5.216336        0.703599        0.315406
# 345            2.607223        2.167043        0.203160        0.237020
#
#      f1_accentedHitsPositionDistance_PM  f1_accentedHitsPositionClinch_PM  \
# 0                              4.304561                          0.490011
# 1                              2.915525                          0.284077
# 2                              1.845861                          0.837298
# 3                              6.017442                          0.523256
# 4                              5.185185                          3.950617
# ..                                  ...                               ...
# 341                            8.421053                          4.210526
# 342                            0.100000                          0.000000
# 343                            2.851600                          0.407371
# 344                            4.682572                          0.849171
# 345                            0.812641                          0.101580
#
#      f1_accentedHitsPositionParter_PM  f1_knockdowns_PM  \
# 0                            0.618168               0.0
# 1                            0.254174               0.0
# 2                            0.723121               0.0
# 3                            1.133721               0.0
# 4                            3.209877               0.0
# ..                                ...               ...
# 341                          3.157895               0.0
# 342                          0.400000               0.0
# 343                          0.000000               0.0
# 344                          0.703599               0.0
# 345                          1.693002               0.0
#
#      f1_protectionPassage_PM  f1_win_streak  f1_loose_streak  \
# 0                   0.105541              0                2
# 1                   0.059806              0                1
# 2                   0.114177              1                0
# 3                   0.087209              3                0
# 4                   0.123457              3                0
# ..                       ...            ...              ...
# 341                 0.000000              2                0
# 342                 0.000000              0                2
# 343                 0.000000              2                0
# 344                 0.121310              1                0
# 345                 0.440181              2                0
#
#      f1_count_of_fights  f2_cumsum_duration  f2_cumsum_winner  \
# 0                    35              2061.0                 9
# 1                    18              1777.0                 7
# 2                    11              2388.0                 5
# 3                     3              3081.0                 8
# 4                     3              1777.0                 2
# ..                  ...                 ...               ...
# 341                   2               875.0                 2
# 342                   2               733.0                 1
# 343                   4              2100.0                 4
# 344                  10              4419.0                11
# 345                   8               876.0                 1
#
#      f2_cumsum_hitsTotal  f2_cumsum_hitsSuccessful  f2_cumsum_takedownTotal  \
# 0                  423.0                     260.0                      6.0
# 1                  550.0                     270.0                      6.0
# 2                  491.0                     219.0                      6.0
# 3                  549.0                     236.0                     23.0
# 4                  380.0                     172.0                     11.0
# ..                   ...                       ...                      ...
# 341                169.0                      97.0                      4.0
# 342                182.0                      83.0                      8.0
# 343                521.0                     263.0                      8.0
# 344                607.0                     355.0                      7.0
# 345                138.0                      51.0                      2.0
#
#      f2_cumsum_takedownSuccessful  f2_cumsum_submissionAttempts  \
# 0                             4.0                           0.0
# 1                             2.0                           2.0
# 2                             3.0                           1.0
# 3                             9.0                           1.0
# 4                             2.0                           1.0
# ..                            ...                           ...
# 341                           3.0                           1.0
# 342                           2.0                           0.0
# 343                           4.0                           3.0
# 344                           2.0                           9.0
# 345                           1.0                           0.0
#
#      f2_cumsum_takeovers  f2_cumsum_accentedHitsTotal  \
# 0                    0.0                        350.0
# 1                    1.0                        472.0
# 2                    0.0                        421.0
# 3                    1.0                        496.0
# 4                    2.0                        293.0
# ..                   ...                          ...
# 341                  0.0                        143.0
# 342                  0.0                        177.0
# 343                  0.0                        454.0
# 344                  4.0                        506.0
# 345                  0.0                        132.0
#
#      f2_cumsum_accentedHitsSuccessful  f2_cumsum_knockdowns  \
# 0                               189.0                   0.0
# 1                               203.0                   0.0
# 2                               156.0                   0.0
# 3                               186.0                   0.0
# 4                                96.0                   0.0
# ..                                ...                   ...
# 341                              77.0                   0.0
# 342                              79.0                   0.0
# 343                             206.0                   0.0
# 344                             260.0                   0.0
# 345                              45.0                   0.0
#
#      f2_cumsum_protectionPassage  f2_cumsum_hitsHeadTotal  \
# 0                            6.0                    299.0
# 1                           10.0                    401.0
# 2                            5.0                    308.0
# 3                            5.0                    436.0
# 4                            4.0                    266.0
# ..                           ...                      ...
# 341                          0.0                     90.0
# 342                          0.0                    156.0
# 343                          7.0                    394.0
# 344                          4.0                    397.0
# 345                          2.0                     95.0
#
#      f2_cumsum_hitsHeadSuccessful  f2_cumsum_hitsBodyTotal  \
# 0                           156.0                     38.0
# 1                           156.0                     56.0
# 2                            84.0                     67.0
# 3                           145.0                     33.0
# 4                            83.0                     20.0
# ..                            ...                      ...
# 341                          35.0                     44.0
# 342                          61.0                     15.0
# 343                         159.0                     51.0
# 344                         176.0                     71.0
# 345                          28.0                     21.0
#
#      f2_cumsum_hitsBodySuccessful  f2_cumsum_hitsLegsTotal  \
# 0                            24.0                     13.0
# 1                            33.0                     15.0
# 2                            40.0                     46.0
# 3                            23.0                     27.0
# 4                            10.0                      7.0
# ..                            ...                      ...
# 341                          33.0                      9.0
# 342                          12.0                      6.0
# 343                          38.0                      9.0
# 344                          48.0                     38.0
# 345                           7.0                     16.0
#
#      f2_cumsum_hitsLegsSuccessful  \
# 0                             9.0
# 1                            14.0
# 2                            32.0
# 3                            18.0
# 4                             3.0
# ..                            ...
# 341                           9.0
# 342                           6.0
# 343                           9.0
# 344                          36.0
# 345                          10.0
#
#      f2_cumsum_accentedHitsPositionDistanceTotal  \
# 0                                          273.0
# 1                                          398.0
# 2                                          389.0
# 3                                          456.0
# 4                                          230.0
# ..                                           ...
# 341                                        134.0
# 342                                        151.0
# 343                                        386.0
# 344                                        456.0
# 345                                        121.0
#
#      f2_cumsum_accentedHitsPositionDistanceSuccessful  \
# 0                                               135.0
# 1                                               145.0
# 2                                               131.0
# 3                                               159.0
# 4                                                54.0
# ..                                                ...
# 341                                              68.0
# 342                                              62.0
# 343                                             157.0
# 344                                             222.0
# 345                                              38.0
#
#      f2_cumsum_accentedHitsPositionClinchTotal  \
# 0                                         16.0
# 1                                         18.0
# 2                                         15.0
# 3                                         16.0
# 4                                          8.0
# ..                                         ...
# 341                                        9.0
# 342                                       25.0
# 343                                       26.0
# 344                                       29.0
# 345                                        1.0
#
#      f2_cumsum_accentedHitsPositionClinchSuccessful  \
# 0                                              13.0
# 1                                              14.0
# 2                                              12.0
# 3                                               8.0
# 4                                               8.0
# ..                                              ...
# 341                                             9.0
# 342                                            16.0
# 343                                            17.0
# 344                                            21.0
# 345                                             1.0
#
#      f2_cumsum_accentedHitsPositionParterTotal  \
# 0                                         61.0
# 1                                         53.0
# 2                                         17.0
# 3                                         24.0
# 4                                         55.0
# ..                                         ...
# 341                                        0.0
# 342                                        1.0
# 343                                       42.0
# 344                                       21.0
# 345                                       10.0
#
#      f2_cumsum_accentedHitsPositionParterSuccessful  \
# 0                                              41.0
# 1                                              42.0
# 2                                              13.0
# 3                                              19.0
# 4                                              34.0
# ..                                              ...
# 341                                             0.0
# 342                                             1.0
# 343                                            32.0
# 344                                            17.0
# 345                                             6.0
#
#      f2_cumsum_winMethods_[DEC]  f2_cumsum_winMethods_[DQ]  \
# 0                             2                          0
# 1                             4                          0
# 2                             6                          0
# 3                             7                          0
# 4                             5                          0
# ..                          ...                        ...
# 341                           1                          1
# 342                           2                          0
# 343                           7                          0
# 344                           8                          0
# 345                           2                          0
#
#      f2_cumsum_winMethods_[KO]  f2_cumsum_winMethods_[SUB]  f2_hits_accuracy  \
# 0                            7                           2          0.614657
# 1                            4                           1          0.490909
# 2                            3                           1          0.446029
# 3                            4                           2          0.429872
# 4                            1                           1          0.452632
# ..                         ...                         ...               ...
# 341                          1                           1          0.573964
# 342                          0                           1          0.456044
# 343                          0                           0          0.504798
# 344                          6                           6          0.584843
# 345                          0                           1          0.369565
#
#      f2_takedown_accuracy  f2_accentedHits_accuracy  f2_hitsHead_accuracy  \
# 0                0.666667                  0.540000              0.521739
# 1                0.333333                  0.430085              0.389027
# 2                0.500000                  0.370546              0.272727
# 3                0.391304                  0.375000              0.332569
# 4                0.181818                  0.327645              0.312030
# ..                    ...                       ...                   ...
# 341              0.750000                  0.538462              0.388889
# 342              0.250000                  0.446328              0.391026
# 343              0.500000                  0.453744              0.403553
# 344              0.285714                  0.513834              0.443325
# 345              0.500000                  0.340909              0.294737
#
#      f2_hitsBody_accuracy  f2_hitsLegs_accuracy  \
# 0                0.631579              0.692308
# 1                0.589286              0.933333
# 2                0.597015              0.695652
# 3                0.696970              0.666667
# 4                0.500000              0.428571
# ..                    ...                   ...
# 341              0.750000              1.000000
# 342              0.800000              1.000000
# 343              0.745098              1.000000
# 344              0.676056              0.947368
# 345              0.333333              0.625000
#
#      f2_accentedHitsPositionDistance_accuracy  \
# 0                                    0.494505
# 1                                    0.364322
# 2                                    0.336761
# 3                                    0.348684
# 4                                    0.234783
# ..                                        ...
# 341                                  0.507463
# 342                                  0.410596
# 343                                  0.406736
# 344                                  0.486842
# 345                                  0.314050
#
#      f2_accentedHitsPositionClinch_accuracy  \
# 0                                  0.812500
# 1                                  0.777778
# 2                                  0.800000
# 3                                  0.500000
# 4                                  1.000000
# ..                                      ...
# 341                                1.000000
# 342                                0.640000
# 343                                0.653846
# 344                                0.724138
# 345                                1.000000
#
#      f2_accentedHitsPositionParter_accuracy  f2_DEC_percent  f2_DQ_percent  \
# 0                                  0.672131        0.222222            0.0
# 1                                  0.792453        0.571429            0.0
# 2                                  0.764706        1.200000            0.0
# 3                                  0.791667        0.875000            0.0
# 4                                  0.618182        2.500000            0.0
# ..                                      ...             ...            ...
# 341                                     NaN        0.500000            0.5
# 342                                1.000000        2.000000            0.0
# 343                                0.761905        1.750000            0.0
# 344                                0.809524        0.727273            0.0
# 345                                0.600000        2.000000            0.0
#
#      f2_KO_percent  f2_SUB_percent  f2_hits_PM  f2_takedown_PM  \
# 0         0.777778        0.222222    7.569141        0.116448
# 1         0.571429        0.142857    9.116488        0.067530
# 2         0.600000        0.200000    5.502513        0.075377
# 3         0.500000        0.250000    4.595910        0.175268
# 4         0.500000        0.500000    5.807541        0.067530
# ..             ...             ...         ...             ...
# 341       0.500000        0.500000    6.651429        0.205714
# 342       0.000000        1.000000    6.793997        0.163711
# 343       0.000000        0.000000    7.514286        0.114286
# 344       0.545455        0.545455    4.820095        0.027155
# 345       0.000000        1.000000    3.493151        0.068493
#
#      f2_accentedHits_PM  f2_hitsHead_PM  f2_hitsBody_PM  f2_hitsLegs_PM  \
# 0              5.502183        4.541485        0.698690        0.262009
# 1              6.854249        5.267304        1.114237        0.472707
# 2              3.919598        2.110553        1.005025        0.804020
# 3              3.622201        2.823759        0.447907        0.350536
# 4              3.241418        2.802476        0.337648        0.101294
# ..                  ...             ...             ...             ...
# 341            5.280000        2.400000        2.262857        0.617143
# 342            6.466576        4.993179        0.982265        0.491132
# 343            5.885714        4.542857        1.085714        0.257143
# 344            3.530210        2.389681        0.651731        0.488798
# 345            3.082192        1.917808        0.479452        0.684932
#
#      f2_accentedHitsPositionDistance_PM  f2_accentedHitsPositionClinch_PM  \
# 0                              3.930131                          0.378457
# 1                              4.895892                          0.472707
# 2                              3.291457                          0.301508
# 3                              3.096397                          0.155794
# 4                              1.823298                          0.270118
# ..                                  ...                               ...
# 341                            4.662857                          0.617143
# 342                            5.075034                          1.309686
# 343                            4.485714                          0.485714
# 344                            3.014257                          0.285132
# 345                            2.602740                          0.068493
#
#      f2_accentedHitsPositionParter_PM  f2_knockdowns_PM  \
# 0                            1.193595               0.0
# 1                            1.418120               0.0
# 2                            0.326633               0.0
# 3                            0.370010               0.0
# 4                            1.148002               0.0
# ..                                ...               ...
# 341                          0.000000               0.0
# 342                          0.081855               0.0
# 343                          0.914286               0.0
# 344                          0.230821               0.0
# 345                          0.410959               0.0
#
#      f2_protectionPassage_PM  f2_win_streak  f2_loose_streak  \
# 0                   0.174672              0                1
# 1                   0.337648              5                0
# 2                   0.125628              0                1
# 3                   0.097371              2                0
# 4                   0.135059              0                1
# ..                       ...            ...              ...
# 341                 0.000000              1                0
# 342                 0.000000              0                2
# 343                 0.200000              0                1
# 344                 0.054311              1                0
# 345                 0.136986              1                0
#
#      f2_count_of_fights      type  cumsum_duration_difference  \
# 0                    11  straight                      5898.0
# 1                     9  straight                      2236.0
# 2                    10  straight                       765.0
# 3                    13  straight                     -2393.0
# 4                     7  straight                     -1291.0
# ..                  ...       ...                         ...
# 341                   4  straight                      -818.0
# 342                   3  straight                      -133.0
# 343                   7  straight                     -1069.0
# 344                  20  straight                     -1946.0
# 345                   3  straight                       896.0
#
#      cumsum_winner_difference  cumsum_hitsTotal_difference  \
# 0                        16.0                       1129.0
# 1                         3.0                          3.0
# 2                         2.0                         48.0
# 3                        -5.0                       -325.0
# ...
#
#      cumsum_accentedHitsPositionParterSuccessful_difference  \
# 0                                                 41.0
# 1                                                -25.0
# 2                                                 25.0
# 3                                                 -6.0
# 4                                                 -8.0
# ..                                                 ...
# 341                                                3.0
# 342                                                3.0
# 343                                              -32.0
# 344                                               12.0
# 345                                               44.0
#
#      cumsum_winMethods_[DEC]_difference  cumsum_winMethods_[DQ]_difference  \
# 0                                  10.0                                0.0
# 1                                   3.0                                0.0
# 2                                   2.0                                0.0
# 3                                  -6.0                                0.0
# 4                                  -5.0                                0.0
# ..                                  ...                                ...
# 341                                -1.0                               -1.0
# 342                                 0.0                                0.0
# 343                                -5.0                                0.0
# 344                                -1.0                                0.0
# 345                                -1.0                                0.0
#
#      cumsum_winMethods_[KO]_difference  cumsum_winMethods_[SUB]_difference  \
# 0                                  9.0                                 5.0
# 1                                  2.0                                 4.0
# 2                                 -2.0                                 1.0
# 3                                 -2.0                                -2.0
# 4                                  2.0                                -1.0
# ..                                 ...                                 ...
# 341                                1.0                                -1.0
# 342                                0.0                                -1.0
# 343                                0.0                                 1.0
# 344                               -4.0                                -5.0
# 345                                2.0                                 4.0
#
#      hits_accuracy_difference  takedown_accuracy_difference  \
# 0                   -0.100482                     -0.322917
# 1                    0.094986                     -0.047619
# 2                    0.132821                      0.029412
# 3                    0.105842                           NaN
# 4                    0.150720                      0.818182
# ..                        ...                           ...
# 341                 -0.018409                     -0.750000
# 342                  0.321734                           NaN
# 343                 -0.076227                           NaN
# 344                 -0.081597                      0.114286
# 345                  0.214976                     -0.062500
#
#      accentedHits_accuracy_difference  hitsHead_accuracy_difference  \
# 0                           -0.048219                     -0.143855
# 1                            0.078726                      0.041172
# 2                            0.102999                      0.114032
# 3                            0.088158                      0.073681
# 4                            0.257150                      0.235267
# ..                                ...                           ...
# 341                          0.017094                      0.032164
# 342                          0.178672                      0.180403
# 343                         -0.070183                     -0.089504
# 344                         -0.050771                     -0.011598
# 345                          0.165670                      0.186466
#
#      hitsBody_accuracy_difference  hitsLegs_accuracy_difference  \
# 0                        0.065789                      0.172276
# 1                        0.092532                      0.012613
# 2                        0.069652                      0.232919
# 3                        0.080808                      0.083333
# 4                        0.312500                      0.428571
# ..                            ...                           ...
# 341                      0.250000                     -0.250000
# 342                           NaN                      0.000000
# 343                     -0.245098                      0.000000
# 344                      0.048944                     -0.182663
# 345                      0.333333                      0.075000
#
#      accentedHitsPositionDistance_accuracy_difference  \
# 0                                           -0.035871
# 1                                            0.115974
# 2                                            0.037756
# 3                                            0.082566
# 4                                            0.185217
# ..                                                ...
# 341                                         -0.086410
# 342                                          0.089404
# 343                                         -0.043773
# 344                                         -0.068187
# 345                                         -0.006357
#
#      accentedHitsPositionClinch_accuracy_difference  \
# 0                                         -0.181432
# 1                                         -0.074074
# 2                                         -0.162319
# 3                                          0.045455
# 4                                         -0.111111
# ..                                              ...
# 341                                        0.000000
# 342                                             NaN
# 343                                       -0.017483
# 344                                        0.036732
# 345                                        0.000000
#
#      accentedHitsPositionParter_accuracy_difference  DEC_percent_difference  \
# 0                                          0.060012                0.257778
# 1                                          0.017071                0.128571
# 2                                         -0.004706               -0.057143
# 3                                         -0.107456               -0.541667
# 4                                          0.124675               -2.500000
# ..                                              ...                     ...
# 341                                             NaN               -0.500000
# 342                                       -0.333333                     inf
# 343                                             NaN               -0.750000
# 344                                       -0.205357                0.272727
# 345                                        0.104225               -1.833333
#
#      DQ_percent_difference  KO_percent_difference  SUB_percent_difference  \
# 0                      0.0              -0.137778                0.057778
# 1                      0.0               0.028571                0.357143
# 2                      0.0              -0.457143                0.085714
# 3                      0.0               0.166667               -0.250000
# 4                      0.0               0.500000               -0.500000
# ..                     ...                    ...                     ...
# 341                   -0.5               0.500000               -0.500000
# 342                    NaN                    NaN                     NaN
# 343                    0.0               0.000000                0.500000
# 344                    0.0              -0.259740               -0.402597
# 345                    0.0               0.333333               -0.166667
#
#      hits_PM_difference  takedown_PM_difference  accentedHits_PM_difference  \
# 0             -1.553310               -0.033523                   -0.089443
# 1             -4.272232               -0.037627                   -3.400474
# 2              0.434690                0.095889                   -0.513318
# 3              5.869206               -0.175268                    4.052218
# 4              7.525793                0.055927                    9.104261
# ..                  ...                     ...                         ...
# 341            9.138045               -0.205714                   10.509474
# 342           -5.393997               -0.163711                   -5.966576
# 343           -3.498767               -0.114286                   -2.626742
# 344            2.701134                0.021369                    2.705131
# 345            0.603915                0.168527                   -0.474968
#
#      hitsHead_PM_difference  hitsBody_PM_difference  hitsLegs_PM_difference  \
# 0                 -1.578801                0.499953                0.989405
# 1                 -3.009642               -0.441424                0.050592
# 2                  0.001721               -0.205786               -0.309253
# 3                  2.844846                0.773024                0.434348
# 4                  7.197524                1.267291                0.639446
# ..                      ...                     ...                     ...
# 341                6.021053                1.947669                2.540752
# 342               -4.593179               -0.982265               -0.391132
# 343               -2.331412               -0.678343                0.383012
# 344                2.826656                0.051868               -0.173392
# 345                0.249235               -0.276292               -0.447911
#
#      accentedHitsPositionDistance_PM_difference  \
# 0                                      0.374430
# 1                                     -1.980367
# 2                                     -1.445596
# 3                                      2.921045
# 4                                      3.361887
# ..                                          ...
# 341                                    3.758195
# 342                                   -4.975034
# 343                                   -1.634114
# 344                                    1.668315
# 345                                   -1.790099
#
#      accentedHitsPositionClinch_PM_difference  \
# 0                                    0.111554
# 1                                   -0.188630
# 2                                    0.535790
# 3                                    0.367462
# 4                                    3.680499
# ..                                        ...
# 341                                  3.593383
# 342                                 -1.309686
# 343                                 -0.078343
# 344                                  0.564039
# 345                                  0.033087
#
#      accentedHitsPositionParter_PM_difference  knockdowns_PM_difference  \
# 0                                   -0.575427                       0.0
# 1                                   -1.163946                       0.0
# 2                                    0.396488                       0.0
# 3                                    0.763711                       0.0
# 4                                    2.061874                       0.0
# ..                                        ...                       ...
# 341                                  3.157895                       0.0
# 342                                  0.318145                       0.0
# 343                                 -0.914286                       0.0
# 344                                  0.472777                       0.0
# 345                                  1.282043                       0.0
#
#      protectionPassage_PM_difference  win_streak_difference  \
# 0                          -0.069132                    0.0
# 1                          -0.277842                   -5.0
# 2                          -0.011451                    1.0
# 3                          -0.010162                    1.0
# 4                          -0.011602                    3.0
# ..                               ...                    ...
# 341                         0.000000                    1.0
# 342                         0.000000                    0.0
# 343                        -0.200000                    2.0
# 344                         0.066999                    0.0
# 345                         0.303194                    1.0
#
#      loose_streak_difference  odds_difference  age_difference  \
# 0                        1.0             2.32             5.0
# 1                        1.0             1.47            -3.0
# 2                       -1.0             0.39            -7.0
# 3                        0.0            -0.47            -3.0
# 4                       -1.0            -5.68           -16.0
# ..                       ...              ...             ...
# 341                      0.0             0.23            -1.0
# 342                      0.0            -0.80             0.0
# 343                     -1.0             0.72            -6.0
# 344                      0.0             1.45            -3.0
# 345                      0.0             0.01            -2.0
#
#      height_difference  armSpan_difference  legSwing_difference  \
# 0                10.16               -2.54                 1.27
# 1                 2.54               -5.08                 0.00
# 2                -2.54               -5.08                -2.54
# 3                -5.08               -7.62                 0.10
# 4                -5.08              -10.16                 5.18
# ..                 ...                 ...                  ...
# 341              -2.54               -2.54                 0.00
# 342              22.86                7.62                 0.00
# 343               7.62               -2.54                 0.00
# 344               2.54                0.00                -2.54
# 345               0.00              -12.70               -11.53
#
#      isHomeCity_difference  isHomeCountry_difference  \
# 0                      0.0                       1.0
# 1                      0.0                       1.0
# 2                      0.0                       0.0
# 3                      0.0                      -1.0
# 4                      0.0                       0.0
# ..                     ...                       ...
# 341                    0.0                       0.0
# 342                    0.0                      -1.0
# 343                    0.0                      -1.0
# 344                    0.0                       0.0
# 345                    0.0                       0.0
#
#      isHomeTimezone_difference  winner  is_fight_night
# 0                          0.0   False           False
# 1                          0.0   False           False
# 2                          0.0   False           False
# 3                          0.0    True           False
# 4                          0.0   False           False
# ..                         ...     ...             ...
# 341                        0.0   False            True
# 342                        0.0   False            True
# 343                        0.0    True            True
# 344                        0.0   False            True
# 345                        0.0   False            True
#
# [331 rows x 215 columns]

# %%
# cat_features = np.where(train1[train_cols].dtypes == 'object')[0]

X_train = train1[train_cols].drop(['f1_odds', 'f2_odds', 'odds_difference'], axis=1)
y_train = train1['winner'].astype(int)

X_val = val1[train_cols].drop(['f1_odds', 'f2_odds', 'odds_difference'], axis=1)
y_val = val1['winner'].astype(int)

print(X_train.shape, X_val.shape)
clf1 = CatBoostClassifier(iterations=3000, 
                           depth=6,
                           learning_rate=0.001,
                           grow_policy='Depthwise', #SymmetricTree Depthwise
                           border_count=254,
#                            colsample_bylevel=0.4,
                           subsample=0.2,
                           l2_leaf_reg=40,
                           eval_metric='Accuracy',
                           boosting_type='Plain', # 'Plain'
                           bootstrap_type='Bernoulli',# 'Bernoulli' Bayesian
                           sampling_frequency='PerTree',
                           max_ctr_complexity=5,
                           has_time=True,
                           task_type='CPU',
                           cat_features=[0,1,2,3,4,5,6,7],
#                            cat_features=cat_features,
                          use_best_model=False,
                          )


clf1.fit(X_train, y_train, plot=True, eval_set=(X_val, y_val), verbose=False)

clf1.save_model('./data_models/catboost_v1_0_13.04.2021_1.cat')
clf1.get_feature_importance(prettified=True)#[:50]['Feature Id'].values
# Out:
# (3976, 191) (331, 191)
#             <style>
#                 .highcharts-tooltip {
#     display: none !important;
# }
# .highcharts-halo {
#     display: none !important;
# }
#
# .catboost {
#     position: relative;
# }
#
# .catboost-panel {
#     position: absolute;
#     height: 100%;
#     width: 280px;
# }
#
# .catboost-panel__controls {
#     margin-left: 0;
# }
#
# .catboost-panel__controls_label {
#     padding: 5px 0 0 8px;
#     cursor: pointer;
#     width: 80px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls_label_time {
#     width: inherit;
# }
#
# .catboost-panel__controls2 {
#     margin-top: 10px;
# }
#
# .catboost-panel__controls2_label {
#     padding: 5px 11px 0 8px;
#     cursor: pointer;
#     width: 90px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls2_label-long {
#     width: 170px;
# }
#
# .catboost-panel__series {
#     height: 340px;
#     overflow-y: auto;
# }
#
# .catboost-graph {
#     margin-left: 290px;
# }
#
# .catboost-graph__tabs {
#     padding: 0 0 0 20px;
# }
#
# .catboost-graph__tab {
#     display: inline-block;
#     padding: 5px 10px 0 0;
# }
#
# .catboost-graph__tab {
#     color: #999;
#     cursor: pointer;
#     transition: color 0.1s linear;
# }
#
# .catboost-graph__tab:hover {
#     color: #333;
# }
#
# .catboost-graph__tab_active {
#     color: #000;
#     cursor: auto;
# }
#
# .catboost-graph__charts {
#     padding-top: 20px;
# }
#
# .catboost-graph__chart {
#     display: none;
# }
#
# .catboost-graph__chart_active {
#     display: block;
# }
#
# .catboost-panel__serie {
#     padding-bottom: 5px;
#     border-bottom: 1px solid rgba(0, 0, 0, 0.3);
#     position: relative;
# }
#
# .catboost-panel__serie_bottom,
# .catboost-panel__serie_middle,
# .catboost-panel__serie_top {
#     white-space: nowrap;
#     position: relative;
# }
#
# #catboost-control-test {
#     margin-left: 11px;
# }
#
# .catboost-panel__serie_label {
#     padding: 0 0 0 8px;
#     width: 200px;
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     cursor: pointer;
#     margin-bottom: 0;
#     overflow: hidden;
#     position: relative;
#     top: 5px;
# }
#
# .catboost-panel__serie_hint {
#     position: absolute;
#     font-size: 9px;
#     left: 0;
# }
#
# .catboost-panel__serie__learn_hint {
#     top: 56px;
# }
#
# .catboost-panel__serie__test_hint {
#     top: 82px;
# }
#
# .catboost-panel__serie_bottom {
#     padding-bottom: 6px;
# }
#
# .catboost-panel__serie_time {
#     position: absolute;
#     top: 5px;
#     right: 2px;
#     height: 20px;
#     padding: 0 0 0 20px;
#     margin-bottom: 3px;
#     overflow: hidden;
#
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     text-align: left;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_test_pic {
#     width: 13px;
#     height: 1px;
#     border-top-width: 1px;
#     position: relative;
#     top: -3px;
#     margin-right: 5px;
# }
#
# .catboost-panel__serie_learn_pic {
#     border-top-style: dashed;
# }
#
# .catboost-panel__serie_test_pic {
#     border-top-style: solid;
# }
#
# .catboost-panel__serie-value {
#     display: inline-block;
#     min-width: 30px;
#     margin-right: 2px;
# }
#
# .catboost-panel__controls_label .catboost-panel__serie_learn_pic {
#     padding-left: 4px;
# }
#
# .catboost-panel__serie_names {
#     white-space: nowrap;
# }
#
# .catboost-panel__serie_scroll {
#     width: 240px;
#     overflow-x: auto;
#     margin-left: 20px;
# }
#
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_learn_value,
# .catboost-panel__serie_best_test_value {
#     width: 85px;
#     position: relative;
#     padding: 0 8px 0 0;
#     box-sizing: content-box;
#     overflow: hidden;
#     text-overflow: ellipsis;
#     top: 5px;
# }
#
# .catboost-panel__serie_iteration,
# .catboost-panel__serie_best_iteration {
#     display: inline-block;
#     position: absolute;
#     box-sizing: content-box;
#     overflow: hidden;
#     right: 2px;
# }
#
# .catboost-panel__serie_iteration {
#     top: 55px;
# }
#
# .catboost-panel__serie_best_iteration {
#     top: 80px;
# }
#
# .catboost-panel__control_slider {
#     width: 100px !important;
#     margin-left: 0;
#     position: relative;
#     display: inline-block !important;
#     top: 3px;
# }
#
# .catboost-panel__control_slidervalue {
#     width: 50px;
#     padding: 2px 3px;
#     margin-left: 4px;
# }
#
# .catboost-panel__serie_time_spend,
# .catboost-panel__serie_time_left {
#     display: inline-block;
# }
#
# .catboost-panel__serie_time_left {
#     margin-left: 10px;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_best_learn_value {
#     display: inline-block;
# }
# .catboost-panel__serie_test_pic,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_test_value {
#     display: inline-block;
# }
#
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_pic,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_name,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_learn_value {
#     display: none;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_pic,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_name,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_test_value {
#     display: none;
# }
#
# /*
# .catboost-panel__series_learn_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_test_value {
#     width: 216px;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_learn_value {
#     width: 216px;
# }
# */
# .catboost-panel__series_test_disabled .catboost-panel__serie__test_hint,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_iteration {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled.catboost-panel__series_learn_disabled .catboost-panel__serie_middle {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled .catboost-panel__serie_bottom {
#     display: none;
# }
#
#             </style>
#             <script>
#                 window.__define = window.define;window.__require = window.require;window.define = undefined;window.require = undefined;/**
# * plotly.js (basic - minified) v1.27.1
# * Copyright 2012-2017, Plotly, Inc.
# * All rights reserved.
# * Licensed under the MIT license
# */
# !function(t){if("object"==typeof exports&&"undefined"!=typeof module)module.exports=t();else if("function"==typeof define&&define.amd)define([],t);else{var e;e="undefined"!=typeof window?window:"undefined"!=typeof global?global:"undefined"!=typeof self?self:this,e.Plotly=t()}}(function(){var t;return function t(e,r,n){function a(i,l){if(!r[i]){if(!e[i]){var s="function"==typeof require&&require;if(!l&&s)return s(i,!0);if(o)return o(i,!0);var c=new Error("Cannot find module '"+i+"'");throw c.code="MODULE_NOT_FOUND",c}var u=r[i]={exports:{}};e[i][0].call(u.exports,function(t){var r=e[i][1][t];return a(r||t)},u,u.exports,t,e,r,n)}return r[i].exports}for(var o="function"==typeof require&&require,i=0;i<n.length;i++)a(n[i]);return a}({1:[function(t,e,r){"use strict";var n=t("../src/lib"),a={"X,X div":"font-family:'Open Sans', verdana, arial, sans-serif;margin:0;padding:0;","X input,X button":"font-family:'Open Sans', verdana, arial, sans-serif;","X input:focus,X button:focus":"outline:none;","X a":"text-decoration:none;","X a:hover":"text-decoration:none;","X .crisp":"shape-rendering:crispEdges;","X .user-select-none":"-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;-o-user-select:none;user-select:none;","X svg":"overflow:hidden;","X svg a":"fill:#447adb;","X svg a:hover":"fill:#3c6dc5;","X .main-svg":"position:absolute;top:0;left:0;pointer-events:none;","X .main-svg .draglayer":"pointer-events:all;","X .cursor-default":"cursor:default;","X .cursor-pointer":"cursor:pointer;","X .cursor-crosshair":"cursor:crosshair;","X .cursor-move":"cursor:move;","X .cursor-col-resize":"cursor:col-resize;","X .cursor-row-resize":"cursor:row-resize;","X .cursor-ns-resize":"cursor:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
#                        Feature Id   Importances
# 0                  age_difference  1.234323e+01
# 1                     f1_legSwing  4.503107e+00
# 2                     f2_legSwing  3.683596e+00
# 3                         f2_city  3.106724e+00
# 4                         f1_city  2.600421e+00
# ..                            ...           ...
# 186              f1_knockdowns_PM  1.334222e-05
# 187  cumsum_knockdowns_difference  4.595096e-06
# 188      knockdowns_PM_difference  1.529413e-35
# 189          f2_cumsum_knockdowns  0.000000e+00
# 190              f2_knockdowns_PM  0.000000e+00
#
# [191 rows x 2 columns]

# %%
# train_cols = clf1.get_feature_importance(prettified=True)[:50]['Feature Id'].values
# cat_features = np.where(train1[train_cols].dtypes == 'object')[0]
# cat_features

# %%
X_train = train2[train_cols].drop(['f1_odds', 'f2_odds', 'odds_difference'], axis=1)
y_train = train2['winner'].astype(int)

X_val = val2[train_cols].drop(['f1_odds', 'f2_odds', 'odds_difference'], axis=1)
y_val = val2['winner'].astype(int)

clf2 = CatBoostClassifier(iterations=3000, 
                           depth=6,
                           learning_rate=0.001,
                           grow_policy='Depthwise', #SymmetricTree Depthwise
                           border_count=254,
#                            colsample_bylevel=0.4,
                           subsample=0.2,
                           l2_leaf_reg=40,
                           eval_metric='Accuracy',
                           boosting_type='Plain', # 'Plain'
                           bootstrap_type='Bernoulli',# 'Bernoulli' Bayesian
                           sampling_frequency='PerTree',
                           max_ctr_complexity=5,
                           has_time=True,
                           task_type='CPU',
                           cat_features=[0,1,2,3,4,5,6,7],
#                            cat_features=cat_features,
                          use_best_model=False,
                          )



clf2.fit(X_train, y_train, plot=True, eval_set=(X_val, y_val), verbose=False)

clf2.save_model('./data_models/catboost_v1_0_13.04.2021_2.cat')
clf2.get_feature_importance(prettified=True)#[:50]['Feature Id'].values
# Out:
#             <style>
#                 .highcharts-tooltip {
#     display: none !important;
# }
# .highcharts-halo {
#     display: none !important;
# }
#
# .catboost {
#     position: relative;
# }
#
# .catboost-panel {
#     position: absolute;
#     height: 100%;
#     width: 280px;
# }
#
# .catboost-panel__controls {
#     margin-left: 0;
# }
#
# .catboost-panel__controls_label {
#     padding: 5px 0 0 8px;
#     cursor: pointer;
#     width: 80px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls_label_time {
#     width: inherit;
# }
#
# .catboost-panel__controls2 {
#     margin-top: 10px;
# }
#
# .catboost-panel__controls2_label {
#     padding: 5px 11px 0 8px;
#     cursor: pointer;
#     width: 90px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls2_label-long {
#     width: 170px;
# }
#
# .catboost-panel__series {
#     height: 340px;
#     overflow-y: auto;
# }
#
# .catboost-graph {
#     margin-left: 290px;
# }
#
# .catboost-graph__tabs {
#     padding: 0 0 0 20px;
# }
#
# .catboost-graph__tab {
#     display: inline-block;
#     padding: 5px 10px 0 0;
# }
#
# .catboost-graph__tab {
#     color: #999;
#     cursor: pointer;
#     transition: color 0.1s linear;
# }
#
# .catboost-graph__tab:hover {
#     color: #333;
# }
#
# .catboost-graph__tab_active {
#     color: #000;
#     cursor: auto;
# }
#
# .catboost-graph__charts {
#     padding-top: 20px;
# }
#
# .catboost-graph__chart {
#     display: none;
# }
#
# .catboost-graph__chart_active {
#     display: block;
# }
#
# .catboost-panel__serie {
#     padding-bottom: 5px;
#     border-bottom: 1px solid rgba(0, 0, 0, 0.3);
#     position: relative;
# }
#
# .catboost-panel__serie_bottom,
# .catboost-panel__serie_middle,
# .catboost-panel__serie_top {
#     white-space: nowrap;
#     position: relative;
# }
#
# #catboost-control-test {
#     margin-left: 11px;
# }
#
# .catboost-panel__serie_label {
#     padding: 0 0 0 8px;
#     width: 200px;
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     cursor: pointer;
#     margin-bottom: 0;
#     overflow: hidden;
#     position: relative;
#     top: 5px;
# }
#
# .catboost-panel__serie_hint {
#     position: absolute;
#     font-size: 9px;
#     left: 0;
# }
#
# .catboost-panel__serie__learn_hint {
#     top: 56px;
# }
#
# .catboost-panel__serie__test_hint {
#     top: 82px;
# }
#
# .catboost-panel__serie_bottom {
#     padding-bottom: 6px;
# }
#
# .catboost-panel__serie_time {
#     position: absolute;
#     top: 5px;
#     right: 2px;
#     height: 20px;
#     padding: 0 0 0 20px;
#     margin-bottom: 3px;
#     overflow: hidden;
#
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     text-align: left;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_test_pic {
#     width: 13px;
#     height: 1px;
#     border-top-width: 1px;
#     position: relative;
#     top: -3px;
#     margin-right: 5px;
# }
#
# .catboost-panel__serie_learn_pic {
#     border-top-style: dashed;
# }
#
# .catboost-panel__serie_test_pic {
#     border-top-style: solid;
# }
#
# .catboost-panel__serie-value {
#     display: inline-block;
#     min-width: 30px;
#     margin-right: 2px;
# }
#
# .catboost-panel__controls_label .catboost-panel__serie_learn_pic {
#     padding-left: 4px;
# }
#
# .catboost-panel__serie_names {
#     white-space: nowrap;
# }
#
# .catboost-panel__serie_scroll {
#     width: 240px;
#     overflow-x: auto;
#     margin-left: 20px;
# }
#
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_learn_value,
# .catboost-panel__serie_best_test_value {
#     width: 85px;
#     position: relative;
#     padding: 0 8px 0 0;
#     box-sizing: content-box;
#     overflow: hidden;
#     text-overflow: ellipsis;
#     top: 5px;
# }
#
# .catboost-panel__serie_iteration,
# .catboost-panel__serie_best_iteration {
#     display: inline-block;
#     position: absolute;
#     box-sizing: content-box;
#     overflow: hidden;
#     right: 2px;
# }
#
# .catboost-panel__serie_iteration {
#     top: 55px;
# }
#
# .catboost-panel__serie_best_iteration {
#     top: 80px;
# }
#
# .catboost-panel__control_slider {
#     width: 100px !important;
#     margin-left: 0;
#     position: relative;
#     display: inline-block !important;
#     top: 3px;
# }
#
# .catboost-panel__control_slidervalue {
#     width: 50px;
#     padding: 2px 3px;
#     margin-left: 4px;
# }
#
# .catboost-panel__serie_time_spend,
# .catboost-panel__serie_time_left {
#     display: inline-block;
# }
#
# .catboost-panel__serie_time_left {
#     margin-left: 10px;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_best_learn_value {
#     display: inline-block;
# }
# .catboost-panel__serie_test_pic,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_test_value {
#     display: inline-block;
# }
#
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_pic,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_name,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_learn_value {
#     display: none;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_pic,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_name,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_test_value {
#     display: none;
# }
#
# /*
# .catboost-panel__series_learn_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_test_value {
#     width: 216px;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_learn_value {
#     width: 216px;
# }
# */
# .catboost-panel__series_test_disabled .catboost-panel__serie__test_hint,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_iteration {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled.catboost-panel__series_learn_disabled .catboost-panel__serie_middle {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled .catboost-panel__serie_bottom {
#     display: none;
# }
#
#             </style>
#             <script>
#                 window.__define = window.define;window.__require = window.require;window.define = undefined;window.require = undefined;/**
# * plotly.js (basic - minified) v1.27.1
# * Copyright 2012-2017, Plotly, Inc.
# * All rights reserved.
# * Licensed under the MIT license
# */
# !function(t){if("object"==typeof exports&&"undefined"!=typeof module)module.exports=t();else if("function"==typeof define&&define.amd)define([],t);else{var e;e="undefined"!=typeof window?window:"undefined"!=typeof global?global:"undefined"!=typeof self?self:this,e.Plotly=t()}}(function(){var t;return function t(e,r,n){function a(i,l){if(!r[i]){if(!e[i]){var s="function"==typeof require&&require;if(!l&&s)return s(i,!0);if(o)return o(i,!0);var c=new Error("Cannot find module '"+i+"'");throw c.code="MODULE_NOT_FOUND",c}var u=r[i]={exports:{}};e[i][0].call(u.exports,function(t){var r=e[i][1][t];return a(r||t)},u,u.exports,t,e,r,n)}return r[i].exports}for(var o="function"==typeof require&&require,i=0;i<n.length;i++)a(n[i]);return a}({1:[function(t,e,r){"use strict";var n=t("../src/lib"),a={"X,X div":"font-family:'Open Sans', verdana, arial, sans-serif;margin:0;padding:0;","X input,X button":"font-family:'Open Sans', verdana, arial, sans-serif;","X input:focus,X button:focus":"outline:none;","X a":"text-decoration:none;","X a:hover":"text-decoration:none;","X .crisp":"shape-rendering:crispEdges;","X .user-select-none":"-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;-o-user-select:none;user-select:none;","X svg":"overflow:hidden;","X svg a":"fill:#447adb;","X svg a:hover":"fill:#3c6dc5;","X .main-svg":"position:absolute;top:0;left:0;pointer-events:none;","X .main-svg .draglayer":"pointer-events:all;","X .cursor-default":"cursor:default;","X .cursor-pointer":"cursor:pointer;","X .cursor-crosshair":"cursor:crosshair;","X .cursor-move":"cursor:move;","X .cursor-col-resize":"cursor:col-resize;","X .cursor-row-resize":"cursor:row-resize;","X .cursor-ns-resize":"cursor:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
#                        Feature Id   Importances
# 0                  age_difference  1.204084e+01
# 1                     f2_legSwing  4.494560e+00
# 2                     f1_legSwing  3.386556e+00
# 3                         f1_city  3.310956e+00
# 4                          f1_age  2.338136e+00
# ..                            ...           ...
# 186              f2_knockdowns_PM  3.217311e-05
# 187      knockdowns_PM_difference  2.773634e-05
# 188  cumsum_knockdowns_difference  1.780833e-35
# 189          f1_cumsum_knockdowns  0.000000e+00
# 190              f1_knockdowns_PM  0.000000e+00
#
# [191 rows x 2 columns]

# %%
clf2.get_feature_importance(prettified=True)['Feature Id'].values
# Out:
# array(['age_difference', 'f2_legSwing', 'f1_legSwing', 'f1_city',
#        'f1_age', 'f2_city', 'takedown_PM_difference', 'f2_age',
#        'f1_takedown_PM', 'protectionPassage_PM_difference',
#        'f1_hitsHead_accuracy', 'armSpan_difference',
#        'hitsHead_accuracy_difference', 'KO_percent_difference',
#        'accentedHitsPositionParter_PM_difference',
#        'f2_protectionPassage_PM', 'win_streak_difference',
#        'accentedHits_PM_difference', 'legSwing_difference',
#        'DEC_percent_difference', 'f1_accentedHits_accuracy',
#        'f1_accentedHitsPositionDistance_accuracy', 'f2_country',
#        'f1_KO_percent', 'f1_country', 'f1_hitsHead_PM', 'f1_DEC_percent',
#        'hitsHead_PM_difference', 'f2_KO_percent',
#        'cumsum_takedownSuccessful_difference', 'city', 'f2_takedown_PM',
#        'cumsum_protectionPassage_difference', 'f2_armSpan',
#        'f2_hitsHead_PM', 'f1_accentedHitsPositionParter_PM',
#        'SUB_percent_difference', 'accentedHits_accuracy_difference',
#        'f1_cumsum_takedownTotal', 'f1_protectionPassage_PM',
#        'f1_takedown_accuracy', 'weightCategory.id',
#        'cumsum_winner_difference', 'f2_accentedHitsPositionParter_PM',
#        'isHomeCountry_difference',
#        'accentedHitsPositionDistance_PM_difference',
#        'accentedHitsPositionDistance_accuracy_difference',
#        'f1_accentedHits_PM', 'f1_cumsum_takedownSuccessful',
#        'f1_accentedHitsPositionDistance_PM',
#        'f2_cumsum_protectionPassage',
#        'f1_accentedHitsPositionParter_accuracy', 'country',
#        'f2_takedown_accuracy', 'f2_accentedHits_PM', 'f2_DEC_percent',
#        'cumsum_hitsHeadSuccessful_difference', 'f1_hitsLegs_PM',
#        'accentedHitsPositionClinch_accuracy_difference',
#        'cumsum_accentedHitsPositionParterTotal_difference',
#        'f2_cumsum_accentedHitsTotal', 'f1_cumsum_accentedHitsTotal',
#        'f2_cumsum_accentedHitsPositionParterTotal',
#        'f1_cumsum_hitsHeadTotal',
#        'f1_accentedHitsPositionClinch_accuracy',
#        'takedown_accuracy_difference', 'f2_cumsum_hitsHeadTotal',
#        'f2_SUB_percent', 'cumsum_takedownTotal_difference',
#        'cumsum_duration_difference', 'f1_cumsum_duration',
#        'hits_PM_difference', 'f2_hits_accuracy',
#        'f1_cumsum_hitsHeadSuccessful', 'f2_hits_PM',
#        'cumsum_accentedHitsPositionParterSuccessful_difference',
#        'accentedHitsPositionParter_accuracy_difference', 'f1_hitsBody_PM',
#        'f2_cumsum_accentedHitsPositionDistanceTotal',
#        'hitsLegs_accuracy_difference',
#        'f2_accentedHitsPositionDistance_PM', 'f1_SUB_percent',
#        'cumsum_accentedHitsSuccessful_difference', 'f2_hitsBody_PM',
#        'f2_cumsum_hitsTotal', 'f1_hits_accuracy', 'f1_hits_PM',
#        'f1_cumsum_hitsTotal', 'cumsum_accentedHitsTotal_difference',
#        'f1_cumsum_accentedHitsSuccessful',
#        'f2_accentedHitsPositionParter_accuracy', 'f1_hitsLegs_accuracy',
#        'cumsum_hitsHeadTotal_difference', 'f2_cumsum_hitsSuccessful',
#        'hitsLegs_PM_difference', 'f2_cumsum_hitsHeadSuccessful',
#        'hitsBody_PM_difference', 'f1_hitsBody_accuracy',
#        'f1_cumsum_accentedHitsPositionDistanceTotal',
#        'f2_hitsBody_accuracy', 'f1_accentedHitsPositionClinch_PM',
#        'f2_accentedHits_accuracy', 'f2_hitsHead_accuracy',
#        'f2_accentedHitsPositionClinch_accuracy',
#        'f2_cumsum_accentedHitsPositionParterSuccessful',
#        'f2_cumsum_duration', 'f2_cumsum_winner', 'f2_hitsLegs_accuracy',
#        'f2_cumsum_accentedHitsSuccessful', 'f2_hitsLegs_PM',
#        'f1_cumsum_winner', 'hits_accuracy_difference',
#        'isHomeTimezone_difference', 'f2_height',
#        'f1_cumsum_accentedHitsPositionParterTotal',
#        'cumsum_hitsTotal_difference', 'f2_accentedHitsPositionClinch_PM',
#        'f1_cumsum_hitsSuccessful', 'f1_win_streak',
#        'cumsum_hitsSuccessful_difference',
#        'cumsum_accentedHitsPositionDistanceTotal_difference',
#        'f1_armSpan', 'accentedHitsPositionClinch_PM_difference',
#        'f2_win_streak', 'f2_accentedHitsPositionDistance_accuracy',
#        'f1_height', 'f1_cumsum_protectionPassage',
#        'hitsBody_accuracy_difference',
#        'f1_cumsum_accentedHitsPositionDistanceSuccessful',
#        'cumsum_accentedHitsPositionDistanceSuccessful_difference',
#        'f2_cumsum_takedownSuccessful', 'height_difference',
#        'f2_cumsum_accentedHitsPositionDistanceSuccessful',
#        'cumsum_submissionAttempts_difference',
#        'f2_cumsum_submissionAttempts',
#        'f1_cumsum_accentedHitsPositionParterSuccessful',
#        'f1_cumsum_hitsLegsSuccessful',
#        'f1_cumsum_accentedHitsPositionClinchTotal',
#        'f2_cumsum_takedownTotal', 'f1_cumsum_winMethods_[KO]',
#        'f2_cumsum_hitsLegsTotal', 'f1_cumsum_hitsLegsTotal',
#        'f2_cumsum_hitsBodyTotal', 'cumsum_hitsBodySuccessful_difference',
#        'f1_cumsum_winMethods_[DEC]', 'f2_cumsum_winMethods_[KO]',
#        'f2_cumsum_accentedHitsPositionClinchTotal',
#        'cumsum_hitsLegsSuccessful_difference',
#        'cumsum_hitsLegsTotal_difference', 'f2_cumsum_hitsBodySuccessful',
#        'cumsum_hitsBodyTotal_difference', 'f2_cumsum_hitsLegsSuccessful',
#        'f2_cumsum_accentedHitsPositionClinchSuccessful',
#        'f1_cumsum_hitsBodySuccessful', 'f2_cumsum_winMethods_[SUB]',
#        'f1_cumsum_accentedHitsPositionClinchSuccessful',
#        'f1_cumsum_hitsBodyTotal',
#        'cumsum_accentedHitsPositionClinchTotal_difference',
#        'cumsum_accentedHitsPositionClinchSuccessful_difference',
#        'f2_isHomeCountry', 'cumsum_winMethods_[DEC]_difference',
#        'f2_cumsum_winMethods_[DEC]', 'f2_isHomeTimezone',
#        'cumsum_winMethods_[SUB]_difference', 'loose_streak_difference',
#        'cumsum_winMethods_[KO]_difference',
#        'f1_cumsum_submissionAttempts', 'f1_cumsum_takeovers',
#        'cumsum_takeovers_difference', 'f1_cumsum_winMethods_[SUB]',
#        'f2_cumsum_takeovers', 'DQ_percent_difference', 'f1_isHomeCountry',
#        'is_fight_night', 'f1_loose_streak', 'f2_loose_streak',
#        'f1_DQ_percent', 'cumsum_winMethods_[DQ]_difference',
#        'f1_isHomeTimezone', 'f2_DQ_percent', 'isHomeCity_difference',
#        'f1_cumsum_winMethods_[DQ]', 'f2_isHomeCity',
#        'f2_cumsum_winMethods_[DQ]', 'f1_isHomeCity',
#        'f2_cumsum_knockdowns', 'f2_knockdowns_PM',
#        'knockdowns_PM_difference', 'cumsum_knockdowns_difference',
#        'f1_cumsum_knockdowns', 'f1_knockdowns_PM'], dtype=object)

# %%
print('Точность букмейкера')
val1['bookmaker_bet'] = (val1['f1_odds'] < val1['f2_odds']).astype(int)
(val1['bookmaker_bet'] == val1['winner']).mean()
# Out:
# Точность букмейкера
# 0.649546827794562

# %%
y_proba = clf1.predict_proba(val1[clf1.feature_names_])
val1['y_proba'] = y_proba[:,1]
val1['y_pred'] = val1['y_proba'] > 0.5

y_proba = clf2.predict_proba(val2[clf2.feature_names_])
val2['y_proba'] = y_proba[:,1]
val2['y_pred'] = val2['y_proba'] > 0.5

val1['y_proba_comb'] = (val1['y_proba'] + 1-val2['y_proba']) / 2
val1['y_pred_comb'] = val1['y_proba_comb'] > 0.5

(val1['y_pred'] != val2['y_pred']).mean()
# Out:
# 0.9154078549848943

# %%
calculate_roi(val1, pred_col='y_pred')
calculate_roi(val2, pred_col='y_pred')
calculate_roi(val1, pred_col='y_pred_comb')
# Out:
#   0%|          | 0/331 [00:00<?, ?it/s]
# {'accuracy:': 0.6344410876132931,
#  'bets_count:': 331,
#  'finish_bank:': 3550.0,
#  'roi:': 10.725075528700906}
#   0%|          | 0/331 [00:00<?, ?it/s]
# {'accuracy:': 0.6283987915407855,
#  'bets_count:': 331,
#  'finish_bank:': 2808.0,
#  'roi:': 8.483383685800604}
#   0%|          | 0/331 [00:00<?, ?it/s]
# {'accuracy:': 0.6404833836858006,
#  'bets_count:': 331,
#  'finish_bank:': 3626.0,
#  'roi:': 10.954682779456194}

# %%
same_preds = val1[val1['y_pred'] != val2['y_pred']]
calculate_roi(same_preds)
# Out:
#   0%|          | 0/303 [00:00<?, ?it/s]
# {'accuracy:': 0.6435643564356436,
#  'bets_count:': 303,
#  'finish_bank:': 3607.0,
#  'roi:': 11.904290429042904}

# %%
val1 = get_winner_favorite(val1)
val2 = get_winner_favorite(val2)

bet_on_favorite = val1[val1['y_pred'] == val1['favorite']]
calculate_roi(bet_on_favorite, pred_col='y_pred')
bet_on_favorite = val2[val2['y_pred'] == val2['favorite']]
calculate_roi(bet_on_favorite, pred_col='y_pred')
bet_on_favorite = val1[val1['y_pred_comb'] == val1['favorite']]
calculate_roi(bet_on_favorite, pred_col='y_pred_comb')
# Out:
#   0%|          | 0/208 [00:00<?, ?it/s]
# {'accuracy:': 0.7259615384615384,
#  'bets_count:': 208,
#  'finish_bank:': 1665.0,
#  'roi:': 8.004807692307692}
#   0%|          | 0/213 [00:00<?, ?it/s]
# {'accuracy:': 0.7183098591549296,
#  'bets_count:': 213,
#  'finish_bank:': 1463.0,
#  'roi:': 6.868544600938967}
#   0%|          | 0/212 [00:00<?, ?it/s]
# {'accuracy:': 0.7264150943396226,
#  'bets_count:': 212,
#  'finish_bank:': 1656.0,
#  'roi:': 7.811320754716981}

# %%
val1 = get_winner_favorite(val1)
val2 = get_winner_favorite(val2)

bet_on_favorite = val1[val1['y_pred'] != val1['favorite']]
calculate_roi(bet_on_favorite, pred_col='y_pred')
bet_on_favorite = val2[val2['y_pred'] != val2['favorite']]
calculate_roi(bet_on_favorite, pred_col='y_pred')
bet_on_favorite = val1[val1['y_pred_comb'] != val1['favorite']]
calculate_roi(bet_on_favorite, pred_col='y_pred_comb')
# Out:
#   0%|          | 0/123 [00:00<?, ?it/s]
# {'accuracy:': 0.4796747967479675,
#  'bets_count:': 123,
#  'finish_bank:': 1885.0,
#  'roi:': 15.325203252032521}
#   0%|          | 0/118 [00:00<?, ?it/s]
# {'accuracy:': 0.4661016949152542,
#  'bets_count:': 118,
#  'finish_bank:': 1345.0,
#  'roi:': 11.398305084745763}
#   0%|          | 0/119 [00:00<?, ?it/s]
# {'accuracy:': 0.48739495798319327,
#  'bets_count:': 119,
#  'finish_bank:': 1970.0,
#  'roi:': 16.554621848739497}

# %%
val1[:1]
# Out:
#    index       city country  duration eventDate.date eventDate.timezone  \
# 0   6359  Las Vegas     USA      40.0     2020-01-18      Europe/Berlin
#
#    fighterId_1  fighterId_2     id     name  rounds             timezone  \
# 0          347          211  39796  UFC 246     1.0  America/Los_Angeles
#
#    weightCategory.id weightCategory.name winMethods  winnerId         f1_name  \
# 0                 14       Не определена     ['KO']     211.0  Donald Cerrone
#
#           f2_name  f1_odds  f2_odds  f1_age  f2_age  f1_height  f2_height  \
# 0  Conor McGregor     3.61     1.29    36.0    31.0     185.42     175.26
#
#    f1_armSpan  f2_armSpan  f1_legSwing  f2_legSwing f1_country f2_country  \
# 0      185.42      187.96       102.87        101.6        USA    Ireland
#
#   f1_city f2_city     f1_timezone       f2_timezone  f1_isHomeCity  \
# 0  Denver  Dublin  America/Denver  America/New_York              0
#
#    f2_isHomeCity  f1_isHomeCountry  f2_isHomeCountry  f1_isHomeTimezone  \
# 0              0                 1                 0                  0
#
#    f2_isHomeTimezone  f1_cumsum_duration  f1_cumsum_winner  \
# 0                  0              7959.0                25
#
#    f1_cumsum_hitsTotal  f1_cumsum_hitsSuccessful  f1_cumsum_takedownTotal  \
# 0               1552.0                     798.0                     32.0
#
#    f1_cumsum_takedownSuccessful  f1_cumsum_submissionAttempts  \
# 0                          11.0                          10.0
#
#    f1_cumsum_takeovers  f1_cumsum_accentedHitsTotal  \
# 0                  1.0                       1460.0
#
#    f1_cumsum_accentedHitsSuccessful  f1_cumsum_knockdowns  \
# 0                             718.0                   0.0
#
#    f1_cumsum_protectionPassage  f1_cumsum_hitsHeadTotal  \
# 0                         14.0                   1040.0
#
#    f1_cumsum_hitsHeadSuccessful  f1_cumsum_hitsBodyTotal  \
# 0                         393.0                    228.0
#
#    f1_cumsum_hitsBodySuccessful  f1_cumsum_hitsLegsTotal  \
# 0                         159.0                    192.0
#
#    f1_cumsum_hitsLegsSuccessful  f1_cumsum_accentedHitsPositionDistanceTotal  \
# 0                         166.0                                       1245.0
#
#    f1_cumsum_accentedHitsPositionDistanceSuccessful  \
# 0                                             571.0
#
#    f1_cumsum_accentedHitsPositionClinchTotal  \
# 0                                      103.0
#
#    f1_cumsum_accentedHitsPositionClinchSuccessful  \
# 0                                            65.0
#
#    f1_cumsum_accentedHitsPositionParterTotal  \
# 0                                      112.0
#
#    f1_cumsum_accentedHitsPositionParterSuccessful  f1_cumsum_winMethods_[DEC]  \
# 0                                            82.0                          12
#
#    f1_cumsum_winMethods_[DQ]  f1_cumsum_winMethods_[KO]  \
# 0                          0                         16
#
#    f1_cumsum_winMethods_[SUB]  f1_hits_accuracy  f1_takedown_accuracy  \
# 0                           7          0.514175               0.34375
#
#    f1_accentedHits_accuracy  f1_hitsHead_accuracy  f1_hitsBody_accuracy  \
# 0                  0.491781              0.377885              0.697368
#
#    f1_hitsLegs_accuracy  f1_accentedHitsPositionDistance_accuracy  \
# 0              0.864583                                  0.458635
#
#    f1_accentedHitsPositionClinch_accuracy  \
# 0                                0.631068
#
#    f1_accentedHitsPositionParter_accuracy  f1_DEC_percent  f1_DQ_percent  \
# 0                                0.732143            0.48            0.0
#
#    f1_KO_percent  f1_SUB_percent  f1_hits_PM  f1_takedown_PM  \
# 0           0.64            0.28    6.015831        0.082925
#
#    f1_accentedHits_PM  f1_hitsHead_PM  f1_hitsBody_PM  f1_hitsLegs_PM  \
# 0             5.41274        2.962684        1.198643        1.251413
#
#    f1_accentedHitsPositionDistance_PM  f1_accentedHitsPositionClinch_PM  \
# 0                            4.304561                          0.490011
#
#    f1_accentedHitsPositionParter_PM  f1_knockdowns_PM  \
# 0                          0.618168               0.0
#
#    f1_protectionPassage_PM  f1_win_streak  f1_loose_streak  \
# 0                 0.105541              0                2
#
#    f1_count_of_fights  f2_cumsum_duration  f2_cumsum_winner  \
# 0                  35              2061.0                 9
#
#    f2_cumsum_hitsTotal  f2_cumsum_hitsSuccessful  f2_cumsum_takedownTotal  \
# 0                423.0                     260.0                      6.0
#
#    f2_cumsum_takedownSuccessful  f2_cumsum_submissionAttempts  \
# 0                           4.0                           0.0
#
#    f2_cumsum_takeovers  f2_cumsum_accentedHitsTotal  \
# 0                  0.0                        350.0
#
#    f2_cumsum_accentedHitsSuccessful  f2_cumsum_knockdowns  \
# 0                             189.0                   0.0
#
#    f2_cumsum_protectionPassage  f2_cumsum_hitsHeadTotal  \
# 0                          6.0                    299.0
#
#    f2_cumsum_hitsHeadSuccessful  f2_cumsum_hitsBodyTotal  \
# 0                         156.0                     38.0
#
#    f2_cumsum_hitsBodySuccessful  f2_cumsum_hitsLegsTotal  \
# 0                          24.0                     13.0
#
#    f2_cumsum_hitsLegsSuccessful  f2_cumsum_accentedHitsPositionDistanceTotal  \
# 0                           9.0                                        273.0
#
#    f2_cumsum_accentedHitsPositionDistanceSuccessful  \
# 0                                             135.0
#
#    f2_cumsum_accentedHitsPositionClinchTotal  \
# 0                                       16.0
#
#    f2_cumsum_accentedHitsPositionClinchSuccessful  \
# 0                                            13.0
#
#    f2_cumsum_accentedHitsPositionParterTotal  \
# 0                                       61.0
#
#    f2_cumsum_accentedHitsPositionParterSuccessful  f2_cumsum_winMethods_[DEC]  \
# 0                                            41.0                           2
#
#    f2_cumsum_winMethods_[DQ]  f2_cumsum_winMethods_[KO]  \
# 0                          0                          7
#
#    f2_cumsum_winMethods_[SUB]  f2_hits_accuracy  f2_takedown_accuracy  \
# 0                           2          0.614657              0.666667
#
#    f2_accentedHits_accuracy  f2_hitsHead_accuracy  f2_hitsBody_accuracy  \
# 0                      0.54              0.521739              0.631579
#
#    f2_hitsLegs_accuracy  f2_accentedHitsPositionDistance_accuracy  \
# 0              0.692308                                  0.494505
#
#    f2_accentedHitsPositionClinch_accuracy  \
# 0                                  0.8125
#
#    f2_accentedHitsPositionParter_accuracy  f2_DEC_percent  f2_DQ_percent  \
# 0                                0.672131        0.222222            0.0
#
#    f2_KO_percent  f2_SUB_percent  f2_hits_PM  f2_takedown_PM  \
# 0       0.777778        0.222222    7.569141        0.116448
#
#    f2_accentedHits_PM  f2_hitsHead_PM  f2_hitsBody_PM  f2_hitsLegs_PM  \
# 0            5.502183        4.541485         0.69869        0.262009
#
#    f2_accentedHitsPositionDistance_PM  f2_accentedHitsPositionClinch_PM  \
# 0                            3.930131                          0.378457
#
#    f2_accentedHitsPositionParter_PM  f2_knockdowns_PM  \
# 0                          1.193595               0.0
#
#    f2_protectionPassage_PM  f2_win_streak  f2_loose_streak  \
# 0                 0.174672              0                1
#
#    f2_count_of_fights      type  cumsum_duration_difference  \
# 0                  11  straight                      5898.0
#
#    cumsum_winner_difference  cumsum_hitsTotal_difference  \
# 0                      16.0                       1129.0
#
#    cumsum_hitsSuccessful_difference  cumsum_takedownTotal_difference  \
# 0                             538.0                             26.0
#
#    cumsum_takedownSuccessful_difference  cumsum_submissionAttempts_difference  \
# 0                                   7.0                                  10.0
#
#    cumsum_takeovers_difference  cumsum_accentedHitsTotal_difference  \
# 0                          1.0                               1110.0
#
#    cumsum_accentedHitsSuccessful_difference  cumsum_knockdowns_difference  \
# 0                                     529.0                           0.0
#
#    cumsum_protectionPassage_difference  cumsum_hitsHeadTotal_difference  \
# 0                                  8.0                            741.0
#
#    cumsum_hitsHeadSuccessful_difference  cumsum_hitsBodyTotal_difference  \
# 0                                 237.0                            190.0
#
#    cumsum_hitsBodySuccessful_difference  cumsum_hitsLegsTotal_difference  \
# 0                                 135.0                            179.0
#
#    cumsum_hitsLegsSuccessful_difference  \
# 0                                 157.0
#
#    cumsum_accentedHitsPositionDistanceTotal_difference  \
# 0                                              972.0
#
#    cumsum_accentedHitsPositionDistanceSuccessful_difference  \
# 0                                              436.0
#
#    cumsum_accentedHitsPositionClinchTotal_difference  \
# 0                                               87.0
#
#    cumsum_accentedHitsPositionClinchSuccessful_difference  \
# 0                                               52.0
#
#    cumsum_accentedHitsPositionParterTotal_difference  \
# 0                                               51.0
#
#    cumsum_accentedHitsPositionParterSuccessful_difference  \
# 0                                               41.0
#
#    cumsum_winMethods_[DEC]_difference  cumsum_winMethods_[DQ]_difference  \
# 0                                10.0                                0.0
#
#    cumsum_winMethods_[KO]_difference  cumsum_winMethods_[SUB]_difference  \
# 0                                9.0                                 5.0
#
#    hits_accuracy_difference  takedown_accuracy_difference  \
# 0                 -0.100482                     -0.322917
#
#    accentedHits_accuracy_difference  hitsHead_accuracy_difference  \
# 0                         -0.048219                     -0.143855
#
#    hitsBody_accuracy_difference  hitsLegs_accuracy_difference  \
# 0                      0.065789                      0.172276
#
#    accentedHitsPositionDistance_accuracy_difference  \
# 0                                         -0.035871
#
#    accentedHitsPositionClinch_accuracy_difference  \
# 0                                       -0.181432
#
#    accentedHitsPositionParter_accuracy_difference  DEC_percent_difference  \
# 0                                        0.060012                0.257778
#
#    DQ_percent_difference  KO_percent_difference  SUB_percent_difference  \
# 0                    0.0              -0.137778                0.057778
#
#    hits_PM_difference  takedown_PM_difference  accentedHits_PM_difference  \
# 0            -1.55331               -0.033523                   -0.089443
#
#    hitsHead_PM_difference  hitsBody_PM_difference  hitsLegs_PM_difference  \
# 0               -1.578801                0.499953                0.989405
#
#    accentedHitsPositionDistance_PM_difference  \
# 0                                     0.37443
#
#    accentedHitsPositionClinch_PM_difference  \
# 0                                  0.111554
#
#    accentedHitsPositionParter_PM_difference  knockdowns_PM_difference  \
# 0                                 -0.575427                       0.0
#
#    protectionPassage_PM_difference  win_streak_difference  \
# 0                        -0.069132                    0.0
#
#    loose_streak_difference  odds_difference  age_difference  \
# 0                      1.0             2.32             5.0
#
#    height_difference  armSpan_difference  legSwing_difference  \
# 0              10.16               -2.54                 1.27
#
#    isHomeCity_difference  isHomeCountry_difference  isHomeTimezone_difference  \
# 0                    0.0                       1.0                        0.0
#
#    winner  is_fight_night  bookmaker_bet   y_proba  y_pred  favorite  \
# 0   False           False              0  0.415911   False     False
#
#    y_proba_comb  y_pred_comb
# 0      0.416857        False

# %%
val2[:1]
# Out:
#    index       city country  duration eventDate.date eventDate.timezone  \
# 0   6359  Las Vegas     USA      40.0     2020-01-18      Europe/Berlin
#
#    fighterId_1  fighterId_2     id     name  rounds             timezone  \
# 0          211          347  39796  UFC 246     1.0  America/Los_Angeles
#
#    weightCategory.id weightCategory.name winMethods  winnerId         f1_name  \
# 0                 14       Не определена     ['KO']     211.0  Conor McGregor
#
#           f2_name  f1_odds  f2_odds  f1_age  f2_age  f1_height  f2_height  \
# 0  Donald Cerrone     1.29     3.61    31.0    36.0     175.26     185.42
#
#    f1_armSpan  f2_armSpan  f1_legSwing  f2_legSwing f1_country f2_country  \
# 0      187.96      185.42        101.6       102.87    Ireland        USA
#
#   f1_city f2_city       f1_timezone     f2_timezone  f1_isHomeCity  \
# 0  Dublin  Denver  America/New_York  America/Denver              0
#
#    f2_isHomeCity  f1_isHomeCountry  f2_isHomeCountry  f1_isHomeTimezone  \
# 0              0                 0                 1                  0
#
#    f2_isHomeTimezone  f1_cumsum_duration  f1_cumsum_winner  \
# 0                  0              2061.0                 9
#
#    f1_cumsum_hitsTotal  f1_cumsum_hitsSuccessful  f1_cumsum_takedownTotal  \
# 0                423.0                     260.0                      6.0
#
#    f1_cumsum_takedownSuccessful  f1_cumsum_submissionAttempts  \
# 0                           4.0                           0.0
#
#    f1_cumsum_takeovers  f1_cumsum_accentedHitsTotal  \
# 0                  0.0                        350.0
#
#    f1_cumsum_accentedHitsSuccessful  f1_cumsum_knockdowns  \
# 0                             189.0                   0.0
#
#    f1_cumsum_protectionPassage  f1_cumsum_hitsHeadTotal  \
# 0                          6.0                    299.0
#
#    f1_cumsum_hitsHeadSuccessful  f1_cumsum_hitsBodyTotal  \
# 0                         156.0                     38.0
#
#    f1_cumsum_hitsBodySuccessful  f1_cumsum_hitsLegsTotal  \
# 0                          24.0                     13.0
#
#    f1_cumsum_hitsLegsSuccessful  f1_cumsum_accentedHitsPositionDistanceTotal  \
# 0                           9.0                                        273.0
#
#    f1_cumsum_accentedHitsPositionDistanceSuccessful  \
# 0                                             135.0
#
#    f1_cumsum_accentedHitsPositionClinchTotal  \
# 0                                       16.0
#
#    f1_cumsum_accentedHitsPositionClinchSuccessful  \
# 0                                            13.0
#
#    f1_cumsum_accentedHitsPositionParterTotal  \
# 0                                       61.0
#
#    f1_cumsum_accentedHitsPositionParterSuccessful  f1_cumsum_winMethods_[DEC]  \
# 0                                            41.0                           2
#
#    f1_cumsum_winMethods_[DQ]  f1_cumsum_winMethods_[KO]  \
# 0                          0                          7
#
#    f1_cumsum_winMethods_[SUB]  f1_hits_accuracy  f1_takedown_accuracy  \
# 0                           2          0.614657              0.666667
#
#    f1_accentedHits_accuracy  f1_hitsHead_accuracy  f1_hitsBody_accuracy  \
# 0                      0.54              0.521739              0.631579
#
#    f1_hitsLegs_accuracy  f1_accentedHitsPositionDistance_accuracy  \
# 0              0.692308                                  0.494505
#
#    f1_accentedHitsPositionClinch_accuracy  \
# 0                                  0.8125
#
#    f1_accentedHitsPositionParter_accuracy  f1_DEC_percent  f1_DQ_percent  \
# 0                                0.672131        0.222222            0.0
#
#    f1_KO_percent  f1_SUB_percent  f1_hits_PM  f1_takedown_PM  \
# 0       0.777778        0.222222    7.569141        0.116448
#
#    f1_accentedHits_PM  f1_hitsHead_PM  f1_hitsBody_PM  f1_hitsLegs_PM  \
# 0            5.502183        4.541485         0.69869        0.262009
#
#    f1_accentedHitsPositionDistance_PM  f1_accentedHitsPositionClinch_PM  \
# 0                            3.930131                          0.378457
#
#    f1_accentedHitsPositionParter_PM  f1_knockdowns_PM  \
# 0                          1.193595               0.0
#
#    f1_protectionPassage_PM  f1_win_streak  f1_loose_streak  \
# 0                 0.174672              0                1
#
#    f1_count_of_fights  f2_cumsum_duration  f2_cumsum_winner  \
# 0                  11              7959.0                25
#
#    f2_cumsum_hitsTotal  f2_cumsum_hitsSuccessful  f2_cumsum_takedownTotal  \
# 0               1552.0                     798.0                     32.0
#
#    f2_cumsum_takedownSuccessful  f2_cumsum_submissionAttempts  \
# 0                          11.0                          10.0
#
#    f2_cumsum_takeovers  f2_cumsum_accentedHitsTotal  \
# 0                  1.0                       1460.0
#
#    f2_cumsum_accentedHitsSuccessful  f2_cumsum_knockdowns  \
# 0                             718.0                   0.0
#
#    f2_cumsum_protectionPassage  f2_cumsum_hitsHeadTotal  \
# 0                         14.0                   1040.0
#
#    f2_cumsum_hitsHeadSuccessful  f2_cumsum_hitsBodyTotal  \
# 0                         393.0                    228.0
#
#    f2_cumsum_hitsBodySuccessful  f2_cumsum_hitsLegsTotal  \
# 0                         159.0                    192.0
#
#    f2_cumsum_hitsLegsSuccessful  f2_cumsum_accentedHitsPositionDistanceTotal  \
# 0                         166.0                                       1245.0
#
#    f2_cumsum_accentedHitsPositionDistanceSuccessful  \
# 0                                             571.0
#
#    f2_cumsum_accentedHitsPositionClinchTotal  \
# 0                                      103.0
#
#    f2_cumsum_accentedHitsPositionClinchSuccessful  \
# 0                                            65.0
#
#    f2_cumsum_accentedHitsPositionParterTotal  \
# 0                                      112.0
#
#    f2_cumsum_accentedHitsPositionParterSuccessful  f2_cumsum_winMethods_[DEC]  \
# 0                                            82.0                          12
#
#    f2_cumsum_winMethods_[DQ]  f2_cumsum_winMethods_[KO]  \
# 0                          0                         16
#
#    f2_cumsum_winMethods_[SUB]  f2_hits_accuracy  f2_takedown_accuracy  \
# 0                           7          0.514175               0.34375
#
#    f2_accentedHits_accuracy  f2_hitsHead_accuracy  f2_hitsBody_accuracy  \
# 0                  0.491781              0.377885              0.697368
#
#    f2_hitsLegs_accuracy  f2_accentedHitsPositionDistance_accuracy  \
# 0              0.864583                                  0.458635
#
#    f2_accentedHitsPositionClinch_accuracy  \
# 0                                0.631068
#
#    f2_accentedHitsPositionParter_accuracy  f2_DEC_percent  f2_DQ_percent  \
# 0                                0.732143            0.48            0.0
#
#    f2_KO_percent  f2_SUB_percent  f2_hits_PM  f2_takedown_PM  \
# 0           0.64            0.28    6.015831        0.082925
#
#    f2_accentedHits_PM  f2_hitsHead_PM  f2_hitsBody_PM  f2_hitsLegs_PM  \
# 0             5.41274        2.962684        1.198643        1.251413
#
#    f2_accentedHitsPositionDistance_PM  f2_accentedHitsPositionClinch_PM  \
# 0                            4.304561                          0.490011
#
#    f2_accentedHitsPositionParter_PM  f2_knockdowns_PM  \
# 0                          0.618168               0.0
#
#    f2_protectionPassage_PM  f2_win_streak  f2_loose_streak  \
# 0                 0.105541              0                2
#
#    f2_count_of_fights      type  cumsum_duration_difference  \
# 0                  35  reversed                     -5898.0
#
#    cumsum_winner_difference  cumsum_hitsTotal_difference  \
# 0                     -16.0                      -1129.0
#
#    cumsum_hitsSuccessful_difference  cumsum_takedownTotal_difference  \
# 0                            -538.0                            -26.0
#
#    cumsum_takedownSuccessful_difference  cumsum_submissionAttempts_difference  \
# 0                                  -7.0                                 -10.0
#
#    cumsum_takeovers_difference  cumsum_accentedHitsTotal_difference  \
# 0                         -1.0                              -1110.0
#
#    cumsum_accentedHitsSuccessful_difference  cumsum_knockdowns_difference  \
# 0                                    -529.0                           0.0
#
#    cumsum_protectionPassage_difference  cumsum_hitsHeadTotal_difference  \
# 0                                 -8.0                           -741.0
#
#    cumsum_hitsHeadSuccessful_difference  cumsum_hitsBodyTotal_difference  \
# 0                                -237.0                           -190.0
#
#    cumsum_hitsBodySuccessful_difference  cumsum_hitsLegsTotal_difference  \
# 0                                -135.0                           -179.0
#
#    cumsum_hitsLegsSuccessful_difference  \
# 0                                -157.0
#
#    cumsum_accentedHitsPositionDistanceTotal_difference  \
# 0                                             -972.0
#
#    cumsum_accentedHitsPositionDistanceSuccessful_difference  \
# 0                                             -436.0
#
#    cumsum_accentedHitsPositionClinchTotal_difference  \
# 0                                              -87.0
#
#    cumsum_accentedHitsPositionClinchSuccessful_difference  \
# 0                                              -52.0
#
#    cumsum_accentedHitsPositionParterTotal_difference  \
# 0                                              -51.0
#
#    cumsum_accentedHitsPositionParterSuccessful_difference  \
# 0                                              -41.0
#
#    cumsum_winMethods_[DEC]_difference  cumsum_winMethods_[DQ]_difference  \
# 0                               -10.0                                0.0
#
#    cumsum_winMethods_[KO]_difference  cumsum_winMethods_[SUB]_difference  \
# 0                               -9.0                                -5.0
#
#    hits_accuracy_difference  takedown_accuracy_difference  \
# 0                  0.100482                      0.322917
#
#    accentedHits_accuracy_difference  hitsHead_accuracy_difference  \
# 0                          0.048219                      0.143855
#
#    hitsBody_accuracy_difference  hitsLegs_accuracy_difference  \
# 0                     -0.065789                     -0.172276
#
#    accentedHitsPositionDistance_accuracy_difference  \
# 0                                          0.035871
#
#    accentedHitsPositionClinch_accuracy_difference  \
# 0                                        0.181432
#
#    accentedHitsPositionParter_accuracy_difference  DEC_percent_difference  \
# 0                                       -0.060012               -0.257778
#
#    DQ_percent_difference  KO_percent_difference  SUB_percent_difference  \
# 0                    0.0               0.137778               -0.057778
#
#    hits_PM_difference  takedown_PM_difference  accentedHits_PM_difference  \
# 0             1.55331                0.033523                    0.089443
#
#    hitsHead_PM_difference  hitsBody_PM_difference  hitsLegs_PM_difference  \
# 0                1.578801               -0.499953               -0.989405
#
#    accentedHitsPositionDistance_PM_difference  \
# 0                                    -0.37443
#
#    accentedHitsPositionClinch_PM_difference  \
# 0                                 -0.111554
#
#    accentedHitsPositionParter_PM_difference  knockdowns_PM_difference  \
# 0                                  0.575427                       0.0
#
#    protectionPassage_PM_difference  win_streak_difference  \
# 0                         0.069132                    0.0
#
#    loose_streak_difference  odds_difference  age_difference  \
# 0                     -1.0            -2.32            -5.0
#
#    height_difference  armSpan_difference  legSwing_difference  \
# 0             -10.16                2.54                -1.27
#
#    isHomeCity_difference  isHomeCountry_difference  isHomeTimezone_difference  \
# 0                    0.0                      -1.0                        0.0
#
#    winner  is_fight_night   y_proba  y_pred  favorite
# 0    True           False  0.582198    True      True

# %%
from catboost import Pool
import matplotlib.pyplot as plt

fi = clf1.get_feature_importance(Pool(X_val, label=y_val, cat_features=[0,1,2,3,4,5,6,7]),
                                type='LossFunctionChange')

feature_score1 = pd.DataFrame(list(zip(X_val.dtypes.index, fi)),
                                columns=['Feature','Score'])

feature_score1 = feature_score1.sort_values(by='Score', ascending=False, inplace=False, kind='quicksort', na_position='last')

plt.rcParams["figure.figsize"] = (12,7)
ax = feature_score1.plot('Feature', 'Score', kind='bar', color='c')
ax.set_title("Feature Importance using {}".format('LossFunctionChange'), fontsize = 14)
ax.set_xlabel("features")
plt.show()

# %%
fi = clf2.get_feature_importance(Pool(X_val, label=y_val, cat_features=[0,1,2,3,4,5,6,7]),
                                type='LossFunctionChange')

feature_score2 = pd.DataFrame(list(zip(X_val.dtypes.index, fi)),
                                columns=['Feature','Score'])

feature_score2 = feature_score2.sort_values(by='Score', ascending=False, inplace=False, kind='quicksort', na_position='last')

plt.rcParams["figure.figsize"] = (12,7)
ax = feature_score2.plot('Feature', 'Score', kind='bar', color='c')
ax.set_title("Feature Importance using {}".format('LossFunctionChange'), fontsize = 14)
ax.set_xlabel("features")
plt.show()

# %%
features1 = feature_score1[feature_score1['Score'] >= 0]
features2 = feature_score2[feature_score2['Score'] >= 0]
features1
# Out:
#                                        Feature         Score
# 184                             age_difference  7.096264e-03
# 123                                     f2_age  1.097813e-03
# 172                     takedown_PM_difference  7.841427e-04
# 111                             f2_takedown_PM  6.530841e-04
# 182                      win_streak_difference  6.187831e-04
# ..                                         ...           ...
# 94                   f2_cumsum_winMethods_[DQ]  7.560844e-07
# 28   f1_cumsum_accentedHitsPositionClinchTotal  7.430822e-07
# 33                   f1_cumsum_winMethods_[DQ]  1.012067e-07
# 119                           f2_knockdowns_PM  0.000000e+00
# 79                        f2_cumsum_knockdowns  0.000000e+00
#
# [136 rows x 2 columns]

# %%
train_cols = set(features1['Feature']) & set(features2['Feature'])
train_cols = features1['Feature']#.drop('odds_difference', axis=1)
train_cols.tolist()
# Out:
# ['age_difference',
#  'f2_age',
#  'takedown_PM_difference',
#  'f2_takedown_PM',
#  'win_streak_difference',
#  'armSpan_difference',
#  'f1_age',
#  'f1_hitsHead_PM',
#  'f1_accentedHitsPositionParter_PM',
#  'protectionPassage_PM_difference',
#  'accentedHitsPositionParter_PM_difference',
#  'f1_cumsum_accentedHitsPositionParterSuccessful',
#  'hitsHead_accuracy_difference',
#  'f1_cumsum_accentedHitsPositionParterTotal',
#  'isHomeCountry_difference',
#  'f1_accentedHits_PM',
#  'f2_protectionPassage_PM',
#  'f2_cumsum_takedownTotal',
#  'f1_protectionPassage_PM',
#  'f2_country',
#  'f1_cumsum_protectionPassage',
#  'cumsum_winner_difference',
#  'f2_hitsHead_accuracy',
#  'f2_accentedHitsPositionParter_PM',
#  'f2_accentedHits_accuracy',
#  'cumsum_takedownSuccessful_difference',
#  'f1_cumsum_hitsHeadTotal',
#  'f1_takedown_PM',
#  'f2_win_streak',
#  'f1_cumsum_hitsTotal',
#  'f1_cumsum_accentedHitsTotal',
#  'f1_KO_percent',
#  'KO_percent_difference',
#  'f1_cumsum_hitsSuccessful',
#  'cumsum_accentedHitsPositionParterTotal_difference',
#  'cumsum_accentedHitsPositionParterSuccessful_difference',
#  'cumsum_takedownTotal_difference',
#  'f1_cumsum_submissionAttempts',
#  'f2_armSpan',
#  'f1_cumsum_hitsHeadSuccessful',
#  'f2_cumsum_takedownSuccessful',
#  'f1_hitsHead_accuracy',
#  'accentedHits_accuracy_difference',
#  'f1_cumsum_accentedHitsSuccessful',
#  'f1_cumsum_accentedHitsPositionDistanceTotal',
#  'hits_PM_difference',
#  'f2_cumsum_takeovers',
#  'cumsum_hitsHeadSuccessful_difference',
#  'f2_cumsum_winMethods_[DEC]',
#  'f1_win_streak',
#  'f1_cumsum_takedownSuccessful',
#  'f2_takedown_accuracy',
#  'cumsum_hitsSuccessful_difference',
#  'DEC_percent_difference',
#  'f1_cumsum_takedownTotal',
#  'f2_cumsum_protectionPassage',
#  'cumsum_protectionPassage_difference',
#  'f1_hits_PM',
#  'accentedHitsPositionDistance_accuracy_difference',
#  'f1_accentedHitsPositionDistance_PM',
#  'SUB_percent_difference',
#  'f2_SUB_percent',
#  'f1_isHomeCountry',
#  'f2_cumsum_accentedHitsPositionParterSuccessful',
#  'cumsum_accentedHitsTotal_difference',
#  'f1_cumsum_accentedHitsPositionDistanceSuccessful',
#  'f2_cumsum_hitsHeadTotal',
#  'f2_cumsum_accentedHitsTotal',
#  'f2_cumsum_hitsHeadSuccessful',
#  'f1_accentedHits_accuracy',
#  'f2_hits_PM',
#  'cumsum_hitsHeadTotal_difference',
#  'f2_DEC_percent',
#  'f2_cumsum_accentedHitsPositionParterTotal',
#  'f2_hitsBody_accuracy',
#  'f1_isHomeTimezone',
#  'isHomeTimezone_difference',
#  'cumsum_hitsLegsSuccessful_difference',
#  'f1_hitsBody_accuracy',
#  'f1_cumsum_hitsLegsTotal',
#  'cumsum_duration_difference',
#  'cumsum_hitsTotal_difference',
#  'f1_cumsum_duration',
#  'f1_cumsum_hitsLegsSuccessful',
#  'f2_cumsum_duration',
#  'f1_cumsum_winner',
#  'hitsBody_accuracy_difference',
#  'f1_DEC_percent',
#  'takedown_accuracy_difference',
#  'f2_cumsum_accentedHitsSuccessful',
#  'cumsum_accentedHitsPositionDistanceTotal_difference',
#  'f2_hits_accuracy',
#  'cumsum_submissionAttempts_difference',
#  'f1_accentedHitsPositionParter_accuracy',
#  'f2_cumsum_hitsLegsTotal',
#  'f2_hitsHead_PM',
#  'f2_cumsum_hitsSuccessful',
#  'weightCategory.id',
#  'f1_cumsum_winMethods_[SUB]',
#  'DQ_percent_difference',
#  'loose_streak_difference',
#  'f1_accentedHitsPositionDistance_accuracy',
#  'cumsum_winMethods_[DQ]_difference',
#  'cumsum_accentedHitsSuccessful_difference',
#  'f2_cumsum_accentedHitsPositionDistanceSuccessful',
#  'f2_cumsum_hitsTotal',
#  'f1_SUB_percent',
#  'is_fight_night',
#  'cumsum_winMethods_[DEC]_difference',
#  'cumsum_accentedHitsPositionDistanceSuccessful_difference',
#  'f1_takedown_accuracy',
#  'f2_cumsum_accentedHitsPositionDistanceTotal',
#  'f1_hitsLegs_PM',
#  'f2_cumsum_submissionAttempts',
#  'f2_cumsum_winMethods_[SUB]',
#  'f2_isHomeCountry',
#  'cumsum_takeovers_difference',
#  'f1_loose_streak',
#  'f2_cumsum_hitsLegsSuccessful',
#  'f2_cumsum_accentedHitsPositionClinchTotal',
#  'hits_accuracy_difference',
#  'f2_loose_streak',
#  'f1_hits_accuracy',
#  'f1_DQ_percent',
#  'f2_DQ_percent',
#  'legSwing_difference',
#  'f1_accentedHitsPositionClinch_accuracy',
#  'isHomeCity_difference',
#  'f2_accentedHits_PM',
#  'cumsum_winMethods_[KO]_difference',
#  'f2_isHomeCity',
#  'f2_cumsum_winMethods_[DQ]',
#  'f1_cumsum_accentedHitsPositionClinchTotal',
#  'f1_cumsum_winMethods_[DQ]',
#  'f2_knockdowns_PM',
#  'f2_cumsum_knockdowns']

# %%
features1[['Feature']]
# Out:
#                                        Feature
# 184                             age_difference
# 123                                     f2_age
# 172                     takedown_PM_difference
# 111                             f2_takedown_PM
# 182                      win_streak_difference
# ..                                         ...
# 94                   f2_cumsum_winMethods_[DQ]
# 28   f1_cumsum_accentedHitsPositionClinchTotal
# 33                   f1_cumsum_winMethods_[DQ]
# 119                           f2_knockdowns_PM
# 79                        f2_cumsum_knockdowns
#
# [136 rows x 1 columns]
