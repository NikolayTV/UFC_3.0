# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from catboost import CatBoostClassifier
import pandas as pd
import json
from pandas import json_normalize
from tqdm import tqdm_notebook as tqdm
import numpy as np
import ast
import time

import sys
import os
sys.path.append(os.path.join(sys.path[0], '../../core/'))

from train_utils import calculate_roi, get_winner_favorite, combine_df, parse_odds

# %%
fighters_df = pd.read_csv("../..//data/0.fighters_raw.csv", index_col=0)
fighters_df["dateOfBirth"] = pd.to_datetime(fighters_df["dateOfBirth"])
fighters_cols = [
    "id",
    "name",
    "weight",
    "height",
    "armSpan",
    "legSwing",
    "weightCategory.id",
    "weightCategory.name",
    "dateOfBirth",
    "country",
    "city",
    "timezone",
]
fighters_df = fighters_df[fighters_cols]
fighters_df.set_index("id", inplace=True)
f_name_dict = fighters_df['name'].to_dict()

all_new_cols = json.load(open('../../data/Catboost_v1_0/all_new_cols_06.04.2021.txt', 'r'))
f_stats_events_cumulative = pd.read_csv('../../data/Catboost_v1_0/PROD_f_stats_events_cumulative_06.04.2021.csv', index_col=0)
# Out:
# {1: 'Tanner Boser',
#  2: 'Giacomo Lemos',
#  3: 'Shamil Abdurakhimov',
#  4: 'Klidson Abreu',
#  5: 'Yoshihiro Akiyama',
#  6: 'Jessica Aguilar',
#  7: 'Juan Adams',
#  8: 'Israel Adesanya',
#  9: 'Abu Azaitar',
#  10: 'Rostem Akman',
#  11: 'Alexandra Albu',
#  12: 'Thiago Alves',
#  13: 'Warlley Alves',
#  14: 'Hector Aldana',
#  15: 'Irene Aldana',
#  16: 'Sultan Aliev',
#  17: 'Arnold Allen',
#  18: 'Eddie Alvarez',
#  19: 'Joel Alvarez',
#  20: 'Iuri Alcantara',
#  21: 'Abdul Razak Alhassan',
#  22: 'Thomas Almeida',
#  23: 'Corey Anderson',
#  24: 'Makwan Amirkhani',
#  25: 'Eryk Anders',
#  26: 'Megan Anderson',
#  27: 'Viviane Araujo',
#  28: 'Jessica Andrade',
#  29: 'Magomed Ankalaev',
#  30: 'Gadzhimurad Antigulov',
#  31: 'Austin Arnett',
#  32: 'Ben Askren',
#  33: 'Julio Arce',
#  34: 'Cyril Asker',
#  35: 'Omari Akhmedov',
#  36: 'Jessin Ayari',
#  37: 'Bryan Barberena',
#  38: 'Renan Barao',
#  39: 'Edson Barboza',
#  40: 'Enrique Barzola',
#  41: 'Mario Bautista',
#  42: 'Raoni Barcelos',
#  43: 'Siyar Bahadurzada',
#  44: 'Gabriel Benitez',
#  45: 'Ryan Benoit',
#  46: 'Manny Bermudez',
#  47: 'Talita Bernardo',
#  48: 'Poliana Botelho',
#  49: 'Tim Boetsch',
#  50: 'Kyle Bochniak',
#  51: 'Martin Bravo',
#  52: 'David Branch',
#  53: 'Randy Brown',
#  54: 'Tom Breese',
#  55: 'Wuliji Buren',
#  56: 'Jarred Brooks',
#  57: 'Shane Burgos',
#  58: 'Humberto Bandenay',
#  59: 'Gilbert Burns',
#  60: 'Matt Bessette',
#  61: 'Charles Byrd',
#  62: 'Chris Weidman',
#  63: 'Matt Wiman',
#  64: 'Brianna Van Buren',
#  65: 'Lando Vannata',
#  66: 'Paige VanZant',
#  67: 'Luigi Vendramini',
#  68: 'Marlon Vera',
#  69: 'Sheldon Westcott',
#  70: 'Marvin Vettori',
#  71: 'Polyana Viana',
#  72: 'Ketlen Vieira',
#  73: 'Gian Villante',
#  74: 'Adam Wieczorek',
#  75: 'James Vick',
#  76: 'Tim Williams',
#  77: 'Mickey Gall',
#  78: 'Alexander Volkov',
#  79: 'Nathaniel Wood',
#  80: 'Tyron Woodley',
#  81: 'Terrion Ware',
#  82: 'John Gunther',
#  83: 'Mitch Gagnon',
#  84: 'Alex Garcia',
#  85: 'Elias Garcia',
#  86: 'Danny Henry',
#  87: 'Christos Giagos',
#  88: 'Gregor Gillespie',
#  89: 'Rick Glenn',
#  90: 'Marcelo Golm',
#  91: 'Jason Gonzalez',
#  92: 'Jared Gordon',
#  93: 'Mike Grundy',
#  94: 'Davey Grant',
#  95: 'Bobby Green',
#  96: 'Desmond Green',
#  97: 'Chris Gruetzemacher',
#  98: 'Max Griffin',
#  99: 'Wang Guan',
#  100: 'Lyman Good',
#  101: 'Clay Guida',
#  102: 'Alexander Gustafsson',
#  103: 'Ciryl Gane',
#  104: 'Thibault Gouti',
#  105: 'Hakeem Dawodu',
#  106: 'Rolando Dy',
#  107: 'Jarjis Danho',
#  108: 'Joe Duffy',
#  109: 'Mark De La Rosa',
#  110: 'Evan Dunham',
#  111: 'Todd Duffee',
#  112: 'Merab Dvalishvili',
#  113: 'Geraldo de Freitas',
#  114: 'Chris de la Rocha',
#  115: 'Marcos Rogerio de Lima',
#  116: 'Trevin Giles',
#  117: 'Chanmi Jeon',
#  118: 'Mike Jackson',
#  119: 'Montel Jackson',
#  120: 'Jingliang Li',
#  121: 'Michael Johnson',
#  122: 'Jon Jones',
#  123: 'Kajan Johnson',
#  124: 'Jordan Johnson',
#  125: 'Alan Jouban',
#  126: 'Luke Jumeau',
#  127: 'Alessio Di Chirico',
#  128: 'Nick Diaz',
#  129: 'Nate Diaz',
#  130: 'CB Dollaway',
#  131: 'Marc Diakiese',
#  132: 'Drew Dober',
#  133: 'Shana Dobson',
#  134: 'John Dodson',
#  135: 'Alexis Davis',
#  136: 'Elizeu Zaleski dos Santos',
#  137: 'Brandon Davis',
#  138: 'Tom Duquesnoy',
#  139: 'Blagoy Ivanov',
#  140: 'Weili Zhang',
#  141: 'David Zawada',
#  142: 'Aiemann Zahabi',
#  143: 'Dan Ige',
#  144: 'Teruto Ishihara',
#  145: 'Ashley Yoder',
#  146: 'Naoki Inoue',
#  147: 'Joanne Calderwood',
#  148: 'Frank Camacho',
#  149: 'Zak Cummings',
#  150: 'Patrick Cummins',
#  151: 'Kyung Ho Kang',
#  152: 'Guido Cannetti',
#  153: 'Nadia Kassem',
#  154: 'Jared Cannonier',
#  155: 'Bryan Caraway',
#  156: 'Alex Caceres',
#  157: 'Brad Katona',
#  158: 'Michael Chiesa',
#  159: 'Priscila Cachoeira',
#  160: 'Kenan Song',
#  161: 'Pannie Kianzad',
#  162: 'Dong Hyun Kim',
#  163: 'Ji Yeon Kim',
#  164: 'Justine Kish',
#  165: 'Devin Clark',
#  166: 'Drakkar Klose',
#  167: 'Karolina Kowalkiewicz',
#  168: 'Jake Collier',
#  169: 'Syuri Kondo',
#  170: 'Daniel Cormier',
#  171: 'Rashad Coulter',
#  172: 'Paulo Costa',
#  173: 'Erik Koch',
#  174: 'Allen Crowder',
#  175: 'Pascal Krauss',
#  176: 'James Krause',
#  177: 'Paul Craig',
#  178: 'Nikita Krylov',
#  179: 'Jose Quinonez',
#  180: 'Aleksei Kunchenko',
#  181: 'Amanda Cooper',
#  182: 'Yana Kunitskaya',
#  183: 'Ion Cutelaba',
#  184: 'Bharat Kandare',
#  185: 'Joe Lauzon',
#  186: 'Lina Lansberg',
#  187: 'Chad Laprise',
#  188: 'Ilir Latifi',
#  189: 'Amanda Lemos',
#  190: 'Ryan LaFlare',
#  191: 'Nik Lentz',
#  192: 'Leah Letson',
#  193: 'Kevin Lee',
#  194: 'Andrea Lee',
#  195: 'Dhiego Lima',
#  196: 'John Lineker',
#  197: 'Hector Lombard',
#  198: 'Benito Lopez',
#  199: 'Artem Lobov',
#  200: 'Derrick Lewis',
#  201: 'Bevon Lewis',
#  202: 'Zabit Magomedsharipov',
#  203: 'Aspen Ladd',
#  204: 'Liu Pingyuan',
#  205: 'Vicente Luque',
#  206: 'Ruslan Magomedov',
#  207: 'Jennifer Maia',
#  208: 'Sabina Mazo',
#  209: 'Adam Milstead',
#  210: 'Court McGee',
#  211: 'Conor McGregor',
#  212: 'Marcos Mariano',
#  213: 'John Makdessi',
#  214: 'Molly McCann',
#  215: 'Julian Marquez',
#  216: 'Randa Markos',
#  217: 'Anthony Rocco Martin',
#  218: 'Jack Marshman',
#  219: 'Islam Makhachev',
#  220: 'Gray Maynard',
#  221: 'Veronica Macedo',
#  222: 'Jordan Mein',
#  223: 'Gerald Meerschaert',
#  224: 'Gilbert Melendez',
#  225: 'Chad Mendes',
#  226: 'Alonzo Menifield',
#  227: 'Emil Meek',
#  228: 'Curtis Millender',
#  229: 'Jim Miller',
#  230: 'Alberto Mina',
#  231: 'Tim Means',
#  232: 'Bryce Mitchell',
#  233: 'Roxanne Modafferi',
#  234: 'Renato Moicano',
#  235: 'Nicco Montano',
#  236: 'Vince Morales',
#  237: 'Sergio Moraes',
#  238: 'Sheymon Moraes',
#  239: 'Joseph Morales',
#  240: 'Sarah Moras',
#  241: 'Dan Moret',
#  242: 'Brandon Moreno',
#  243: 'Maryna Moroz',
#  244: 'Alex Morono',
#  245: 'Ashkan Mokhtarian',
#  246: 'Jake Matthews',
#  247: 'Khalid Murtazaliev',
#  248: 'Magomed Mustafaev',
#  249: 'Belal Muhammad',
#  250: 'Lauren Mueller',
#  251: 'Nad Narimani',
#  252: 'Vince Murdock',
#  253: 'Keita Nakamura',
#  254: 'Rose Namajunas',
#  255: 'Ismail Naurdiev',
#  256: 'Francis Ngannou',
#  257: 'Ben Nguyen',
#  258: 'Antonio Braga Neto',
#  259: 'Kennedy Nzechukwu',
#  260: 'Geoff Neal',
#  261: 'Rogerio Nogueira',
#  262: 'Said Nurmagomedov',
#  263: 'Sage Northcutt',
#  264: 'Amanda Nunes',
#  265: 'Khabib Nurmagomedov',
#  266: 'Olivier Aubin-Mercier',
#  267: 'Journey Newson',
#  268: "Sean O'Malley",
#  269: 'Alistair Overeem',
#  270: 'Volkan Oezdemir',
#  271: 'Yushin Okami',
#  272: 'JJ Aldrich',
#  273: 'Michal Oleksiejczuk',
#  274: 'Charles Oliveira',
#  275: 'Alex Oliveira',
#  276: 'Teemu Packalen',
#  277: 'Andrei Arlovski',
#  278: 'Zak Ottow',
#  279: 'CM Punk',
#  280: 'Alan Patrick',
#  281: 'Luis Pena',
#  282: 'Alex Perez',
#  283: 'Devin Powell',
#  284: 'Carlo Pedersoli',
#  285: 'Jessica Penne',
#  286: 'Michel Pereira',
#  287: 'Markus Perez',
#  288: 'Mike Perry',
#  289: 'Raphael Pessoa',
#  290: 'Sergio Pettis',
#  291: 'Ross Pearson',
#  292: 'Anthony Pettis',
#  293: 'Steven Peterson',
#  294: 'Vinc Pichel',
#  295: 'Callan Potter',
#  296: 'Michel Prazeres',
#  297: 'Niko Price',
#  298: 'Kyle Prepolec',
#  299: 'Marcin Prachnio',
#  300: 'Lucie Pudilova',
#  301: 'Claudio Puelles',
#  302: 'Oskar Piechota',
#  303: 'Khalil Rountree Jr.',
#  304: 'Aleksandar Rakic',
#  305: 'Davi Ramos',
#  306: 'Ricardo Ramos',
#  307: 'Chance Rencountre',
#  308: 'Alex Reyes',
#  309: 'Dominick Reyes',
#  310: 'Polo Reyes',
#  311: 'Jordan Rinaldi',
#  312: 'Karl Roberson',
#  313: 'Danny Roberts',
#  314: 'Roosevelt Roberts',
#  315: 'Yair Rodriguez',
#  316: 'Mike Rodriguez',
#  317: 'Charles Rosa',
#  318: 'Marina Rodriguez',
#  319: 'Jairzinho Rozenstruik',
#  320: 'Yoel Romero',
#  321: 'Mara Romero Borella',
#  322: 'Ben Rothwell',
#  323: 'Stevie Ray',
#  324: 'Ricky Rainey',
#  325: 'Frankie Saenz',
#  326: 'Cris Cyborg',
#  327: 'Gokhan Saki',
#  328: 'Augusto Sakai',
#  329: 'Muslim Salikhov',
#  330: 'George Sullivan',
#  331: 'Luke Sanders',
#  332: 'Joby Sanchez',
#  333: 'Hector Sandoval',
#  334: 'Leonardo Santos',
#  335: 'Thiago Santos',
#  336: 'Roberto Sanchez',
#  337: 'Ulka Sasaki',
#  338: 'Andrew Sanchez',
#  339: 'Diego Sanchez',
#  340: 'Saparbeg Safarov',
#  341: 'Tarec Saffiedine',
#  342: 'Stefan Sekulic',
#  343: 'Cub Swanson',
#  344: 'Matt Sayles',
#  345: 'Ovince Saint Preux',
#  346: 'Felipe Silva',
#  347: 'Donald Cerrone',
#  348: 'Mayra Bueno Silva',
#  349: 'Joaquim Silva',
#  350: 'Claudio Silva',
#  351: 'Arjan Bhullar',
#  352: 'Douglas Silva de Andrade',
#  353: 'Ricky Simon',
#  354: 'Chas Skelly',
#  355: 'Justin Scoggins',
#  356: 'Bradley Scott',
#  357: 'Trevor Smith',
#  358: 'Anthony Smith',
#  359: 'Peter Sobotta',
#  360: 'Ben Saunders',
#  361: 'Jinsoo Son',
#  362: 'Dmitry Sosnovskiy',
#  363: 'Jacare Souza',
#  364: 'Livinha Souza',
#  365: 'Ryan Spann',
#  366: 'Daniel Spitz',
#  367: 'Aljamain Sterling',
#  368: 'Julija Stoliarenko',
#  369: 'Jeremy Stephens',
#  370: 'Maia Stevenson',
#  371: 'Darko Stosic',
#  372: 'Sean Strickland',
#  373: 'Boston Salmon',
#  374: 'Cody Stamann',
#  375: 'Darren Stewart',
#  376: 'Tatiana Suarez',
#  377: 'Andre Soukhamthath',
#  378: 'Xiaonan Yan',
#  379: 'Cory Sandhagen',
#  380: 'Mairbek Taisumov',
#  381: 'Jon Tuck',
#  382: 'Gavin Tucker',
#  383: 'Khalid Taha',
#  384: 'Nordine Taleb',
#  385: 'David Teymur',
#  386: 'Dequan Townsend',
#  387: 'Jose Torres',
#  388: 'Daniel Teymur',
#  389: 'Glover Teixeira',
#  390: 'Elias Theodorou',
#  391: 'Francisco Trinaldo',
#  392: 'Tecia Torres',
#  393: 'Michael Trizano',
#  394: 'Salim Touahri',
#  395: 'Zubaira Tukhugov',
#  396: 'Jalin Turner',
#  397: 'Jesse Taylor',
#  398: 'Craig White',
#  399: 'Alex White',
#  400: 'Bartosz Fabinski',
#  401: 'Emily Whitmire',
#  402: 'Michelle Waterson',
#  403: 'Tony Ferguson',
#  404: 'Diego Ferreira',
#  405: 'Cezar Ferreira',
#  406: 'Deiveson Figueiredo',
#  407: 'Andre Fili',
#  408: 'Justin Frazier',
#  409: 'John Phillips',
#  410: 'Jussier Formiga',
#  411: 'Matt Frevola',
#  412: 'Nasrat Haqparast',
#  413: 'Rustam Khabilov',
#  414: 'Damir Hadzovic',
#  415: 'Mark Hunt',
#  416: 'Nick Hein',
#  417: 'Walt Harris',
#  418: 'Ed Herman',
#  419: 'Nohelin Hernandez',
#  420: 'Jack Hermansson',
#  421: 'Alexander Hernandez',
#  422: 'Felice Herrig',
#  423: 'Ryan Hall',
#  424: 'Mizuto Hirota',
#  425: 'Uriah Hall',
#  426: 'Kevin Holland',
#  427: 'Holly Holm',
#  428: 'Kurt Holobaugh',
#  429: 'Chris Holdsworth',
#  430: 'Scott Holtzman',
#  431: 'Sabah Homasi',
#  432: 'Carlos Huachin',
#  433: 'Darrell Horcher',
#  434: 'Dan Hooker',
#  435: 'Dong Hyun Ma',
#  436: 'John Hathaway',
#  437: 'Alex Chambers',
#  438: 'Dooho Choi',
#  439: 'Katlyn Chookagian',
#  440: 'Eric Shelton',
#  441: 'Chase Sherman',
#  442: 'Matt Schnell',
#  443: 'Ashlee Evans-Smith',
#  444: 'Te Edwards',
#  445: 'Andre Ewell',
#  446: 'Tonya Evinger',
#  447: 'Leon Edwards',
#  448: 'Abdul-Kerim Edilov',
#  449: 'Sam Alvey',
#  450: 'Jake Ellenberger',
#  451: 'Joe Ellenberger',
#  452: 'Julian Erosa',
#  453: 'Ramazan Emeev',
#  454: 'Josh Emmett',
#  455: 'Luis Henrique',
#  456: 'Jodie Esquibel',
#  457: 'Jordan Espinosa',
#  458: 'Carla Esparza',
#  459: 'Juan Espino',
#  460: 'Song Yadong',
#  461: 'Al Iaquinta',
#  462: 'Yanan Wu',
#  463: 'Alexander Yakovlev',
#  464: 'Norifumi Yamamoto',
#  465: 'Petr Yan',
#  466: 'Shane Young',
#  467: 'Adam Yandiev',
#  468: 'Hu Yaozong',
#  469: 'Rani Yahya',
#  470: 'Germaine de Randamie',
#  471: 'John Allan',
#  472: 'Darren Elkins',
#  473: 'Max Holloway',
#  474: 'Frankie Edgar',
#  475: 'Krzysztof Jotko',
#  476: 'Alexandre Pantoja',
#  477: 'Kyle Stewart',
#  478: 'Robbie Lawler',
#  479: 'Jorge Masvidal',
#  480: 'Jan Blachowicz',
#  481: 'Luke Rockhold',
#  482: 'Claudia Gadelha',
#  483: 'Edmen Shahbazyan',
#  484: 'Junior Dos Santos',
#  485: 'Joseph Benavidez',
#  486: 'Demian Maia',
#  487: 'Amanda Ribas',
#  488: 'Maurice Greene',
#  489: 'Junior Albini',
#  490: 'Anderson Dos Santos',
#  491: 'Chan Sung Jung',
#  492: 'Eric Spicely',
#  493: 'Henry Cejudo',
#  494: 'Marlon Moraes',
#  495: 'Tai Tuivasa',
#  496: 'Jimmie Rivera',
#  497: 'Ricardo Lamas',
#  498: 'Calvin Kattar',
#  499: 'Angela Hill',
#  500: 'Jimi Manuwa',
#  501: 'Antonio Carlos Junior',
#  502: 'Grant Dawson',
#  503: 'Anderson Silva',
#  504: 'Bethe Correia',
#  505: 'BJ Penn',
#  506: 'Derek Brunson',
#  507: 'Macy Chiasson',
#  508: 'Marcin Tybura',
#  509: 'Jeff Hughes',
#  510: 'Misha Cirkunov',
#  511: 'Jimmy Crute',
#  512: 'Greg Hardy',
#  513: 'Dmitrii Smoliakov',
#  514: 'Mike Davis',
#  515: 'Aleksei Oleinik',
#  516: 'Dustin Poirier',
#  517: 'Rafael Fiziev',
#  518: 'Dwight Grant',
#  519: 'Wilson Reis',
#  520: 'Justin Gaethje',
#  521: 'Sodiq Yusuff',
#  522: 'Ray Borg',
#  523: 'Casey Kenney',
#  524: 'Stephen Thompson',
#  525: 'Maycee Barber',
#  526: 'Gunnar Nelson',
#  527: 'Nicolae Negumereanu',
#  528: 'Beneil Dariush',
#  529: 'Marion Reneau',
#  530: 'Louis Smolka',
#  531: 'Kamaru Usman',
#  532: 'Cody Garbrandt',
#  533: 'Pedro Munhoz',
#  534: 'Alejandro Perez',
#  535: 'Gina Mazany',
#  536: 'Stefan Struve',
#  537: 'Paul Felder',
#  538: 'Cain Velasquez',
#  539: 'Cortney Casey',
#  540: 'Cynthia Calvillo',
#  541: 'Myles Jury',
#  542: 'Kron Gracie',
#  543: 'Raphael Assuncao',
#  544: 'Justin Ledet',
#  545: 'Anthony Hernandez',
#  546: 'Magomed Bibulatov',
#  547: 'Carlos Condit',
#  548: 'Alexander Volkanovski',
#  549: 'Cat Zingano',
#  550: 'Brian Kelleher',
#  551: 'Brian Ortega',
#  552: 'Nina Ansaroff',
#  553: 'Matthew Lopez',
#  554: 'Mauricio Rua',
#  555: 'Tyson Pedro',
#  556: 'Justin Willis',
#  557: 'Rafael Dos Anjos',
#  558: 'Michel Batista',
#  559: 'Curtis Blaydes',
#  560: 'Neil Magny',
#  561: 'Santiago Ponzinibbio',
#  562: 'Raquel Pennington',
#  563: 'Jason Knight',
#  564: 'Don Madge',
#  565: 'Darren Till',
#  566: 'John Moraga',
#  567: 'TJ Dillashaw',
#  568: 'Demetrious Johnson',
#  569: 'Brett Johns',
#  570: 'Danielle Taylor',
#  571: 'Jose Aldo',
#  572: 'Joanna Jedrzejczyk',
#  573: 'Dustin Ortiz',
#  574: 'Matheus Nicolau',
#  575: 'Alvaro Herrera',
#  576: 'Vitor Miranda',
#  577: 'Jeremy Kimball',
#  578: 'Damian Stasiak',
#  579: 'Dennis Bermudez',
#  580: 'Eddie Wineland',
#  581: 'Stipe Miocic',
#  582: 'Rob Font',
#  583: 'Brad Tavares',
#  584: 'Jay Cucciniello',
#  585: 'Allan Zuniga',
#  586: 'Tyler Diamond',
#  587: 'Daichi Abe',
#  588: 'Shinsho Anzai',
#  589: 'Viviane Pereira',
#  590: 'Jenel Lausa',
#  591: 'Robert Whittaker',
#  592: 'Mirsad Bektic',
#  593: 'Mike Santiago',
#  594: 'Mads Burnell',
#  595: 'Daniel Kelly',
#  596: 'Alexa Grasso',
#  597: 'Diego Rivas',
#  598: 'Henry Briones',
#  599: 'Kelvin Gastelum',
#  600: 'Mackenzie Dern',
#  601: 'Vitor Belfort',
#  602: 'James Bochnovic',
#  603: 'Luan Chagas',
#  604: 'Patrick Williams',
#  605: 'Fabricio Werdum',
#  606: 'Oliver Enkamp',
#  607: 'Mike Pyle',
#  608: 'Sara McMann',
#  609: 'Albert Morales',
#  610: 'Yancy Medeiros',
#  611: 'Brian Camozzi',
#  612: 'Joshua Burkman',
#  613: 'Damien Brown',
#  614: 'Rob Wilkinson',
#  615: 'Tim Johnson',
#  616: 'Joe Soto',
#  617: 'Juliana Lima',
#  618: 'Gleison Tibau',
#  619: 'Tim Elliott',
#  620: 'Abel Trujillo',
#  621: 'Erick Silva',
#  622: 'Bojan Velickovic',
#  623: 'Jamie Moyle',
#  624: 'Valentina Shevchenko',
#  625: 'Liz Carmouche',
#  626: 'Eduardo Garagorri',
#  627: 'Bobby Moffett',
#  628: 'Rogerio Bontorin',
#  629: 'Raulian Paiva',
#  630: 'Chris Gutierrez',
#  631: 'Rachael Ostovich',
#  632: 'Rodolfo Vieira',
#  633: 'Taila Santos',
#  634: 'Ariane Carnelossi',
#  635: 'Laureano Staropoli',
#  636: 'Wellington Turman',
#  637: 'Julianna Pena',
#  638: 'Jonathan Martinez',
#  639: 'Felicia Spencer',
#  640: 'Marc-Andre Barriault',
#  641: 'Arman Tsarukyan',
#  642: 'SeungWoo Choi',
#  643: 'Yoshinori Horie',
#  644: 'Lauren Murphy',
#  645: 'Gillian Robertson',
#  646: 'Sarah Frota',
#  647: 'Antonina Shevchenko',
#  648: 'Julia Avila',
#  649: 'Vinicius Moreira',
#  650: 'Dalcha Lungiambula',
#  651: 'Montana De La Rosa',
#  652: 'Kevin Aguilar',
#  653: 'Deron Winn',
#  654: 'Ariane Lipski',
#  655: 'Jessica Eye',
#  656: 'Grigorii Popov',
#  657: 'Chris Fishgold',
#  658: 'Sergey Khandozhko',
#  659: 'Sung Bin Jo',
#  660: 'Bea Malecki',
#  661: 'Duda Santana',
#  662: 'Danilo Belluardo',
#  663: 'Ian Heinisch',
#  664: 'Austin Hubbard',
#  665: 'Derrick Krantz',
#  666: 'Charles Jourdain',
#  667: 'Sijara Eubanks',
#  668: 'Thiago Moises',
#  669: 'Luana Carolina',
#  670: 'Serghei Spivac',
#  671: 'Cole Smith',
#  672: 'Thomas Gifford',
#  673: 'Takashi Sato',
#  674: 'Virna Jandiroba',
#  675: 'Sergei Pavlovich',
#  676: 'Alen Amedovski',
#  677: 'Movsar Evloev',
#  678: 'Alex Da Silva',
#  679: 'Zelim Imadaev',
#  680: 'Randy Costa',
#  681: 'Jesus Pinedo',
#  682: 'Ryan MacDonald',
#  683: 'Johnny Walker',
#  684: 'Hannah Cifers',
#  685: 'Damir Ismagulov',
#  686: 'Devonte Smith',
#  687: 'Kai Kara-France',
#  688: 'Jordan Griffin',
#  689: 'Suman Mokhtarian',
#  690: 'Su Mudaerji',
#  691: 'Kalindra Faria',
#  692: 'Joe Giannetti',
#  693: 'Barb Honchak',
#  694: 'Richie Smullen',
#  695: 'Jessica-Rose Clark',
#  696: 'Felipe Arantes',
#  697: 'Melinda Fabian',
#  698: 'Bec Rawlings',
#  699: 'Russell Doane',
#  700: 'Jeremy Kennedy',
#  701: 'Gabriel Silva',
#  702: 'Domingo Pilarte',
#  703: 'Felipe Colares',
#  704: 'Michael Bisping',
#  705: 'Will Brooks',
#  706: 'Anthony Hamilton',
#  707: 'Michel Quinones',
#  708: 'Marcel Fortuna',
#  709: 'Georges St-Pierre',
#  710: 'Hacran Dias',
#  711: 'Christian Colombo',
#  712: 'Marcin Held',
#  713: 'Jonathan Wilson',
#  714: 'Pearl Gonzalez',
#  715: 'Takanori Gomi',
#  716: 'Zu Anyanwu',
#  717: 'Jason Saggo',
#  718: 'Adriano Martins',
#  719: 'Bojan Mihajlovic',
#  720: 'Andrew Holbrook',
#  721: 'Damian Grabowski',
#  722: 'Frankie Perez',
#  723: 'James Mulheron',
#  724: 'Neil Seery',
#  725: 'Charlie Ward',
#  726: 'Leslie Smith',
#  727: 'Daniel Omielanczuk',
#  728: 'Travis Browne',
#  729: 'Nick Roehrick',
#  730: 'Tom Gallicchio',
#  731: 'Dennis Siver',
#  732: 'Johnny Case',
#  733: 'Josh Stansbury',
#  734: 'Kwan Ho Kwak',
#  735: 'Dominique Steele',
#  736: 'Kiichi Kunimoto',
#  737: 'Johnny Eduardo',
#  738: 'Jimmy Wallhead',
#  739: 'Alex Nicholson',
#  740: 'Reza Madadi',
#  741: 'Nico Musoke',
#  742: 'Joachim Christensen',
#  743: 'Michael McBride',
#  744: 'Cindy Dandois',
#  745: 'Roy Nelson',
#  746: 'Augusto Mendes',
#  747: 'Nathan Coy',
#  748: 'Ronda Rousey',
#  749: 'Dominick Cruz',
#  750: 'Keith Berish',
#  751: 'Chris Camozzi',
#  752: 'Jonathan Meunier',
#  753: 'Magnus Cedenblad',
#  754: 'Rashid Magomedov',
#  755: 'Heather Jo Clark',
#  756: 'Tae Hyun Bang',
#  757: 'Alberto Uda',
#  758: 'Steve Bosse',
#  759: 'Henrique da Silva',
#  760: 'Igor Pokrajac',
#  761: 'Frank Mir',
#  762: 'Tom Lawlor',
#  763: 'Joe Proctor',
#  764: 'Mickael Lebout',
#  765: 'Larissa Pacheco',
#  766: 'Marcelo Guimaraes',
#  767: 'Tiequan Zhang',
#  768: 'Luiz Cane',
#  769: 'Dan Hardy',
#  770: 'John Alessio',
#  771: 'Seth Petruzelli',
#  772: 'Brodie Farber',
#  773: 'Nate Loughran',
#  774: 'Mike Kyle',
#  775: 'Benji Radach',
#  776: 'Dan Severn',
#  777: 'Cesar Marscucci',
#  778: 'Josh Stuart',
#  779: 'Justin Martin',
#  780: 'Harold Howard',
#  781: 'Eldo Xavier Dias',
#  782: 'Urijah Faber',
#  785: 'Liana Jojua',
#  786: 'Ricardo Abreu',
#  787: 'Adlan Amagov',
#  788: 'Josh Barnett',
#  789: 'Matt Brown',
#  790: 'Alan Belcher',
#  791: 'Kerry Vera',
#  792: 'Justin Wilcox',
#  793: 'Manvel Gamburyan',
#  794: 'Mark Godbeer',
#  795: 'Matt Grice',
#  796: 'Forrest Griffin',
#  797: 'Ryan Janes',
#  798: 'Kyle Jensen',
#  799: 'Anthony Johnson',
#  800: 'Aisling Daly',
#  801: 'Martin Kampmann',
#  802: 'Tim Kennedy',
#  803: 'Mitch Clarke',
#  804: 'Patrick Cote',
#  805: 'Tina Lahdemaki',
#  806: 'Thales Leites',
#  807: 'Brock Lesnar',
#  808: 'Scott McAfee',
#  809: 'Doug Marshall',
#  810: 'Ronny Markes',
#  811: 'Nazareno Malegarie',
#  812: 'Jason Miller',
#  813: 'Kazuo Misaki',
#  814: 'Mark Munoz',
#  815: 'Rafael Natal',
#  816: 'Mats Nilsson',
#  817: 'Kyle Noke',
#  818: 'Joao Pierini',
#  819: 'Brad Pickett',
#  820: 'Sean Pierson',
#  821: 'Mike Swick',
#  822: 'Matt Serra',
#  823: 'Dion Staring',
#  824: 'Sam Stout',
#  825: 'James Te Huna',
#  826: 'James Terry',
#  827: 'Miesha Tate',
#  828: 'Drew Fickett',
#  829: 'Costas Philippou',
#  830: 'Kenny Florian',
#  831: 'Johny Hendricks',
#  832: 'Jimy Hettes',
#  833: 'Paddy Holohan',
#  834: 'Matt Hughes',
#  835: 'Brendan Schaub',
#  836: 'Yves Edwards',
#  837: 'Anna Elmose',
#  838: 'Dongi Yang',
#  839: 'Colby Covington',
#  840: 'Bruno Silva',
#  841: 'Ottman Azaitar',
#  842: 'Kyle Nelson',
#  843: 'Alex Gorgees',
#  846: 'Olaf Alfonso',
#  847: 'Minotauro Nogueira',
#  848: 'Dan Henderson',
#  849: 'Rashad Evans',
#  850: 'Lyoto Machida',
#  851: 'Francimar Barroso',
#  852: 'Galore Bofando',
#  853: 'Oluwale Bamgbose',
#  854: 'Carls John De Tomas',
#  855: 'Angela Magana',
#  856: 'DeAnna Bennett',
#  857: 'Christina Marks',
#  858: 'Karine Gevorgyan',
#  859: 'Ariel Beck',
#  860: 'Bobby Nash',
#  861: 'Kailin Curran',
#  862: 'Nate Marquardt',
#  863: 'Hyun Gyu Lim',
#  864: 'Chris Wade',
#  865: 'Marco Beltran',
#  866: 'Gegard Mousasi',
#  867: 'Mike de la Torre',
#  868: 'Scott Askham',
#  869: 'Garreth McLellan',
#  870: 'Sam Sicilia',
#  871: 'Alessandro Ricci',
#  872: 'Reginaldo Vieira',
#  873: 'Phillipe Nover',
#  874: 'Roan Carneiro',
#  875: 'Michinori Tanaka',
#  876: 'JC Cottrell',
#  877: 'Viktor Pesta',
#  878: 'Jocelyn Jones-Lybarger',
#  879: 'Brandon Thatch',
#  880: 'Cole Miller',
#  881: 'James Moontasri',
#  882: 'Takeya Mizugaki',
#  883: 'Fredy Serrano',
#  884: 'Valerie Letourneau',
#  885: 'Zach Makovsky',
#  886: "Sean O'Connell",
#  887: 'Tiago Trator',
#  888: 'Joe Gigliotti',
#  889: "Brendan O'Reilly",
#  890: 'Elvis Mutapcic',
#  891: 'Yusuke Kasuya',
#  892: 'Seohee Ham',
#  893: 'Richard Walsh',
#  894: 'Ning Guangyou',
#  895: 'Geane Herrera',
#  896: 'Yao Zhikui',
#  897: 'Ryan Bader',
#  898: 'Kyoji Horiguchi',
#  899: 'Ali Bagautinov',
#  900: 'Milana Dudieva',
#  901: 'Erick Montano',
#  902: 'Erik Perez',
#  903: 'Jason Novelli',
#  904: 'Chris Avila',
#  905: 'Lukasz Sajewski',
#  906: 'Albert Tumenov',
#  907: 'Tamdan McCrory',
#  908: 'Cody East',
#  909: 'Kelly Faszholz',
#  910: 'Antonio Silva',
#  911: 'Hector Urbina',
#  912: 'Glaico Franca',
#  913: 'Kenny Robertson',
#  914: 'Maximo Blanco',
#  915: 'Leonardo Augusto Leleco',
#  916: 'Augusto Montano',
#  917: 'Joey Gomez',
#  918: 'Caio Magalhaes',
#  919: 'Sean Spencer',
#  920: 'Nicolas Dalby',
#  921: 'Taylor Lapilus',
#  922: 'Leandro Issa',
#  923: 'Leandro Silva',
#  924: 'Kevin Casey',
#  925: 'Shane Campbell',
#  926: 'Rick Story',
#  927: 'Elizabeth Phillips',
#  928: 'Lorenz Larkin',
#  929: 'Tatsuya Kawajiri',
#  930: 'Horacio Gutierrez',
#  931: 'Francisco Rivera',
#  932: 'Michael Graves',
#  933: 'Cesar Arzamendia',
#  934: 'Jim Alers',
#  935: 'Michael McDonald',
#  936: 'Josh Samman',
#  937: 'Cristina Stanciu',
#  938: 'Cody Pfister',
#  939: 'Enrique Marin',
#  940: 'Cory Hendricks',
#  941: 'Anton Zafir',
#  942: 'Mehdi Baghdad',
#  943: 'Anthony Birchak',
#  944: 'Dileno Lopes',
#  945: 'Jerrod Sanders',
#  946: 'Rory MacDonald',
#  947: 'Chris Beal',
#  948: 'Yan Cabral',
#  949: 'Willie Gates',
#  950: 'Chris Kelades',
#  951: 'Clint Hester',
#  952: 'Efrain Escudero',
#  953: 'Gabriel Gonzaga',
#  954: 'Ian Entwistle',
#  955: 'Rob Whiteford',
#  956: 'Lucas Martins',
#  957: 'Rin Nakai',
#  958: 'Mark Eddiva',
#  959: 'Viscardi Andrade',
#  960: 'Justin Salas',
#  961: 'Mike Wilkinson',
#  962: 'Yaotzin Meza',
#  963: 'Chris Dempsey',
#  964: 'Norman Parke',
#  965: 'Martin Svensson',
#  966: 'Joe Riggs',
#  967: 'Jonavin Webb',
#  968: 'Jared Rosholt',
#  969: 'Rafael Feijao',
#  970: 'KJ Noons',
#  971: 'Noad Lahat',
#  972: 'Damon Jackson',
#  973: 'Levan Makashvili',
#  974: 'Masio Fullen',
#  975: 'Matt Dwyer',
#  976: 'Felipe Olivieri',
#  977: 'Matt Mitrione',
#  978: 'Daron Cruickshank',
#  979: 'Diego Brandao',
#  980: 'Tony Sims',
#  981: 'Masanori Kanehara',
#  982: 'Edgar Garcia',
#  983: 'Danny Castillo',
#  984: 'Sarah Kaufman',
#  985: 'Hayder Hassan',
#  986: 'Marcin Wrzosek',
#  987: 'Mike Pierce',
#  988: 'Konstantin Erokhin',
#  989: 'Abner Lloveras',
#  990: 'John Howard',
#  991: 'Andreas Stahl',
#  992: 'Emily Peters Kagan',
#  993: 'Benson Henderson',
#  994: 'Yui Chul Nam',
#  995: 'Scott Jorgensen',
#  996: 'Vernon Ramos',
#  997: 'Valmir Lazaro',
#  998: 'Akbarh Arreola',
#  999: 'Anthony Perosh',
#  1000: 'Richie Vaculik',
#  1001: 'Danny Martinez',
#  1002: 'Steve Montgomery',
#  1003: 'Steve Kennedy',
#  1004: 'Piotr Hallmann',
#  ...}

# %%
# Out:
# {'static_supl_cols': ['winner',
#   'city',
#   'country',
#   'duration',
#   'fighterId_1',
#   'fighterId_2',
#   'name',
#   'rounds',
#   'eventDate.timezone',
#   'weightCategory.name',
#   'winnerId',
#   'f1_odds',
#   'f2_odds',
#   'f1_age',
#   'f2_age',
#   'f1_count_of_fights',
#   'f2_count_of_fights'],
#  'f2_cumsum_col_names': ['f2_cumsum_duration',
#   'f2_cumsum_winner',
#   'f2_cumsum_hitsTotal',
#   'f2_cumsum_hitsSuccessful',
#   'f2_cumsum_takedownTotal',
#   'f2_cumsum_takedownSuccessful',
#   'f2_cumsum_submissionAttempts',
#   'f2_cumsum_takeovers',
#   'f2_cumsum_accentedHitsTotal',
#   'f2_cumsum_accentedHitsSuccessful',
#   'f2_cumsum_knockdowns',
#   'f2_cumsum_protectionPassage',
#   'f2_cumsum_hitsHeadTotal',
#   'f2_cumsum_hitsHeadSuccessful',
#   'f2_cumsum_hitsBodyTotal',
#   'f2_cumsum_hitsBodySuccessful',
#   'f2_cumsum_hitsLegsTotal',
#   'f2_cumsum_hitsLegsSuccessful',
#   'f2_cumsum_accentedHitsPositionDistanceTotal',
#   'f2_cumsum_accentedHitsPositionDistanceSuccessful',
#   'f2_cumsum_accentedHitsPositionClinchTotal',
#   'f2_cumsum_accentedHitsPositionClinchSuccessful',
#   'f2_cumsum_accentedHitsPositionParterTotal',
#   'f2_cumsum_accentedHitsPositionParterSuccessful',
#   'f2_cumsum_winMethods_[DEC]',
#   'f2_cumsum_winMethods_[DQ]',
#   'f2_cumsum_winMethods_[KO]',
#   'f2_cumsum_winMethods_[SUB]'],
#  'f1_cumsum_col_names': ['f1_cumsum_duration',
#   'f1_cumsum_winner',
#   'f1_cumsum_hitsTotal',
#   'f1_cumsum_hitsSuccessful',
#   'f1_cumsum_takedownTotal',
#   'f1_cumsum_takedownSuccessful',
#   'f1_cumsum_submissionAttempts',
#   'f1_cumsum_takeovers',
#   'f1_cumsum_accentedHitsTotal',
#   'f1_cumsum_accentedHitsSuccessful',
#   'f1_cumsum_knockdowns',
#   'f1_cumsum_protectionPassage',
#   'f1_cumsum_hitsHeadTotal',
#   'f1_cumsum_hitsHeadSuccessful',
#   'f1_cumsum_hitsBodyTotal',
#   'f1_cumsum_hitsBodySuccessful',
#   'f1_cumsum_hitsLegsTotal',
#   'f1_cumsum_hitsLegsSuccessful',
#   'f1_cumsum_accentedHitsPositionDistanceTotal',
#   'f1_cumsum_accentedHitsPositionDistanceSuccessful',
#   'f1_cumsum_accentedHitsPositionClinchTotal',
#   'f1_cumsum_accentedHitsPositionClinchSuccessful',
#   'f1_cumsum_accentedHitsPositionParterTotal',
#   'f1_cumsum_accentedHitsPositionParterSuccessful',
#   'f1_cumsum_winMethods_[DEC]',
#   'f1_cumsum_winMethods_[DQ]',
#   'f1_cumsum_winMethods_[KO]',
#   'f1_cumsum_winMethods_[SUB]'],
#  'new_cumsum_colnames': ['cumsum_duration',
#   'cumsum_winner',
#   'cumsum_hitsTotal',
#   'cumsum_hitsSuccessful',
#   'cumsum_takedownTotal',
#   'cumsum_takedownSuccessful',
#   'cumsum_submissionAttempts',
#   'cumsum_takeovers',
#   'cumsum_accentedHitsTotal',
#   'cumsum_accentedHitsSuccessful',
#   'cumsum_knockdowns',
#   'cumsum_protectionPassage',
#   'cumsum_hitsHeadTotal',
#   'cumsum_hitsHeadSuccessful',
#   'cumsum_hitsBodyTotal',
#   'cumsum_hitsBodySuccessful',
#   'cumsum_hitsLegsTotal',
#   'cumsum_hitsLegsSuccessful',
#   'cumsum_accentedHitsPositionDistanceTotal',
#   'cumsum_accentedHitsPositionDistanceSuccessful',
#   'cumsum_accentedHitsPositionClinchTotal',
#   'cumsum_accentedHitsPositionClinchSuccessful',
#   'cumsum_accentedHitsPositionParterTotal',
#   'cumsum_accentedHitsPositionParterSuccessful',
#   'cumsum_winMethods_[DEC]',
#   'cumsum_winMethods_[DQ]',
#   'cumsum_winMethods_[KO]',
#   'cumsum_winMethods_[SUB]'],
#  'new_accuracy_cols': ['hits_accuracy',
#   'takedown_accuracy',
#   'accentedHits_accuracy',
#   'hitsHead_accuracy',
#   'hitsBody_accuracy',
#   'hitsLegs_accuracy',
#   'accentedHitsPositionDistance_accuracy',
#   'accentedHitsPositionClinch_accuracy',
#   'accentedHitsPositionParter_accuracy'],
#  'new_percent_cols': ['DEC_percent',
#   'DQ_percent',
#   'KO_percent',
#   'SUB_percent'],
#  'new_PM_cols': ['hits_PM',
#   'takedown_PM',
#   'accentedHits_PM',
#   'hitsHead_PM',
#   'hitsBody_PM',
#   'hitsLegs_PM',
#   'accentedHitsPositionDistance_PM',
#   'accentedHitsPositionClinch_PM',
#   'accentedHitsPositionParter_PM',
#   'knockdowns_PM',
#   'protectionPassage_PM'],
#  'new_streak_cols': ['win_streak', 'loose_streak']}

# %%
f_stats_events_cumulative
# Out:
#       cumsum_duration  cumsum_winner  cumsum_hitsTotal  cumsum_hitsSuccessful  \
# 6266            300.0              1              51.0                   35.0
# 6353            600.0              1              88.0                   48.0
# 6532            761.0              2             110.0                   63.0
# 6585            917.0              3             146.0                   91.0
# 6733           1217.0              3             201.0                  120.0
# ...               ...            ...               ...                    ...
# 6820            248.0              1              49.0                   25.0
# 6806            300.0              1              93.0                   42.0
# 6836            600.0              1             133.0                   72.0
# 6813            240.0              0              11.0                    7.0
# 6837             26.0              0               NaN                    NaN
#
#       cumsum_takedownTotal  cumsum_takedownSuccessful  \
# 6266                   0.0                        0.0
# 6353                   0.0                        0.0
# 6532                   0.0                        0.0
# 6585                   0.0                        0.0
# 6733                   0.0                        0.0
# ...                    ...                        ...
# 6820                   1.0                        1.0
# 6806                   2.0                        0.0
# 6836                   3.0                        0.0
# 6813                   0.0                        0.0
# 6837                   NaN                        NaN
#
#       cumsum_submissionAttempts  cumsum_takeovers  cumsum_accentedHitsTotal  \
# 6266                        0.0               0.0                      51.0
# 6353                        0.0               0.0                      88.0
# 6532                        0.0               0.0                     110.0
# 6585                        0.0               0.0                     146.0
# 6733                        0.0               0.0                     201.0
# ...                         ...               ...                       ...
# 6820                        0.0               0.0                      45.0
# 6806                        0.0               0.0                      93.0
# 6836                        0.0               0.0                     107.0
# 6813                        0.0               0.0                       8.0
# 6837                        NaN               NaN                       NaN
#
#       cumsum_accentedHitsSuccessful  ...  hitsBody_PM  hitsLegs_PM  \
# 6266                           35.0  ...     3.000000     1.800000
# 6353                           48.0  ...     1.800000     1.300000
# 6532                           63.0  ...     1.576873     1.576873
# 6585                           91.0  ...     1.701200     1.962923
# 6733                          120.0  ...     1.331142     2.514380
# ...                             ...  ...          ...          ...
# 6820                           21.0  ...     0.483871     0.483871
# 6806                           42.0  ...     3.000000     2.800000
# 6836                           50.0  ...     1.500000     1.800000
# 6813                            4.0  ...     0.000000     0.250000
# 6837                            NaN  ...          NaN          NaN
#
#       accentedHitsPositionDistance_PM  accentedHitsPositionClinch_PM  \
# 6266                         7.000000                           0.00
# 6353                         4.800000                           0.00
# 6532                         4.888305                           0.00
# 6585                         5.299891                           0.00
# 6733                         5.423172                           0.00
# ...                               ...                            ...
# 6820                         4.838710                           0.00
# 6806                         8.200000                           0.20
# 6836                         4.600000                           0.20
# 6813                         0.750000                           0.25
# 6837                              NaN                            NaN
#
#       accentedHitsPositionParter_PM  knockdowns_PM  protectionPassage_PM  \
# 6266                       0.000000            0.0              0.000000
# 6353                       0.000000            0.0              0.000000
# 6532                       0.078844            0.0              0.078844
# 6585                       0.654308            0.0              0.065431
# 6733                       0.493016            0.0              0.049302
# ...                             ...            ...                   ...
# 6820                       0.241935            0.0              0.000000
# 6806                       0.000000            0.0              0.000000
# 6836                       0.200000            0.0              0.000000
# 6813                       0.000000            0.0              0.000000
# 6837                            NaN            NaN                   NaN
#
#       win_streak  loose_streak       fighterName
# 6266           1             0      Tanner Boser
# 6353           0             1      Tanner Boser
# 6532           1             0      Tanner Boser
# 6585           2             0      Tanner Boser
# 6733           0             1      Tanner Boser
# ...          ...           ...               ...
# 6820           1             0      Manon Fiorot
# 6806           1             0  Joselyne Edwards
# 6836           0             1  Joselyne Edwards
# 6813           0             1  Gaetano Pirrello
# 6837           0             1      Denys Bondar
#
# [13754 rows x 90 columns]

# %%
f_stats_events_cumulative[f_stats_events_cumulative['fighterId'] == 3667]
# Out:
#       cumsum_duration  cumsum_winner  cumsum_hitsTotal  cumsum_hitsSuccessful  \
# 6813            240.0              0              11.0                    7.0
#
#       cumsum_takedownTotal  cumsum_takedownSuccessful  \
# 6813                   0.0                        0.0
#
#       cumsum_submissionAttempts  cumsum_takeovers  cumsum_accentedHitsTotal  \
# 6813                        0.0               0.0                       8.0
#
#       cumsum_accentedHitsSuccessful  ...  hitsBody_PM  hitsLegs_PM  \
# 6813                            4.0  ...          0.0         0.25
#
#       accentedHitsPositionDistance_PM  accentedHitsPositionClinch_PM  \
# 6813                             0.75                           0.25
#
#       accentedHitsPositionParter_PM  knockdowns_PM  protectionPassage_PM  \
# 6813                            0.0            0.0                   0.0
#
#       win_streak  loose_streak       fighterName
# 6813           0             1  Gaetano Pirrello
#
# [1 rows x 90 columns]

# %%
f_stats_events_cumulative[f_stats_events_cumulative['fighterName'] == 'Donald Cerrone']
# Out:
#       cumsum_duration  cumsum_winner  cumsum_hitsTotal  cumsum_hitsSuccessful  \
# 1645            300.0              1              69.0                   30.0
# 2376            463.0              2              74.0                   33.0
# 2418            691.0              3             122.0                   64.0
# 2533            991.0              4             188.0                  104.0
# 2592           1172.0              5             251.0                  136.0
# 2676           1314.0              6             274.0                  145.0
# 2751           1614.0              6             351.0                  182.0
# 2878           1914.0              7             419.0                  213.0
# 2989           1990.0              8             428.0                  217.0
# 3131           2145.0              8             440.0                  221.0
# 3256           2445.0              9             517.0                  273.0
# 3345           2745.0              9             558.0                  293.0
# 3443           2974.0             10             582.0                  304.0
# 3515           3254.0             11             619.0                  320.0
# 3621           3449.0             12             639.0                  331.0
# 3751           3660.0             13             680.0                  349.0
# 3853           3960.0             14             758.0                  404.0
# 3986           4260.0             15             806.0                  433.0
# 3997           4560.0             16             850.0                  455.0
# 4153           4844.0             17             943.0                  495.0
# 4439           4910.0             17             950.0                  499.0
# 4500           5063.0             18             960.0                  506.0
# 4634           5218.0             19             991.0                  526.0
# 4729           5340.0             20            1033.0                  555.0
# 4910           5374.0             21            1038.0                  559.0
# 4946           5434.0             21            1045.0                  560.0
# 5185           5734.0             21            1119.0                  600.0
# 5261           5994.0             21            1143.0                  614.0
# 5437           6292.0             22            1200.0                  642.0
# 5579           6592.0             22            1223.0                  654.0
# 5753           6878.0             23            1237.0                  664.0
# 5858           7101.0             24            1312.0                  708.0
# 6011           7401.0             25            1410.0                  751.0
# 6063           7701.0             25            1500.0                  781.0
# 6204           7959.0             25            1552.0                  798.0
# 6359           7999.0             25            1553.0                  798.0
# 6457           8299.0             25            1618.0                  823.0
#
#       cumsum_takedownTotal  cumsum_takedownSuccessful  \
# 1645                   3.0                        2.0
# 2376                   3.0                        2.0
# 2418                   4.0                        3.0
# 2533                   5.0                        3.0
# 2592                   5.0                        3.0
# 2676                   5.0                        3.0
# 2751                   5.0                        3.0
# 2878                   6.0                        3.0
# 2989                   6.0                        3.0
# 3131                   6.0                        3.0
# 3256                   7.0                        4.0
# 3345                   7.0                        4.0
# 3443                   9.0                        5.0
# 3515                  10.0                        6.0
# 3621                  11.0                        6.0
# 3751                  11.0                        6.0
# 3853                  12.0                        6.0
# 3986                  13.0                        7.0
# 3997                  18.0                        7.0
# 4153                  18.0                        7.0
# 4439                  19.0                        7.0
# 4500                  21.0                        8.0
# 4634                  21.0                        8.0
# 4729                  21.0                        8.0
# 4910                  21.0                        8.0
# 4946                  21.0                        8.0
# 5185                  26.0                        8.0
# 5261                  28.0                        9.0
# 5437                  29.0                        9.0
# 5579                  30.0                       10.0
# 5753                  31.0                       10.0
# 5858                  31.0                       10.0
# 6011                  31.0                       10.0
# 6063                  32.0                       11.0
# 6204                  32.0                       11.0
# 6359                  32.0                       11.0
# 6457                  36.0                       11.0
#
#       cumsum_submissionAttempts  cumsum_takeovers  cumsum_accentedHitsTotal  \
# 1645                        0.0               0.0                      68.0
# 2376                        3.0               0.0                      72.0
# 2418                        4.0               0.0                     106.0
# 2533                        4.0               0.0                     172.0
# 2592                        4.0               0.0                     232.0
# 2676                        5.0               0.0                     255.0
# 2751                        5.0               0.0                     326.0
# 2878                        5.0               0.0                     394.0
# 2989                        5.0               0.0                     403.0
# 3131                        5.0               0.0                     415.0
# 3256                        5.0               0.0                     458.0
# 3345                        5.0               0.0                     498.0
# 3443                        6.0               0.0                     521.0
# 3515                        6.0               0.0                     558.0
# 3621                        8.0               0.0                     578.0
# 3751                        8.0               0.0                     619.0
# 3853                        8.0               0.0                     681.0
# 3986                        8.0               0.0                     724.0
# 3997                        8.0               0.0                     768.0
# 4153                        8.0               0.0                     861.0
# 4439                        8.0               0.0                     868.0
# 4500                        9.0               0.0                     874.0
# 4634                        9.0               0.0                     905.0
# 4729                        9.0               0.0                     945.0
# 4910                        9.0               0.0                     950.0
# 4946                        9.0               0.0                     957.0
# 5185                        9.0               0.0                    1029.0
# 5261                        9.0               0.0                    1053.0
# 5437                        9.0               0.0                    1110.0
# 5579                        9.0               0.0                    1132.0
# 5753                       10.0               1.0                    1145.0
# 5858                       10.0               1.0                    1220.0
# 6011                       10.0               1.0                    1318.0
# 6063                       10.0               1.0                    1408.0
# 6204                       10.0               1.0                    1460.0
# 6359                       10.0               1.0                    1461.0
# 6457                       10.0               1.0                    1526.0
#
#       cumsum_accentedHitsSuccessful  ...  hitsBody_PM  hitsLegs_PM  \
# 1645                           29.0  ...     0.600000     0.800000
# 2376                           31.0  ...     0.388769     0.518359
# 2418                           48.0  ...     0.694645     0.694645
# 2533                           88.0  ...     0.908174     1.574168
# 2592                          118.0  ...     0.870307     1.638225
# 2676                          127.0  ...     0.867580     1.552511
# 2751                          160.0  ...     1.003717     1.412639
# 2878                          191.0  ...     1.253918     1.442006
# 2989                          195.0  ...     1.206030     1.417085
# 3131                          199.0  ...     1.146853     1.342657
# 3256                          222.0  ...     1.079755     1.177914
# 3345                          241.0  ...     1.202186     1.136612
# 3443                          251.0  ...     1.190316     1.069267
# 3515                          267.0  ...     1.198525     1.124770
# 3621                          278.0  ...     1.165555     1.113366
# 3751                          296.0  ...     1.180328     1.147541
# 3853                          338.0  ...     1.227273     1.212121
# 3986                          362.0  ...     1.169014     1.366197
# 3997                          384.0  ...     1.171053     1.394737
# 4153                          424.0  ...     1.114781     1.461602
# 4439                          428.0  ...     1.112016     1.454175
# 4500                          432.0  ...     1.113964     1.422082
# 4634                          452.0  ...     1.103871     1.437332
# 4729                          479.0  ...     1.146067     1.460674
# 4910                          483.0  ...     1.138817     1.462598
# 4946                          484.0  ...     1.137284     1.446448
# 5185                          522.0  ...     1.161493     1.381235
# 5261                          536.0  ...     1.161161     1.391391
# 5437                          564.0  ...     1.211062     1.335029
# 5579                          575.0  ...     1.192354     1.310680
# 5753                          584.0  ...     1.177668     1.282350
# 5858                          628.0  ...     1.216730     1.267427
# 6011                          671.0  ...     1.183624     1.289015
# 6063                          701.0  ...     1.207635     1.285547
# 6204                          718.0  ...     1.198643     1.251413
# 6359                          718.0  ...     1.192649     1.245156
# 6457                          743.0  ...     1.207374     1.229064
#
#       accentedHitsPositionDistance_PM  accentedHitsPositionClinch_PM  \
# 1645                         5.600000                       0.200000
# 2376                         3.758099                       0.129590
# 2418                         3.473227                       0.173661
# 2533                         4.722503                       0.181635
# 2592                         4.709898                       0.204778
# 2676                         4.520548                       0.228311
# 2751                         4.795539                       0.297398
# 2878                         4.984326                       0.282132
# 2989                         4.914573                       0.271357
# 3131                         4.671329                       0.251748
# 3256                         4.269939                       0.220859
# 3345                         4.196721                       0.218579
# 3443                         4.014795                       0.262273
# 3515                         3.964352                       0.239705
# 3621                         3.931574                       0.226153
# 3751                         3.983607                       0.213115
# 3853                         4.121212                       0.303030
# 3986                         4.056338                       0.295775
# 3997                         4.052632                       0.302632
# 4153                         4.285714                       0.309661
# 4439                         4.276986                       0.305499
# 4500                         4.159589                       0.331819
# 4634                         4.174013                       0.356458
# 4729                         4.292135                       0.382022
# 4910                         4.309639                       0.379606
# 4946                         4.273095                       0.375414
# 5185                         4.300663                       0.502267
# 5261                         4.244244                       0.490490
# 5437                         4.272092                       0.476796
# 5579                         4.150485                       0.473301
# 5753                         4.012794                       0.497238
# 5858                         4.072666                       0.549218
# 6011                         4.248075                       0.526956
# 6063                         4.316323                       0.506428
# 6204                         4.304561                       0.490011
# 6359                         4.283035                       0.487561
# 6457                         4.301723                       0.477166
#
#       accentedHitsPositionParter_PM  knockdowns_PM  protectionPassage_PM  \
# 1645                       0.000000            0.0              0.000000
# 2376                       0.129590            0.0              0.000000
# 2418                       0.520984            0.0              0.260492
# 2533                       0.423814            0.0              0.181635
# 2592                       1.126280            0.0              0.153584
# 2676                       1.050228            0.0              0.182648
# 2751                       0.855019            0.0              0.148699
# 2878                       0.721003            0.0              0.125392
# 2989                       0.693467            0.0              0.120603
# 3131                       0.643357            0.0              0.111888
# 3256                       0.957055            0.0              0.147239
# 3345                       0.852459            0.0              0.131148
# 3443                       0.786819            0.0              0.141224
# 3515                       0.719115            0.0              0.129072
# 3621                       0.678458            0.0              0.139171
# 3751                       0.655738            0.0              0.131148
# 3853                       0.696970            0.0              0.136364
# 3986                       0.746479            0.0              0.126761
# 3997                       0.697368            0.0              0.118421
# 4153                       0.656482            0.0              0.111478
# 4439                       0.647658            0.0              0.109980
# 4500                       0.628086            0.0              0.130357
# 4634                       0.666922            0.0              0.126485
# 4729                       0.707865            0.0              0.123596
# 4910                       0.703387            0.0              0.122814
# 4946                       0.695620            0.0              0.121457
# 5185                       0.659226            0.0              0.115103
# 5261                       0.630631            0.0              0.110110
# 5437                       0.629371            0.0              0.104895
# 5579                       0.609830            0.0              0.109223
# 5753                       0.584472            0.0              0.122129
# 5858                       0.684411            0.0              0.118293
# 6011                       0.664775            0.0              0.113498
# 6063                       0.638878            0.0              0.109077
# 6204                       0.618168            0.0              0.105541
# 6359                       0.615077            0.0              0.105013
# 6457                       0.592843            0.0              0.101217
#
#       win_streak  loose_streak     fighterName
# 1645           1             0  Donald Cerrone
# 2376           2             0  Donald Cerrone
# 2418           3             0  Donald Cerrone
# 2533           4             0  Donald Cerrone
# 2592           5             0  Donald Cerrone
# 2676           6             0  Donald Cerrone
# 2751           0             1  Donald Cerrone
# 2878           1             0  Donald Cerrone
# 2989           2             0  Donald Cerrone
# 3131           0             1  Donald Cerrone
# 3256           1             0  Donald Cerrone
# 3345           0             1  Donald Cerrone
# 3443           1             0  Donald Cerrone
# 3515           2             0  Donald Cerrone
# 3621           3             0  Donald Cerrone
# 3751           4             0  Donald Cerrone
# 3853           5             0  Donald Cerrone
# 3986           6             0  Donald Cerrone
# 3997           7             0  Donald Cerrone
# 4153           8             0  Donald Cerrone
# 4439           0             1  Donald Cerrone
# 4500           1             0  Donald Cerrone
# 4634           2             0  Donald Cerrone
# 4729           3             0  Donald Cerrone
# 4910           4             0  Donald Cerrone
# 4946           0             1  Donald Cerrone
# 5185           0             2  Donald Cerrone
# 5261           0             3  Donald Cerrone
# 5437           1             0  Donald Cerrone
# 5579           0             1  Donald Cerrone
# 5753           1             0  Donald Cerrone
# 5858           2             0  Donald Cerrone
# 6011           3             0  Donald Cerrone
# 6063           0             1  Donald Cerrone
# 6204           0             2  Donald Cerrone
# 6359           0             3  Donald Cerrone
# 6457           0             4  Donald Cerrone
#
# [37 rows x 90 columns]

# %%
all_fightCols_list = all_new_cols['new_cumsum_colnames']+all_new_cols['new_accuracy_cols']+\
    all_new_cols['new_percent_cols']+all_new_cols['new_PM_cols']+all_new_cols['new_streak_cols'] + \
    all_new_cols['new_difference_cols'] + ['count_of_fights', 'age'] #,

# all_fightCols_list = [i + '_difference' for i in all_fightCols_list]
# all_fightCols_list += all_new_cols['f2_cumsum_col_names'] 
# all_fightCols_list += all_new_cols['f1_cumsum_col_names'] 
# all_fightCols_list += ['f1_age', 'f2_age']

# %%
fighters_df['name']
# Out:
# id
# 1              Tanner Boser
# 2             Giacomo Lemos
# 3       Shamil Abdurakhimov
# 4             Klidson Abreu
# 5         Yoshihiro Akiyama
#                ...
# 3673     Rinat Fakhretdinov
# 3674        Carlston Harris
# 3675            Askar Askar
# 3676       Patrick Sabatini
# 3677           Marcelo Rojo
# Name: name, Length: 3669, dtype: object

# %%
fighter1_stats
# Out:
# Empty DataFrame
# Columns: [cumsum_duration, cumsum_winner, cumsum_hitsTotal, cumsum_hitsSuccessful, cumsum_takedownTotal, cumsum_takedownSuccessful, cumsum_submissionAttempts, cumsum_takeovers, cumsum_accentedHitsTotal, cumsum_accentedHitsSuccessful, cumsum_knockdowns, cumsum_protectionPassage, cumsum_hitsHeadTotal, cumsum_hitsHeadSuccessful, cumsum_hitsBodyTotal, cumsum_hitsBodySuccessful, cumsum_hitsLegsTotal, cumsum_hitsLegsSuccessful, cumsum_accentedHitsPositionDistanceTotal, cumsum_accentedHitsPositionDistanceSuccessful, cumsum_accentedHitsPositionClinchTotal, cumsum_accentedHitsPositionClinchSuccessful, cumsum_accentedHitsPositionParterTotal, cumsum_accentedHitsPositionParterSuccessful, cumsum_winMethods_[DEC], cumsum_winMethods_[DQ], cumsum_winMethods_[KO], cumsum_winMethods_[SUB], current_duration, winner, current_hitsTotal, current_hitsSuccessful, current_takedownTotal, current_takedownSuccessful, current_submissionAttempts, current_takeovers, current_accentedHitsTotal, current_accentedHitsSuccessful, current_knockdowns, current_protectionPassage, current_hitsHeadTotal, current_hitsHeadSuccessful, current_hitsBodyTotal, current_hitsBodySuccessful, current_hitsLegsTotal, current_hitsLegsSuccessful, current_accentedHitsPositionDistanceTotal, current_accentedHitsPositionDistanceSuccessful, current_accentedHitsPositionClinchTotal, current_accentedHitsPositionClinchSuccessful, current_accentedHitsPositionParterTotal, current_accentedHitsPositionParterSuccessful, current_winMethods_[DEC], current_winMethods_[DQ], current_winMethods_[KO], current_winMethods_[SUB], age, eventDate.date, fighterId, fighter_nbr, odds, winnerId, count_of_fights, hits_accuracy, takedown_accuracy, accentedHits_accuracy, hitsHead_accuracy, hitsBody_accuracy, hitsLegs_accuracy, accentedHitsPositionDistance_accuracy, accentedHitsPositionClinch_accuracy, accentedHitsPositionParter_accuracy, DEC_percent, DQ_percent, KO_percent, SUB_percent, hits_PM, takedown_PM, accentedHits_PM, hitsHead_PM, hitsBody_PM, hitsLegs_PM, accentedHitsPositionDistance_PM, accentedHitsPositionClinch_PM, accentedHitsPositionParter_PM, knockdowns_PM, protectionPassage_PM, win_streak, loose_streak, fighterName]
# Index: []
#
# [0 rows x 90 columns]

# %%
import datetime

f1_name = 'Yoshihiro Akiyama'
f2_name = 'Jim Miller'
event_date = datetime.date(2021, 4, 5)


f1_birthDate = fighters_df[fighters_df['name'] == f1_name]['dateOfBirth']
f1_age = ((pd.to_datetime(event_date) - pd.to_datetime(f1_birthDate)) / 365).dt.days.values[0]

f2_birthDate = fighters_df[fighters_df['name'] == f2_name]['dateOfBirth']
f2_age = ((pd.to_datetime(event_date) - pd.to_datetime(f2_birthDate)) / 365).dt.days.values[0]


fighter1_stats = f_stats_events_cumulative[f_stats_events_cumulative['fighterName'] == f1_name]#.iloc[-1]
fighter1_stats_NaNs = (fighter1_stats[all_fightCols_list].isna().sum(axis=1) / fighter1_stats.shape[1])
fighter1_stats = pd.DataFrame(fighter1_stats[fighter1_stats_NaNs < 0.2].iloc[-1]).T.reset_index(drop=True)

fighter2_stats = f_stats_events_cumulative[f_stats_events_cumulative['fighterName'] == f2_name]#.iloc[-1]
fighter2_stats_NaNs = (fighter2_stats[all_fightCols_list].isna().sum(axis=1) / fighter2_stats.shape[1])
fighter2_stats = pd.DataFrame(fighter2_stats[fighter2_stats_NaNs < 0.2].iloc[-1]).T.reset_index(drop=True)
fighter2_stats
# Out:
#   cumsum_duration cumsum_winner cumsum_hitsTotal cumsum_hitsSuccessful  \
# 0          7510.0            21            982.0                 460.0
#
#   cumsum_takedownTotal cumsum_takedownSuccessful cumsum_submissionAttempts  \
# 0                 40.0                      18.0                      19.0
#
#   cumsum_takeovers cumsum_accentedHitsTotal cumsum_accentedHitsSuccessful  \
# 0              0.0                    832.0                         325.0
#
#    ... hitsBody_PM hitsLegs_PM accentedHitsPositionDistance_PM  \
# 0  ...    0.439414     0.60719                        1.821571
#
#   accentedHitsPositionClinch_PM accentedHitsPositionParter_PM knockdowns_PM  \
# 0                      0.431425                      0.343542           0.0
#
#   protectionPassage_PM win_streak loose_streak fighterName
# 0             0.151798          1            0  Jim Miller
#
# [1 rows x 90 columns]

# %%
X_df = pd.DataFrame(index=[0])

X_df = X_df.join(
    fighter1_stats[all_fightCols_list].add_prefix("f1_")) #, on="id"

X_df = X_df.join(
    fighter2_stats[all_fightCols_list].add_prefix("f2_"))

X_df.loc[0, ['f1_age', 'f2_age']] = f1_age, f2_age
X_df
# Out:
#   f1_cumsum_duration f1_cumsum_winner f1_cumsum_hitsTotal  \
# 0             3458.0               11               585.0
#
#   f1_cumsum_hitsSuccessful f1_cumsum_takedownTotal  \
# 0                    292.0                    15.0
#
#   f1_cumsum_takedownSuccessful f1_cumsum_submissionAttempts  \
# 0                         12.0                          8.0
#
#   f1_cumsum_takeovers f1_cumsum_accentedHitsTotal  \
# 0                 0.0                       454.0
#
#   f1_cumsum_accentedHitsSuccessful  ... f2_hitsLegs_PM  \
# 0                            190.0  ...        0.60719
#
#   f2_accentedHitsPositionDistance_PM f2_accentedHitsPositionClinch_PM  \
# 0                           1.821571                         0.431425
#
#   f2_accentedHitsPositionParter_PM f2_knockdowns_PM f2_protectionPassage_PM  \
# 0                         0.343542              0.0                0.151798
#
#   f2_win_streak f2_loose_streak f2_count_of_fights f2_age
# 0             1               0                 33     37
#
# [1 rows x 112 columns]

# %%
def difference(events_df_joined, cols):
    df = events_df_joined.copy()
    # цикл заменяет столбцы характеристик каждого бойца столбцами разницы этих характеристик
    for col in cols:
        df[col+'_difference'] = events_df_joined['f1_'+col].astype(float) - events_df_joined['f2_'+col].astype(float)

    df['age_difference'] = events_df_joined['f1_age'] - events_df_joined['f2_age'] # не стал удалять столбцы с возрастом

    return df

X_df_combined = difference(X_df, all_fightCols_list)
X_df_combined_reversed = X_df_combined*-1
X_df_combined_reversed
# Out:
#   f1_cumsum_duration f1_cumsum_winner f1_cumsum_hitsTotal  \
# 0            -3458.0              -11              -585.0
#
#   f1_cumsum_hitsSuccessful f1_cumsum_takedownTotal  \
# 0                   -292.0                   -15.0
#
#   f1_cumsum_takedownSuccessful f1_cumsum_submissionAttempts  \
# 0                        -12.0                         -8.0
#
#   f1_cumsum_takeovers f1_cumsum_accentedHitsTotal  \
# 0                -0.0                      -454.0
#
#   f1_cumsum_accentedHitsSuccessful  ... hitsLegs_PM_difference  \
# 0                           -190.0  ...               0.485733
#
#   accentedHitsPositionDistance_PM_difference  \
# 0                                   0.051762
#
#   accentedHitsPositionClinch_PM_difference  \
# 0                                 0.223212
#
#   accentedHitsPositionParter_PM_difference knockdowns_PM_difference  \
# 0                                -0.975139                     -0.0
#
#   protectionPassage_PM_difference win_streak_difference  \
# 0                       -0.177873                   1.0
#
#   loose_streak_difference count_of_fights_difference age_difference
# 0                    -1.0                       17.0             -8
#
# [1 rows x 168 columns]

# %%
X_df_combined_reversed.columns.tolist()
# Out:
# ['f1_cumsum_duration',
#  'f1_cumsum_winner',
#  'f1_cumsum_hitsTotal',
#  'f1_cumsum_hitsSuccessful',
#  'f1_cumsum_takedownTotal',
#  'f1_cumsum_takedownSuccessful',
#  'f1_cumsum_submissionAttempts',
#  'f1_cumsum_takeovers',
#  'f1_cumsum_accentedHitsTotal',
#  'f1_cumsum_accentedHitsSuccessful',
#  'f1_cumsum_knockdowns',
#  'f1_cumsum_protectionPassage',
#  'f1_cumsum_hitsHeadTotal',
#  'f1_cumsum_hitsHeadSuccessful',
#  'f1_cumsum_hitsBodyTotal',
#  'f1_cumsum_hitsBodySuccessful',
#  'f1_cumsum_hitsLegsTotal',
#  'f1_cumsum_hitsLegsSuccessful',
#  'f1_cumsum_accentedHitsPositionDistanceTotal',
#  'f1_cumsum_accentedHitsPositionDistanceSuccessful',
#  'f1_cumsum_accentedHitsPositionClinchTotal',
#  'f1_cumsum_accentedHitsPositionClinchSuccessful',
#  'f1_cumsum_accentedHitsPositionParterTotal',
#  'f1_cumsum_accentedHitsPositionParterSuccessful',
#  'f1_cumsum_winMethods_[DEC]',
#  'f1_cumsum_winMethods_[DQ]',
#  'f1_cumsum_winMethods_[KO]',
#  'f1_cumsum_winMethods_[SUB]',
#  'f1_hits_accuracy',
#  'f1_takedown_accuracy',
#  'f1_accentedHits_accuracy',
#  'f1_hitsHead_accuracy',
#  'f1_hitsBody_accuracy',
#  'f1_hitsLegs_accuracy',
#  'f1_accentedHitsPositionDistance_accuracy',
#  'f1_accentedHitsPositionClinch_accuracy',
#  'f1_accentedHitsPositionParter_accuracy',
#  'f1_DEC_percent',
#  'f1_DQ_percent',
#  'f1_KO_percent',
#  'f1_SUB_percent',
#  'f1_hits_PM',
#  'f1_takedown_PM',
#  'f1_accentedHits_PM',
#  'f1_hitsHead_PM',
#  'f1_hitsBody_PM',
#  'f1_hitsLegs_PM',
#  'f1_accentedHitsPositionDistance_PM',
#  'f1_accentedHitsPositionClinch_PM',
#  'f1_accentedHitsPositionParter_PM',
#  'f1_knockdowns_PM',
#  'f1_protectionPassage_PM',
#  'f1_win_streak',
#  'f1_loose_streak',
#  'f1_count_of_fights',
#  'f1_age',
#  'f2_cumsum_duration',
#  'f2_cumsum_winner',
#  'f2_cumsum_hitsTotal',
#  'f2_cumsum_hitsSuccessful',
#  'f2_cumsum_takedownTotal',
#  'f2_cumsum_takedownSuccessful',
#  'f2_cumsum_submissionAttempts',
#  'f2_cumsum_takeovers',
#  'f2_cumsum_accentedHitsTotal',
#  'f2_cumsum_accentedHitsSuccessful',
#  'f2_cumsum_knockdowns',
#  'f2_cumsum_protectionPassage',
#  'f2_cumsum_hitsHeadTotal',
#  'f2_cumsum_hitsHeadSuccessful',
#  'f2_cumsum_hitsBodyTotal',
#  'f2_cumsum_hitsBodySuccessful',
#  'f2_cumsum_hitsLegsTotal',
#  'f2_cumsum_hitsLegsSuccessful',
#  'f2_cumsum_accentedHitsPositionDistanceTotal',
#  'f2_cumsum_accentedHitsPositionDistanceSuccessful',
#  'f2_cumsum_accentedHitsPositionClinchTotal',
#  'f2_cumsum_accentedHitsPositionClinchSuccessful',
#  'f2_cumsum_accentedHitsPositionParterTotal',
#  'f2_cumsum_accentedHitsPositionParterSuccessful',
#  'f2_cumsum_winMethods_[DEC]',
#  'f2_cumsum_winMethods_[DQ]',
#  'f2_cumsum_winMethods_[KO]',
#  'f2_cumsum_winMethods_[SUB]',
#  'f2_hits_accuracy',
#  'f2_takedown_accuracy',
#  'f2_accentedHits_accuracy',
#  'f2_hitsHead_accuracy',
#  'f2_hitsBody_accuracy',
#  'f2_hitsLegs_accuracy',
#  'f2_accentedHitsPositionDistance_accuracy',
#  'f2_accentedHitsPositionClinch_accuracy',
#  'f2_accentedHitsPositionParter_accuracy',
#  'f2_DEC_percent',
#  'f2_DQ_percent',
#  'f2_KO_percent',
#  'f2_SUB_percent',
#  'f2_hits_PM',
#  'f2_takedown_PM',
#  'f2_accentedHits_PM',
#  'f2_hitsHead_PM',
#  'f2_hitsBody_PM',
#  'f2_hitsLegs_PM',
#  'f2_accentedHitsPositionDistance_PM',
#  'f2_accentedHitsPositionClinch_PM',
#  'f2_accentedHitsPositionParter_PM',
#  'f2_knockdowns_PM',
#  'f2_protectionPassage_PM',
#  'f2_win_streak',
#  'f2_loose_streak',
#  'f2_count_of_fights',
#  'f2_age',
#  'cumsum_duration_difference',
#  'cumsum_winner_difference',
#  'cumsum_hitsTotal_difference',
#  'cumsum_hitsSuccessful_difference',
#  'cumsum_takedownTotal_difference',
#  'cumsum_takedownSuccessful_difference',
#  'cumsum_submissionAttempts_difference',
#  'cumsum_takeovers_difference',
#  'cumsum_accentedHitsTotal_difference',
#  'cumsum_accentedHitsSuccessful_difference',
#  'cumsum_knockdowns_difference',
#  'cumsum_protectionPassage_difference',
#  'cumsum_hitsHeadTotal_difference',
#  'cumsum_hitsHeadSuccessful_difference',
#  'cumsum_hitsBodyTotal_difference',
#  'cumsum_hitsBodySuccessful_difference',
#  'cumsum_hitsLegsTotal_difference',
#  'cumsum_hitsLegsSuccessful_difference',
#  'cumsum_accentedHitsPositionDistanceTotal_difference',
#  'cumsum_accentedHitsPositionDistanceSuccessful_difference',
#  'cumsum_accentedHitsPositionClinchTotal_difference',
#  'cumsum_accentedHitsPositionClinchSuccessful_difference',
#  'cumsum_accentedHitsPositionParterTotal_difference',
#  'cumsum_accentedHitsPositionParterSuccessful_difference',
#  'cumsum_winMethods_[DEC]_difference',
#  'cumsum_winMethods_[DQ]_difference',
#  'cumsum_winMethods_[KO]_difference',
#  'cumsum_winMethods_[SUB]_difference',
#  'hits_accuracy_difference',
#  'takedown_accuracy_difference',
#  'accentedHits_accuracy_difference',
#  'hitsHead_accuracy_difference',
#  'hitsBody_accuracy_difference',
#  'hitsLegs_accuracy_difference',
#  'accentedHitsPositionDistance_accuracy_difference',
#  'accentedHitsPositionClinch_accuracy_difference',
#  'accentedHitsPositionParter_accuracy_difference',
#  'DEC_percent_difference',
#  'DQ_percent_difference',
#  'KO_percent_difference',
#  'SUB_percent_difference',
#  'hits_PM_difference',
#  'takedown_PM_difference',
#  'accentedHits_PM_difference',
#  'hitsHead_PM_difference',
#  'hitsBody_PM_difference',
#  'hitsLegs_PM_difference',
#  'accentedHitsPositionDistance_PM_difference',
#  'accentedHitsPositionClinch_PM_difference',
#  'accentedHitsPositionParter_PM_difference',
#  'knockdowns_PM_difference',
#  'protectionPassage_PM_difference',
#  'win_streak_difference',
#  'loose_streak_difference',
#  'count_of_fights_difference',
#  'age_difference']

# %%
clf = CatBoostClassifier()
clf.load_model('../../models/Catboost_v1_0/catboost_v1_0_06.04.2021.cat')
model_cols = clf.feature_names_
model_cols
# Out:
# ['cumsum_duration_difference',
#  'cumsum_winner_difference',
#  'cumsum_hitsTotal_difference',
#  'cumsum_hitsSuccessful_difference',
#  'cumsum_takedownTotal_difference',
#  'cumsum_takedownSuccessful_difference',
#  'cumsum_submissionAttempts_difference',
#  'cumsum_takeovers_difference',
#  'cumsum_accentedHitsTotal_difference',
#  'cumsum_accentedHitsSuccessful_difference',
#  'cumsum_knockdowns_difference',
#  'cumsum_protectionPassage_difference',
#  'cumsum_hitsHeadTotal_difference',
#  'cumsum_hitsHeadSuccessful_difference',
#  'cumsum_hitsBodyTotal_difference',
#  'cumsum_hitsBodySuccessful_difference',
#  'cumsum_hitsLegsTotal_difference',
#  'cumsum_hitsLegsSuccessful_difference',
#  'cumsum_accentedHitsPositionDistanceTotal_difference',
#  'cumsum_accentedHitsPositionDistanceSuccessful_difference',
#  'cumsum_accentedHitsPositionClinchTotal_difference',
#  'cumsum_accentedHitsPositionClinchSuccessful_difference',
#  'cumsum_accentedHitsPositionParterTotal_difference',
#  'cumsum_accentedHitsPositionParterSuccessful_difference',
#  'cumsum_winMethods_[DEC]_difference',
#  'cumsum_winMethods_[DQ]_difference',
#  'cumsum_winMethods_[KO]_difference',
#  'cumsum_winMethods_[SUB]_difference',
#  'hits_accuracy_difference',
#  'takedown_accuracy_difference',
#  'accentedHits_accuracy_difference',
#  'hitsHead_accuracy_difference',
#  'hitsBody_accuracy_difference',
#  'hitsLegs_accuracy_difference',
#  'accentedHitsPositionDistance_accuracy_difference',
#  'accentedHitsPositionClinch_accuracy_difference',
#  'accentedHitsPositionParter_accuracy_difference',
#  'DEC_percent_difference',
#  'DQ_percent_difference',
#  'KO_percent_difference',
#  'SUB_percent_difference',
#  'hits_PM_difference',
#  'takedown_PM_difference',
#  'accentedHits_PM_difference',
#  'hitsHead_PM_difference',
#  'hitsBody_PM_difference',
#  'hitsLegs_PM_difference',
#  'accentedHitsPositionDistance_PM_difference',
#  'accentedHitsPositionClinch_PM_difference',
#  'accentedHitsPositionParter_PM_difference',
#  'knockdowns_PM_difference',
#  'protectionPassage_PM_difference',
#  'win_streak_difference',
#  'loose_streak_difference',
#  'count_of_fights_difference',
#  'age_difference',
#  'f2_cumsum_duration',
#  'f2_cumsum_winner',
#  'f2_cumsum_hitsTotal',
#  'f2_cumsum_hitsSuccessful',
#  'f2_cumsum_takedownTotal',
#  'f2_cumsum_takedownSuccessful',
#  'f2_cumsum_submissionAttempts',
#  'f2_cumsum_takeovers',
#  'f2_cumsum_accentedHitsTotal',
#  'f2_cumsum_accentedHitsSuccessful',
#  'f2_cumsum_knockdowns',
#  'f2_cumsum_protectionPassage',
#  'f2_cumsum_hitsHeadTotal',
#  'f2_cumsum_hitsHeadSuccessful',
#  'f2_cumsum_hitsBodyTotal',
#  'f2_cumsum_hitsBodySuccessful',
#  'f2_cumsum_hitsLegsTotal',
#  'f2_cumsum_hitsLegsSuccessful',
#  'f2_cumsum_accentedHitsPositionDistanceTotal',
#  'f2_cumsum_accentedHitsPositionDistanceSuccessful',
#  'f2_cumsum_accentedHitsPositionClinchTotal',
#  'f2_cumsum_accentedHitsPositionClinchSuccessful',
#  'f2_cumsum_accentedHitsPositionParterTotal',
#  'f2_cumsum_accentedHitsPositionParterSuccessful',
#  'f2_cumsum_winMethods_[DEC]',
#  'f2_cumsum_winMethods_[DQ]',
#  'f2_cumsum_winMethods_[KO]',
#  'f2_cumsum_winMethods_[SUB]',
#  'f1_cumsum_duration',
#  'f1_cumsum_winner',
#  'f1_cumsum_hitsTotal',
#  'f1_cumsum_hitsSuccessful',
#  'f1_cumsum_takedownTotal',
#  'f1_cumsum_takedownSuccessful',
#  'f1_cumsum_submissionAttempts',
#  'f1_cumsum_takeovers',
#  'f1_cumsum_accentedHitsTotal',
#  'f1_cumsum_accentedHitsSuccessful',
#  'f1_cumsum_knockdowns',
#  'f1_cumsum_protectionPassage',
#  'f1_cumsum_hitsHeadTotal',
#  'f1_cumsum_hitsHeadSuccessful',
#  'f1_cumsum_hitsBodyTotal',
#  'f1_cumsum_hitsBodySuccessful',
#  'f1_cumsum_hitsLegsTotal',
#  'f1_cumsum_hitsLegsSuccessful',
#  'f1_cumsum_accentedHitsPositionDistanceTotal',
#  'f1_cumsum_accentedHitsPositionDistanceSuccessful',
#  'f1_cumsum_accentedHitsPositionClinchTotal',
#  'f1_cumsum_accentedHitsPositionClinchSuccessful',
#  'f1_cumsum_accentedHitsPositionParterTotal',
#  'f1_cumsum_accentedHitsPositionParterSuccessful',
#  'f1_cumsum_winMethods_[DEC]',
#  'f1_cumsum_winMethods_[DQ]',
#  'f1_cumsum_winMethods_[KO]',
#  'f1_cumsum_winMethods_[SUB]',
#  'f1_age',
#  'f2_age']

# %%
y_proba_straight = clf.predict_proba(X_df_combined[model_cols])[:,1]
y_proba_reversed = clf.predict_proba(X_df_combined_reversed[model_cols])[:,0]
y_proba = np.mean([y_proba_straight, y_proba_reversed])
y_proba
# Out:
# 0.4491422108146935
