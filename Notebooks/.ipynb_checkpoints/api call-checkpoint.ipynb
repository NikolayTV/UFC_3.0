# %%
import subprocess
import shlex
import json
from glob import glob
from tqdm import tqdm_notebook as tqdm
import pandas as pd

import sys
import os
sys.path.append(os.path.join(sys.path[0], '../'))

from core.train_utils import calculate_roi, get_winner_favorite
from core.events_utils import parse_odds

# %%
df = pd.read_csv('./Catboost_v1_2/data_models/events_joined_total_08.04.2021.csv', index_col=0)
cat_cols = ['city', 'country', 'is_fight_night', 'weightCategory.id', 
              'f1_country', 'f2_country', 'f1_city', 'f2_city']

df[cat_cols] = df[cat_cols].fillna('unknown')
# df = df[(df['f1_count_of_fights'] >= 1) & (df['f2_count_of_fights'] >= 1)]

df['eventDate.date'] = pd.to_datetime(df['eventDate.date'])
df['weightCategory.id'] = df['weightCategory.id'].astype('object')

df  = df[(df['eventDate.date'].dt.year == 2021) &
        ((df['type']=='straight'))]
df = df[~df['odds_difference'].isna()]

df
# Out:
#            city               country  duration      eventDate.date  \
# 5791  Abu Dhabi  United Arab Emirates     300.0 2021-01-16 00:00:01
# 5792  Abu Dhabi  United Arab Emirates     300.0 2021-01-16 00:00:02
# 5793  Abu Dhabi  United Arab Emirates     300.0 2021-01-16 00:00:03
# 5794  Abu Dhabi  United Arab Emirates     300.0 2021-01-16 00:00:04
# 5795  Abu Dhabi  United Arab Emirates     300.0 2021-01-16 00:00:05
# ...         ...                   ...       ...                 ...
# 5920  Las Vegas                   USA      82.0 2021-04-10 00:00:07
# 5922  Las Vegas                   USA     300.0 2021-04-10 00:00:09
# 5923  Las Vegas                   USA     288.0 2021-04-10 00:00:10
# 5924  Las Vegas                   USA     127.0 2021-04-10 00:00:11
# 5925  Las Vegas                   USA     300.0 2021-04-10 00:00:12
#
#      eventDate.timezone  fighterId_1  fighterId_2   id             name  \
# 5791      Europe/Berlin         2597         3418  139  UFC Fight Night
# 5792      Europe/Berlin         3398          240  138  UFC Fight Night
# 5793      Europe/Berlin          141          453  136  UFC Fight Night
# 5794      Europe/Berlin         3219         2319  137  UFC Fight Night
# 5795      Europe/Berlin          462         3666  135  UFC Fight Night
# ...                 ...          ...          ...  ...              ...
# 5920      Europe/Berlin          430         3587  262  UFC Fight Night
# 5922      Europe/Berlin         3037          288  261  UFC Fight Night
# 5923      Europe/Berlin          552          600  258  UFC Fight Night
# 5924      Europe/Berlin          449          215  259  UFC Fight Night
# 5925      Europe/Berlin          521           17  256  UFC Fight Night
#
#       rounds  ... odds_difference age_difference height_difference  \
# 5791     3.0  ...            1.52           -1.0             -2.54
# 5792     3.0  ...            1.20            0.0             -5.08
# 5793     3.0  ...            2.03           -3.0              5.08
# 5794     3.0  ...            1.23            1.0              0.00
# 5795     3.0  ...            0.00           -1.0              5.08
# ...      ...  ...             ...            ...               ...
# 5920     2.0  ...            1.58            7.0             -2.54
# 5922     3.0  ...           -0.51            5.0              7.62
# 5923     1.0  ...           -0.43            7.0              2.54
# 5924     2.0  ...            1.04            4.0              0.00
# 5925     3.0  ...           -0.56            0.0              2.54
#
#      armSpan_difference  legSwing_difference isHomeCity_difference  \
# 5791               5.08                 0.00                   0.0
# 5792              -5.08                 5.28                   0.0
# 5793              -2.54                -4.88                   0.0
# 5794              -2.54                 0.00                   0.0
# 5795               0.00                -2.74                   0.0
# ...                 ...                  ...                   ...
# 5920              -2.54                -2.74                   0.0
# 5922               7.62                 2.74                   0.0
# 5923               2.54                 5.08                   0.0
# 5924               7.62                 2.54                   0.0
# 5925               2.54                 2.74                   0.0
#
#      isHomeCountry_difference  isHomeTimezone_difference  winner  \
# 5791                      0.0                        0.0   False
# 5792                      0.0                        0.0    True
# 5793                      0.0                        0.0   False
# 5794                      0.0                        0.0   False
# 5795                      0.0                        0.0   False
# ...                       ...                        ...     ...
# 5920                      1.0                        0.0   False
# 5922                      0.0                        0.0    True
# 5923                      0.0                        0.0   False
# 5924                      0.0                        0.0   False
# 5925                      0.0                        0.0   False
#
#       is_fight_night
# 5791            True
# 5792            True
# 5793            True
# 5794            True
# 5795            True
# ...              ...
# 5920            True
# 5922            True
# 5923            True
# 5924            True
# 5925            True
#
# [122 rows x 214 columns]

# %%
events_df = pd.read_csv('../data/0.events_raw.csv', index_col=0)
### Убираем строки, где `winnerId` не совпадает с айди ни одного из бойцов
events_df = events_df[~((events_df["winnerId"] != events_df["fighterId_1"]) & (events_df["winnerId"] != events_df["fighterId_2"]))]

events_df[["f1_odds", "f2_odds"]] = events_df[["avgOdds", "fighterId_1", "fighterId_2"]]\
            .apply(lambda row: parse_odds(row), axis=1)

events_df = events_df[~events_df['f1_odds'].isna()]
events_df = events_df.reset_index()

events_df['eventDate.date'] = pd.to_datetime(events_df['eventDate.date'])
events_df = events_df[(events_df['eventDate.date'].dt.year == 2021)]
events_df
# Out:
#      index                                            avgOdds       city  \
# 542      0  [{'fighterId': 2597, 'value': 2.95}, {'fighter...  Abu Dhabi
# 543      0  [{'fighterId': 240, 'value': 1.5}, {'fighterId...  Abu Dhabi
# 544      0  [{'fighterId': 141, 'value': 3.37}, {'fighterI...  Abu Dhabi
# 545      0  [{'fighterId': 2319, 'value': 1.49}, {'fighter...  Abu Dhabi
# 546      0  [{'fighterId': 462, 'value': 1.93}, {'fighterI...  Abu Dhabi
# ..     ...                                                ...        ...
# 659      0  [{'fighterId': 430, 'value': 3}, {'fighterId':...  Las Vegas
# 660      0  [{'fighterId': 288, 'value': 2.22}, {'fighterI...  Las Vegas
# 661      0  [{'fighterId': 552, 'value': 1.74}, {'fighterI...  Las Vegas
# 662      0  [{'fighterId': 215, 'value': 1.54}, {'fighterI...  Las Vegas
# 663      0  [{'fighterId': 17, 'value': 2.25}, {'fighterId...  Las Vegas
#
#      completed               country  duration      eventDate.date  \
# 542       True  United Arab Emirates     300.0 2021-01-16 00:00:01
# 543       True  United Arab Emirates     300.0 2021-01-16 00:00:02
# 544       True  United Arab Emirates     300.0 2021-01-16 00:00:03
# 545       True  United Arab Emirates     300.0 2021-01-16 00:00:04
# 546       True  United Arab Emirates     300.0 2021-01-16 00:00:05
# ..         ...                   ...       ...                 ...
# 659       True                   USA      82.0 2021-04-10 00:00:07
# 660       True                   USA     300.0 2021-04-10 00:00:09
# 661       True                   USA     288.0 2021-04-10 00:00:10
# 662       True                   USA     127.0 2021-04-10 00:00:11
# 663       True                   USA     300.0 2021-04-10 00:00:12
#
#     eventDate.timezone  eventDate.timezone_type  fighterId_1  ...  \
# 542      Europe/Berlin                        3         2597  ...
# 543      Europe/Berlin                        3          240  ...
# 544      Europe/Berlin                        3          141  ...
# 545      Europe/Berlin                        3         2319  ...
# 546      Europe/Berlin                        3          462  ...
# ..                 ...                      ...          ...  ...
# 659      Europe/Berlin                        3          430  ...
# 660      Europe/Berlin                        3          288  ...
# 661      Europe/Berlin                        3          552  ...
# 662      Europe/Berlin                        3          215  ...
# 663      Europe/Berlin                        3           17  ...
#
#                                                   link             name  \
# 542  http://www.ufcstats.com/fight-details/3d903bc3...  UFC Fight Night
# 543  http://www.ufcstats.com/fight-details/97c80f69...  UFC Fight Night
# 544  http://www.ufcstats.com/fight-details/3fcd53eb...  UFC Fight Night
# 545  http://www.ufcstats.com/fight-details/0165bd3c...  UFC Fight Night
# 546  http://www.ufcstats.com/fight-details/97ad63e6...  UFC Fight Night
# ..                                                 ...              ...
# 659  http://www.ufcstats.com/fight-details/99829621...  UFC Fight Night
# 660  http://www.ufcstats.com/fight-details/ac9a8b73...  UFC Fight Night
# 661  http://www.ufcstats.com/fight-details/0992795f...  UFC Fight Night
# 662  http://www.ufcstats.com/fight-details/646eeca9...  UFC Fight Night
# 663  http://www.ufcstats.com/fight-details/71b81d81...  UFC Fight Night
#
#      rounds             timezone weightCategory.id      weightCategory.name  \
# 542     3.0           Asia/Dubai                 4           Полулегкий вес
# 543     3.0           Asia/Dubai                12    Женский легчайший вес
# 544     3.0           Asia/Dubai                 6          Полусредний вес
# 545     3.0           Asia/Dubai                 9              Тяжелый вес
# 546     3.0           Asia/Dubai                12    Женский легчайший вес
# ..      ...                  ...               ...                      ...
# 659     2.0  America/Los_Angeles                 5               Легкий вес
# 660     3.0  America/Los_Angeles                 6          Полусредний вес
# 661     1.0  America/Los_Angeles                10  Женский минимальный вес
# 662     2.0  America/Los_Angeles                 7              Средний вес
# 663     3.0  America/Los_Angeles                 4           Полулегкий вес
#
#     winMethods  winnerId f1_odds f2_odds
# 542    ['DEC']    3418.0    2.95    1.43
# 543    ['DEC']    3398.0    1.50    2.70
# 544    ['DEC']     453.0    3.37    1.34
# 545    ['DEC']    2319.0    1.49    2.72
# 546    ['DEC']    3666.0    1.93    1.93
# ..         ...       ...     ...     ...
# 659     ['KO']    3587.0    3.00    1.42
# 660    ['DEC']    3037.0    2.22    1.71
# 661    ['SUB']     600.0    1.74    2.17
# 662    ['SUB']     215.0    1.54    2.58
# 663    ['DEC']      17.0    2.25    1.69
#
# [122 rows x 23 columns]

# %%
for ind in tqdm(events_df.index[:]):
    f1_id, f2_id, f1_odd, f2_odd, weightCategory_id, city, country, eventDate, eventName, eventTimezone = \
        events_df.loc[ind, ['fighterId_1', 'fighterId_2', 'f1_odds', 'f2_odds', 'weightCategory.id',
                            'city', 'country', 'eventDate.date', 'name', 'timezone']]

    f1_id, f2_id, f1_odd, f2_odd, weightCategory_id, city, country, eventDate, eventName, eventTimezone
   
    Curl = f"""curl -X 'GET' \
  'http://127.0.0.1:8001/predict_fight?f1_id={f1_id}&f2_id={f2_id}&f1_odd={f1_odd}&f2_odd={f2_odd}&\
weightCategory_id={weightCategory_id}&\
city={city.replace(' ', '%20')}&\
country={country.replace(' ', '%20')}&\
event_date={str(eventDate)[:10]}&\
event_name={eventName.replace(' ', '%20')}&\
time_zone={eventTimezone}' \
  -H 'accept: application/json'"""

    args = shlex.split(Curl)
    process = subprocess.Popen(args, shell=False, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    stdout, stderr = process.communicate()
    response = json.loads(stdout.decode("UTF-8"))
    if response['success']:    

        events_df.at[ind, 'v1_0'] = response['y_proba_catboost_v1_0']
        events_df.at[ind, 'v1_1'] = response['y_proba_catboost_v1_1']
        events_df.at[ind, 'v1_2'] = response['y_proba_catboost_v1_2']
        events_df.at[ind, 'v1_1_2020'] = response['y_proba_catboost_v1_1_2020']
        events_df.at[ind, 'v1_2_2020'] = response['y_proba_catboost_v1_2_2020']
# Out:
# /home/nikolay/anaconda3/envs/must/lib/python3.7/site-packages/ipykernel_launcher.py:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """Entry point for launching an IPython kernel.
#   0%|          | 0/122 [00:00<?, ?it/s]

# %%
events_df['winner'] = events_df['winnerId'] == events_df['fighterId_1']

events_df['v1_0_pred'] = events_df['v1_0'] > 0.5
events_df['v1_1_pred'] = events_df['v1_1'] > 0.5
events_df['v1_2_pred'] = events_df['v1_2'] > 0.5
events_df['v1_1_2020_pred'] = events_df['v1_1_2020'] > 0.5
events_df['v1_2_2020_pred'] = events_df['v1_2_2020'] > 0.5

        
print('v1_0_pred', (events_df['v1_0_pred'] == events_df['winner']).mean())
print('v1_1_pred', (events_df['v1_1_pred'] == events_df['winner']).mean())
print('v1_2_pred', (events_df['v1_2_pred'] == events_df['winner']).mean())
print('v1_1_2020_pred', (events_df['v1_1_2020_pred'] == events_df['winner']).mean())
print('v1_2_2020_pred', (events_df['v1_2_2020_pred'] == events_df['winner']).mean())
# Out:
# v1_0_pred 0.5491803278688525
# v1_1_pred 0.6311475409836066
# v1_2_pred 0.5901639344262295
# v1_1_2020_pred 0.6065573770491803
# v1_2_2020_pred 0.5737704918032787

# %%
events_df['f1_count_of_fights'] = df['f1_count_of_fights'].values
events_df['f2_count_of_fights'] = df['f2_count_of_fights'].values
events_df
# Out:
#      index                                            avgOdds       city  \
# 542      0  [{'fighterId': 2597, 'value': 2.95}, {'fighter...  Abu Dhabi
# 543      0  [{'fighterId': 240, 'value': 1.5}, {'fighterId...  Abu Dhabi
# 544      0  [{'fighterId': 141, 'value': 3.37}, {'fighterI...  Abu Dhabi
# 545      0  [{'fighterId': 2319, 'value': 1.49}, {'fighter...  Abu Dhabi
# 546      0  [{'fighterId': 462, 'value': 1.93}, {'fighterI...  Abu Dhabi
# ..     ...                                                ...        ...
# 659      0  [{'fighterId': 430, 'value': 3}, {'fighterId':...  Las Vegas
# 660      0  [{'fighterId': 288, 'value': 2.22}, {'fighterI...  Las Vegas
# 661      0  [{'fighterId': 552, 'value': 1.74}, {'fighterI...  Las Vegas
# 662      0  [{'fighterId': 215, 'value': 1.54}, {'fighterI...  Las Vegas
# 663      0  [{'fighterId': 17, 'value': 2.25}, {'fighterId...  Las Vegas
#
#      completed               country  duration      eventDate.date  \
# 542       True  United Arab Emirates     300.0 2021-01-16 00:00:01
# 543       True  United Arab Emirates     300.0 2021-01-16 00:00:02
# 544       True  United Arab Emirates     300.0 2021-01-16 00:00:03
# 545       True  United Arab Emirates     300.0 2021-01-16 00:00:04
# 546       True  United Arab Emirates     300.0 2021-01-16 00:00:05
# ..         ...                   ...       ...                 ...
# 659       True                   USA      82.0 2021-04-10 00:00:07
# 660       True                   USA     300.0 2021-04-10 00:00:09
# 661       True                   USA     288.0 2021-04-10 00:00:10
# 662       True                   USA     127.0 2021-04-10 00:00:11
# 663       True                   USA     300.0 2021-04-10 00:00:12
#
#     eventDate.timezone  eventDate.timezone_type  fighterId_1  ...  v1_1_2020  \
# 542      Europe/Berlin                        3         2597  ...   0.487962
# 543      Europe/Berlin                        3          240  ...   0.546180
# 544      Europe/Berlin                        3          141  ...   0.485018
# 545      Europe/Berlin                        3         2319  ...   0.520119
# 546      Europe/Berlin                        3          462  ...        NaN
# ..                 ...                      ...          ...  ...        ...
# 659      Europe/Berlin                        3          430  ...   0.488962
# 660      Europe/Berlin                        3          288  ...   0.531791
# 661      Europe/Berlin                        3          552  ...   0.482123
# 662      Europe/Berlin                        3          215  ...   0.553431
# 663      Europe/Berlin                        3           17  ...   0.496869
#
#     v1_2_2020  winner v1_0_pred v1_1_pred  v1_2_pred v1_1_2020_pred  \
# 542  0.507212   False      True      True       True          False
# 543  0.522711   False      True      True       True           True
# 544  0.491521   False     False     False      False          False
# 545  0.487667    True     False      True      False           True
# 546       NaN   False     False     False      False          False
# ..        ...     ...       ...       ...        ...            ...
# 659  0.472830   False     False     False      False          False
# 660  0.508890   False      True     False       True           True
# 661  0.451193   False     False     False      False          False
# 662  0.512090    True      True      True       True           True
# 663  0.493411    True     False      True       True          False
#
#      v1_2_2020_pred f1_count_of_fights f2_count_of_fights
# 542            True                  1                  1
# 543            True                  3                  8
# 544           False                  3                  5
# 545           False                  2                  2
# 546           False                  3                  0
# ..              ...                ...                ...
# 659           False                 11                  1
# 660            True                  4                 14
# 661           False                  7                  6
# 662            True                 19                  3
# 663           False                  4                  7
#
# [122 rows x 36 columns]

# %%
q = events_df[(events_df['f1_count_of_fights'] >= 1) & (events_df['f2_count_of_fights'] >= 1)]
      
print('v1_0_pred', (q['v1_0_pred'] == q['winner']).mean())
print('v1_1_pred', (q['v1_1_pred'] == q['winner']).mean())
print('v1_2_pred', (q['v1_2_pred'] == q['winner']).mean())
print('v1_1_2020_pred', (q['v1_1_2020_pred'] == q['winner']).mean())
print('v1_2_2020_pred', (q['v1_2_2020_pred'] == q['winner']).mean())
# Out:
# v1_0_pred 0.56
# v1_1_pred 0.66
# v1_2_pred 0.61
# v1_1_2020_pred 0.63
# v1_2_2020_pred 0.59

# %%
q['v1_1']
# Out:
# 542    0.513070
# 543    0.535575
# 544    0.496520
# 545    0.517640
# 547    0.467415
#          ...
# 659    0.464218
# 660    0.495302
# 661    0.452577
# 662    0.510241
# 663    0.506410
# Name: v1_1, Length: 100, dtype: float64
