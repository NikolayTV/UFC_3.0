# %%
import pandas as pd
import json
from pandas import json_normalize
from tqdm import tqdm_notebook as tqdm
import numpy as np
import requests
import ast


pd.set_option('display.precision',6)
pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None

# response = requests.get('https://bet2face.com/api/getEventsSummaryData/page/', verify=False)
response = requests.get('https://bet2face.com/api/getFightersSummaryData/page/', verify=False)
data = response.json()
data
# total_pages = data['total_pages']
# total_pages
# Out:
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'total_pages': 73,
#  'current_page': 1,
#  'fighters': [{'id': 1,
#    'name': 'Tanner Boser',
#    'rank': 16,
#    'weightCategory': {'id': 9, 'name': 'Тяжелый вес'},
#    'dateOfBirth': '1991-08-02',
#    'weight': 115.67,
#    'height': 187.96,
#    'armSpan': 190.5,
#    'legSwing': None,
#    'wins': 19,
#    'looses': 7,
#    'draws': 1,
#    'significantStrikesLandPerMinute': '4.54',
#    'significantStrikesMissedPerMinute': '2.70',
#    'sigStrikesAccuracy': 55,
#    'significantStrikesDefendPercent': 63,
#    'submissionAttemptsPer15minutes': None,
#    'takedownsPer15min': None,
#    'takedownsAccuracy': None,
#    'takedownsDefendPercent': 100,
#    'knockdownsPerFight': '0.00',
#    'avgFightTime': None,
#    'city': 'Bonnyville',
#    'country': 'Canada',
#    'timezone': 'America/Edmonton',
#    'methods': {'winMethods': {'DEC': '1', 'KO': '2'},
#     'looseMethods': {'DEC': '2'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/tannerboser-5d3570e3c8d49.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/tannerboser-5d2c38e596414.jpeg',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/tannerboser-5d35711a963ed.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/tannerboser-5d3570e3ceca4.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/tannerboser-5d3570e3cc279.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/tannerboser-5d3570d8ea36f.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/tannerboser-5d2c38e5908e5.jpeg',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 2,
#    'name': 'Giacomo Lemos',
#    'rank': 16,
#    'weightCategory': {'id': 9, 'name': 'Тяжелый вес'},
#    'dateOfBirth': '1989-06-23',
#    'weight': 112.04,
#    'height': 190.5,
#    'armSpan': 190.5,
#    'legSwing': None,
#    'wins': 6,
#    'looses': 0,
#    'draws': 0,
#    'significantStrikesLandPerMinute': None,
#    'significantStrikesMissedPerMinute': None,
#    'sigStrikesAccuracy': None,
#    'significantStrikesDefendPercent': None,
#    'submissionAttemptsPer15minutes': None,
#    'takedownsPer15min': None,
#    'takedownsAccuracy': None,
#    'takedownsDefendPercent': None,
#    'knockdownsPerFight': '0.00',
#    'avgFightTime': None,
#    'city': '',
#    'country': 'Brazil',
#    'timezone': 'America/Sao_Paulo',
#    'methods': {'winMethods': [], 'looseMethods': []},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/giacomolemos-5d43fb27a1e0a.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/dzakomolemos-5d356c4a583b2.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/dzakomolemos-5d356d325afaa.png',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/dzakomolemos-5d356c4a56b91.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/dzakomolemos-5d356c4a52506.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/dzakomolemos-5d356c4a49e3e.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/dzakomolemos-5d356c4a45926.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/dzakomolemos-5d356c4a3f62e.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 3,
#    'name': 'Shamil Abdurakhimov',
#    'rank': 16,
#    'weightCategory': {'id': 9, 'name': 'Тяжелый вес'},
#    'dateOfBirth': '1981-09-02',
#    'weight': 106.59,
#    'height': 190.5,
#    'armSpan': 193.04,
#    'legSwing': 105.41,
#    'wins': 20,
#    'looses': 5,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '2.45',
#    'significantStrikesMissedPerMinute': '2.45',
#    'sigStrikesAccuracy': 44,
#    'significantStrikesDefendPercent': 58,
#    'submissionAttemptsPer15minutes': '0.20',
#    'takedownsPer15min': '1.23',
#    'takedownsAccuracy': 24,
#    'takedownsDefendPercent': 47,
#    'knockdownsPerFight': '0.35',
#    'avgFightTime': '11:41',
#    'city': 'Makhachkala',
#    'country': 'Dagestan',
#    'timezone': 'Europe/Moscow',
#    'methods': {'winMethods': {'DEC': '3', 'KO': '2'},
#     'looseMethods': {'KO': '3'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/samilabdurahimov-5d38193d1ad95.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/samilabdurahimov-5d3080d9351fb.jpeg',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/hamil_bdurakhimov_2_21649.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/hamil_bdurakhimov_0_13654.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 4,
#    'name': 'Klidson Abreu',
#    'rank': 16,
#    'weightCategory': {'id': 8, 'name': 'Полутяжелый вес'},
#    'dateOfBirth': '1992-12-24',
#    'weight': 92.99,
#    'height': 182.88,
#    'armSpan': 187.96,
#    'legSwing': None,
#    'wins': 15,
#    'looses': 4,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '2.05',
#    'significantStrikesMissedPerMinute': '2.90',
#    'sigStrikesAccuracy': 40,
#    'significantStrikesDefendPercent': 55,
#    'submissionAttemptsPer15minutes': None,
#    'takedownsPer15min': '0.64',
#    'takedownsAccuracy': 20,
#    'takedownsDefendPercent': 80,
#    'knockdownsPerFight': '0.00',
#    'avgFightTime': '15:00',
#    'city': 'Manaus',
#    'country': 'Brazil',
#    'timezone': 'America/Manaus',
#    'methods': {'winMethods': {'DEC': '1'}, 'looseMethods': {'DEC': '2'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/klidsonabreu-5d38193deb034.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/klidsonabreu-5d2dfd81c700b.jpeg',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/lidson_breu_2_38493.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 5,
#    'name': 'Yoshihiro Akiyama',
#    'rank': 16,
#    'weightCategory': {'id': 6, 'name': 'Полусредний вес'},
#    'dateOfBirth': '1975-07-29',
#    'weight': 77.11,
#    'height': 177.8,
#    'armSpan': 190.5,
#    'legSwing': 106.68,
#    'wins': 14,
#    'looses': 6,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '3.10',
#    'significantStrikesMissedPerMinute': '3.62',
#    'sigStrikesAccuracy': 41,
#    'significantStrikesDefendPercent': 57,
#    'submissionAttemptsPer15minutes': '1.00',
#    'takedownsPer15min': '2.29',
#    'takedownsAccuracy': 67,
#    'takedownsDefendPercent': 92,
#    'knockdownsPerFight': '0.00',
#    'avgFightTime': '13:05',
#    'city': 'Ikuno',
#    'country': 'Japan',
#    'timezone': 'Asia/Tokyo',
#    'methods': {'winMethods': {'DEC': '2'},
#     'looseMethods': {'DEC': '3', 'KO': '1', 'SUB': '1'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/josihiroakiama-5d38194285539.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/josihiroakiama-5d401c2f76e91.jpeg',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/oshikhiro_kiyami_2_61495.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/oshikhiro_kiyami_0_72452.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 6,
#    'name': 'Jessica Aguilar',
#    'rank': 16,
#    'weightCategory': {'id': 10, 'name': 'Женский минимальный вес'},
#    'dateOfBirth': '1982-05-08',
#    'weight': 52.16,
#    'height': 160.02,
#    'armSpan': 160.02,
#    'legSwing': 90.17,
#    'wins': 20,
#    'looses': 8,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '4.93',
#    'significantStrikesMissedPerMinute': '7.19',
#    'sigStrikesAccuracy': 50,
#    'significantStrikesDefendPercent': 53,
#    'submissionAttemptsPer15minutes': '0.20',
#    'takedownsPer15min': '0.94',
#    'takedownsAccuracy': 25,
#    'takedownsDefendPercent': 50,
#    'knockdownsPerFight': '0.00',
#    'avgFightTime': '12:44',
#    'city': 'Veracruz',
#    'country': 'Mexico',
#    'timezone': 'America/Mexico_City',
#    'methods': {'winMethods': {'DEC': '1'},
#     'looseMethods': {'DEC': '3', 'SUB': '1'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/dzessikaagilar-5d381945d27dc.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/dzessikaagilar-5d30bb91a7386.png',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/zhessika_gilar_2_43205.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/zhessika_gilar_0_42725.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 7,
#    'name': 'Juan Adams',
#    'rank': 16,
#    'weightCategory': {'id': 9, 'name': 'Тяжелый вес'},
#    'dateOfBirth': '1992-01-16',
#    'weight': 120.2,
#    'height': 195.58,
#    'armSpan': 203.2,
#    'legSwing': 114.3,
#    'wins': 5,
#    'looses': 3,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '7.09',
#    'significantStrikesMissedPerMinute': '4.06',
#    'sigStrikesAccuracy': 55,
#    'significantStrikesDefendPercent': 34,
#    'submissionAttemptsPer15minutes': None,
#    'takedownsPer15min': '0.91',
#    'takedownsAccuracy': 66,
#    'takedownsDefendPercent': 57,
#    'knockdownsPerFight': '0.00',
#    'avgFightTime': '10:58',
#    'city': '',
#    'country': 'United States',
#    'timezone': 'America/New_York',
#    'methods': {'winMethods': {'KO': '1'},
#     'looseMethods': {'DEC': '1', 'KO': '2'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/huanadams-5d381946af04e.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/huanadams-5d2da1d769cab.jpeg',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/huanadams-5d2da1d76dd4d.jpeg',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/huan_dams_2_82221.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 8,
#    'name': 'Israel Adesanya',
#    'rank': 16,
#    'weightCategory': {'id': 7, 'name': 'Средний вес'},
#    'dateOfBirth': '1989-07-22',
#    'weight': 83.91,
#    'height': 193.04,
#    'armSpan': 203.2,
#    'legSwing': 113.03,
#    'wins': 20,
#    'looses': 1,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '3.95',
#    'significantStrikesMissedPerMinute': '2.63',
#    'sigStrikesAccuracy': 49,
#    'significantStrikesDefendPercent': 61,
#    'submissionAttemptsPer15minutes': '0.30',
#    'takedownsPer15min': None,
#    'takedownsAccuracy': None,
#    'takedownsDefendPercent': 82,
#    'knockdownsPerFight': '1.02',
#    'avgFightTime': '13:42',
#    'city': 'Lagos',
#    'country': 'Nigeria',
#    'timezone': 'Africa/Lagos',
#    'methods': {'winMethods': {'DEC': '5', 'KO': '4'},
#     'looseMethods': {'DEC': '1'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/israeladesana-5d381947959b3.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/israeladesana-5d3076e631ac1.jpeg',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/srael_desanya_2_69896.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/srael_desanya_0_86368.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 9,
#    'name': 'Abu Azaitar',
#    'rank': 16,
#    'weightCategory': {'id': 7, 'name': 'Средний вес'},
#    'dateOfBirth': '1986-03-10',
#    'weight': 83.91,
#    'height': 175.26,
#    'armSpan': 193.04,
#    'legSwing': None,
#    'wins': 14,
#    'looses': 3,
#    'draws': 1,
#    'significantStrikesLandPerMinute': '5.21',
#    'significantStrikesMissedPerMinute': '5.35',
#    'sigStrikesAccuracy': 44,
#    'significantStrikesDefendPercent': 50,
#    'submissionAttemptsPer15minutes': None,
#    'takedownsPer15min': '0.50',
#    'takedownsAccuracy': 25,
#    'takedownsDefendPercent': 40,
#    'knockdownsPerFight': '0.00',
#    'avgFightTime': '15:00',
#    'city': '',
#    'country': 'Germany',
#    'timezone': 'Europe/Berlin',
#    'methods': {'winMethods': {'DEC': '1'}, 'looseMethods': {'KO': '1'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/abuazajtar-5d38194899cd6.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/abuazajtar-5d3bf6ac42838.png',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/bu_zaytar_2_43019.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/bu_zaytar_0_44302.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 10,
#    'name': 'Rostem Akman',
#    'rank': 16,
#    'weightCategory': {'id': 6, 'name': 'Полусредний вес'},
#    'dateOfBirth': '1991-12-19',
#    'weight': 77.11,
#    'height': 177.8,
#    'armSpan': 182.88,
#    'legSwing': None,
#    'wins': 6,
#    'looses': 2,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '1.80',
#    'significantStrikesMissedPerMinute': '3.97',
#    'sigStrikesAccuracy': 25,
#    'significantStrikesDefendPercent': 57,
#    'submissionAttemptsPer15minutes': None,
#    'takedownsPer15min': '1.00',
#    'takedownsAccuracy': 40,
#    'takedownsDefendPercent': 87,
#    'knockdownsPerFight': '0.00',
#    'avgFightTime': None,
#    'city': '',
#    'country': 'Sweden',
#    'timezone': 'Europe/Stockholm',
#    'methods': {'winMethods': [], 'looseMethods': {'DEC': '2'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/rostemakman-5d38194d24008.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/rostemakman-5d3ffb8700e54.png',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/ostam_kman_0_90744.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 11,
#    'name': 'Aleksandra Albu',
#    'rank': 16,
#    'weightCategory': {'id': 10, 'name': 'Женский минимальный вес'},
#    'dateOfBirth': '1990-07-14',
#    'weight': 52.16,
#    'height': 157.48,
#    'armSpan': 160.02,
#    'legSwing': 91.44,
#    'wins': 3,
#    'looses': 2,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '4.83',
#    'significantStrikesMissedPerMinute': '5.56',
#    'sigStrikesAccuracy': 47,
#    'significantStrikesDefendPercent': 38,
#    'submissionAttemptsPer15minutes': '0.40',
#    'takedownsPer15min': '2.27',
#    'takedownsAccuracy': 50,
#    'takedownsDefendPercent': 77,
#    'knockdownsPerFight': '0.00',
#    'avgFightTime': '08:12',
#    'city': '',
#    'country': '',
#    'timezone': None,
#    'methods': {'winMethods': {'DEC': '1', 'SUB': '1'},
#     'looseMethods': {'DEC': '1', 'SUB': '1'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/aleksandraalbu-5d38195062048.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/aleksandraalbu-5d30ba7e886ed.png',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/leksandra_lbu_2_9039.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/leksandra_lbu_0_83514.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 12,
#    'name': 'Thiago Alves',
#    'rank': 16,
#    'weightCategory': {'id': 6, 'name': 'Полусредний вес'},
#    'dateOfBirth': '1983-10-03',
#    'weight': 77.11,
#    'height': 175.26,
#    'armSpan': 177.8,
#    'legSwing': 95.25,
#    'wins': 23,
#    'looses': 15,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '3.73',
#    'significantStrikesMissedPerMinute': '3.42',
#    'sigStrikesAccuracy': 41,
#    'significantStrikesDefendPercent': 62,
#    'submissionAttemptsPer15minutes': '0.30',
#    'takedownsPer15min': '0.71',
#    'takedownsAccuracy': 60,
#    'takedownsDefendPercent': 63,
#    'knockdownsPerFight': '0.70',
#    'avgFightTime': '11:10',
#    'city': 'Fortaleza',
#    'country': 'Brazil',
#    'timezone': 'America/Fortaleza',
#    'methods': {'winMethods': {'DEC': '6', 'KO': '8', 'SUB': '1'},
#     'looseMethods': {'DEC': '6', 'KO': '3', 'SUB': '3'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/tiagoalves-5d3819513a5d8.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/tiagoalves-5d3089e6c96ef.jpeg',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/tiagoalves-5d308a1e00ab9.jpeg',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/iago_lves_2_27710.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/iago_lves_0_89882.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 13,
#    'name': 'Warlley Alves',
#    'rank': 16,
#    'weightCategory': {'id': 6, 'name': 'Полусредний вес'},
#    'dateOfBirth': '1991-01-04',
#    'weight': 77.11,
#    'height': 180.34,
#    'armSpan': 182.88,
#    'legSwing': 106.68,
#    'wins': 15,
#    'looses': 4,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '3.09',
#    'significantStrikesMissedPerMinute': '3.62',
#    'sigStrikesAccuracy': 47,
#    'significantStrikesDefendPercent': 50,
#    'submissionAttemptsPer15minutes': '1.00',
#    'takedownsPer15min': '1.48',
#    'takedownsAccuracy': 54,
#    'takedownsDefendPercent': 75,
#    'knockdownsPerFight': '0.27',
#    'avgFightTime': '11:16',
#    'city': 'Governador Valadares',
#    'country': 'Brazil',
#    'timezone': 'America/Sao_Paulo',
#    'methods': {'winMethods': {'DEC': '2', 'KO': '3', 'SUB': '3'},
#     'looseMethods': {'DEC': '2', 'KO': '1', 'SUB': '1'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/vorlialves-5d3819520e9bd.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/vorlialves-5d3f137a36f11.png',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/orli_lves_2_89146.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/orli_lves_0_22071.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 14,
#    'name': 'Hector Aldana',
#    'rank': 16,
#    'weightCategory': {'id': 6, 'name': 'Полусредний вес'},
#    'dateOfBirth': '1988-08-17',
#    'weight': 77.11,
#    'height': 180.34,
#    'armSpan': 182.88,
#    'legSwing': 102.87,
#    'wins': 4,
#    'looses': 3,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '3.59',
#    'significantStrikesMissedPerMinute': '5.08',
#    'sigStrikesAccuracy': 38,
#    'significantStrikesDefendPercent': 59,
#    'submissionAttemptsPer15minutes': None,
#    'takedownsPer15min': '0.93',
#    'takedownsAccuracy': 100,
#    'takedownsDefendPercent': None,
#    'knockdownsPerFight': '0.00',
#    'avgFightTime': '12:23',
#    'city': '',
#    'country': 'Mexico',
#    'timezone': 'America/Mexico_City',
#    'methods': {'winMethods': [], 'looseMethods': {'DEC': '1', 'KO': '2'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/hektoraldana-5d3819554e6da.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/hektoraldana-5d3f145b41ebf.png',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/hektor_ldana_2_75622.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/hektor_ldana_0_97266.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 15,
#    'name': 'Irene Aldana',
#    'rank': 16,
#    'weightCategory': {'id': 12, 'name': 'Женский легчайший вес'},
#    'dateOfBirth': '1988-03-26',
#    'weight': 61.24,
#    'height': 175.26,
#    'armSpan': 172.72,
#    'legSwing': 97.79,
#    'wins': 12,
#    'looses': 6,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '5.52',
#    'significantStrikesMissedPerMinute': '5.97',
#    'sigStrikesAccuracy': 38,
#    'significantStrikesDefendPercent': 61,
#    'submissionAttemptsPer15minutes': '0.10',
#    'takedownsPer15min': '0.23',
#    'takedownsAccuracy': 50,
#    'takedownsDefendPercent': 84,
#    'knockdownsPerFight': '0.00',
#    'avgFightTime': '14:44',
#    'city': 'Culiacan',
#    'country': 'Mexico',
#    'timezone': 'America/Mazatlan',
#    'methods': {'winMethods': {'DEC': '3', 'KO': '1', 'SUB': '1'},
#     'looseMethods': {'DEC': '4'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/irenaldana-5d381959db459.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/irenaldana-5d383f51630e6.png',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/ren_ldana_2_90271.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/ren_ldana_0_35070.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 16,
#    'name': 'Sultan Aliev',
#    'rank': 16,
#    'weightCategory': {'id': 6, 'name': 'Полусредний вес'},
#    'dateOfBirth': '1984-09-17',
#    'weight': 77.11,
#    'height': 180.34,
#    'armSpan': 187.96,
#    'legSwing': 101.6,
#    'wins': 15,
#    'looses': 3,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '1.41',
#    'significantStrikesMissedPerMinute': '2.20',
#    'sigStrikesAccuracy': 45,
#    'significantStrikesDefendPercent': 56,
#    'submissionAttemptsPer15minutes': None,
#    'takedownsPer15min': '1.76',
#    'takedownsAccuracy': 38,
#    'takedownsDefendPercent': 100,
#    'knockdownsPerFight': '0.00',
#    'avgFightTime': '09:14',
#    'city': '',
#    'country': 'Russia',
#    'timezone': 'Europe/Moscow',
#    'methods': {'winMethods': {'DEC': '2'}, 'looseMethods': {'KO': '2'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/sultanaliev-5d38195e76565.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/sultanaliev-5d3f178591e59.png',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/ultan_liev_2_45292.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/ultan_liev_0_66239.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 17,
#    'name': 'Arnold Allen',
#    'rank': 16,
#    'weightCategory': {'id': 4, 'name': 'Полулегкий вес'},
#    'dateOfBirth': '1994-01-22',
#    'weight': 65.77,
#    'height': 172.72,
#    'armSpan': 177.8,
#    'legSwing': 99.06,
#    'wins': 17,
#    'looses': 1,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '2.96',
#    'significantStrikesMissedPerMinute': '2.15',
#    'sigStrikesAccuracy': 40,
#    'significantStrikesDefendPercent': 66,
#    'submissionAttemptsPer15minutes': '0.40',
#    'takedownsPer15min': '1.44',
#    'takedownsAccuracy': 50,
#    'takedownsDefendPercent': 76,
#    'knockdownsPerFight': '0.30',
#    'avgFightTime': '14:04',
#    'city': 'Suffolk',
#    'country': 'England',
#    'timezone': None,
#    'methods': {'winMethods': {'DEC': '6', 'SUB': '2'}, 'looseMethods': []},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/arnoldallen-5d3819630954d.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/arnoldallen-5d399f9d1b012.jpeg',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/rnold_llen_2_11393.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/rnold_llen_0_86680.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 18,
#    'name': 'Eddie Alvarez',
#    'rank': 16,
#    'weightCategory': {'id': 5, 'name': 'Легкий вес'},
#    'dateOfBirth': '1984-01-11',
#    'weight': 70.31,
#    'height': 175.26,
#    'armSpan': 175.26,
#    'legSwing': 102.87,
#    'wins': 29,
#    'looses': 6,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '4.32',
#    'significantStrikesMissedPerMinute': '4.39',
#    'sigStrikesAccuracy': 41,
#    'significantStrikesDefendPercent': 55,
#    'submissionAttemptsPer15minutes': '0.50',
#    'takedownsPer15min': '2.92',
#    'takedownsAccuracy': 36,
#    'takedownsDefendPercent': 92,
#    'knockdownsPerFight': '0.47',
#    'avgFightTime': '11:07',
#    'city': 'Kensington',
#    'country': 'United States',
#    'timezone': 'America/New_York',
#    'methods': {'winMethods': {'DEC': '2', 'KO': '2'},
#     'looseMethods': {'DEC': '1', 'KO': '2'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/eddialvarez-5d381964d87ac.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/eddialvarez-5e04de34be306.png',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/eddialvarez-5d3d931081cc0.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/eddialvarez-5d3d93107f754.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/eddialvarez-5d3d93107c707.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/ddi_lvarez_2_8337.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/ddi_lvarez_0_91197.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 19,
#    'name': 'Joel Alvarez',
#    'rank': 16,
#    'weightCategory': {'id': 5, 'name': 'Легкий вес'},
#    'dateOfBirth': '1994-03-02',
#    'weight': 70.31,
#    'height': 190.5,
#    'armSpan': 195.58,
#    'legSwing': None,
#    'wins': 18,
#    'looses': 2,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '2.84',
#    'significantStrikesMissedPerMinute': '3.31',
#    'sigStrikesAccuracy': 37,
#    'significantStrikesDefendPercent': 53,
#    'submissionAttemptsPer15minutes': '1.60',
#    'takedownsPer15min': None,
#    'takedownsAccuracy': None,
#    'takedownsDefendPercent': 77,
#    'knockdownsPerFight': '0.00',
#    'avgFightTime': '15:00',
#    'city': 'Gijón',
#    'country': 'Spain',
#    'timezone': 'Europe/Madrid',
#    'methods': {'winMethods': {'KO': '1', 'SUB': '2'},
#     'looseMethods': {'DEC': '1'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/dzoelalvarez-5d3819695974f.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/dzoelalvarez-5d39534044039.jpeg',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/oel_lvarez_2_71184.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/oel_lvarez_1_73457.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/oel_lvarez_0_39409.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 20,
#    'name': 'Iuri Alcantara',
#    'rank': 16,
#    'weightCategory': {'id': 3, 'name': 'Легчайший вес'},
#    'dateOfBirth': '1980-08-04',
#    'weight': 61.24,
#    'height': 175.26,
#    'armSpan': 180.34,
#    'legSwing': 101.6,
#    'wins': 35,
#    'looses': 10,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '2.72',
#    'significantStrikesMissedPerMinute': '2.79',
#    'sigStrikesAccuracy': 45,
#    'significantStrikesDefendPercent': 49,
#    'submissionAttemptsPer15minutes': '0.80',
#    'takedownsPer15min': '1.44',
#    'takedownsAccuracy': 62,
#    'takedownsDefendPercent': 60,
#    'knockdownsPerFight': '0.42',
#    'avgFightTime': '09:21',
#    'city': '',
#    'country': '',
#    'timezone': None,
#    'methods': {'winMethods': {'DEC': '5', 'KO': '3', 'SUB': '2'},
#     'looseMethods': {'DEC': '5', 'KO': '1', 'SUB': '1'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/urialkantara-5d38196e18289.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/urialkantara-5d38572b413cf.png',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/urialkantara-5d38572b3dc98.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/uri_lkantara_2_31551.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/uri_lkantara_0_95075.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 21,
#    'name': 'Abdul Razak Alhassan',
#    'rank': 16,
#    'weightCategory': {'id': 6, 'name': 'Полусредний вес'},
#    'dateOfBirth': '1985-08-11',
#    'weight': 77.11,
#    'height': 177.8,
#    'armSpan': 185.42,
#    'legSwing': 99.06,
#    'wins': 10,
#    'looses': 3,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '4.54',
#    'significantStrikesMissedPerMinute': '5.11',
#    'sigStrikesAccuracy': 48,
#    'significantStrikesDefendPercent': 53,
#    'submissionAttemptsPer15minutes': None,
#    'takedownsPer15min': '0.72',
#    'takedownsAccuracy': 28,
#    'takedownsDefendPercent': 42,
#    'knockdownsPerFight': '3.64',
#    'avgFightTime': '04:57',
#    'city': 'Minneapolis',
#    'country': 'Minnesota',
#    'timezone': 'America/Chicago',
#    'methods': {'winMethods': {'KO': '4'},
#     'looseMethods': {'DEC': '2', 'KO': '1'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/abdulrazakalhasan-5d38196ee3693.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/abdulrazakalhasan-5d3ffbb8dc1e0.png',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/bdul_azak_lkhasan_2_87596.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/bdul_azak_lkhasan_0_15232.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 22,
#    'name': 'Thomas Almeida',
#    'rank': 16,
#    'weightCategory': {'id': 3, 'name': 'Легчайший вес'},
#    'dateOfBirth': '1991-07-31',
#    'weight': 65.77,
#    'height': 170.18,
#    'armSpan': 177.8,
#    'legSwing': 97.79,
#    'wins': 22,
#    'looses': 5,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '4.84',
#    'significantStrikesMissedPerMinute': '4.93',
#    'sigStrikesAccuracy': 43,
#    'significantStrikesDefendPercent': 61,
#    'submissionAttemptsPer15minutes': None,
#    'takedownsPer15min': '0.17',
#    'takedownsAccuracy': 14,
#    'takedownsDefendPercent': 75,
#    'knockdownsPerFight': '0.59',
#    'avgFightTime': '07:38',
#    'city': 'Sao Paulo',
#    'country': 'Brazil',
#    'timezone': 'America/Sao_Paulo',
#    'methods': {'winMethods': {'DEC': '1', 'KO': '4'},
#     'looseMethods': {'DEC': '2', 'KO': '3'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/tomasalmejda-5d38197371ae9.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/tomasalmejda-5d3857d1eb42e.png',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/tomasalmejda-5d3857d1f0ec2.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/omas_lmeyda_2_66661.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/omas_lmeyda_0_29128.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 23,
#    'name': 'Corey Anderson',
#    'rank': 16,
#    'weightCategory': {'id': 8, 'name': 'Полутяжелый вес'},
#    'dateOfBirth': '1989-09-22',
#    'weight': 92.99,
#    'height': 190.5,
#    'armSpan': 200.66,
#    'legSwing': 111.76,
#    'wins': 14,
#    'looses': 5,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '4.43',
#    'significantStrikesMissedPerMinute': '2.22',
#    'sigStrikesAccuracy': 46,
#    'significantStrikesDefendPercent': 59,
#    'submissionAttemptsPer15minutes': None,
#    'takedownsPer15min': '4.89',
#    'takedownsAccuracy': 50,
#    'takedownsDefendPercent': 83,
#    'knockdownsPerFight': '0.09',
#    'avgFightTime': '12:07',
#    'city': 'Rockton',
#    'country': 'United States',
#    'timezone': 'America/New_York',
#    'methods': {'winMethods': {'DEC': '7', 'KO': '3'},
#     'looseMethods': {'DEC': '1', 'KO': '4'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/korianderson-5d38197806a45.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/korianderson-5d41939706f7f.jpeg',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/ori_nderson_2_45773.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/ori_nderson_0_93706.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 24,
#    'name': 'Makwan Amirkhani',
#    'rank': 16,
#    'weightCategory': {'id': 4, 'name': 'Полулегкий вес'},
#    'dateOfBirth': '1988-11-08',
#    'weight': 65.77,
#    'height': 177.8,
#    'armSpan': 182.88,
#    'legSwing': 104.14,
#    'wins': 16,
#    'looses': 5,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '1.42',
#    'significantStrikesMissedPerMinute': '2.63',
#    'sigStrikesAccuracy': 44,
#    'significantStrikesDefendPercent': 51,
#    'submissionAttemptsPer15minutes': '1.40',
#    'takedownsPer15min': '3.37',
#    'takedownsAccuracy': 37,
#    'takedownsDefendPercent': 57,
#    'knockdownsPerFight': '0.32',
#    'avgFightTime': '09:22',
#    'city': '',
#    'country': 'Iraq',
#    'timezone': 'Asia/Baghdad',
#    'methods': {'winMethods': {'DEC': '2', 'KO': '1', 'SUB': '3'},
#     'looseMethods': {'DEC': '2', 'KO': '1'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/makvanamirhani-5d381978d1c71.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/makvanamirhani-5d39ae6ee3f09.jpeg',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/akvan_mirkhani_2_28530.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/akvan_mirkhani_0_48292.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 25,
#    'name': 'Eryk Anders',
#    'rank': 16,
#    'weightCategory': {'id': 8, 'name': 'Полутяжелый вес'},
#    'dateOfBirth': '1987-04-21',
#    'weight': 83.91,
#    'height': 185.42,
#    'armSpan': 190.5,
#    'legSwing': 110.49,
#    'wins': 13,
#    'looses': 5,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '3.23',
#    'significantStrikesMissedPerMinute': '4.15',
#    'sigStrikesAccuracy': 46,
#    'significantStrikesDefendPercent': 51,
#    'submissionAttemptsPer15minutes': '0.10',
#    'takedownsPer15min': '1.62',
#    'takedownsAccuracy': 35,
#    'takedownsDefendPercent': 80,
#    'knockdownsPerFight': '0.65',
#    'avgFightTime': '12:59',
#    'city': 'San Antonio',
#    'country': 'Texas',
#    'timezone': 'America/Chicago',
#    'methods': {'winMethods': {'DEC': '2', 'KO': '3'},
#     'looseMethods': {'DEC': '4', 'KO': '1'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/erikanders-5d38197999b05.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/erikanders-5d41917c791b2.jpeg',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/rik_nders_2_41965.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/rik_nders_0_88750.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 26,
#    'name': 'Megan Anderson',
#    'rank': 16,
#    'weightCategory': {'id': 13, 'name': 'Женский полулегкий вес'},
#    'dateOfBirth': '1990-02-11',
#    'weight': 65.77,
#    'height': 182.88,
#    'armSpan': 182.88,
#    'legSwing': 109.22,
#    'wins': 11,
#    'looses': 5,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '1.76',
#    'significantStrikesMissedPerMinute': '3.35',
#    'sigStrikesAccuracy': 46,
#    'significantStrikesDefendPercent': 37,
#    'submissionAttemptsPer15minutes': '0.50',
#    'takedownsPer15min': '0.52',
#    'takedownsAccuracy': 25,
#    'takedownsDefendPercent': 53,
#    'knockdownsPerFight': '0.52',
#    'avgFightTime': '08:01',
#    'city': 'Gold Coast',
#    'country': 'Australia',
#    'timezone': 'Australia/Brisbane',
#    'methods': {'winMethods': {'KO': '2', 'SUB': '1'},
#     'looseMethods': {'DEC': '1', 'SUB': '2'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/megananderson-5d38197e4ae0f.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/megananderson-5d3ac37400708.jpeg',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/egan_nderson_2_7056.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/egan_nderson_0_70590.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 27,
#    'name': 'Viviane Araujo',
#    'rank': 16,
#    'weightCategory': {'id': 12, 'name': 'Женский легчайший вес'},
#    'dateOfBirth': '1986-11-21',
#    'weight': 56.7,
#    'height': 162.56,
#    'armSpan': 172.72,
#    'legSwing': None,
#    'wins': 10,
#    'looses': 2,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '4.97',
#    'significantStrikesMissedPerMinute': '4.84',
#    'sigStrikesAccuracy': 48,
#    'significantStrikesDefendPercent': 60,
#    'submissionAttemptsPer15minutes': '0.20',
#    'takedownsPer15min': '2.33',
#    'takedownsAccuracy': 64,
#    'takedownsDefendPercent': 94,
#    'knockdownsPerFight': '0.37',
#    'avgFightTime': '12:54',
#    'city': '',
#    'country': 'Brazil',
#    'timezone': 'America/Sao_Paulo',
#    'methods': {'winMethods': {'DEC': '3', 'KO': '1'},
#     'looseMethods': {'DEC': '1'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/vivianearauho-5d3819829bf9d.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/vivianearauho-5d385b23e63a0.png',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/iviane_raujo_2_63459.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/iviane_raujo_1_36029.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/vivianearauho-5d385b2d552d1.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/iviane_raujo_2_99521.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 28,
#    'name': 'Jessica Andrade',
#    'rank': 16,
#    'weightCategory': {'id': 10, 'name': 'Женский минимальный вес'},
#    'dateOfBirth': '1991-09-25',
#    'weight': 52.16,
#    'height': 154.94,
#    'armSpan': 157.48,
#    'legSwing': 88.9,
#    'wins': 21,
#    'looses': 8,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '6.38',
#    'significantStrikesMissedPerMinute': '5.26',
#    'sigStrikesAccuracy': 49,
#    'significantStrikesDefendPercent': 53,
#    'submissionAttemptsPer15minutes': '0.40',
#    'takedownsPer15min': '3.11',
#    'takedownsAccuracy': 57,
#    'takedownsDefendPercent': 76,
#    'knockdownsPerFight': '0.18',
#    'avgFightTime': '11:04',
#    'city': 'Umuarama',
#    'country': 'Brazil',
#    'timezone': 'America/Sao_Paulo',
#    'methods': {'winMethods': {'DEC': '6', 'KO': '4', 'SUB': '2'},
#     'looseMethods': {'DEC': '2', 'KO': '2', 'SUB': '2'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/dzessikaandrade-5d3819837e1cf.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/dzessikaandrade-5d2f1dff9f336.jpeg',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/dzessikaandrade-5d2f1dfbc0b3a.jpeg',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/dzessikaandrade-5d2f1c864ae61.jpeg',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/zhessika_ndrade_2_81175.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/zhessika_ndrade_0_75508.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 29,
#    'name': 'Magomed Ankalaev',
#    'rank': 16,
#    'weightCategory': {'id': 8, 'name': 'Полутяжелый вес'},
#    'dateOfBirth': '1992-06-02',
#    'weight': 92.99,
#    'height': 190.5,
#    'armSpan': 190.5,
#    'legSwing': 116.84,
#    'wins': 15,
#    'looses': 1,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '3.41',
#    'significantStrikesMissedPerMinute': '1.78',
#    'sigStrikesAccuracy': 53,
#    'significantStrikesDefendPercent': 65,
#    'submissionAttemptsPer15minutes': None,
#    'takedownsPer15min': '1.18',
#    'takedownsAccuracy': 33,
#    'takedownsDefendPercent': 85,
#    'knockdownsPerFight': '1.18',
#    'avgFightTime': '11:03',
#    'city': '',
#    'country': 'Russia',
#    'timezone': 'Europe/Moscow',
#    'methods': {'winMethods': {'DEC': '2', 'KO': '4'},
#     'looseMethods': {'SUB': '1'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/magomedankalaev-5d3819880ebf9.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/magomedankalaev-5d2dfe10e5657.jpeg',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/agomed_nkalaev_2_75557.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/agomed_nkalaev_0_48869.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 30,
#    'name': 'Gadzhimurad Antigulov',
#    'rank': 16,
#    'weightCategory': {'id': 8, 'name': 'Полутяжелый вес'},
#    'dateOfBirth': '1987-02-09',
#    'weight': 92.99,
#    'height': 180.34,
#    'armSpan': 177.8,
#    'legSwing': 101.6,
#    'wins': 20,
#    'looses': 8,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '2.08',
#    'significantStrikesMissedPerMinute': '4.21',
#    'sigStrikesAccuracy': 55,
#    'significantStrikesDefendPercent': 40,
#    'submissionAttemptsPer15minutes': '1.40',
#    'takedownsPer15min': '5.08',
#    'takedownsAccuracy': 36,
#    'takedownsDefendPercent': None,
#    'knockdownsPerFight': '0.00',
#    'avgFightTime': '02:38',
#    'city': 'Anapa',
#    'country': 'Russia',
#    'timezone': 'Europe/Moscow',
#    'methods': {'winMethods': {'SUB': '2'},
#     'looseMethods': {'KO': '3', 'SUB': '1'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/gadzimuradantigulov-5d38198ca1f5b.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/gadzimuradantigulov-5d4190ec80154.jpeg',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/adzhimurad_ntigulov_2_24627.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/adzhimurad_ntigulov_0_55691.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 31,
#    'name': 'Austin Arnett',
#    'rank': 16,
#    'weightCategory': {'id': 4, 'name': 'Полулегкий вес'},
#    'dateOfBirth': '1991-10-22',
#    'weight': 65.77,
#    'height': 182.88,
#    'armSpan': 182.88,
#    'legSwing': 104.14,
#    'wins': 16,
#    'looses': 6,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '4.52',
#    'significantStrikesMissedPerMinute': '6.38',
#    'sigStrikesAccuracy': 41,
#    'significantStrikesDefendPercent': 62,
#    'submissionAttemptsPer15minutes': '0.20',
#    'takedownsPer15min': '0.44',
#    'takedownsAccuracy': 18,
#    'takedownsDefendPercent': 57,
#    'knockdownsPerFight': '0.00',
#    'avgFightTime': '12:56',
#    'city': '',
#    'country': 'United States',
#    'timezone': 'America/New_York',
#    'methods': {'winMethods': {'DEC': '1'},
#     'looseMethods': {'DEC': '2', 'KO': '1'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/ostinarnett-5d38198d7aeb3.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/ostinarnett-5d39bf7827d17.jpeg',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/stin_rnett_2_49626.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/stin_rnett_0_54973.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 32,
#    'name': 'Ben Askren',
#    'rank': 16,
#    'weightCategory': {'id': 6, 'name': 'Полусредний вес'},
#    'dateOfBirth': '1984-07-18',
#    'weight': 77.11,
#    'height': 180.34,
#    'armSpan': 185.42,
#    'legSwing': None,
#    'wins': 19,
#    'looses': 2,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '3.64',
#    'significantStrikesMissedPerMinute': '5.66',
#    'sigStrikesAccuracy': 49,
#    'significantStrikesDefendPercent': 36,
#    'submissionAttemptsPer15minutes': '0.90',
#    'takedownsPer15min': '4.33',
#    'takedownsAccuracy': 55,
#    'takedownsDefendPercent': None,
#    'knockdownsPerFight': '0.00',
#    'avgFightTime': '01:43',
#    'city': 'Cedar Rapids',
#    'country': 'Iowa',
#    'timezone': 'America/Chicago',
#    'methods': {'winMethods': {'SUB': '1'},
#     'looseMethods': {'KO': '1', 'SUB': '1'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/benaskren-5d38198e516f9.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/benaskren-5d3d8cf55111e.png',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/benaskren-5d3d8d6094478.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/en_skren_2_93827.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/en_skren_0_26420.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 33,
# ...
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/dson_arbosa_2_62171.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/dson_arbosa_0_88414.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 40,
#    'name': 'Enrique Barzola',
#    'rank': 16,
#    'weightCategory': {'id': 4, 'name': 'Полулегкий вес'},
#    'dateOfBirth': '1989-04-28',
#    'weight': 65.77,
#    'height': 170.18,
#    'armSpan': 177.8,
#    'legSwing': 91.44,
#    'wins': 17,
#    'looses': 5,
#    'draws': 2,
#    'significantStrikesLandPerMinute': '3.91',
#    'significantStrikesMissedPerMinute': '2.97',
#    'sigStrikesAccuracy': 41,
#    'significantStrikesDefendPercent': 68,
#    'submissionAttemptsPer15minutes': '0.30',
#    'takedownsPer15min': '4.20',
#    'takedownsAccuracy': 45,
#    'takedownsDefendPercent': 66,
#    'knockdownsPerFight': '0.00',
#    'avgFightTime': '15:00',
#    'city': 'Lima',
#    'country': 'Peru',
#    'timezone': 'America/New_York',
#    'methods': {'winMethods': {'DEC': '6'}, 'looseMethods': {'DEC': '3'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/enrikebarzola-5d3819a732de2.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/enrikebarzola-5d2f1c6626b2b.jpeg',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/nrike_arzola_2_46448.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/nrike_arzola_0_40796.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 41,
#    'name': 'Mario Bautista',
#    'rank': 16,
#    'weightCategory': {'id': 3, 'name': 'Легчайший вес'},
#    'dateOfBirth': '1993-07-01',
#    'weight': 61.24,
#    'height': 175.26,
#    'armSpan': 175.26,
#    'legSwing': None,
#    'wins': 8,
#    'looses': 2,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '5.71',
#    'significantStrikesMissedPerMinute': '4.78',
#    'sigStrikesAccuracy': 45,
#    'significantStrikesDefendPercent': 54,
#    'submissionAttemptsPer15minutes': None,
#    'takedownsPer15min': '0.48',
#    'takedownsAccuracy': 33,
#    'takedownsDefendPercent': 70,
#    'knockdownsPerFight': '0.00',
#    'avgFightTime': None,
#    'city': '',
#    'country': 'United States',
#    'timezone': 'America/New_York',
#    'methods': {'winMethods': {'DEC': '1', 'KO': '1'},
#     'looseMethods': {'KO': '1', 'SUB': '1'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/mariobautista-5d3819ab6fb39.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/mariobautista-5d385c1ab5d82.png',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/ario_autista_2_51615.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/ario_autista_0_35192.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 42,
#    'name': 'Raoni Barcelos',
#    'rank': 16,
#    'weightCategory': {'id': 4, 'name': 'Полулегкий вес'},
#    'dateOfBirth': '1987-05-01',
#    'weight': 61.24,
#    'height': 170.18,
#    'armSpan': 170.18,
#    'legSwing': 99.06,
#    'wins': 16,
#    'looses': 1,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '5.59',
#    'significantStrikesMissedPerMinute': '4.17',
#    'sigStrikesAccuracy': 52,
#    'significantStrikesDefendPercent': 67,
#    'submissionAttemptsPer15minutes': '0.70',
#    'takedownsPer15min': '2.23',
#    'takedownsAccuracy': 56,
#    'takedownsDefendPercent': 85,
#    'knockdownsPerFight': '0.66',
#    'avgFightTime': '10:21',
#    'city': '',
#    'country': 'Brazil',
#    'timezone': 'America/Sao_Paulo',
#    'methods': {'winMethods': {'DEC': '2', 'KO': '2', 'SUB': '1'},
#     'looseMethods': []},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/raonibarselos-5d3819ac4107c.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/raonibarselos-5d3ac0e037151.jpeg',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/aoni_arselos_2_97935.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/aoni_arselos_0_14095.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 43,
#    'name': 'Siyar Bahadurzada',
#    'rank': 16,
#    'weightCategory': {'id': 6, 'name': 'Полусредний вес'},
#    'dateOfBirth': '1984-04-17',
#    'weight': 77.11,
#    'height': 180.34,
#    'armSpan': 185.42,
#    'legSwing': 114.3,
#    'wins': 24,
#    'looses': 8,
#    'draws': 1,
#    'significantStrikesLandPerMinute': '2.91',
#    'significantStrikesMissedPerMinute': '3.23',
#    'sigStrikesAccuracy': 40,
#    'significantStrikesDefendPercent': 49,
#    'submissionAttemptsPer15minutes': '0.30',
#    'takedownsPer15min': '1.32',
#    'takedownsAccuracy': 61,
#    'takedownsDefendPercent': 62,
#    'knockdownsPerFight': '0.99',
#    'avgFightTime': '10:49',
#    'city': 'Kabul',
#    'country': 'Afghanistan',
#    'timezone': 'Asia/Kabul',
#    'methods': {'winMethods': {'KO': '3', 'SUB': '1'},
#     'looseMethods': {'DEC': '4'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/siarbahadurzada-5d3819ad139c5.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/siarbahadurzada-5d3f1563669a8.png',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/iyar_akhadurzada_2_53729.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/iyar_akhadurzada_0_6443.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 44,
#    'name': 'Gabriel Benitez',
#    'rank': 16,
#    'weightCategory': {'id': 4, 'name': 'Полулегкий вес'},
#    'dateOfBirth': '1988-06-15',
#    'weight': 70.31,
#    'height': 172.72,
#    'armSpan': 180.34,
#    'legSwing': 102.87,
#    'wins': 22,
#    'looses': 9,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '4.38',
#    'significantStrikesMissedPerMinute': '3.26',
#    'sigStrikesAccuracy': 38,
#    'significantStrikesDefendPercent': 70,
#    'submissionAttemptsPer15minutes': '1.20',
#    'takedownsPer15min': '0.17',
#    'takedownsAccuracy': 50,
#    'takedownsDefendPercent': 56,
#    'knockdownsPerFight': '0.46',
#    'avgFightTime': '09:23',
#    'city': '',
#    'country': 'Mexico',
#    'timezone': 'America/Mexico_City',
#    'methods': {'winMethods': {'DEC': '2', 'KO': '2', 'SUB': '2'},
#     'looseMethods': {'DEC': '2', 'KO': '2'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/gabrielbenitez-5d3819addf460.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/gabrielbenitez-5d30845b71e82.jpeg',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/abriel_enitez_2_27485.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/abriel_enitez_0_91286.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 45,
#    'name': 'Ryan Benoit',
#    'rank': 16,
#    'weightCategory': {'id': 2, 'name': 'Наилегчайший вес'},
#    'dateOfBirth': '1989-08-25',
#    'weight': 56.7,
#    'height': 165.1,
#    'armSpan': 172.72,
#    'legSwing': 96.52,
#    'wins': 10,
#    'looses': 7,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '2.95',
#    'significantStrikesMissedPerMinute': '3.40',
#    'sigStrikesAccuracy': 41,
#    'significantStrikesDefendPercent': 60,
#    'submissionAttemptsPer15minutes': '0.50',
#    'takedownsPer15min': '0.33',
#    'takedownsAccuracy': 25,
#    'takedownsDefendPercent': 70,
#    'knockdownsPerFight': '0.79',
#    'avgFightTime': '10:13',
#    'city': '',
#    'country': 'United States',
#    'timezone': 'America/New_York',
#    'methods': {'winMethods': {'DEC': '1', 'KO': '2'},
#     'looseMethods': {'DEC': '3', 'SUB': '2'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/raanbenua-5d3819b26fe19.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/raanbenua-5d3809044d7e0.png',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/ayan_enua_2_47693.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/ayan_enua_0_89306.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 46,
#    'name': 'Manny Bermudez',
#    'rank': 16,
#    'weightCategory': {'id': 3, 'name': 'Легчайший вес'},
#    'dateOfBirth': '1994-07-16',
#    'weight': 65.77,
#    'height': 177.8,
#    'armSpan': 180.34,
#    'legSwing': 101.6,
#    'wins': 14,
#    'looses': 2,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '2.92',
#    'significantStrikesMissedPerMinute': '2.68',
#    'sigStrikesAccuracy': 61,
#    'significantStrikesDefendPercent': 46,
#    'submissionAttemptsPer15minutes': '3.10',
#    'takedownsPer15min': '3.06',
#    'takedownsAccuracy': 54,
#    'takedownsDefendPercent': None,
#    'knockdownsPerFight': '1.28',
#    'avgFightTime': '03:54',
#    'city': '',
#    'country': 'United States',
#    'timezone': 'America/New_York',
#    'methods': {'winMethods': {'SUB': '3'},
#     'looseMethods': {'DEC': '1', 'SUB': '1'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/mennibermudez-5d3819b5b2c79.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/mennibermudez-5d38172dd4b49.png',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/enni_ermudez_2_64955.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/enni_ermudez_0_64691.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 47,
#    'name': 'Talita Bernardo',
#    'rank': 16,
#    'weightCategory': {'id': 12, 'name': 'Женский легчайший вес'},
#    'dateOfBirth': '1987-03-04',
#    'weight': 61.24,
#    'height': 162.56,
#    'armSpan': 172.72,
#    'legSwing': 101.6,
#    'wins': 6,
#    'looses': 4,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '3.12',
#    'significantStrikesMissedPerMinute': '4.04',
#    'sigStrikesAccuracy': 42,
#    'significantStrikesDefendPercent': 55,
#    'submissionAttemptsPer15minutes': '0.50',
#    'takedownsPer15min': '1.62',
#    'takedownsAccuracy': 22,
#    'takedownsDefendPercent': 28,
#    'knockdownsPerFight': '0.00',
#    'avgFightTime': '14:58',
#    'city': 'Barra de São João',
#    'country': 'Brazil',
#    'timezone': 'America/Sao_Paulo',
#    'methods': {'winMethods': {'DEC': '1'},
#     'looseMethods': {'DEC': '1', 'KO': '2'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/talitabernardo-5d3819b69759f.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/talitabernardo-5d359fc984fbf.png',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/alita_ernardo_2_66017.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/alita_ernardo_0_89553.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 48,
#    'name': 'Poliana Botelho',
#    'rank': 16,
#    'weightCategory': {'id': 10, 'name': 'Женский минимальный вес'},
#    'dateOfBirth': '1988-12-15',
#    'weight': 52.16,
#    'height': 172.72,
#    'armSpan': 170.18,
#    'legSwing': 99.06,
#    'wins': 8,
#    'looses': 3,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '3.00',
#    'significantStrikesMissedPerMinute': '3.08',
#    'sigStrikesAccuracy': 56,
#    'significantStrikesDefendPercent': 50,
#    'submissionAttemptsPer15minutes': None,
#    'takedownsPer15min': '0.89',
#    'takedownsAccuracy': 100,
#    'takedownsDefendPercent': 80,
#    'knockdownsPerFight': '0.42',
#    'avgFightTime': '06:47',
#    'city': 'Muriae',
#    'country': 'Brazil',
#    'timezone': 'America/Sao_Paulo',
#    'methods': {'winMethods': {'DEC': '2', 'KO': '1'},
#     'looseMethods': {'DEC': '1', 'SUB': '1'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/polianabotelo-5d3819b76e71a.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/polianabotelo-5d3084e30d83a.jpeg',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/polianabotelo-5d3084ec616c7.jpeg',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/oliana_otelo_2_95167.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/oliana_otelo_0_79386.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 49,
#    'name': 'Tim Boetsch',
#    'rank': 16,
#    'weightCategory': {'id': 7, 'name': 'Средний вес'},
#    'dateOfBirth': '1981-01-28',
#    'weight': 83.91,
#    'height': 182.88,
#    'armSpan': 187.96,
#    'legSwing': 106.68,
#    'wins': 21,
#    'looses': 13,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '2.93',
#    'significantStrikesMissedPerMinute': '2.90',
#    'sigStrikesAccuracy': 50,
#    'significantStrikesDefendPercent': 57,
#    'submissionAttemptsPer15minutes': '0.80',
#    'takedownsPer15min': '1.45',
#    'takedownsAccuracy': 34,
#    'takedownsDefendPercent': 59,
#    'knockdownsPerFight': '0.48',
#    'avgFightTime': '09:02',
#    'city': 'Lincolnville',
#    'country': 'United States',
#    'timezone': 'America/New_York',
#    'methods': {'winMethods': {'DEC': '5', 'KO': '7'},
#     'looseMethods': {'DEC': '3', 'KO': '4', 'SUB': '5'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/timbotc-5d3819bc0dff0.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/timbotc-5d385f1821f89.jpeg',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/im_otch_2_60746.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/im_otch_0_302.png',
#      'isFullFace': False,
#      'isProfile': False}]},
#   {'id': 50,
#    'name': 'Kyle Bochniak',
#    'rank': 16,
#    'weightCategory': {'id': 4, 'name': 'Полулегкий вес'},
#    'dateOfBirth': '1987-02-05',
#    'weight': 65.77,
#    'height': 170.18,
#    'armSpan': 177.8,
#    'legSwing': 97.79,
#    'wins': 8,
#    'looses': 5,
#    'draws': 0,
#    'significantStrikesLandPerMinute': '2.63',
#    'significantStrikesMissedPerMinute': '5.11',
#    'sigStrikesAccuracy': 31,
#    'significantStrikesDefendPercent': 58,
#    'submissionAttemptsPer15minutes': None,
#    'takedownsPer15min': '1.14',
#    'takedownsAccuracy': 15,
#    'takedownsDefendPercent': 62,
#    'knockdownsPerFight': '0.17',
#    'avgFightTime': '15:00',
#    'city': 'Gloucester',
#    'country': 'United States',
#    'timezone': 'Europe/London',
#    'methods': {'winMethods': {'DEC': '2'}, 'looseMethods': {'DEC': '5'}},
#    'disciplines': [],
#    'photos': [{'url': 'http://bet2face.com/uploads/images/fighters/kajlbocniak-5d3819bf569c6.png',
#      'isFullFace': True,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/kajlbocniak-5d3ac0306ebee.jpeg',
#      'isFullFace': False,
#      'isProfile': True},
#     {'url': 'http://bet2face.com/uploads/images/fighters/ayl_ochniak_2_84746.png',
#      'isFullFace': False,
#      'isProfile': False},
#     {'url': 'http://bet2face.com/uploads/images/fighters/ayl_ochniak_0_6982.png',
#      'isFullFace': False,
#      'isProfile': False}]}]}

# %%
# download fighters data
def download_fighters():
    df = pd.DataFrame()
    total_pages = requests.get('https://bet2face.com/api/getFightersSummaryData/page/', verify=False).json()['total_pages']
    print('Total pages:', total_pages)
    
    for i in tqdm(range(1, total_pages+1)):
        response2 = requests.get('https://bet2face.com/api/getFightersSummaryData/page/{}'.format(i), verify=False)
        data = response2.json()
        if data['fighters'] != None:
            chunk = json_normalize(data['fighters'])
            df = pd.concat([df, chunk], sort=True)

    df = df.reset_index(drop=True)
    df.to_csv('0.fighters_raw.csv')
    print('Downloading finished')


def process_fighters():
    df = pd.read_csv('data/0.fighters_raw.csv', index_col=0)
    print('original shape', df.shape)
    
    df['dateOfBirth'] = pd.to_datetime(df['dateOfBirth'])
    df['birthYear'] = df['dateOfBirth'].dt.year

    df.drop([i for i in df.columns if i.startswith('methods')], axis=1, inplace=True)

    df['height'] = df['height'].fillna(df['height'].median())
    df['dateOfBirth'] = pd.to_datetime(df['dateOfBirth'])

    df['birthYear'] = df['dateOfBirth'].dt.year
    df['birthYear'] = df.birthYear.fillna(df.birthYear.median())
    df['avgFightTime'].replace(":", '.', regex=True, inplace=True)
    df['avgFightTime'] = df['avgFightTime'].fillna(df['avgFightTime'].median())
    df['knockdownsPerFight'].fillna(0, inplace=True)
    df['weight'].fillna(df['weight'].median(), inplace=True)
    df['armSpan'].fillna(df['armSpan'].median(), inplace=True)
    df['legSwing'].fillna(df['legSwing'].median(), inplace=True)

    df["win%"] = 100 * (df["wins"] / (df["wins"] + df["looses"] + df["draws"]))

#     df = df.drop(['twitter', 'website', 'instagram', 'careerDisclosedEarnings', 'dateOfBirth'], axis=1)
    
    df['takedownsPer15min'].fillna(0, inplace=True)
    df['takedownsDefendPercent'].fillna(0, inplace=True)
    df['takedownsAccuracy'].fillna(0, inplace=True)
    df['submissionAttemptsPer15minutes'].fillna(0, inplace=True)

    df = df.loc[~((df['significantStrikesDefendPercent'] == 0) &
               (df['significantStrikesLandPerMinute'] == 0) &
               (df['significantStrikesMissedPerMinute'] == 0) &
               (df['submissionAttemptsPer15minutes'] == 0) &
               (df['takedownsAccuracy'] == 0) &
               (df['takedownsDefendPercent'] == 0) &
               (df['takedownsPer15min'] == 0) 
              )]
    
    
    df.to_csv('data/1.fighters_processed.csv')
    print('final shape:', df.shape)

download_fighters()
# process_fighters()
# Out:
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Total pages: 73
# <ipython-input-2-c14fd71649c1>:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm(range(1, total_pages+1)):
#   0%|          | 0/73 [00:00<?, ?it/s]
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Downloading finished

# %%
def download_events():
    # # Download data from bet2face
    df = pd.DataFrame()
    total_pages = requests.get('https://bet2face.com/api/getEventsSummaryData/page/', verify=False).json()['total_pages']
    print('Total pages:', total_pages)
    
    for i in tqdm(range(1, total_pages+1)):
        response = requests.get('https://bet2face.com/api/getEventsSummaryData/page/{}'.format(i), verify=False)
        response_json = response.json()
        events = response_json['events']
#         if i != 101:
        for event in events:
            chunk = json_normalize(event)
            fighterId_1,  fighterId_2 = chunk['fighters'][0][0]['fighterId'], chunk['fighters'][0][1]['fighterId']
            chunk['fighterId_1'] = fighterId_1
            chunk['fighterId_2'] = fighterId_2
            df = pd.concat([df, chunk], sort=True)
    df.to_csv('0.events_raw.csv')

def process_events():
    df = pd.read_csv('data/0.events_raw.csv', index_col=0)
    df = df.reset_index()
    pd.to_datetime(df['eventDate.date']).dt.year.value_counts()

    # Добавить кэффы в df
    for i in df.index[:]:
        try:
            avgodds = df.loc[i, 'avgOdds']

            if avgodds == '[]':
                continue

            # Преобразую данные о коэффах из строки
            ids1, odd1 = int(avgodds.split()[1].split(',')[0]), float(avgodds.split()[3].split('}')[0])
            ids2, odd2 = int(avgodds.split()[5].split(',')[0]), float(avgodds.split()[7].split('}')[0])

            # Проверить совпадает ли fighterId_1 с ids1 (который в avgOdds)
            if df.loc[i, 'fighterId_1'] == ids1:
                df.at[i, 'odd1'] = odd1
                df.at[i, 'odd2'] = odd2

            if df.loc[i, 'fighterId_1'] == ids2:
                df.at[i, 'odd1'] = odd2
                df.at[i, 'odd2'] = odd1

        except IndexError:
            print(avgodds)

    print('percent of fighter1 winners:', np.mean(df.winnerId == df.fighterId_1))

    # randomly swap fighter1 and fighter2 for half of the dataset to create "negative cases"
    swap_indices = np.random.choice(len(df), size = len(df) // 2, replace = False)

    Fighter1_ColInd = np.where(df.columns == 'fighterId_1')[0][0]
    Fighter2_ColInd = np.where(df.columns == 'fighterId_2')[0][0]
    df.iloc[swap_indices, [Fighter1_ColInd, Fighter2_ColInd]] = df.iloc[swap_indices, [Fighter2_ColInd, Fighter1_ColInd]].values # swap fighters
    
    odd1_ColInd = np.where(df.columns == 'odd1')[0][0]
    odd2_ColInd = np.where(df.columns == 'odd2')[0][0]
    df.iloc[swap_indices, [odd1_ColInd, odd2_ColInd]] = df.iloc[swap_indices, [odd2_ColInd, odd1_ColInd]].values # swap odds

    # winner equal 1 if winner is fighter 1
    df['winner'] = df['winnerId'] == df['fighterId_1']
    df['winner'] = df['winner'].astype(np.int8)
    df.shape
    print('percent of fighter1 winners after swappint:', np.mean(df.winnerId == df.fighterId_1))
    df.to_csv('data/1.events_processed.csv')
      
download_events()
# process_events()
# Out:
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Total pages: 121
# <ipython-input-3-1fdc3a2c4367>:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm(range(1, total_pages+1)):
#   0%|          | 0/121 [00:00<?, ?it/s]
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/nikolay/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bet2face.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
df = pd.read_csv('data/0.events_raw.csv')
df
# Out:
#       Unnamed: 0                                            avgOdds  \
# 0              0                                                 []
# 1              0                                                 []
# 2              0                                                 []
# 3              0                                                 []
# 4              0                                                 []
# ...          ...                                                ...
# 7095           0                                                 []
# 7096           0  [{'fighterId': 53, 'value': 2}, {'fighterId': ...
# 7097           0  [{'fighterId': 145, 'value': 3.95}, {'fighterI...
# 7098           0  [{'fighterId': 246, 'value': 2.75}, {'fighterI...
# 7099           0  [{'fighterId': 628, 'value': 2.1}, {'fighterId...
#
#            city  completed country  duration              eventDate.date  \
# 0        Denver       True     USA     104.0  1993-11-12 00:00:00.000000
# 1        Denver       True     USA      52.0  1993-11-12 00:00:00.000000
# 2        Denver       True     USA      59.0  1993-11-12 00:00:00.000000
# 3        Denver       True     USA      57.0  1993-11-12 00:00:00.000000
# 4        Denver       True     USA     138.0  1993-11-12 00:00:00.000000
# ...         ...        ...     ...       ...                         ...
# 7095  Las Vegas      False     USA       NaN  2021-02-27 00:00:00.000000
# 7096  Las Vegas      False     USA       NaN  2021-02-27 01:45:00.000000
# 7097  Las Vegas      False     USA       NaN  2021-02-27 03:45:00.000000
# 7098  Las Vegas       True     USA     208.0  2021-03-06 00:00:00.000000
# 7099  Las Vegas       True     USA     295.0  2021-03-06 00:00:00.000000
#
#      eventDate.timezone  eventDate.timezone_type  fighterId_1  fighterId_2  \
# 0         Europe/Berlin                        3         1646         1923
# 1         Europe/Berlin                        3         1777         1883
# 2         Europe/Berlin                        3         1908         1923
# 3         Europe/Berlin                        3         1631         1646
# 4         Europe/Berlin                        3         1646         1924
# ...                 ...                      ...          ...          ...
# 7095      Europe/Berlin                        3          309         3416
# 7096      Europe/Berlin                        3           53          275
# 7097      Europe/Berlin                        3          145          499
# 7098      Europe/Berlin                        3          246         2073
# 7099      Europe/Berlin                        3          628          687
#
#                                                fighters     id  \
# 0     [{'fighterId': 1646, 'fightStats': {'hitsTotal...   5201
# 1     [{'fighterId': 1777, 'fightStats': {'hitsTotal...   5202
# 2     [{'fighterId': 1908, 'fightStats': {'hitsTotal...   5203
# 3     [{'fighterId': 1631, 'fightStats': {'hitsTotal...   5204
# 4     [{'fighterId': 1646, 'fightStats': {'hitsTotal...   5205
# ...                                                 ...    ...
# 7095  [{'fighterId': 309, 'fightStats': [], 'roundSt...  40432
# 7096  [{'fighterId': 53, 'fightStats': [], 'roundSta...  40492
# 7097  [{'fighterId': 145, 'fightStats': [], 'roundSt...  40507
# 7098  [{'fighterId': 246, 'fightStats': {'hitsTotal'...  40452
# 7099  [{'fighterId': 628, 'fightStats': {'hitsTotal'...  40453
#
#                                                    link             name  \
# 0     http://www.ufcstats.com/fight-details/64139d1d...            UFC 1
# 1     http://www.ufcstats.com/fight-details/00b07967...            UFC 1
# 2     http://www.ufcstats.com/fight-details/ac7ca2ec...            UFC 1
# 3     http://www.ufcstats.com/fight-details/ffd16691...            UFC 1
# 4     http://www.ufcstats.com/fight-details/cecdc0da...            UFC 1
# ...                                                 ...              ...
# 7095  http://www.ufcstats.com/fight-details/5d11136d...  UFC Fight Night
# 7096  http://www.ufcstats.com/fight-details/dd3dc5fe...  UFC Fight Night
# 7097  http://www.ufcstats.com/fight-details/8ad9b2f0...  UFC Fight Night
# 7098  http://www.ufcstats.com/fight-details/7ad09f88...          UFC 259
# 7099  http://www.ufcstats.com/fight-details/873306ad...          UFC 259
#
#       rounds             timezone  weightCategory.id      weightCategory.name  \
# 0        1.0       America/Denver                  7              Средний вес
# 1        1.0       America/Denver                  8          Полутяжелый вес
# 2        1.0       America/Denver                  9              Тяжелый вес
# 3        1.0       America/Denver                  8          Полутяжелый вес
# 4        1.0       America/Denver                  7              Средний вес
# ...      ...                  ...                ...                      ...
# 7095     NaN  America/Los_Angeles                  8          Полутяжелый вес
# 7096     NaN  America/Los_Angeles                  6          Полусредний вес
# 7097     NaN  America/Los_Angeles                 10  Женский минимальный вес
# 7098     3.0  America/Los_Angeles                  6          Полусредний вес
# 7099     1.0  America/Los_Angeles                  2         Наилегчайший вес
#
#      winMethods  winnerId
# 0       ['SUB']    1646.0
# 1       ['SUB']    1777.0
# 2        ['KO']    1923.0
# 3       ['SUB']    1646.0
# 4       ['SUB']    1646.0
# ...         ...       ...
# 7095         []       NaN
# 7096         []       NaN
# 7097         []       NaN
# 7098    ['SUB']    2073.0
# 7099     ['KO']     687.0
#
# [7100 rows x 21 columns]
